# %%
#Processing evcc block ack
import csv
import numpy as np

with open('csv/DataLink/max_interf_VI/evcc_blockack_max_VI.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    startint_seq_num_block_ack = []
    timelist_block_ack = []
    
    for row in rows:
        startint_seq_num_block_ack.append(int(row['Starting Sequence Number']))
        timelist_block_ack.append(float(row['Time']))

# %%
#for debug
if(len(startint_seq_num_block_ack) != len(timelist_block_ack)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_block_ack))
# Out:
# 1081

# %%
#Processing evcc send
with open('csv/DataLink/max_interf_VI/evcc_send_max_VI.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_evcc_send = []
    seq_num_evcc_send = []
    data_length_evcc_send = []
    info_evcc_send = []
    frame_num_evcc_send = []
    
    for row in rows:
        timelist_evcc_send.append(float(row['Time']))
        seq_num_evcc_send.append(int(row['Sequence number']))
        data_length_evcc_send.append(int(row['Data Length']))
        info_evcc_send.append(str(row['Info']))
        frame_num_evcc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_evcc_send) != len(seq_num_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(data_length_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(info_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(frame_num_evcc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send))
# Out:
# 1413

# %%
timelist_evcc_send_split = []
seq_num_evcc_send_split = []
data_length_evcc_send_split = []
info_evcc_send_split = []
frame_num_evcc_send_split = []

round_start_point = 0
round_end_point = 0

sdpreq_index_list = []
#Fetch first packet index of data length = 74 (SDP request) in each round
for i in range(0, len(data_length_evcc_send)):
    if(i == 0 and data_length_evcc_send[i] == 74):
        sdpreq_index_list.append(i)
    if(i > 0 and data_length_evcc_send[i] == 74 and data_length_evcc_send[i-1] != 74):
        sdpreq_index_list.append(i)
sdpreq_index_list.append(len(data_length_evcc_send)) #Add the end of list index

for i in range(0, len(sdpreq_index_list)-1):
    timelist_evcc_send_split.append([timelist_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    seq_num_evcc_send_split.append([seq_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    data_length_evcc_send_split.append([data_length_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    info_evcc_send_split.append([info_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    frame_num_evcc_send_split.append([frame_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])

# %%
#for debug
if(len(timelist_evcc_send_split) != len(seq_num_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(data_length_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(info_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(frame_num_evcc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_evcc_send_split)):
    print(timelist_evcc_send_split[i][0]-timelist_evcc_send_split[i-1][0])
# Out:
# 21.213796999999996
# 21.092091000000003
# 21.918331999999992
# 21.30716000000001
# 21.18570299999999
# 20.990022999999994
# 20.82461600000002
# 21.15932699999999
# 21.300291000000016
# 20.659411999999975
# 21.841017000000022
# 21.329883999999964
# 20.81181700000002
# 20.725662999999997
# 20.172725000000014
# 22.323061999999993
# 20.69175100000001
# 20.68096700000001
# 21.39833299999998

# %%
#Set evcc time anchor in each round per stage
evcc_send_time_anchor = []
#data_length_in_each_stage = [74, 96, 189, 173, 173, 173, 185, 461, 189, 173]
wierd_packet = {}
packet_loss_testing_round_7_flag = False

global last_SeqNum

last_SeqNum = 0

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(evcc_send_time_anchor_each_round):
    print("Time difference: " + str(evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-1]-
                          evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    global last_SeqNum
    
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        
        #Avoid 802.11 retry by sequence number
        if(seqnum == last_SeqNum):
            return False
        else:
            last_SeqNum = seqnum
        return True
    
    else:
        #debug
        print("\nFalse")
        print("Stage Num = " + str(stageNum))
        print("Valid Stage Num = " + str(valid_stageNum))
        print("What is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet.get(frameNum) != None):
        del wierd_packet[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_evcc_send_split)):
#for i in [10]:
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    evcc_send_time_anchor_each_round = [timelist_evcc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_evcc_send_split[i][0], info_evcc_send_split[i][0])
    stageNum = stageNum + 1
    
    for j in range(1, len(data_length_evcc_send_split[i])):
        #Stage 2
        if(data_length_evcc_send_split[i][j] == 96 and data_length_evcc_send_split[i][j-1] != 96):
            if(checkstage_num(stageNum, 2, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 3
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 3, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                '''
                #Deal with packet loss......
                if(i == 7 and packet_loss_testing_round_7_flag == False):
                    evcc_send_time_anchor_each_round.append(204.698447)
                    printinfo(stageNum, 1041301, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_7_flag = True
                '''
                continue
                
        #Stage 4 
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            #if(info_evcc_send_split[i][j][-2:] == 'TC'):
            if(checkstage_num(stageNum, 4, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
           
        #Stage 5, tricky
        if(data_length_evcc_send_split[i][j] == 173):    
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
            
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                if(i == 10):
                    for k in range(1, 4):
                        if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                            isTCfound = True
                            break
                else:
                    for k in range(1, 3):
                        if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                            isTCfound = True
                            break
                
                if(not isTCfound):
                    if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1  
                        
                        continue
                
        #Stage 6, tricky
        if(data_length_evcc_send_split[i][j] == 173):
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1

                    continue

            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                
                if(i == 10): #Backward checking 3 packets
                    for k in range(1, 4):
                        if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                            isTCfound = True
                            break
                else:
                    #Backward checking 2 packets
                    isTCfound = False
                    for k in range(1, 3):
                        if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                            isTCfound = True
                            break

                if(not isTCfound):
                    if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1
                        
                        continue

        #Stage 7
        if(data_length_evcc_send_split[i][j] == 185 and data_length_evcc_send_split[i][j-1] != 185):
            if(checkstage_num(stageNum, 7, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 8
        if(data_length_evcc_send_split[i][j] == 461 and data_length_evcc_send_split[i][j-1] != 461):
            if(checkstage_num(stageNum, 8, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
        #Stage 9
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 9, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 10
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                for k in range(1, 3):
                    if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                        isTCfound = True
                        break

                if(not isTCfound):
                    if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1
                
        if(stageNum == 11): break
        
    evcc_send_time_anchor.append(evcc_send_time_anchor_each_round)
# Out:
# -------- Test Round 1 --------
# -----------------------------------------
# Stage 1 finish. No. 78949, Info QoS Data, SN=874, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 80627, Info QoS Data, SN=549, FN=0, Flags=.p.....TC
# Time difference: 0.3326129999999985
# -----------------------------------------
# Stage 3 finish. No. 82809, Info QoS Data, SN=883, FN=0, Flags=.p.....TC
# Time difference: 0.38810199999999995
# -----------------------------------------
# Stage 4 finish. No. 84227, Info QoS Data, SN=885, FN=0, Flags=.p.....TC
# Time difference: 0.29332899999999995
#
# False
# Stage Num = 5
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 84273
# Time 18.677886 #Seq 885 Info QoS Data, SN=885, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 84341
# Time 18.698635 #Seq 3912 Info QoS Data, SN=3912, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 84819
# Time 18.775439 #Seq 888 Info QoS Data, SN=888, FN=0, Flags=.p.....TC
#
#
# No. 84819 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 84819, Info QoS Data, SN=888, FN=0, Flags=.p.....TC
# Time difference: 0.10834399999999889
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 84997
# Time 18.823898 #Seq 3915 Info QoS Data, SN=3915, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 85663
# Time 18.926024 #Seq 890 Info QoS Data, SN=890, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 85663
# Time 18.926024 #Seq 890 Info QoS Data, SN=890, FN=0, Flags=.p.....TC
#
#
# No. 85663 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 85663, Info QoS Data, SN=890, FN=0, Flags=.p.....TC
# Time difference: 0.15058500000000308
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 85707
# Time 18.930923 #Seq 890 Info QoS Data, SN=890, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 85707
# Time 18.930923 #Seq 890 Info QoS Data, SN=890, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 85837
# Time 18.953571 #Seq 3917 Info QoS Data, SN=3917, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 7 finish. No. 87134, Info QoS Data, SN=893, FN=0, Flags=.p.....TC
# Time difference: 0.20523199999999875
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 87144
# Time 19.137657 #Seq 3920 Info QoS Data, SN=3920, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 88304, Info QoS Data, SN=895, FN=0, Flags=.p.....TC
# Time difference: 0.17963400000000007
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 89185
# Time 19.434118 #Seq 897 Info QoS Data, SN=897, FN=0, Flags=.p.....TC
#
#
# No. 89185 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 89185, Info QoS Data, SN=897, FN=0, Flags=.p.....TC
# Time difference: 0.123228000000001
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 90090
# Time 19.574065 #Seq 899 Info QoS Data, SN=899, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 90090
# Time 19.574065 #Seq 899 Info QoS Data, SN=899, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 90090
# Time 19.574065 #Seq 899 Info QoS Data, SN=899, FN=0, Flags=.p.....TC
#
#
# No. 90090 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 90090, Info QoS Data, SN=899, FN=0, Flags=.p.....TC
# Time difference: 0.13994699999999938
#
# -------- Test Round 2 --------
# -----------------------------------------
# Stage 1 finish. No. 206736, Info Data, SN=3974, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 209911, Info QoS Data, SN=3953, FN=0, Flags=.p....F.C
# Time difference: 0.517394000000003
# -----------------------------------------
# Stage 3 finish. No. 213469, Info QoS Data, SN=3963, FN=0, Flags=.p....F.C
# Time difference: 0.5262249999999966
# -----------------------------------------
# Stage 4 finish. No. 214216, Info QoS Data, SN=3965, FN=0, Flags=.p....F.C
# Time difference: 0.12372600000000489
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 214558
# Time 40.093667 #Seq 3967 Info QoS Data, SN=3967, FN=0, Flags=.p....F.C
#
#
# No. 214558 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 214558, Data length 173, Info QoS Data, SN=3967, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 214558, Info QoS Data, SN=3967, FN=0, Flags=.p....F.C
# Time difference: 0.05947400000000158
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 215514
# Time 40.239289 #Seq 3969 Info QoS Data, SN=3969, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 215514
# Time 40.239289 #Seq 3969 Info QoS Data, SN=3969, FN=0, Flags=.p....F.C
#
#
# No. 215514 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 215514, Data length 173, Info QoS Data, SN=3969, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 215514, Info QoS Data, SN=3969, FN=0, Flags=.p....F.C
# Time difference: 0.14562199999999592
# -----------------------------------------
# Stage 7 finish. No. 216505, Info QoS Data, SN=3972, FN=0, Flags=.p....F.C
# Time difference: 0.16264400000000023
# -----------------------------------------
# Stage 8 finish. No. 217611, Info QoS Data, SN=3974, FN=0, Flags=.p....F.C
# Time difference: 0.15873899999999708
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 217823
# Time 40.595487 #Seq 3976 Info QoS Data, SN=3976, FN=0, Flags=.p....F.C
#
#
# No. 217823 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 217823, Info QoS Data, SN=3976, FN=0, Flags=.p....F.C
# Time difference: 0.03481500000000182
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 218760
# Time 40.7689 #Seq 3978 Info QoS Data, SN=3978, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 218760
# Time 40.7689 #Seq 3978 Info QoS Data, SN=3978, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 218760
# Time 40.7689 #Seq 3978 Info QoS Data, SN=3978, FN=0, Flags=.p....F.C
#
#
# No. 218760 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 218760, Data length 173, Info QoS Data, SN=3978, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 218760, Info QoS Data, SN=3978, FN=0, Flags=.p....F.C
# Time difference: 0.1734130000000036
#
# -------- Test Round 3 --------
# -----------------------------------------
# Stage 1 finish. No. 337285, Info Data, SN=85, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 340766, Info QoS Data, SN=4017, FN=0, Flags=.p....F.C
# Time difference: 0.5500789999999967
# -----------------------------------------
# Stage 3 finish. No. 343251, Info QoS Data, SN=4028, FN=0, Flags=.p....F.C
# Time difference: 0.3904899999999998
# -----------------------------------------
# Stage 4 finish. No. 345957, Info QoS Data, SN=4030, FN=0, Flags=.p....F.C
# Time difference: 0.4198120000000003
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 346218
# Time 61.361698 #Seq 4032 Info QoS Data, SN=4032, FN=0, Flags=.p....F.C
#
#
# No. 346218 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 346218, Data length 173, Info QoS Data, SN=4032, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 346218, Info QoS Data, SN=4032, FN=0, Flags=.p....F.C
# Time difference: 0.04237799999999936
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 346905
# Time 61.475493 #Seq 4034 Info QoS Data, SN=4034, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 346905
# Time 61.475493 #Seq 4034 Info QoS Data, SN=4034, FN=0, Flags=.p....F.C
#
#
# No. 346905 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 346905, Data length 173, Info QoS Data, SN=4034, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 346905, Info QoS Data, SN=4034, FN=0, Flags=.p....F.C
# Time difference: 0.1137950000000032
# -----------------------------------------
# Stage 7 finish. No. 350485, Info QoS Data, SN=4036, FN=0, Flags=.p....F.C
# Time difference: 0.5602379999999982
# -----------------------------------------
# Stage 8 finish. No. 352223, Info QoS Data, SN=4041, FN=0, Flags=.p....F.C
# Time difference: 0.26356400000000235
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 352711
# Time 62.385877 #Seq 4043 Info QoS Data, SN=4043, FN=0, Flags=.p....F.C
#
#
# No. 352711 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 352711, Info QoS Data, SN=4043, FN=0, Flags=.p....F.C
# Time difference: 0.08658199999999994
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 353802
# Time 62.555311 #Seq 4045 Info QoS Data, SN=4045, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 353802
# Time 62.555311 #Seq 4045 Info QoS Data, SN=4045, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 353802
# Time 62.555311 #Seq 4045 Info QoS Data, SN=4045, FN=0, Flags=.p....F.C
#
#
# No. 353802 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 353802, Data length 173, Info QoS Data, SN=4045, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 353802, Info QoS Data, SN=4045, FN=0, Flags=.p....F.C
# Time difference: 0.16943400000000253
#
# -------- Test Round 4 --------
# -----------------------------------------
# Stage 1 finish. No. 474149, Info Data, SN=306, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 476805, Info QoS Data, SN=4080, FN=0, Flags=.p....F.C
# Time difference: 0.4447840000000127
# -----------------------------------------
# Stage 3 finish. No. 481592, Info QoS Data, SN=4090, FN=0, Flags=.p....F.C
# Time difference: 0.7248209999999915
# -----------------------------------------
# Stage 4 finish. No. 482408, Info QoS Data, SN=4092, FN=0, Flags=.p....F.C
# Time difference: 0.12740300000000104
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 482984
# Time 83.270155 #Seq 4094 Info QoS Data, SN=4094, FN=0, Flags=.p....F.C
#
#
# No. 482984 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 482984, Data length 173, Info QoS Data, SN=4094, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 482984, Info QoS Data, SN=4094, FN=0, Flags=.p....F.C
# Time difference: 0.09587600000000407
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 483849
# Time 83.389257 #Seq 4095 Info QoS Data, SN=4095, FN=0, Flags=.p....F.C
#
#
# No. 483849 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 483849, Data length 173, Info QoS Data, SN=4095, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 483849, Info QoS Data, SN=4095, FN=0, Flags=.p....F.C
# Time difference: 0.11910199999999804
# -----------------------------------------
# Stage 7 finish. No. 485124, Info QoS Data, SN=2, FN=0, Flags=.p....F.C
# Time difference: 0.20816499999999394
# -----------------------------------------
# Stage 8 finish. No. 486196, Info QoS Data, SN=4, FN=0, Flags=.p....F.C
# Time difference: 0.23091100000000608
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 487196
# Time 83.972676 #Seq 6 Info QoS Data, SN=6, FN=0, Flags=.p....F.C
#
#
# No. 487196 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 487196, Info QoS Data, SN=6, FN=0, Flags=.p....F.C
# Time difference: 0.14434300000000633
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 487966
# Time 84.102185 #Seq 8 Info QoS Data, SN=8, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 487966
# Time 84.102185 #Seq 8 Info QoS Data, SN=8, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 487966
# Time 84.102185 #Seq 8 Info QoS Data, SN=8, FN=0, Flags=.p....F.C
#
#
# No. 487966 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 487966, Data length 173, Info QoS Data, SN=8, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 487966, Info QoS Data, SN=8, FN=0, Flags=.p....F.C
# Time difference: 0.12950899999999876
#
# -------- Test Round 5 --------
# -----------------------------------------
# Stage 1 finish. No. 604872, Info QoS Data, SN=1047, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 608543, Info QoS Data, SN=674, FN=0, Flags=.p.....TC
# Time difference: 0.5900570000000016
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 610791
# Time 104.193515 #Seq 1056 Info QoS Data, SN=1056, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 610791
# Time 104.193515 #Seq 1056 Info QoS Data, SN=1056, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 610791
# Time 104.193515 #Seq 1056 Info QoS Data, SN=1056, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 610791
# Time 104.193515 #Seq 1056 Info QoS Data, SN=1056, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 612240, Info QoS Data, SN=1059, FN=0, Flags=.p.....TC
# Time difference: 0.6329909999999899
# -----------------------------------------
# Stage 4 finish. No. 613357, Info QoS Data, SN=1061, FN=0, Flags=.p.....TC
# Time difference: 0.16338900000000933
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 613493
# Time 104.610271 #Seq 59 Info QoS Data, SN=59, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 613681
# Time 104.633375 #Seq 1063 Info QoS Data, SN=1063, FN=0, Flags=.p.....TC
#
#
# No. 613681 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 613681, Info QoS Data, SN=1063, FN=0, Flags=.p.....TC
# Time difference: 0.06250699999999654
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 613889
# Time 104.661681 #Seq 61 Info QoS Data, SN=61, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 614383
# Time 104.746891 #Seq 1065 Info QoS Data, SN=1065, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 614383
# Time 104.746891 #Seq 1065 Info QoS Data, SN=1065, FN=0, Flags=.p.....TC
#
#
# No. 614383 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 614383, Info QoS Data, SN=1065, FN=0, Flags=.p.....TC
# Time difference: 0.11351600000000417
# -----------------------------------------
# Stage 7 finish. No. 615295, Info QoS Data, SN=1068, FN=0, Flags=.p.....TC
# Time difference: 0.22307499999999436
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 615300
# Time 104.972174 #Seq 66 Info QoS Data, SN=66, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 615862, Info QoS Data, SN=1070, FN=0, Flags=.p.....TC
# Time difference: 0.16973600000000033
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 615976
# Time 105.171087 #Seq 1072 Info QoS Data, SN=1072, FN=0, Flags=.p.....TC
#
#
# No. 615976 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 615976, Info QoS Data, SN=1072, FN=0, Flags=.p.....TC
# Time difference: 0.03138500000000022
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 616389
# Time 105.275033 #Seq 1074 Info QoS Data, SN=1074, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 616389
# Time 105.275033 #Seq 1074 Info QoS Data, SN=1074, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 616389
# Time 105.275033 #Seq 1074 Info QoS Data, SN=1074, FN=0, Flags=.p.....TC
#
#
# No. 616389 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 616389, Info QoS Data, SN=1074, FN=0, Flags=.p.....TC
# Time difference: 0.10394599999999343
#
# -------- Test Round 6 --------
# -----------------------------------------
# Stage 1 finish. No. 707575, Info Data, SN=731, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 709825, Info QoS Data, SN=115, FN=0, Flags=.p....F.C
# Time difference: 0.4235260000000096
# -----------------------------------------
# Stage 3 finish. No. 712384, Info QoS Data, SN=125, FN=0, Flags=.p....F.C
# Time difference: 0.42359399999999425
# -----------------------------------------
# Stage 4 finish. No. 713289, Info QoS Data, SN=127, FN=0, Flags=.p....F.C
# Time difference: 0.15183299999999633
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 713577
# Time 125.399587 #Seq 129 Info QoS Data, SN=129, FN=0, Flags=.p....F.C
#
#
# No. 713577 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 713577, Data length 173, Info QoS Data, SN=129, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 713577, Info QoS Data, SN=129, FN=0, Flags=.p....F.C
# Time difference: 0.030500000000003524
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 714204
# Time 125.515253 #Seq 131 Info QoS Data, SN=131, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 714204
# Time 125.515253 #Seq 131 Info QoS Data, SN=131, FN=0, Flags=.p....F.C
#
#
# No. 714204 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 714204, Data length 173, Info QoS Data, SN=131, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 714204, Info QoS Data, SN=131, FN=0, Flags=.p....F.C
# Time difference: 0.11566600000000449
# -----------------------------------------
# Stage 7 finish. No. 715295, Info QoS Data, SN=134, FN=0, Flags=.p..R.F.C
# Time difference: 0.18590899999999522
# -----------------------------------------
# Stage 8 finish. No. 716396, Info QoS Data, SN=136, FN=0, Flags=.p....F.C
# Time difference: 0.18582600000000582
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 716928
# Time 125.951837 #Seq 138 Info QoS Data, SN=138, FN=0, Flags=.p....F.C
#
#
# No. 716928 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 716928, Info QoS Data, SN=138, FN=0, Flags=.p....F.C
# Time difference: 0.06484899999999527
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 717583
# Time 126.071295 #Seq 1117 Info QoS Data, SN=1117, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 717583
# Time 126.071295 #Seq 1117 Info QoS Data, SN=1117, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 717583
# Time 126.071295 #Seq 1117 Info QoS Data, SN=1117, FN=0, Flags=.p..R..TC
#
#
# No. 717583 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 717583, Info QoS Data, SN=1117, FN=0, Flags=.p..R..TC
# Time difference: 0.11945800000000872
#
# -------- Test Round 7 --------
# -----------------------------------------
# Stage 1 finish. No. 833005, Info Data, SN=937, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 836432, Info QoS Data, SN=175, FN=0, Flags=.p....F.C
# Time difference: 0.5869070000000249
# -----------------------------------------
# Stage 3 finish. No. 839024, Info QoS Data, SN=185, FN=0, Flags=.p....F.C
# Time difference: 0.4103580000000022
# -----------------------------------------
# Stage 4 finish. No. 839989, Info QoS Data, SN=187, FN=0, Flags=.p....F.C
# Time difference: 0.14190699999997491
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 840300
# Time 146.548955 #Seq 1149 Info QoS Data, SN=1149, FN=0, Flags=.p..R..TC
#
#
# No. 840300 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 840300, Info QoS Data, SN=1149, FN=0, Flags=.p..R..TC
# Time difference: 0.04962600000001771
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 840301
# Time 146.549049 #Seq 1149 Info QoS Data, SN=1149, FN=0, Flags=.p..R..TC
#
#
# No. 840301 has been found. Delete from wierd list.
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 840302
# Time 146.549531 #Seq 1149 Info QoS Data, SN=1149, FN=0, Flags=.p..R..TC
#
#
# No. 840302 has been found. Delete from wierd list.
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 840303
# Time 146.549907 #Seq 1149 Info QoS Data, SN=1149, FN=0, Flags=.p..R..TC
#
#
# No. 840303 has been found. Delete from wierd list.
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 841018
# Time 146.660161 #Seq 191 Info QoS Data, SN=191, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 841018
# Time 146.660161 #Seq 191 Info QoS Data, SN=191, FN=0, Flags=.p....F.C
#
#
# No. 841018 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 841018, Data length 173, Info QoS Data, SN=191, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 841018, Info QoS Data, SN=191, FN=0, Flags=.p....F.C
# Time difference: 0.11120599999998149
# -----------------------------------------
# Stage 7 finish. No. 842019, Info QoS Data, SN=194, FN=0, Flags=.p....F.C
# Time difference: 0.1445319999999981
# -----------------------------------------
# Stage 8 finish. No. 842834, Info QoS Data, SN=196, FN=0, Flags=.p....F.C
# Time difference: 0.13682200000002354
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 843558
# Time 147.049794 #Seq 198 Info QoS Data, SN=198, FN=0, Flags=.p....F.C
#
#
# No. 843558 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 843558, Info QoS Data, SN=198, FN=0, Flags=.p....F.C
# Time difference: 0.1082789999999818
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 844487
# Time 147.220064 #Seq 200 Info QoS Data, SN=200, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 844487
# Time 147.220064 #Seq 200 Info QoS Data, SN=200, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 844487
# Time 147.220064 #Seq 200 Info QoS Data, SN=200, FN=0, Flags=.p....F.C
#
#
# No. 844487 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 844487, Data length 173, Info QoS Data, SN=200, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 844487, Info QoS Data, SN=200, FN=0, Flags=.p....F.C
# Time difference: 0.17027000000001635
#
# -------- Test Round 8 --------
# -----------------------------------------
# Stage 1 finish. No. 956337, Info QoS Data, SN=1178, FN=0, Flags=.p..R..TC
# -----------------------------------------
# Stage 2 finish. No. 959336, Info QoS Data, SN=718, FN=0, Flags=.p.....TC
# Time difference: 0.5406799999999805
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 962273
# Time 167.213425 #Seq 1185 Info QoS Data, SN=1185, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 962273
# Time 167.213425 #Seq 1185 Info QoS Data, SN=1185, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 962273
# Time 167.213425 #Seq 1185 Info QoS Data, SN=1185, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 962273
# Time 167.213425 #Seq 1185 Info QoS Data, SN=1185, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 963249, Info QoS Data, SN=1188, FN=0, Flags=.p.....TC
# Time difference: 0.6458840000000237
# -----------------------------------------
# Stage 4 finish. No. 964028, Info QoS Data, SN=1190, FN=0, Flags=.p.....TC
# Time difference: 0.1261429999999848
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 965711
# Time 167.80154 #Seq 1193 Info QoS Data, SN=1193, FN=0, Flags=.p.....TC
#
#
# No. 965711 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 965711, Info QoS Data, SN=1193, FN=0, Flags=.p.....TC
# Time difference: 0.30405999999999267
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 965716
# Time 167.801901 #Seq 247 Info QoS Data, SN=247, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 965716
# Time 167.801901 #Seq 247 Info QoS Data, SN=247, FN=0, Flags=.p....F.C
#
#
# No. 965716 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 965716, Data length 173, Info QoS Data, SN=247, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 965716, Info QoS Data, SN=247, FN=0, Flags=.p....F.C
# Time difference: 0.0003609999999980573
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 966229
# Time 167.873294 #Seq 1194 Info QoS Data, SN=1194, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 966229
# Time 167.873294 #Seq 1194 Info QoS Data, SN=1194, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 7 finish. No. 967134, Info QoS Data, SN=1197, FN=0, Flags=.p.....TC
# Time difference: 0.232908000000009
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 967251
# Time 168.050711 #Seq 252 Info QoS Data, SN=252, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 968217, Info QoS Data, SN=1199, FN=0, Flags=.p.....TC
# Time difference: 0.1696929999999952
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 969245
# Time 168.380815 #Seq 1201 Info QoS Data, SN=1201, FN=0, Flags=.p.....TC
#
#
# No. 969245 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 969245, Info QoS Data, SN=1201, FN=0, Flags=.p.....TC
# Time difference: 0.1763130000000217
#
# False
# Stage Num = 10
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 969257
# Time 168.381756 #Seq 256 Info QoS Data, SN=256, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 969257
# Time 168.381756 #Seq 256 Info QoS Data, SN=256, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 969722
# Time 168.459075 #Seq 1202 Info QoS Data, SN=1202, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 969722
# Time 168.459075 #Seq 1202 Info QoS Data, SN=1202, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 969722
# Time 168.459075 #Seq 1202 Info QoS Data, SN=1202, FN=0, Flags=.p.....TC
#
#
# No. 969722 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 969722, Info QoS Data, SN=1202, FN=0, Flags=.p.....TC
# Time difference: 0.07826000000000022
#
# -------- Test Round 9 --------
# -----------------------------------------
# Stage 1 finish. No. 1081699, Info Data, SN=1359, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 1084998, Info QoS Data, SN=291, FN=0, Flags=.p....F.C
# Time difference: 0.5485260000000096
# -----------------------------------------
# Stage 3 finish. No. 1088119, Info QoS Data, SN=303, FN=0, Flags=.p....F.C
# Time difference: 0.4656889999999976
# -----------------------------------------
# Stage 4 finish. No. 1089088, Info QoS Data, SN=305, FN=0, Flags=.p....F.C
# Time difference: 0.15147699999999986
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1089949
# Time 188.627077 #Seq 307 Info QoS Data, SN=307, FN=0, Flags=.p....F.C
#
#
# No. 1089949 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 1089949, Data length 173, Info QoS Data, SN=307, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 1089949, Info QoS Data, SN=307, FN=0, Flags=.p....F.C
# Time difference: 0.11728500000000963
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1090343
# Time 188.69583 #Seq 308 Info QoS Data, SN=308, FN=0, Flags=.p....F.C
#
#
# No. 1090343 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 1090343, Data length 173, Info QoS Data, SN=308, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 1090343, Info QoS Data, SN=308, FN=0, Flags=.p....F.C
# Time difference: 0.06875299999998674
# -----------------------------------------
# Stage 7 finish. No. 1091405, Info QoS Data, SN=311, FN=0, Flags=.p....F.C
# Time difference: 0.16674000000000433
# -----------------------------------------
# Stage 8 finish. No. 1092724, Info QoS Data, SN=313, FN=0, Flags=.p....F.C
# Time difference: 0.17889999999999873
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1093766
# Time 189.220326 #Seq 1241 Info QoS Data, SN=1241, FN=0, Flags=.p..R..TC
#
#
# No. 1093766 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1093766, Info QoS Data, SN=1241, FN=0, Flags=.p..R..TC
# Time difference: 0.17885599999999613
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1095713
# Time 189.526085 #Seq 1243 Info QoS Data, SN=1243, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1095713
# Time 189.526085 #Seq 1243 Info QoS Data, SN=1243, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1095713
# Time 189.526085 #Seq 1243 Info QoS Data, SN=1243, FN=0, Flags=.p..R..TC
#
#
# No. 1095713 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1095713, Info QoS Data, SN=1243, FN=0, Flags=.p..R..TC
# Time difference: 0.3057589999999948
#
# -------- Test Round 10 --------
# -----------------------------------------
# Stage 1 finish. No. 1215158, Info Data, SN=1570, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 1217996, Info QoS Data, SN=351, FN=0, Flags=.p....F.C
# Time difference: 0.45679199999997877
# -----------------------------------------
# Stage 3 finish. No. 1220431, Info QoS Data, SN=362, FN=0, Flags=.p....F.C
# Time difference: 0.4152909999999963
# -----------------------------------------
# Stage 4 finish. No. 1221079, Info QoS Data, SN=364, FN=0, Flags=.p....F.C
# Time difference: 0.127239000000003
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1221237
# Time 209.669706 #Seq 366 Info QoS Data, SN=366, FN=0, Flags=.p....F.C
#
#
# No. 1221237 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 1221237, Data length 173, Info QoS Data, SN=366, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 1221237, Info QoS Data, SN=366, FN=0, Flags=.p....F.C
# Time difference: 0.02599299999999971
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1222015
# Time 209.795813 #Seq 368 Info QoS Data, SN=368, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1222015
# Time 209.795813 #Seq 368 Info QoS Data, SN=368, FN=0, Flags=.p....F.C
#
#
# No. 1222015 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 1222015, Data length 173, Info QoS Data, SN=368, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 1222015, Info QoS Data, SN=368, FN=0, Flags=.p....F.C
# Time difference: 0.12610700000001884
# -----------------------------------------
# Stage 7 finish. No. 1222954, Info QoS Data, SN=371, FN=0, Flags=.p....F.C
# Time difference: 0.14426399999999262
# -----------------------------------------
# Stage 8 finish. No. 1223928, Info QoS Data, SN=373, FN=0, Flags=.p....F.C
# Time difference: 0.16434799999998972
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1224191
# Time 210.172946 #Seq 375 Info QoS Data, SN=375, FN=0, Flags=.p....F.C
#
#
# No. 1224191 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1224191, Info QoS Data, SN=375, FN=0, Flags=.p....F.C
# Time difference: 0.06852100000000405
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1225245
# Time 210.340627 #Seq 377 Info QoS Data, SN=377, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1225245
# Time 210.340627 #Seq 377 Info QoS Data, SN=377, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1225245
# Time 210.340627 #Seq 377 Info QoS Data, SN=377, FN=0, Flags=.p....F.C
#
#
# No. 1225245 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 1225245, Data length 173, Info QoS Data, SN=377, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 1225245, Info QoS Data, SN=377, FN=0, Flags=.p....F.C
# Time difference: 0.16768100000001596
#
# -------- Test Round 11 --------
# -----------------------------------------
# Stage 1 finish. No. 1342293, Info QoS Data, SN=1306, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1345230, Info QoS Data, SN=769, FN=0, Flags=.p.....TC
# Time difference: 0.41694400000000087
# -----------------------------------------
# Stage 3 finish. No. 1351721, Info QoS Data, SN=1314, FN=0, Flags=.p.....TC
# Time difference: 1.037842000000012
#
# False
# Stage Num = 4
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1352289
# Time 230.834072 #Seq 433 Info QoS Data, SN=433, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 4
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 1352289
# Time 230.834072 #Seq 433 Info QoS Data, SN=433, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 4 finish. No. 1353631, Info QoS Data, SN=1316, FN=0, Flags=.p.....TC
# Time difference: 0.27903499999999326
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1353737
# Time 231.071336 #Seq 435 Info QoS Data, SN=435, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 1353737
# Time 231.071336 #Seq 435 Info QoS Data, SN=435, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1354242
# Time 231.133534 #Seq 1319 Info QoS Data, SN=1319, FN=0, Flags=.p.....TC
#
#
# No. 1354242 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 1354242, Info QoS Data, SN=1319, FN=0, Flags=.p.....TC
# Time difference: 0.09591000000000349
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1354243
# Time 231.134738 #Seq 1319 Info QoS Data, SN=1319, FN=0, Flags=.p..R..TC
#
#
# No. 1354243 has been found. Delete from wierd list.
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1354440
# Time 231.199718 #Seq 438 Info QoS Data, SN=438, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 1354440
# Time 231.199718 #Seq 438 Info QoS Data, SN=438, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1355536
# Time 231.364708 #Seq 1321 Info QoS Data, SN=1321, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1355536
# Time 231.364708 #Seq 1321 Info QoS Data, SN=1321, FN=0, Flags=.p.....TC
#
#
# No. 1355536 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1355536, Info QoS Data, SN=1321, FN=0, Flags=.p.....TC
# Time difference: 0.23117400000000998
# -----------------------------------------
# Stage 7 finish. No. 1356845, Info QoS Data, SN=1324, FN=0, Flags=.p.....TC
# Time difference: 0.18567299999998
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 1356849
# Time 231.55183 #Seq 443 Info QoS Data, SN=443, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 1358022, Info QoS Data, SN=1326, FN=0, Flags=.p.....TC
# Time difference: 0.1814560000000256
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1358506
# Time 231.81074 #Seq 1328 Info QoS Data, SN=1328, FN=0, Flags=.p.....TC
#
#
# No. 1358506 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1358506, Info QoS Data, SN=1328, FN=0, Flags=.p.....TC
# Time difference: 0.07890299999999684
#
# False
# Stage Num = 10
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1358556
# Time 231.818201 #Seq 447 Info QoS Data, SN=447, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 1358556
# Time 231.818201 #Seq 447 Info QoS Data, SN=447, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1359235
# Time 231.929266 #Seq 1330 Info QoS Data, SN=1330, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1359235
# Time 231.929266 #Seq 1330 Info QoS Data, SN=1330, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1359235
# Time 231.929266 #Seq 1330 Info QoS Data, SN=1330, FN=0, Flags=.p.....TC
#
#
# No. 1359235 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1359235, Info QoS Data, SN=1330, FN=0, Flags=.p.....TC
# Time difference: 0.1185260000000028
#
# -------- Test Round 12 --------
# -----------------------------------------
# Stage 1 finish. No. 1479396, Info QoS Data, SN=1348, FN=0, Flags=.p..R..TC
# -----------------------------------------
# Stage 2 finish. No. 1482831, Info QoS Data, SN=787, FN=0, Flags=.p.....TC
# Time difference: 0.5203309999999988
# -----------------------------------------
# Stage 3 finish. No. 1486634, Info QoS Data, SN=1359, FN=0, Flags=.p.....TC
# Time difference: 0.5331989999999962
# -----------------------------------------
# Stage 4 finish. No. 1487578, Info QoS Data, SN=1361, FN=0, Flags=.p.....TC
# Time difference: 0.13311799999999607
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1487825
# Time 252.380894 #Seq 498 Info QoS Data, SN=498, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1488067
# Time 252.411015 #Seq 1363 Info QoS Data, SN=1363, FN=0, Flags=.p.....TC
#
#
# No. 1488067 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 1488067, Info QoS Data, SN=1363, FN=0, Flags=.p.....TC
# Time difference: 0.07954699999999093
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1488083
# Time 252.418169 #Seq 500 Info QoS Data, SN=500, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1488566
# Time 252.514814 #Seq 1365 Info QoS Data, SN=1365, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1488566
# Time 252.514814 #Seq 1365 Info QoS Data, SN=1365, FN=0, Flags=.p.....TC
#
#
# No. 1488566 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1488566, Info QoS Data, SN=1365, FN=0, Flags=.p.....TC
# Time difference: 0.1037990000000093
# -----------------------------------------
# Stage 7 finish. No. 1489633, Info QoS Data, SN=1368, FN=0, Flags=.p.....TC
# Time difference: 0.16474099999999225
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 1489763
# Time 252.693162 #Seq 505 Info QoS Data, SN=505, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 1491468, Info QoS Data, SN=1370, FN=0, Flags=.p.....TC
# Time difference: 0.2960910000000183
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1492052
# Time 253.063095 #Seq 1372 Info QoS Data, SN=1372, FN=0, Flags=.p.....TC
#
#
# No. 1492052 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1492052, Info QoS Data, SN=1372, FN=0, Flags=.p.....TC
# Time difference: 0.08744899999999234
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1492855
# Time 253.191069 #Seq 1374 Info QoS Data, SN=1374, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1492855
# Time 253.191069 #Seq 1374 Info QoS Data, SN=1374, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1492855
# Time 253.191069 #Seq 1374 Info QoS Data, SN=1374, FN=0, Flags=.p.....TC
#
#
# No. 1492855 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1492855, Info QoS Data, SN=1374, FN=0, Flags=.p.....TC
# Time difference: 0.1279739999999947
#
# -------- Test Round 13 --------
# -----------------------------------------
# Stage 1 finish. No. 1612605, Info QoS Data, SN=1393, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1615532, Info QoS Data, SN=803, FN=0, Flags=.p.....TC
# Time difference: 0.4956549999999993
# -----------------------------------------
# Stage 3 finish. No. 1618644, Info QoS Data, SN=1403, FN=0, Flags=.p.....TC
# Time difference: 0.5009690000000546
#
# False
# Stage Num = 4
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1618669
# Time 273.475818 #Seq 557 Info QoS Data, SN=557, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 4
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 1618669
# Time 273.475818 #Seq 557 Info QoS Data, SN=557, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 4 finish. No. 1619206, Info QoS Data, SN=1405, FN=0, Flags=.p.....TC
# Time difference: 0.07488999999998214
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1619357
# Time 273.571114 #Seq 559 Info QoS Data, SN=559, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1619703
# Time 273.616121 #Seq 1407 Info QoS Data, SN=1407, FN=0, Flags=.p.....TC
#
#
# No. 1619703 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 1619703, Info QoS Data, SN=1407, FN=0, Flags=.p.....TC
# Time difference: 0.0699030000000107
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1619900
# Time 273.650743 #Seq 561 Info QoS Data, SN=561, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1620456
# Time 273.747486 #Seq 1409 Info QoS Data, SN=1409, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1620456
# Time 273.747486 #Seq 1409 Info QoS Data, SN=1409, FN=0, Flags=.p.....TC
#
#
# No. 1620456 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1620456, Info QoS Data, SN=1409, FN=0, Flags=.p.....TC
# Time difference: 0.13136499999995976
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1620594
# Time 273.777315 #Seq 563 Info QoS Data, SN=563, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 7 finish. No. 1621618, Info QoS Data, SN=1412, FN=0, Flags=.p.....TC
# Time difference: 0.18971200000004274
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 1621640
# Time 273.945147 #Seq 566 Info QoS Data, SN=566, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 1622529, Info QoS Data, SN=1414, FN=0, Flags=.p.....TC
# Time difference: 0.14929099999994833
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1623173
# Time 274.183102 #Seq 1416 Info QoS Data, SN=1416, FN=0, Flags=.p.....TC
#
#
# No. 1623173 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1623173, Info QoS Data, SN=1416, FN=0, Flags=.p.....TC
# Time difference: 0.09661300000004758
#
# False
# Stage Num = 10
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1623349
# Time 274.213506 #Seq 570 Info QoS Data, SN=570, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 1623349
# Time 274.213506 #Seq 570 Info QoS Data, SN=570, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1624083
# Time 274.325966 #Seq 1418 Info QoS Data, SN=1418, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1624083
# Time 274.325966 #Seq 1418 Info QoS Data, SN=1418, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1624083
# Time 274.325966 #Seq 1418 Info QoS Data, SN=1418, FN=0, Flags=.p.....TC
#
#
# No. 1624083 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1624083, Info QoS Data, SN=1418, FN=0, Flags=.p.....TC
# Time difference: 0.14286399999997457
#
# -------- Test Round 14 --------
# -----------------------------------------
# Stage 1 finish. No. 1726045, Info QoS Data, SN=1436, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1728421, Info QoS Data, SN=811, FN=0, Flags=.p.....TC
# Time difference: 0.40074300000003404
# -----------------------------------------
# Stage 3 finish. No. 1732633, Info QoS Data, SN=1446, FN=0, Flags=.p.....TC
# Time difference: 0.7187529999999924
# -----------------------------------------
# Stage 4 finish. No. 1733412, Info QoS Data, SN=611, FN=0, Flags=.p....F.C
# ...
# What is this packet? Data Length = 173 No. 1899748
# Time 336.303632 #Seq 859 Info QoS Data, SN=859, FN=0, Flags=.p....F.C
#
#
# No. 1899748 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 1899748, Data length 173, Info QoS Data, SN=859, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 1899748, Info QoS Data, SN=859, FN=0, Flags=.p....F.C
# Time difference: 0.24047799999999597
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1899758
# Time 336.304365 #Seq 859 Info QoS Data, SN=859, FN=0, Flags=.p..R.F.C
#
#
# No. 1899758 has been found. Delete from wierd list.
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1900926
# Time 336.653586 #Seq 861 Info QoS Data, SN=861, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1900926
# Time 336.653586 #Seq 861 Info QoS Data, SN=861, FN=0, Flags=.p....F.C
#
#
# No. 1900926 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 1900926, Data length 173, Info QoS Data, SN=861, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 1900926, Info QoS Data, SN=861, FN=0, Flags=.p....F.C
# Time difference: 0.3499540000000252
# -----------------------------------------
# Stage 7 finish. No. 1901377, Info QoS Data, SN=864, FN=0, Flags=.p....F.C
# Time difference: 0.18059699999997747
# -----------------------------------------
# Stage 8 finish. No. 1901966, Info QoS Data, SN=866, FN=0, Flags=.p....F.C
# Time difference: 0.18796300000002475
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1902388
# Time 337.154854 #Seq 868 Info QoS Data, SN=868, FN=0, Flags=.p....F.C
#
#
# No. 1902388 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1902388, Info QoS Data, SN=868, FN=0, Flags=.p....F.C
# Time difference: 0.13270799999997962
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1902967
# Time 337.300075 #Seq 870 Info QoS Data, SN=870, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1902967
# Time 337.300075 #Seq 870 Info QoS Data, SN=870, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1902967
# Time 337.300075 #Seq 870 Info QoS Data, SN=870, FN=0, Flags=.p....F.C
#
#
# No. 1902967 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 1902967, Data length 173, Info QoS Data, SN=870, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 1902967, Info QoS Data, SN=870, FN=0, Flags=.p....F.C
# Time difference: 0.14522099999999227
#
# -------- Test Round 17 --------
# -----------------------------------------
# Stage 1 finish. No. 1966579, Info Data, SN=3064, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 1968133, Info QoS Data, SN=906, FN=0, Flags=.p....F.C
# Time difference: 0.4242770000000178
# -----------------------------------------
# Stage 3 finish. No. 1969888, Info QoS Data, SN=917, FN=0, Flags=.p....F.C
# Time difference: 0.5830070000000092
# -----------------------------------------
# Stage 4 finish. No. 1970244, Info QoS Data, SN=919, FN=0, Flags=.p....F.C
# Time difference: 0.10861599999998361
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1970569
# Time 357.743036 #Seq 921 Info QoS Data, SN=921, FN=0, Flags=.p....F.C
#
#
# No. 1970569 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 1970569, Data length 173, Info QoS Data, SN=921, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 1970569, Info QoS Data, SN=921, FN=0, Flags=.p....F.C
# Time difference: 0.11916500000000951
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1971119
# Time 357.911261 #Seq 923 Info QoS Data, SN=923, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1971119
# Time 357.911261 #Seq 923 Info QoS Data, SN=923, FN=0, Flags=.p....F.C
#
#
# No. 1971119 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 1971119, Data length 173, Info QoS Data, SN=923, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 1971119, Info QoS Data, SN=923, FN=0, Flags=.p....F.C
# Time difference: 0.16822500000000673
# -----------------------------------------
# Stage 7 finish. No. 1971671, Info QoS Data, SN=926, FN=0, Flags=.p....F.C
# Time difference: 0.1647289999999657
# -----------------------------------------
# Stage 8 finish. No. 1972000, Info QoS Data, SN=928, FN=0, Flags=.p....F.C
# Time difference: 0.10185100000001057
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1972368
# Time 358.286303 #Seq 930 Info QoS Data, SN=930, FN=0, Flags=.p....F.C
#
#
# No. 1972368 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1972368, Info QoS Data, SN=930, FN=0, Flags=.p....F.C
# Time difference: 0.10846199999997452
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1972717
# Time 358.405441 #Seq 932 Info QoS Data, SN=932, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1972717
# Time 358.405441 #Seq 932 Info QoS Data, SN=932, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1972717
# Time 358.405441 #Seq 932 Info QoS Data, SN=932, FN=0, Flags=.p....F.C
#
#
# No. 1972717 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 1972717, Data length 173, Info QoS Data, SN=932, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 1972717, Info QoS Data, SN=932, FN=0, Flags=.p....F.C
# Time difference: 0.11913800000002084
#
# -------- Test Round 18 --------
# -----------------------------------------
# Stage 1 finish. No. 2030956, Info Data, SN=3267, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 2032924, Info QoS Data, SN=971, FN=0, Flags=.p....F.C
# Time difference: 0.5677749999999833
# -----------------------------------------
# Stage 3 finish. No. 2034618, Info QoS Data, SN=982, FN=0, Flags=.p....F.C
# Time difference: 0.36085800000000745
# -----------------------------------------
# Stage 4 finish. No. 2035133, Info QoS Data, SN=984, FN=0, Flags=.p..R.F.C
# Time difference: 0.09789200000000164
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2035574
# Time 378.298407 #Seq 986 Info QoS Data, SN=986, FN=0, Flags=.p....F.C
#
#
# No. 2035574 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 2035574, Data length 173, Info QoS Data, SN=986, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 2035574, Info QoS Data, SN=986, FN=0, Flags=.p....F.C
# Time difference: 0.07215999999999667
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2035835
# Time 378.353691 #Seq 988 Info QoS Data, SN=988, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2035835
# Time 378.353691 #Seq 988 Info QoS Data, SN=988, FN=0, Flags=.p....F.C
#
#
# No. 2035835 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 2035835, Data length 173, Info QoS Data, SN=988, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 2035835, Info QoS Data, SN=988, FN=0, Flags=.p....F.C
# Time difference: 0.055284000000028755
# -----------------------------------------
# Stage 7 finish. No. 2036828, Info QoS Data, SN=991, FN=0, Flags=.p....F.C
# Time difference: 0.16440399999999045
# -----------------------------------------
# Stage 8 finish. No. 2038997, Info QoS Data, SN=993, FN=0, Flags=.p....F.C
# Time difference: 0.38655699999998205
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2039205
# Time 378.952388 #Seq 995 Info QoS Data, SN=995, FN=0, Flags=.p....F.C
#
#
# No. 2039205 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 2039205, Info QoS Data, SN=995, FN=0, Flags=.p....F.C
# Time difference: 0.047735999999986234
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2039608
# Time 379.1026 #Seq 997 Info QoS Data, SN=997, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2039608
# Time 379.1026 #Seq 997 Info QoS Data, SN=997, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 2039608
# Time 379.1026 #Seq 997 Info QoS Data, SN=997, FN=0, Flags=.p....F.C
#
#
# No. 2039608 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 2039608, Data length 173, Info QoS Data, SN=997, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 2039608, Info QoS Data, SN=997, FN=0, Flags=.p....F.C
# Time difference: 0.15021200000001045
#
# -------- Test Round 19 --------
# -----------------------------------------
# Stage 1 finish. No. 2112310, Info Data, SN=3485, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 2114494, Info QoS Data, SN=1030, FN=0, Flags=.p....F.C
# Time difference: 0.4597569999999678
# -----------------------------------------
# Stage 3 finish. No. 2116201, Info QoS Data, SN=1040, FN=0, Flags=.p....F.C
# Time difference: 0.39036600000002863
# -----------------------------------------
# Stage 4 finish. No. 2116728, Info QoS Data, SN=1042, FN=0, Flags=.p....F.C
# Time difference: 0.1023569999999836
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2116924
# Time 398.865414 #Seq 1044 Info QoS Data, SN=1044, FN=0, Flags=.p....F.C
#
#
# No. 2116924 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 2116924, Data length 173, Info QoS Data, SN=1044, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 2116924, Info QoS Data, SN=1044, FN=0, Flags=.p....F.C
# Time difference: 0.03224499999998898
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2118106
# Time 399.051679 #Seq 1046 Info QoS Data, SN=1046, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2118106
# Time 399.051679 #Seq 1046 Info QoS Data, SN=1046, FN=0, Flags=.p....F.C
#
#
# No. 2118106 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 2118106, Data length 173, Info QoS Data, SN=1046, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 2118106, Info QoS Data, SN=1046, FN=0, Flags=.p....F.C
# Time difference: 0.1862649999999917
# -----------------------------------------
# Stage 7 finish. No. 2118989, Info QoS Data, SN=1050, FN=0, Flags=.p....F.C
# Time difference: 0.19362700000004907
# -----------------------------------------
# Stage 8 finish. No. 2120140, Info QoS Data, SN=1052, FN=0, Flags=.p....F.C
# Time difference: 0.182912999999985
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2120607
# Time 399.49599 #Seq 1054 Info QoS Data, SN=1054, FN=0, Flags=.p....F.C
#
#
# No. 2120607 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 2120607, Info QoS Data, SN=1054, FN=0, Flags=.p....F.C
# Time difference: 0.06777099999999336
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2122803
# Time 399.834235 #Seq 1056 Info QoS Data, SN=1056, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2122803
# Time 399.834235 #Seq 1056 Info QoS Data, SN=1056, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 2122803
# Time 399.834235 #Seq 1056 Info QoS Data, SN=1056, FN=0, Flags=.p....F.C
#
#
# No. 2122803 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 2122803, Data length 173, Info QoS Data, SN=1056, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 2122803, Info QoS Data, SN=1056, FN=0, Flags=.p....F.C
# Time difference: 0.33824499999997215
#
# -------- Test Round 20 --------
# -----------------------------------------
# Stage 1 finish. No. 2242472, Info Data, SN=3695, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 2245262, Info QoS Data, SN=1083, FN=0, Flags=.p....F.C
# Time difference: 0.4557970000000182
# -----------------------------------------
# Stage 3 finish. No. 2248831, Info QoS Data, SN=1094, FN=0, Flags=.p....F.C
# Time difference: 0.5330139999999801
# -----------------------------------------
# Stage 4 finish. No. 2249390, Info QoS Data, SN=1096, FN=0, Flags=.p....F.C
# Time difference: 0.08612199999998893
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2250075
# Time 420.453497 #Seq 1098 Info QoS Data, SN=1098, FN=0, Flags=.p....F.C
#
#
# No. 2250075 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 2250075, Data length 173, Info QoS Data, SN=1098, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 2250075, Info QoS Data, SN=1098, FN=0, Flags=.p....F.C
# Time difference: 0.09954200000004221
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2250650
# Time 420.539648 #Seq 1100 Info QoS Data, SN=1100, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2250650
# Time 420.539648 #Seq 1100 Info QoS Data, SN=1100, FN=0, Flags=.p....F.C
#
#
# No. 2250650 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 2250650, Data length 173, Info QoS Data, SN=1100, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 2250650, Info QoS Data, SN=1100, FN=0, Flags=.p....F.C
# Time difference: 0.08615099999997256
# -----------------------------------------
# Stage 7 finish. No. 2251856, Info QoS Data, SN=1103, FN=0, Flags=.p....F.C
# Time difference: 0.18865299999998797
# -----------------------------------------
# Stage 8 finish. No. 2253188, Info QoS Data, SN=1105, FN=0, Flags=.p....F.C
# Time difference: 0.24199600000002874
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2254128
# Time 421.100572 #Seq 1107 Info QoS Data, SN=1107, FN=0, Flags=.p....F.C
#
#
# No. 2254128 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 2254128, Info QoS Data, SN=1107, FN=0, Flags=.p....F.C
# Time difference: 0.13027499999998327
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2255018
# Time 421.234174 #Seq 1109 Info QoS Data, SN=1109, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2255018
# Time 421.234174 #Seq 1109 Info QoS Data, SN=1109, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 2255018
# Time 421.234174 #Seq 1109 Info QoS Data, SN=1109, FN=0, Flags=.p....F.C
#
#
# No. 2255018 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 2255018, Data length 173, Info QoS Data, SN=1109, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 2255018, Info QoS Data, SN=1109, FN=0, Flags=.p....F.C
# Time difference: 0.13360199999999622

# %%
#for debug
print(str(len(evcc_send_time_anchor)) + '\n')
for i in range(0, len(evcc_send_time_anchor)):
    print("i = " + str(i))
    print(len(evcc_send_time_anchor[i]))
# Out:
# 20
#
# i = 0
# 10
# i = 1
# 10
# i = 2
# 10
# i = 3
# 10
# i = 4
# 10
# i = 5
# 10
# i = 6
# 10
# i = 7
# 10
# i = 8
# 10
# i = 9
# 10
# i = 10
# 10
# i = 11
# 10
# i = 12
# 10
# i = 13
# 10
# i = 14
# 10
# i = 15
# 10
# i = 16
# 10
# i = 17
# 10
# i = 18
# 10
# i = 19
# 10

# %%
#wierd_packet
#len(wierd_packet)

# %%
#for debug
for i in range(0, len(evcc_send_time_anchor)):
    print("i = " + str(i))
    print(evcc_send_time_anchor[i][len(evcc_send_time_anchor[i])-1]-evcc_send_time_anchor[i][0])
# Out:
# i = 0
# 1.9210139999999996
# i = 1
# 1.9020520000000047
# i = 2
# 2.5963720000000023
# i = 3
# 2.2249140000000125
# i = 4
# 2.09060199999999
# i = 5
# 1.7011610000000132
# i = 6
# 1.859907000000021
# i = 7
# 2.274302000000006
# i = 8
# 2.1819849999999974
# i = 9
# 1.696235999999999
# i = 10
# 2.6254630000000247
# i = 11
# 2.046248999999989
# i = 12
# 1.8512620000000197
# i = 13
# 1.8893300000000295
# i = 14
# 1.5204550000000268
# i = 15
# 3.115165999999988
# i = 16
# 1.8974699999999984
# i = 17
# 1.902877999999987
# i = 18
# 1.9535459999999603
# i = 19
# 1.9551519999999982

# %%
#Processing secc send
with open('csv/DataLink/max_interf_VI/secc_send_max_VI.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_secc_send = []
    seq_num_secc_send = []
    data_length_secc_send = []
    info_secc_send = []
    frame_num_secc_send = []
    
    for row in rows:
        timelist_secc_send.append(float(row['Time']))
        seq_num_secc_send.append(int(row['Sequence number']))
        data_length_secc_send.append(int(row['Data Length']))
        info_secc_send.append(str(row['Info']))
        frame_num_secc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_secc_send) != len(seq_num_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(data_length_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(info_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(frame_num_secc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send))
# Out:
# 1097

# %%
timelist_secc_send_split = []
seq_num_secc_send_split = []
data_length_secc_send_split = []
info_secc_send_split = []
frame_num_secc_send_split = []

round_start_point = 0
round_end_point = 0

sdpres_index_list = []
#Fetch first packet index of data length = 92 (SDP response) in each round
for i in range(0, len(data_length_secc_send)):
    if(i == 0 and data_length_secc_send[i] == 92):
        sdpres_index_list.append(i)
    if(i > 0 and data_length_secc_send[i] == 92 and data_length_secc_send[i-1] != 92):
        sdpres_index_list.append(i)
sdpres_index_list.append(len(data_length_secc_send)) #Add the end of list index

for i in range(0, len(sdpres_index_list)-1):
        timelist_secc_send_split.append([timelist_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        seq_num_secc_send_split.append([seq_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        data_length_secc_send_split.append([data_length_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        info_secc_send_split.append([info_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        frame_num_secc_send_split.append([frame_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])

# %%
#for debug
if(len(timelist_secc_send_split) != len(seq_num_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(data_length_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(info_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(frame_num_secc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i))
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0
# 65
# i = 1
# 51
# i = 2
# 56
# i = 3
# 51
# i = 4
# 53
# i = 5
# 52
# i = 6
# 49
# i = 7
# 54
# i = 8
# 57
# i = 9
# 54
# i = 10
# 55
# i = 11
# 52
# i = 12
# 59
# i = 13
# 51
# i = 14
# 55
# i = 15
# 58
# i = 16
# 54
# i = 17
# 60
# i = 18
# 56
# i = 19
# 55

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 21.185836000000002
# 21.101421000000002
# 21.915005
# 21.40216199999999
# 21.090398000000008
# 21.00210899999999
# 20.92316200000002
# 21.058704999999975
# 21.29693900000001
# 20.687948000000006
# 21.936227000000002
# 21.272485999999986
# 20.788201000000015
# 20.674171
# 20.166541999999993
# 22.32945699999999
# 20.707889000000023
# 20.665899999999965
# 21.396488000000033

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i) + ' ', end = '')
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0 65
# i = 1 51
# i = 2 56
# i = 3 51
# i = 4 53
# i = 5 52
# i = 6 49
# i = 7 54
# i = 8 57
# i = 9 54
# i = 10 55
# i = 11 52
# i = 12 59
# i = 13 51
# i = 14 55
# i = 15 58
# i = 16 54
# i = 17 60
# i = 18 56
# i = 19 55

# %%
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 21.185836000000002
# 21.101421000000002
# 21.915005
# 21.40216199999999
# 21.090398000000008
# 21.00210899999999
# 20.92316200000002
# 21.058704999999975
# 21.29693900000001
# 20.687948000000006
# 21.936227000000002
# 21.272485999999986
# 20.788201000000015
# 20.674171
# 20.166541999999993
# 22.32945699999999
# 20.707889000000023
# 20.665899999999965
# 21.396488000000033

# %%
#Set secc time anchor in each round per stage
secc_send_time_anchor = []
#data_length_in_each_stage = [92, 173, 157, 189, 253, 173, 189, 173, 493, 173]
wierd_packet_secc = {}
packet_loss_testing_round_11_flag = False

global last_seqNum
last_seqNum = 0

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(secc_send_time_anchor_each_round):
    print("Time difference: " + str(secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-1]-
                          secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    global last_seqNum
    
    if(stageNum == valid_stageNum):
        if(seqnum == last_seqNum):
            return False
        else:
            check_wield_packet_list(frameNum)
            return True
    else:
        #debug
        print("\nWhat is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet_secc[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet_secc.get(frameNum) != None):
        del wierd_packet_secc[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_secc_send_split)):
#for i in [11]:
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    secc_send_time_anchor_each_round = [timelist_secc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_secc_send_split[i][0], info_secc_send_split[i][0])
    stageNum = stageNum + 1

    for j in range(1, len(data_length_secc_send_split[i])):
        #Stage 2
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 2, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 3
        if(data_length_secc_send_split[i][j] == 157 and data_length_secc_send_split[i][j-1] != 157):
            if(checkstage_num(stageNum, 3, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 4
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 4, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                    
                continue
                
        #Stage 5
        if(data_length_secc_send_split[i][j] == 253 and data_length_secc_send_split[i][j-1] != 253):
            if(checkstage_num(stageNum, 5, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 11 and packet_loss_testing_round_11_flag == False):
                    secc_send_time_anchor_each_round.append(252.53151)
                    printinfo(stageNum, 1488692, "Packet Loss")
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_11_flag = True
                
                continue
                
        #Stage 6
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 6, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 7
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 7, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 8
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 8, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 9
        if(data_length_secc_send_split[i][j] == 493 and data_length_secc_send_split[i][j-1] != 493):
            if(checkstage_num(stageNum, 9, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 10
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        
        if(stageNum == 11): break
        
    secc_send_time_anchor.append(secc_send_time_anchor_each_round)
# Out:
# -------- Test Round 1 --------
# -----------------------------------------
# Stage 1 finish. No. 79172, Info QoS Data, SN=1073, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 82654, Info QoS Data, SN=1082, FN=0, Flags=.p.....TC
# Time difference: 0.6522639999999988
# -----------------------------------------
# Stage 3 finish. No. 83531, Info QoS Data, SN=1084, FN=0, Flags=.p.....TC
# Time difference: 0.18346500000000177
# -----------------------------------------
# Stage 4 finish. No. 84525, Info QoS Data, SN=1087, FN=0, Flags=.p.....TC
# Time difference: 0.20877899999999983
# -----------------------------------------
# Stage 5 finish. No. 85250, Info QoS Data, SN=1089, FN=0, Flags=.p.....TC
# Time difference: 0.12373699999999843
#
# What is this packet? Data Length = 173 No. 85947
# Time 18.971312 #Seq 1091 Info QoS Data, SN=1091, FN=0, Flags=.p.....TC
#
#
# No. 85947 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 85947, Info QoS Data, SN=1091, FN=0, Flags=.p.....TC
# Time difference: 0.11721600000000265
#
# What is this packet? Data Length = 189 No. 87607
# Time 19.208727 #Seq 1093 Info QoS Data, SN=1093, FN=0, Flags=.p.....TC
#
#
# No. 87607 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 87607, Info QoS Data, SN=1093, FN=0, Flags=.p.....TC
# Time difference: 0.2374149999999986
#
# What is this packet? Data Length = 173 No. 88784
# Time 19.378188 #Seq 1095 Info QoS Data, SN=1095, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 88784
# Time 19.378188 #Seq 1095 Info QoS Data, SN=1095, FN=0, Flags=.p.....TC
#
#
# No. 88784 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 88784, Info QoS Data, SN=1095, FN=0, Flags=.p.....TC
# Time difference: 0.16946100000000186
# -----------------------------------------
# Stage 9 finish. No. 89589, Info QoS Data, SN=1097, FN=0, Flags=.p.....TC
# Time difference: 0.1254969999999993
#
# What is this packet? Data Length = 173 No. 90453
# Time 19.640525 #Seq 1099 Info QoS Data, SN=1099, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 90453
# Time 19.640525 #Seq 1099 Info QoS Data, SN=1099, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 90453
# Time 19.640525 #Seq 1099 Info QoS Data, SN=1099, FN=0, Flags=.p.....TC
#
#
# No. 90453 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 90453, Info QoS Data, SN=1099, FN=0, Flags=.p.....TC
# Time difference: 0.1368399999999994
#
# -------- Test Round 2 --------
# -----------------------------------------
# Stage 1 finish. No. 206783, Info QoS Data, SN=1121, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 212870, Info QoS Data, SN=1130, FN=0, Flags=.p.....TC
# Time difference: 0.9431420000000017
# -----------------------------------------
# Stage 3 finish. No. 213500, Info QoS Data, SN=1132, FN=0, Flags=.p.....TC
# Time difference: 0.11059299999999439
# -----------------------------------------
# Stage 4 finish. No. 214302, Info QoS Data, SN=1134, FN=0, Flags=.p.....TC
# Time difference: 0.12728800000000007
# -----------------------------------------
# Stage 5 finish. No. 214630, Info QoS Data, SN=1136, FN=0, Flags=.p.....TC
# Time difference: 0.05203800000000314
#
# What is this packet? Data Length = 173 No. 215602
# Time 40.248423 #Seq 1138 Info QoS Data, SN=1138, FN=0, Flags=.p.....TC
#
#
# No. 215602 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 215602, Info QoS Data, SN=1138, FN=0, Flags=.p.....TC
# Time difference: 0.14367500000000177
#
# What is this packet? Data Length = 189 No. 216806
# Time 40.444248 #Seq 1140 Info QoS Data, SN=1140, FN=0, Flags=.p.....TC
#
#
# No. 216806 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 216806, Info QoS Data, SN=1140, FN=0, Flags=.p.....TC
# Time difference: 0.19582499999999925
#
# What is this packet? Data Length = 173 No. 217679
# Time 40.573963 #Seq 1142 Info QoS Data, SN=1142, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 217679
# Time 40.573963 #Seq 1142 Info QoS Data, SN=1142, FN=0, Flags=.p.....TC
#
#
# No. 217679 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 217679, Info QoS Data, SN=1142, FN=0, Flags=.p.....TC
# Time difference: 0.12971499999999736
# -----------------------------------------
# Stage 9 finish. No. 217963, Info QoS Data, SN=1144, FN=0, Flags=.p.....TC
# Time difference: 0.051258000000004245
#
# What is this packet? Data Length = 173 No. 218870
# Time 40.783692 #Seq 1146 Info QoS Data, SN=1146, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 218870
# Time 40.783692 #Seq 1146 Info QoS Data, SN=1146, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 218870
# Time 40.783692 #Seq 1146 Info QoS Data, SN=1146, FN=0, Flags=.p.....TC
#
#
# No. 218870 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 218870, Info QoS Data, SN=1146, FN=0, Flags=.p.....TC
# Time difference: 0.1584709999999987
#
# -------- Test Round 3 --------
# -----------------------------------------
# Stage 1 finish. No. 337320, Info QoS Data, SN=1169, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 342907, Info QoS Data, SN=1178, FN=0, Flags=.p.....TC
# Time difference: 0.8789139999999946
# -----------------------------------------
# Stage 3 finish. No. 344658, Info QoS Data, SN=1180, FN=0, Flags=.p.....TC
# Time difference: 0.26613600000000304
# -----------------------------------------
# Stage 4 finish. No. 345998, Info QoS Data, SN=1183, FN=0, Flags=.p.....TC
# Time difference: 0.21474699999999558
# -----------------------------------------
# Stage 5 finish. No. 346300, Info QoS Data, SN=1185, FN=0, Flags=.p.....TC
# Time difference: 0.04090600000000677
#
# What is this packet? Data Length = 173 No. 346943
# Time 61.485474 #Seq 1187 Info QoS Data, SN=1187, FN=0, Flags=.p.....TC
#
#
# No. 346943 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 346943, Info QoS Data, SN=1187, FN=0, Flags=.p.....TC
# Time difference: 0.11166300000000007
#
# What is this packet? Data Length = 189 No. 351469
# Time 62.169744 #Seq 1190 Info QoS Data, SN=1190, FN=0, Flags=.p.....TC
#
#
# No. 351469 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 351469, Info QoS Data, SN=1190, FN=0, Flags=.p.....TC
# Time difference: 0.6842699999999979
#
# What is this packet? Data Length = 173 No. 352515
# Time 62.331897 #Seq 1192 Info QoS Data, SN=1192, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 352515
# Time 62.331897 #Seq 1192 Info QoS Data, SN=1192, FN=0, Flags=.p.....TC
#
#
# No. 352515 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 352515, Info QoS Data, SN=1192, FN=0, Flags=.p.....TC
# Time difference: 0.16215299999999644
# -----------------------------------------
# Stage 9 finish. No. 353047, Info QoS Data, SN=1194, FN=0, Flags=.p.....TC
# Time difference: 0.09749800000000164
#
# What is this packet? Data Length = 173 No. 353843
# Time 62.565872 #Seq 1196 Info QoS Data, SN=1196, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 353843
# Time 62.565872 #Seq 1196 Info QoS Data, SN=1196, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 353843
# Time 62.565872 #Seq 1196 Info QoS Data, SN=1196, FN=0, Flags=.p.....TC
#
#
# No. 353843 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 353843, Info QoS Data, SN=1196, FN=0, Flags=.p.....TC
# Time difference: 0.1364769999999993
#
# -------- Test Round 4 --------
# -----------------------------------------
# Stage 1 finish. No. 474177, Info QoS Data, SN=1218, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 481092, Info QoS Data, SN=1227, FN=0, Flags=.p.....TC
# Time difference: 1.0749079999999935
# -----------------------------------------
# Stage 3 finish. No. 481714, Info QoS Data, SN=1229, FN=0, Flags=.p.....TC
# Time difference: 0.102248000000003
# -----------------------------------------
# Stage 4 finish. No. 482500, Info QoS Data, SN=1231, FN=0, Flags=.p.....TC
# Time difference: 0.11974499999999466
# -----------------------------------------
# Stage 5 finish. No. 483028, Info QoS Data, SN=1233, FN=0, Flags=.p.....TC
# Time difference: 0.09594700000000955
#
# What is this packet? Data Length = 173 No. 483991
# Time 83.408951 #Seq 1235 Info QoS Data, SN=1235, FN=0, Flags=.p.....TC
#
#
# No. 483991 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 483991, Info QoS Data, SN=1235, FN=0, Flags=.p.....TC
# Time difference: 0.12798999999999694
#
# What is this packet? Data Length = 189 No. 485480
# Time 83.641996 #Seq 1237 Info QoS Data, SN=1237, FN=0, Flags=.p.....TC
#
#
# No. 485480 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 485480, Info QoS Data, SN=1237, FN=0, Flags=.p.....TC
# Time difference: 0.23304500000000417
#
# What is this packet? Data Length = 173 No. 486456
# Time 83.85867 #Seq 1239 Info QoS Data, SN=1239, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 486456
# Time 83.85867 #Seq 1239 Info QoS Data, SN=1239, FN=0, Flags=.p.....TC
#
#
# No. 486456 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 486456, Info QoS Data, SN=1239, FN=0, Flags=.p.....TC
# Time difference: 0.2166739999999976
# -----------------------------------------
# Stage 9 finish. No. 487262, Info QoS Data, SN=1241, FN=0, Flags=.p.....TC
# Time difference: 0.13540399999999408
#
# What is this packet? Data Length = 173 No. 488003
# Time 84.114424 #Seq 1243 Info QoS Data, SN=1243, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 488003
# Time 84.114424 #Seq 1243 Info QoS Data, SN=1243, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 488003
# Time 84.114424 #Seq 1243 Info QoS Data, SN=1243, FN=0, Flags=.p.....TC
#
#
# No. 488003 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 488003, Info QoS Data, SN=1243, FN=0, Flags=.p.....TC
# Time difference: 0.12035000000000196
#
# -------- Test Round 5 --------
# -----------------------------------------
# Stage 1 finish. No. 605566, Info QoS Data, SN=1265, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 611672, Info QoS Data, SN=1276, FN=0, Flags=.p.....TC
# Time difference: 1.0376470000000069
# -----------------------------------------
# Stage 3 finish. No. 612489, Info QoS Data, SN=1278, FN=0, Flags=.p.....TC
# Time difference: 0.12358500000000561
# -----------------------------------------
# Stage 4 finish. No. 613521, Info QoS Data, SN=1280, FN=0, Flags=.p.....TC
# Time difference: 0.16867399999999577
# -----------------------------------------
# Stage 5 finish. No. 613903, Info QoS Data, SN=1282, FN=0, Flags=.p.....TC
# Time difference: 0.04998399999999492
#
# What is this packet? Data Length = 173 No. 614718
# Time 104.814781 #Seq 1284 Info QoS Data, SN=1284, FN=0, Flags=.p.....TC
#
#
# No. 614718 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 614718, Info QoS Data, SN=1284, FN=0, Flags=.p.....TC
# Time difference: 0.1446159999999992
#
# What is this packet? Data Length = 189 No. 615533
# Time 105.01056 #Seq 1286 Info QoS Data, SN=1286, FN=0, Flags=.p.....TC
#
#
# No. 615533 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 615533, Info QoS Data, SN=1286, FN=0, Flags=.p.....TC
# Time difference: 0.1957790000000017
#
# What is this packet? Data Length = 173 No. 615880
# Time 105.159458 #Seq 1288 Info QoS Data, SN=1288, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 615880
# Time 105.159458 #Seq 1288 Info QoS Data, SN=1288, FN=0, Flags=.p.....TC
#
#
# No. 615880 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 615880, Info QoS Data, SN=1288, FN=0, Flags=.p.....TC
# Time difference: 0.14889800000000264
# -----------------------------------------
# Stage 9 finish. No. 616138, Info QoS Data, SN=1290, FN=0, Flags=.p.....TC
# Time difference: 0.03251400000000615
#
# What is this packet? Data Length = 173 No. 616402
# Time 105.285976 #Seq 1292 Info QoS Data, SN=1292, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 616402
# Time 105.285976 #Seq 1292 Info QoS Data, SN=1292, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 616402
# Time 105.285976 #Seq 1292 Info QoS Data, SN=1292, FN=0, Flags=.p.....TC
#
#
# No. 616402 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 616402, Info QoS Data, SN=1292, FN=0, Flags=.p.....TC
# Time difference: 0.0940039999999982
#
# -------- Test Round 6 --------
# -----------------------------------------
# Stage 1 finish. No. 707596, Info QoS Data, SN=1315, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 712067, Info QoS Data, SN=1324, FN=0, Flags=.p.....TC
# Time difference: 0.7835110000000043
# -----------------------------------------
# Stage 3 finish. No. 712610, Info QoS Data, SN=1326, FN=0, Flags=.p.....TC
# Time difference: 0.07603199999999788
# -----------------------------------------
# Stage 4 finish. No. 713415, Info QoS Data, SN=1328, FN=0, Flags=.p.....TC
# Time difference: 0.14233500000000276
# -----------------------------------------
# Stage 5 finish. No. 713658, Info QoS Data, SN=1330, FN=0, Flags=.p.....TC
# Time difference: 0.029646999999997092
#
# What is this packet? Data Length = 173 No. 714290
# Time 125.5306 #Seq 1332 Info QoS Data, SN=1332, FN=0, Flags=.p.....TC
#
#
# No. 714290 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 714290, Info QoS Data, SN=1332, FN=0, Flags=.p.....TC
# Time difference: 0.11840200000000323
#
# What is this packet? Data Length = 189 No. 715453
# Time 125.740205 #Seq 1335 Info QoS Data, SN=1335, FN=0, Flags=.p.....TC
#
#
# No. 715453 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 715453, Info QoS Data, SN=1335, FN=0, Flags=.p.....TC
# Time difference: 0.20960499999999627
#
# What is this packet? Data Length = 173 No. 716456
# Time 125.904319 #Seq 1337 Info QoS Data, SN=1337, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 716456
# Time 125.904319 #Seq 1337 Info QoS Data, SN=1337, FN=0, Flags=.p.....TC
#
#
# No. 716456 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 716456, Info QoS Data, SN=1337, FN=0, Flags=.p.....TC
# Time difference: 0.16411399999999787
# -----------------------------------------
# Stage 9 finish. No. 716995, Info QoS Data, SN=1339, FN=0, Flags=.p.....TC
# Time difference: 0.06038999999999817
#
# What is this packet? Data Length = 173 No. 717732
# Time 126.098543 #Seq 1341 Info QoS Data, SN=1341, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 717732
# Time 126.098543 #Seq 1341 Info QoS Data, SN=1341, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 717732
# Time 126.098543 #Seq 1341 Info QoS Data, SN=1341, FN=0, Flags=.p.....TC
#
#
# No. 717732 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 717732, Info QoS Data, SN=1341, FN=0, Flags=.p.....TC
# Time difference: 0.13383400000000734
#
# -------- Test Round 7 --------
# -----------------------------------------
# Stage 1 finish. No. 833176, Info QoS Data, SN=1364, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 838725, Info QoS Data, SN=1373, FN=0, Flags=.p.....TC
# Time difference: 0.9217680000000144
# -----------------------------------------
# Stage 3 finish. No. 839117, Info QoS Data, SN=1375, FN=0, Flags=.p.....TC
# Time difference: 0.06263200000000779
# -----------------------------------------
# Stage 4 finish. No. 840076, Info QoS Data, SN=1377, FN=0, Flags=.p.....TC
# Time difference: 0.14683799999997404
# -----------------------------------------
# Stage 5 finish. No. 840361, Info QoS Data, SN=1379, FN=0, Flags=.p.....TC
# Time difference: 0.047671000000008235
#
# What is this packet? Data Length = 173 No. 841096
# Time 146.669581 #Seq 1381 Info QoS Data, SN=1381, FN=0, Flags=.p.....TC
#
#
# No. 841096 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 841096, Info QoS Data, SN=1381, FN=0, Flags=.p.....TC
# Time difference: 0.1078899999999976
#
# What is this packet? Data Length = 189 No. 842264
# Time 146.848746 #Seq 1383 Info QoS Data, SN=1383, FN=0, Flags=.p.....TC
#
#
# No. 842264 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 842264, Info QoS Data, SN=1383, FN=0, Flags=.p.....TC
# Time difference: 0.1791650000000118
#
# What is this packet? Data Length = 173 No. 843027
# Time 146.973014 #Seq 1385 Info QoS Data, SN=1385, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 843027
# Time 146.973014 #Seq 1385 Info QoS Data, SN=1385, FN=0, Flags=.p.....TC
#
#
# No. 843027 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 843027, Info QoS Data, SN=1385, FN=0, Flags=.p.....TC
# Time difference: 0.12426800000000071
# -----------------------------------------
# Stage 9 finish. No. 843641, Info QoS Data, SN=1387, FN=0, Flags=.p.....TC
# Time difference: 0.08827199999998925
#
# What is this packet? Data Length = 173 No. 844609
# Time 147.229027 #Seq 1389 Info QoS Data, SN=1389, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 844609
# Time 147.229027 #Seq 1389 Info QoS Data, SN=1389, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 844609
# Time 147.229027 #Seq 1389 Info QoS Data, SN=1389, FN=0, Flags=.p.....TC
#
#
# No. 844609 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 844609, Info QoS Data, SN=1389, FN=0, Flags=.p.....TC
# Time difference: 0.16774100000000658
#
# -------- Test Round 8 --------
# -----------------------------------------
# Stage 1 finish. No. 956834, Info QoS Data, SN=1411, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 962997, Info QoS Data, SN=1421, FN=0, Flags=.p.....TC
# Time difference: 1.022184999999979
# -----------------------------------------
# Stage 3 finish. No. 963547, Info QoS Data, SN=1423, FN=0, Flags=.p.....TC
# Time difference: 0.09725600000001577
# -----------------------------------------
# Stage 4 finish. No. 965237, Info QoS Data, SN=1425, FN=0, Flags=.p.....TC
# Time difference: 0.3017729999999972
# -----------------------------------------
# Stage 5 finish. No. 965770, Info QoS Data, SN=1428, FN=0, Flags=.p.....TC
# Time difference: 0.08316999999999553
#
# What is this packet? Data Length = 173 No. 966344
# Time 167.889723 #Seq 1430 Info QoS Data, SN=1430, FN=0, Flags=.p.....TC
#
#
# No. 966344 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 966344, Info QoS Data, SN=1430, FN=0, Flags=.p.....TC
# Time difference: 0.07939500000000521
#
# What is this packet? Data Length = 189 No. 967618
# Time 168.0982 #Seq 1432 Info QoS Data, SN=1432, FN=0, Flags=.p.....TC
#
#
# No. 967618 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 967618, Info QoS Data, SN=1432, FN=0, Flags=.p.....TC
# Time difference: 0.2084769999999878
#
# What is this packet? Data Length = 173 No. 968487
# Time 168.257787 #Seq 1434 Info QoS Data, SN=1434, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 968487
# Time 168.257787 #Seq 1434 Info QoS Data, SN=1434, FN=0, Flags=.p.....TC
#
#
# No. 968487 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 968487, Info QoS Data, SN=1434, FN=0, Flags=.p.....TC
# Time difference: 0.15958700000001613
# -----------------------------------------
# Stage 9 finish. No. 969316, Info QoS Data, SN=1436, FN=0, Flags=.p.....TC
# Time difference: 0.14302599999999188
#
# What is this packet? Data Length = 173 No. 970047
# Time 168.520571 #Seq 1438 Info QoS Data, SN=1438, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 970047
# Time 168.520571 #Seq 1438 Info QoS Data, SN=1438, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 970047
# Time 168.520571 #Seq 1438 Info QoS Data, SN=1438, FN=0, Flags=.p.....TC
#
#
# No. 970047 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 970047, Info QoS Data, SN=1438, FN=0, Flags=.p.....TC
# Time difference: 0.11975799999999026
#
# -------- Test Round 9 --------
# -----------------------------------------
# Stage 1 finish. No. 1081778, Info QoS Data, SN=1460, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1087802, Info QoS Data, SN=1468, FN=0, Flags=.p.....TC
# Time difference: 0.9350470000000257
# -----------------------------------------
# Stage 3 finish. No. 1088155, Info QoS Data, SN=1470, FN=0, Flags=.p.....TC
# Time difference: 0.0689390000000003
# -----------------------------------------
# Stage 4 finish. No. 1089356, Info QoS Data, SN=1472, FN=0, Flags=.p.....TC
# Time difference: 0.17948199999997883
#
# What is this packet? Data Length = 189 No. 1089366
# Time 188.548794 #Seq 1472 Info QoS Data, SN=1472, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 189 No. 1089366
# Time 188.548794 #Seq 1472 Info QoS Data, SN=1472, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 189 No. 1089385
# Time 188.550144 #Seq 1472 Info QoS Data, SN=1472, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 189 No. 1089385
# Time 188.550144 #Seq 1472 Info QoS Data, SN=1472, FN=0, Flags=.p..R..TC
#
# -----------------------------------------
# Stage 5 finish. No. 1089965, Info QoS Data, SN=1474, FN=0, Flags=.p.....TC
# Time difference: 0.08663800000002198
#
# What is this packet? Data Length = 173 No. 1090403
# Time 188.704861 #Seq 1476 Info QoS Data, SN=1476, FN=0, Flags=.p.....TC
#
#
# No. 1090403 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1090403, Info QoS Data, SN=1476, FN=0, Flags=.p.....TC
# Time difference: 0.07010599999998135
#
# What is this packet? Data Length = 189 No. 1091545
# Time 188.885137 #Seq 1479 Info QoS Data, SN=1479, FN=0, Flags=.p.....TC
#
#
# No. 1091545 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1091545, Info QoS Data, SN=1479, FN=0, Flags=.p.....TC
# Time difference: 0.1802759999999921
#
# What is this packet? Data Length = 173 No. 1093095
# Time 189.110904 #Seq 1481 Info QoS Data, SN=1481, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1093095
# Time 189.110904 #Seq 1481 Info QoS Data, SN=1481, FN=0, Flags=.p.....TC
#
#
# No. 1093095 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1093095, Info QoS Data, SN=1481, FN=0, Flags=.p.....TC
# Time difference: 0.22576700000001892
# -----------------------------------------
# Stage 9 finish. No. 1094199, Info QoS Data, SN=1483, FN=0, Flags=.p.....TC
# Time difference: 0.18682999999998628
#
# What is this packet? Data Length = 173 No. 1096281
# Time 189.61528 #Seq 1486 Info QoS Data, SN=1486, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1096281
# Time 189.61528 #Seq 1486 Info QoS Data, SN=1486, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1096281
# Time 189.61528 #Seq 1486 Info QoS Data, SN=1486, FN=0, Flags=.p.....TC
#
#
# No. 1096281 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1096281, Info QoS Data, SN=1486, FN=0, Flags=.p.....TC
# Time difference: 0.3175460000000214
#
# -------- Test Round 10 --------
# -----------------------------------------
# Stage 1 finish. No. 1215267, Info QoS Data, SN=1508, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1219793, Info QoS Data, SN=1517, FN=0, Flags=.p.....TC
# Time difference: 0.7525779999999997
# -----------------------------------------
# Stage 3 finish. No. 1220554, Info QoS Data, SN=1519, FN=0, Flags=.p.....TC
# Time difference: 0.13616500000000542
# -----------------------------------------
# Stage 4 finish. No. 1221100, Info QoS Data, SN=1521, FN=0, Flags=.p.....TC
# Time difference: 0.09734100000000012
# -----------------------------------------
# Stage 5 finish. No. 1221338, Info QoS Data, SN=1523, FN=0, Flags=.p.....TC
# Time difference: 0.03235499999999547
#
# What is this packet? Data Length = 173 No. 1222029
# Time 209.80259 #Seq 1525 Info QoS Data, SN=1525, FN=0, Flags=.p.....TC
#
#
# No. 1222029 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1222029, Info QoS Data, SN=1525, FN=0, Flags=.p.....TC
# Time difference: 0.12256300000001374
#
# What is this packet? Data Length = 189 No. 1223219
# Time 209.981233 #Seq 1527 Info QoS Data, SN=1527, FN=0, Flags=.p.....TC
#
#
# No. 1223219 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1223219, Info QoS Data, SN=1527, FN=0, Flags=.p.....TC
# Time difference: 0.1786429999999939
#
# What is this packet? Data Length = 173 No. 1223997
# Time 210.124579 #Seq 1529 Info QoS Data, SN=1529, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1223997
# Time 210.124579 #Seq 1529 Info QoS Data, SN=1529, FN=0, Flags=.p.....TC
#
#
# No. 1223997 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1223997, Info QoS Data, SN=1529, FN=0, Flags=.p.....TC
# Time difference: 0.1433460000000082
# -----------------------------------------
# Stage 9 finish. No. 1224454, Info QoS Data, SN=1531, FN=0, Flags=.p.....TC
# Time difference: 0.07527999999999224
#
# What is this packet? Data Length = 173 No. 1225260
# Time 210.346435 #Seq 1533 Info QoS Data, SN=1533, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1225260
# Time 210.346435 #Seq 1533 Info QoS Data, SN=1533, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1225260
# Time 210.346435 #Seq 1533 Info QoS Data, SN=1533, FN=0, Flags=.p.....TC
#
#
# No. 1225260 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1225260, Info QoS Data, SN=1533, FN=0, Flags=.p.....TC
# Time difference: 0.14657600000001025
#
# -------- Test Round 11 --------
# -----------------------------------------
# Stage 1 finish. No. 1342647, Info QoS Data, SN=1556, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1351226, Info QoS Data, SN=1566, FN=0, Flags=.p.....TC
# Time difference: 1.3396710000000098
# -----------------------------------------
# Stage 3 finish. No. 1352560, Info QoS Data, SN=1568, FN=0, Flags=.p.....TC
# Time difference: 0.1825680000000034
#
# What is this packet? Data Length = 157 No. 1352565
# Time 230.873986 #Seq 1568 Info QoS Data, SN=1568, FN=0, Flags=.p..R..TC
#
# -----------------------------------------
# Stage 4 finish. No. 1353934, Info QoS Data, SN=1571, FN=0, Flags=.p.....TC
# Time difference: 0.21406099999998673
# -----------------------------------------
# Stage 5 finish. No. 1354587, Info QoS Data, SN=1573, FN=0, Flags=.p.....TC
# Time difference: 0.12776999999999816
#
# What is this packet? Data Length = 173 No. 1355613
# Time 231.376744 #Seq 1575 Info QoS Data, SN=1575, FN=0, Flags=.p.....TC
#
#
# No. 1355613 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1355613, Info QoS Data, SN=1575, FN=0, Flags=.p.....TC
# Time difference: 0.16313800000000356
#
# What is this packet? Data Length = 189 No. 1357339
# Time 231.619745 #Seq 1577 Info QoS Data, SN=1577, FN=0, Flags=.p.....TC
#
#
# No. 1357339 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1357339, Info QoS Data, SN=1577, FN=0, Flags=.p.....TC
# Time difference: 0.24300099999999247
#
# What is this packet? Data Length = 173 No. 1358107
# Time 231.751952 #Seq 1579 Info QoS Data, SN=1579, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1358107
# Time 231.751952 #Seq 1579 Info QoS Data, SN=1579, FN=0, Flags=.p.....TC
#
#
# No. 1358107 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1358107, Info QoS Data, SN=1579, FN=0, Flags=.p.....TC
# Time difference: 0.13220699999999397
# -----------------------------------------
# Stage 9 finish. No. 1358700, Info QoS Data, SN=1581, FN=0, Flags=.p.....TC
# Time difference: 0.08870200000001205
#
# What is this packet? Data Length = 173 No. 1359570
# Time 231.983766 #Seq 1583 Info QoS Data, SN=1583, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1359570
# Time 231.983766 #Seq 1583 Info QoS Data, SN=1583, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1359570
# Time 231.983766 #Seq 1583 Info QoS Data, SN=1583, FN=0, Flags=.p.....TC
#
#
# No. 1359570 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1359570, Info QoS Data, SN=1583, FN=0, Flags=.p.....TC
# Time difference: 0.14311200000000213
#
# -------- Test Round 12 --------
# -----------------------------------------
# Stage 1 finish. No. 1480371, Info QoS Data, SN=1605, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1486224, Info QoS Data, SN=1615, FN=0, Flags=.p.....TC
# Time difference: 0.8580809999999985
# -----------------------------------------
# Stage 3 finish. No. 1486736, Info QoS Data, SN=1617, FN=0, Flags=.p.....TC
# Time difference: 0.07339500000000498
# -----------------------------------------
# Stage 4 finish. No. 1487847, Info QoS Data, SN=1619, FN=0, Flags=.p.....TC
# Time difference: 0.17198600000000397
# -----------------------------------------
# Stage 5 finish. No. 1488310, Info QoS Data, SN=1621, FN=0, Flags=.p.....TC
# Time difference: 0.07041399999999953
# -----------------------------------------
# Stage 6 finish. No. 1488692, Info Packet Loss
# Time difference: 0.07187099999998736
#
# What is this packet? Data Length = 189 No. 1490408
# Time 252.787349 #Seq 1625 Info QoS Data, SN=1625, FN=0, Flags=.p.....TC
#
#
# No. 1490408 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1490408, Info QoS Data, SN=1625, FN=0, Flags=.p.....TC
# Time difference: 0.2558390000000088
#
# What is this packet? Data Length = 173 No. 1491805
# Time 253.018852 #Seq 1627 Info QoS Data, SN=1627, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1491805
# Time 253.018852 #Seq 1627 Info QoS Data, SN=1627, FN=0, Flags=.p.....TC
#
#
# No. 1491805 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1491805, Info QoS Data, SN=1627, FN=0, Flags=.p.....TC
# Time difference: 0.23150300000000357
# -----------------------------------------
# Stage 9 finish. No. 1492157, Info QoS Data, SN=1629, FN=0, Flags=.p.....TC
# Time difference: 0.06586299999997891
#
# What is this packet? Data Length = 173 No. 1493259
# Time 253.23299 #Seq 1631 Info QoS Data, SN=1631, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1493259
# Time 253.23299 #Seq 1631 Info QoS Data, SN=1631, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1493259
# Time 253.23299 #Seq 1631 Info QoS Data, SN=1631, FN=0, Flags=.p.....TC
#
#
# No. 1493259 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1493259, Info QoS Data, SN=1631, FN=0, Flags=.p.....TC
# Time difference: 0.14827500000001237
#
# -------- Test Round 13 --------
# -----------------------------------------
# Stage 1 finish. No. 1613081, Info QoS Data, SN=1654, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1618156, Info QoS Data, SN=1663, FN=0, Flags=.p.....TC
# Time difference: 0.8413199999999961
# -----------------------------------------
# Stage 3 finish. No. 1618753, Info QoS Data, SN=1665, FN=0, Flags=.p.....TC
# Time difference: 0.08299500000003945
# -----------------------------------------
# Stage 4 finish. No. 1619379, Info QoS Data, SN=1667, FN=0, Flags=.p.....TC
# Time difference: 0.0952649999999835
# -----------------------------------------
# Stage 5 finish. No. 1619965, Info QoS Data, SN=1669, FN=0, Flags=.p.....TC
# Time difference: 0.08976100000000997
#
# What is this packet? Data Length = 173 No. 1620692
# Time 273.788222 #Seq 1671 Info QoS Data, SN=1671, FN=0, Flags=.p.....TC
#
#
# No. 1620692 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1620692, Info QoS Data, SN=1671, FN=0, Flags=.p.....TC
# Time difference: 0.12063200000000052
#
# What is this packet? Data Length = 189 No. 1621925
# Time 273.988187 #Seq 1673 Info QoS Data, SN=1673, FN=0, Flags=.p.....TC
#
#
# No. 1621925 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1621925, Info QoS Data, SN=1673, FN=0, Flags=.p.....TC
# Time difference: 0.1999649999999633
#
# What is this packet? Data Length = 173 No. 1622786
# Time 274.11764 #Seq 1675 Info QoS Data, SN=1675, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1622786
# Time 274.11764 #Seq 1675 Info QoS Data, SN=1675, FN=0, Flags=.p.....TC
#
#
# No. 1622786 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1622786, Info QoS Data, SN=1675, FN=0, Flags=.p.....TC
# Time difference: 0.12945300000001225
# -----------------------------------------
# Stage 9 finish. No. 1623511, Info QoS Data, SN=1677, FN=0, Flags=.p.....TC
# Time difference: 0.11856199999999717
#
# What is this packet? Data Length = 173 No. 1624388
# Time 274.376054 #Seq 1679 Info QoS Data, SN=1679, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1624388
# Time 274.376054 #Seq 1679 Info QoS Data, SN=1679, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1624388
# Time 274.376054 #Seq 1679 Info QoS Data, SN=1679, FN=0, Flags=.p.....TC
#
#
# No. 1624388 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1624388, Info QoS Data, SN=1679, FN=0, Flags=.p.....TC
# Time difference: 0.13985200000001896
#
# -------- Test Round 14 --------
# -----------------------------------------
# Stage 1 finish. No. 1726408, Info QoS Data, SN=1701, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1731756, Info QoS Data, SN=1710, FN=0, Flags=.p.....TC
# Time difference: 0.9067410000000109
# -----------------------------------------
# Stage 3 finish. No. 1732947, Info QoS Data, SN=1712, FN=0, Flags=.p.....TC
# Time difference: 0.20305400000000873
# -----------------------------------------
# Stage 4 finish. No. 1733523, Info QoS Data, SN=1714, FN=0, Flags=.p.....TC
# Time difference: 0.08936699999998154
# -----------------------------------------
# Stage 5 finish. No. 1733679, Info QoS Data, SN=1716, FN=0, Flags=.p.....TC
# Time difference: 0.025504000000012184
#
# What is this packet? Data Length = 173 No. 1734452
# Time 294.690428 #Seq 1718 Info QoS Data, SN=1718, FN=0, Flags=.p.....TC
#
#
# No. 1734452 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1734452, Info QoS Data, SN=1718, FN=0, Flags=.p.....TC
# Time difference: 0.11931199999997943
#
# What is this packet? Data Length = 189 No. 1735573
# Time 294.908843 #Seq 1721 Info QoS Data, SN=1721, FN=0, Flags=.p.....TC
#
#
# No. 1735573 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1735573, Info QoS Data, SN=1721, FN=0, Flags=.p.....TC
# Time difference: 0.21841499999999314
#
# What is this packet? Data Length = 173 No. 1736350
# Time 295.026352 #Seq 1723 Info QoS Data, SN=1723, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1736350
# Time 295.026352 #Seq 1723 Info QoS Data, SN=1723, FN=0, Flags=.p.....TC
#
#
# No. 1736350 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1736350, Info QoS Data, SN=1723, FN=0, Flags=.p.....TC
# Time difference: 0.1175089999999841
# -----------------------------------------
# Stage 9 finish. No. 1736599, Info QoS Data, SN=1725, FN=0, Flags=.p.....TC
# Time difference: 0.07575200000002269
#
# What is this packet? Data Length = 173 No. 1737391
# Time 295.220829 #Seq 1727 Info QoS Data, SN=1727, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1737391
# Time 295.220829 #Seq 1727 Info QoS Data, SN=1727, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1737391
# Time 295.220829 #Seq 1727 Info QoS Data, SN=1727, FN=0, Flags=.p.....TC
#
#
# No. 1737391 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1737391, Info QoS Data, SN=1727, FN=0, Flags=.p.....TC
# Time difference: 0.11872499999998354
#
# -------- Test Round 15 --------
# -----------------------------------------
# Stage 1 finish. No. 1822569, Info QoS Data, SN=1749, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1825183, Info QoS Data, SN=1758, FN=0, Flags=.p.....TC
# Time difference: 0.7231259999999793
# -----------------------------------------
# Stage 3 finish. No. 1825350, Info QoS Data, SN=1760, FN=0, Flags=.p.....TC
# Time difference: 0.04149200000000519
# -----------------------------------------
# Stage 4 finish. No. 1825917, Info QoS Data, SN=1762, FN=0, Flags=.p.....TC
# Time difference: 0.13787200000001576
# -----------------------------------------
# Stage 5 finish. No. 1826001, Info QoS Data, SN=1764, FN=0, Flags=.p.....TC
# Time difference: 0.023103999999989355
#
# What is this packet? Data Length = 173 No. 1826450
# Time 315.036702 #Seq 1766 Info QoS Data, SN=1766, FN=0, Flags=.p.....TC
#
#
# No. 1826450 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1826450, Info QoS Data, SN=1766, FN=0, Flags=.p.....TC
# Time difference: 0.09048699999999599
#
# What is this packet? Data Length = 189 No. 1827199
# Time 315.216959 #Seq 1768 Info QoS Data, SN=1768, FN=0, Flags=.p.....TC
#
#
# No. 1827199 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1827199, Info QoS Data, SN=1768, FN=0, Flags=.p.....TC
# Time difference: 0.18025699999998324
#
# What is this packet? Data Length = 173 No. 1827765
# Time 315.373739 #Seq 1770 Info QoS Data, SN=1770, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1827765
# Time 315.373739 #Seq 1770 Info QoS Data, SN=1770, FN=0, Flags=.p.....TC
#
#
# No. 1827765 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1827765, Info QoS Data, SN=1770, FN=0, Flags=.p.....TC
# Time difference: 0.15678000000002612
# -----------------------------------------
# Stage 9 finish. No. 1828156, Info QoS Data, SN=1772, FN=0, Flags=.p.....TC
# Time difference: 0.06873400000000629
#
# What is this packet? Data Length = 173 No. 1828556
# Time 315.540246 #Seq 1774 Info QoS Data, SN=1774, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1828556
# Time 315.540246 #Seq 1774 Info QoS Data, SN=1774, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1828556
# Time 315.540246 #Seq 1774 Info QoS Data, SN=1774, FN=0, Flags=.p.....TC
#
#
# No. 1828556 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1828556, Info QoS Data, SN=1774, FN=0, Flags=.p.....TC
# Time difference: 0.09777300000001787
#
# -------- Test Round 16 --------
# -----------------------------------------
# Stage 1 finish. No. 1893583, Info QoS Data, SN=1796, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1897427, Info QoS Data, SN=1805, FN=0, Flags=.p.....TC
# Time difference: 1.3316130000000044
# -----------------------------------------
# Stage 3 finish. No. 1897974, Info QoS Data, SN=1807, FN=0, Flags=.p.....TC
# Time difference: 0.2303810000000226
# -----------------------------------------
# Stage 4 finish. No. 1898995, Info QoS Data, SN=1810, FN=0, Flags=.p.....TC
# Time difference: 0.32421099999999115
# -----------------------------------------
# Stage 5 finish. No. 1899790, Info QoS Data, SN=1812, FN=0, Flags=.p.....TC
# Time difference: 0.2435989999999606
#
# What is this packet? Data Length = 173 No. 1900969
# Time 336.662252 #Seq 1814 Info QoS Data, SN=1814, FN=0, Flags=.p.....TC
#
#
# No. 1900969 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1900969, Info QoS Data, SN=1814, FN=0, Flags=.p.....TC
# Time difference: 0.3452850000000467
#
# What is this packet? Data Length = 189 No. 1901570
# Time 336.877761 #Seq 1816 Info QoS Data, SN=1816, FN=0, Flags=.p.....TC
#
#
# No. 1901570 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1901570, Info QoS Data, SN=1816, FN=0, Flags=.p.....TC
# Time difference: 0.21550899999999729
#
# What is this packet? Data Length = 173 No. 1902125
# Time 337.040618 #Seq 1818 Info QoS Data, SN=1818, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1902125
# Time 337.040618 #Seq 1818 Info QoS Data, SN=1818, FN=0, Flags=.p.....TC
#
#
# No. 1902125 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1902125, Info QoS Data, SN=1818, FN=0, Flags=.p.....TC
# Time difference: 0.16285699999997405
# -----------------------------------------
# Stage 9 finish. No. 1902555, Info QoS Data, SN=1820, FN=0, Flags=.p.....TC
# Time difference: 0.13744600000001128
#
# What is this packet? Data Length = 173 No. 1903042
# Time 337.308124 #Seq 1822 Info QoS Data, SN=1822, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1903042
# Time 337.308124 #Seq 1822 Info QoS Data, SN=1822, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1903042
# Time 337.308124 #Seq 1822 Info QoS Data, SN=1822, FN=0, Flags=.p.....TC
#
#
# No. 1903042 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1903042, Info QoS Data, SN=1822, FN=0, Flags=.p.....TC
# Time difference: 0.1300600000000145
#
# -------- Test Round 17 --------
# -----------------------------------------
# Stage 1 finish. No. 1966642, Info QoS Data, SN=1845, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1969749, Info QoS Data, SN=1853, FN=0, Flags=.p.....TC
# Time difference: 0.9360980000000154
# -----------------------------------------
# Stage 3 finish. No. 1969993, Info QoS Data, SN=1855, FN=0, Flags=.p.....TC
# Time difference: 0.07377300000001696
# -----------------------------------------
# Stage 4 finish. No. 1970261, Info QoS Data, SN=1857, FN=0, Flags=.p.....TC
# Time difference: 0.10985799999997425
# -----------------------------------------
# Stage 5 finish. No. 1970608, Info QoS Data, SN=1859, FN=0, Flags=.p.....TC
# Time difference: 0.11160200000000486
#
# What is this packet? Data Length = 173 No. 1971233
# Time 357.928233 #Seq 1861 Info QoS Data, SN=1861, FN=0, Flags=.p.....TC
#
#
# No. 1971233 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1971233, Info QoS Data, SN=1861, FN=0, Flags=.p.....TC
# Time difference: 0.18028199999997696
#
# What is this packet? Data Length = 189 No. 1971752
# Time 358.099185 #Seq 1864 Info QoS Data, SN=1864, FN=0, Flags=.p.....TC
#
#
# No. 1971752 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1971752, Info QoS Data, SN=1864, FN=0, Flags=.p.....TC
# Time difference: 0.17095199999999977
#
# What is this packet? Data Length = 173 No. 1972081
# Time 358.187433 #Seq 1866 Info QoS Data, SN=1866, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1972081
# Time 358.187433 #Seq 1866 Info QoS Data, SN=1866, FN=0, Flags=.p.....TC
#
#
# No. 1972081 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1972081, Info QoS Data, SN=1866, FN=0, Flags=.p.....TC
# Time difference: 0.08824800000002142
# -----------------------------------------
# Stage 9 finish. No. 1972410, Info QoS Data, SN=1868, FN=0, Flags=.p.....TC
# Time difference: 0.10797300000001542
#
# What is this packet? Data Length = 173 No. 1972763
# Time 358.410102 #Seq 1870 Info QoS Data, SN=1870, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1972763
# Time 358.410102 #Seq 1870 Info QoS Data, SN=1870, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1972763
# Time 358.410102 #Seq 1870 Info QoS Data, SN=1870, FN=0, Flags=.p.....TC
#
#
# No. 1972763 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1972763, Info QoS Data, SN=1870, FN=0, Flags=.p.....TC
# Time difference: 0.11469599999998081
#
# -------- Test Round 18 --------
# -----------------------------------------
# Stage 1 finish. No. 2031006, Info QoS Data, SN=1892, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2034270, Info QoS Data, SN=1901, FN=0, Flags=.p.....TC
# Time difference: 0.8557619999999702
# -----------------------------------------
# Stage 3 finish. No. 2034670, Info QoS Data, SN=1903, FN=0, Flags=.p.....TC
# Time difference: 0.059512000000040643
# -----------------------------------------
# Stage 4 finish. No. 2035151, Info QoS Data, SN=1905, FN=0, Flags=.p.....TC
# Time difference: 0.09162799999995741
# -----------------------------------------
# Stage 5 finish. No. 2035639, Info QoS Data, SN=1907, FN=0, Flags=.p.....TC
# Time difference: 0.07136300000001938
#
# What is this packet? Data Length = 173 No. 2036006
# Time 378.37709 #Seq 1909 Info QoS Data, SN=1909, FN=0, Flags=.p.....TC
#
#
# No. 2036006 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2036006, Info QoS Data, SN=1909, FN=0, Flags=.p.....TC
# Time difference: 0.07431600000001026
#
# What is this packet? Data Length = 189 No. 2037201
# Time 378.55851 #Seq 1911 Info QoS Data, SN=1911, FN=0, Flags=.p.....TC
#
#
# No. 2037201 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2037201, Info QoS Data, SN=1911, FN=0, Flags=.p.....TC
# Time difference: 0.1814200000000028
#
# What is this packet? Data Length = 173 No. 2039067
# Time 378.92013 #Seq 1914 Info QoS Data, SN=1914, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2039067
# Time 378.92013 #Seq 1914 Info QoS Data, SN=1914, FN=0, Flags=.p.....TC
#
#
# No. 2039067 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2039067, Info QoS Data, SN=1914, FN=0, Flags=.p.....TC
# Time difference: 0.3616199999999594
# -----------------------------------------
# Stage 9 finish. No. 2039346, Info QoS Data, SN=1916, FN=0, Flags=.p.....TC
# Time difference: 0.06121900000005098
#
# What is this packet? Data Length = 173 No. 2039671
# Time 379.11291 #Seq 1918 Info QoS Data, SN=1918, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2039671
# Time 379.11291 #Seq 1918 Info QoS Data, SN=1918, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2039671
# Time 379.11291 #Seq 1918 Info QoS Data, SN=1918, FN=0, Flags=.p.....TC
#
#
# No. 2039671 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2039671, Info QoS Data, SN=1918, FN=0, Flags=.p.....TC
# Time difference: 0.1315609999999765
#
# -------- Test Round 19 --------
# -----------------------------------------
# Stage 1 finish. No. 2112353, Info QoS Data, SN=1940, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2115745, Info QoS Data, SN=1949, FN=0, Flags=.p.....TC
# Time difference: 0.7532540000000267
# -----------------------------------------
# Stage 3 finish. No. 2116229, Info QoS Data, SN=1951, FN=0, Flags=.p.....TC
# Time difference: 0.0958439999999996
# -----------------------------------------
# Stage 4 finish. No. 2116777, Info QoS Data, SN=1953, FN=0, Flags=.p.....TC
# Time difference: 0.10142400000000862
# -----------------------------------------
# Stage 5 finish. No. 2117076, Info QoS Data, SN=1955, FN=0, Flags=.p.....TC
# Time difference: 0.042239999999992506
#
# What is this packet? Data Length = 173 No. 2118117
# Time 399.057199 #Seq 1958 Info QoS Data, SN=1958, FN=0, Flags=.p.....TC
#
#
# No. 2118117 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2118117, Info QoS Data, SN=1958, FN=0, Flags=.p.....TC
# Time difference: 0.17402800000002117
#
# What is this packet? Data Length = 189 No. 2119282
# Time 399.291459 #Seq 1961 Info QoS Data, SN=1961, FN=0, Flags=.p.....TC
#
#
# No. 2119282 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2119282, Info QoS Data, SN=1961, FN=0, Flags=.p.....TC
# Time difference: 0.2342599999999493
#
# What is this packet? Data Length = 173 No. 2120333
# Time 399.444596 #Seq 1963 Info QoS Data, SN=1963, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2120333
# Time 399.444596 #Seq 1963 Info QoS Data, SN=1963, FN=0, Flags=.p.....TC
#
#
# No. 2120333 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2120333, Info QoS Data, SN=1963, FN=0, Flags=.p.....TC
# Time difference: 0.15313700000001518
# -----------------------------------------
# Stage 9 finish. No. 2120669, Info QoS Data, SN=1965, FN=0, Flags=.p.....TC
# Time difference: 0.06530700000001843
#
# What is this packet? Data Length = 173 No. 2122982
# Time 399.852115 #Seq 1968 Info QoS Data, SN=1968, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2122982
# Time 399.852115 #Seq 1968 Info QoS Data, SN=1968, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2122982
# Time 399.852115 #Seq 1968 Info QoS Data, SN=1968, FN=0, Flags=.p.....TC
#
#
# No. 2122982 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2122982, Info QoS Data, SN=1968, FN=0, Flags=.p.....TC
# Time difference: 0.3422120000000177
#
# -------- Test Round 20 --------
# -----------------------------------------
# Stage 1 finish. No. 2242539, Info QoS Data, SN=1991, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2248343, Info QoS Data, SN=2000, FN=0, Flags=.p.....TC
# Time difference: 0.9092679999999973
# -----------------------------------------
# Stage 3 finish. No. 2248896, Info QoS Data, SN=2002, FN=0, Flags=.p.....TC
# Time difference: 0.08069399999999405
# -----------------------------------------
# Stage 4 finish. No. 2249557, Info QoS Data, SN=2004, FN=0, Flags=.p.....TC
# Time difference: 0.09340500000001839
# -----------------------------------------
# Stage 5 finish. No. 2250172, Info QoS Data, SN=2006, FN=0, Flags=.p.....TC
# Time difference: 0.0982909999999606
#
# What is this packet? Data Length = 173 No. 2250710
# Time 420.54951 #Seq 2008 Info QoS Data, SN=2008, FN=0, Flags=.p.....TC
#
#
# No. 2250710 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2250710, Info QoS Data, SN=2008, FN=0, Flags=.p.....TC
# Time difference: 0.08095500000001721
#
# What is this packet? Data Length = 189 No. 2252164
# Time 420.766599 #Seq 2010 Info QoS Data, SN=2010, FN=0, Flags=.p.....TC
#
#
# No. 2252164 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2252164, Info QoS Data, SN=2010, FN=0, Flags=.p.....TC
# Time difference: 0.2170889999999872
#
# What is this packet? Data Length = 173 No. 2253387
# Time 420.989488 #Seq 2012 Info QoS Data, SN=2012, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2253387
# Time 420.989488 #Seq 2012 Info QoS Data, SN=2012, FN=0, Flags=.p.....TC
#
#
# No. 2253387 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2253387, Info QoS Data, SN=2012, FN=0, Flags=.p.....TC
# Time difference: 0.22288900000000922
# -----------------------------------------
# Stage 9 finish. No. 2254233, Info QoS Data, SN=2014, FN=0, Flags=.p.....TC
# Time difference: 0.12264900000002399
#
# What is this packet? Data Length = 173 No. 2255134
# Time 421.254064 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2255134
# Time 421.254064 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2255134
# Time 421.254064 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
#
#
# No. 2255134 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2255134, Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
# Time difference: 0.14192700000000968

# %%
#for debug
print(str(len(secc_send_time_anchor)) + '\n')
for i in range(0, len(secc_send_time_anchor)):
    print(str(i) + ": " + str(len(secc_send_time_anchor[i])))
# Out:
# 20
#
# 0: 10
# 1: 10
# 2: 10
# 3: 10
# 4: 10
# 5: 10
# 6: 10
# 7: 10
# 8: 10
# 9: 10
# 10: 10
# 11: 10
# 12: 10
# 13: 10
# 14: 10
# 15: 10
# 16: 10
# 17: 10
# 18: 10
# 19: 10

# %%
#for debug
for i in range(0, len(secc_send_time_anchor)):
    print(secc_send_time_anchor[i][len(secc_send_time_anchor[i])-1]-secc_send_time_anchor[i][0])
# Out:
# 1.9546740000000007
# 1.9120050000000006
# 2.5927639999999954
# 2.2263109999999955
# 1.995701000000011
# 1.717870000000005
# 1.8462450000000104
# 2.214626999999979
# 2.250631000000027
# 1.684847000000019
# 2.6342300000000023
# 1.947226999999998
# 1.8178050000000212
# 1.8743789999999763
# 1.519625000000019
# 3.1209610000000225
# 1.8934820000000059
# 1.8884009999999876
# 1.9617060000000492
# 1.9671670000000177

# %%
#BLOCK ACK processing
#Time evcc sends blockACK after secc send
evcc_blockAck_time_anchor = []

blockack_index = 0
for i in range(0, len(secc_send_time_anchor)):
    evcc_blockAck_time_anchor_in_each_round = []
    
    for j in range(0, len(secc_send_time_anchor[i])):
        while(timelist_block_ack[blockack_index] < secc_send_time_anchor[i][j]):
            blockack_index = blockack_index + 1
        evcc_blockAck_time_anchor_in_each_round.append(timelist_block_ack[blockack_index])
        #print("ACK time difference = " + str(
        #timelist_block_ack[blockack_index] - secc_send_time_anchor[i][j]))
    
    evcc_blockAck_time_anchor.append(evcc_blockAck_time_anchor_in_each_round)

# %%
#SECC Packet Loss dict & Block Ack Loss
#secc_packet_loss_dict[i] = {stageNum}
# i = 5, j = 0 is packet loss of evcc BLOCK ACK
# i = 3, j = 9 is packet loss of evcc BLOCK ACK
secc_packet_loss_dict = {}
#secc_packet_loss_dict[6] = {8, 9}

#Block ack loss
secc_packet_loss_dict[11] = {0}
secc_packet_loss_dict[4] = {0}


#for i in secc_packet_loss_dict.get(5): print(i)
#7 in secc_packet_loss_dict.get(5)

# %%
#Calculate the avg. block ack latency
sum_latency = 0
cnt = 0
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) == None):
            sum_latency = sum_latency + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
            cnt = cnt + 1
        elif(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)): continue
            else:
                sum_latency = sum_latency + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
                cnt = cnt + 1
        else: continue
avg_blockAck_latency = sum_latency/cnt
print("Avg Block Ack latency = " + str(avg_blockAck_latency) + " s")
print(cnt)
# Out:
# Avg Block Ack latency = 0.03628645959595716 s
# 198

# %%
#For curiousity
#Calculate the avg. block ack latency of the appending packet loss packets
sum_latency_2 = 0
cnt = 0
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)):
                sum_latency_2 = sum_latency_2 + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
                cnt = cnt + 1
        else: continue
avg_blockAck_latency_2 = sum_latency_2/cnt
print("Avg Block Ack latency = " + str(avg_blockAck_latency_2) + " s")
print(cnt)
# Out:
# Avg Block Ack latency = 0.1315425000000019 s
# 2

# %%
#For debug. Can see testing round 6 (i = 5) has longer block ack latency due to packet loss.
# I only append the secc send time, but didn't append the block time.
from statistics import mean

for i in range(0, len(evcc_blockAck_time_anchor)):
    print("i = " + str(i) + ": " + str(mean(evcc_blockAck_time_anchor[i])-mean(secc_send_time_anchor[i])))
# Out:
# i = 0: 0.023469999999999658
# i = 1: 0.0527233000000038
# i = 2: 0.05302950000000095
# i = 3: 0.03626629999999409
# i = 4: 0.0375230000000073
# i = 5: 0.01972959999999091
# i = 6: 0.019822400000009566
# i = 7: 0.029884399999986044
# i = 8: 0.05256199999999467
# i = 9: 0.02400739999998791
# i = 10: 0.061985399999997526
# i = 11: 0.05328860000000191
# i = 12: 0.03141099999999142
# i = 13: 0.02223670000000766
# i = 14: 0.015627700000038658
# i = 15: 0.08445879999999306
# i = 16: 0.037311799999997675
# i = 17: 0.022336300000006304
# i = 18: 0.036431499999991956
# i = 19: 0.03067470000002004

# %%
#Use the avg. block ack latency for the lost secc sent packets
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)):
                evcc_blockAck_time_anchor[i][j] = secc_send_time_anchor[i][j] + avg_blockAck_latency
                print("i = " + str(i))
                print("j = " + str(j))
        else: continue
# Out:
# i = 4
# j = 0
# i = 11
# j = 0

# %%
#for debug check wierd value
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_send_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))
        if(evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))

# %%
#For debug
i = 4
for j in [0]:
    print("Stage " + str(j+1))
    print(evcc_send_time_anchor[i][j])
    print(secc_send_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j]-evcc_send_time_anchor[i][j])
# Out:
# Stage 1
# 103.184431
# 103.290275
# 103.32656145959595
# 0.14213045959594695

# %%
path = 'time_record/max_VI_80211.txt'
f = open(path, 'w')
for i in range(0, len(evcc_send_time_anchor)):
    for j in range(0, len(evcc_send_time_anchor[i])):
        print((evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j])*1000, file=f, end="")
        f.writelines('\t')
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][len(evcc_blockAck_time_anchor[i])-1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    f.writelines('20')
    f.writelines('\t')
    f.writelines('0')
    f.writelines('\t')
    f.writelines('\n')
f.close()

# %%
#如果 TCP 有 retransmission，在 Data Link Layer seq 會往下傳送，很難抓取
