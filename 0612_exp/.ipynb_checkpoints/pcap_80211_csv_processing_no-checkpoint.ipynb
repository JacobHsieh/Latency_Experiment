# %%
#Processing evcc block ack
import csv
import numpy as np

with open('csv/DataLink/no_interf/evcc_blockack_no_interf.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    startint_seq_num_block_ack = []
    timelist_block_ack = []
    
    for row in rows:
        startint_seq_num_block_ack.append(int(row['Starting Sequence Number']))
        timelist_block_ack.append(float(row['Time']))

# %%
#for debug
if(len(startint_seq_num_block_ack) != len(timelist_block_ack)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_block_ack))
# Out:
# 1472

# %%
#Processing evcc send
with open('csv/DataLink/no_interf/evcc_send_no_interf.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_evcc_send = []
    seq_num_evcc_send = []
    data_length_evcc_send = []
    info_evcc_send = []
    frame_num_evcc_send = []
    
    for row in rows:
        timelist_evcc_send.append(float(row['Time']))
        seq_num_evcc_send.append(int(row['Sequence number']))
        data_length_evcc_send.append(int(row['Data Length']))
        info_evcc_send.append(str(row['Info']))
        frame_num_evcc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_evcc_send) != len(seq_num_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(data_length_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(info_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(frame_num_evcc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send))
# Out:
# 1194

# %%
timelist_evcc_send_split = []
seq_num_evcc_send_split = []
data_length_evcc_send_split = []
info_evcc_send_split = []
frame_num_evcc_send_split = []

round_start_point = 0
round_end_point = 0

sdpreq_index_list = []
#Fetch first packet index of data length = 74 (SDP request) in each round
for i in range(0, len(data_length_evcc_send)):
    if(i == 0 and data_length_evcc_send[i] == 74):
        sdpreq_index_list.append(i)
    if(i > 0 and data_length_evcc_send[i] == 74 and data_length_evcc_send[i-1] != 74):
        sdpreq_index_list.append(i)
sdpreq_index_list.append(len(data_length_evcc_send)) #Add the end of list index

for i in range(0, len(sdpreq_index_list)-1):
    timelist_evcc_send_split.append([timelist_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    seq_num_evcc_send_split.append([seq_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    data_length_evcc_send_split.append([data_length_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    info_evcc_send_split.append([info_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    frame_num_evcc_send_split.append([frame_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])

# %%
#for debug
if(len(timelist_evcc_send_split) != len(seq_num_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(data_length_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(info_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(frame_num_evcc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_evcc_send_split)):
    print(timelist_evcc_send_split[i][0]-timelist_evcc_send_split[i-1][0])
# Out:
# 19.495452000000004
# 19.327887999999994
# 19.398499000000008
# 19.317899999999995
# 19.464499000000004
# 19.032795000000007
# 19.199557999999996
# 19.316410999999988
# 19.353589
# 19.046269999999993
# 19.356486000000018
# 21.298900999999972
# 20.784387000000038
# 19.558335
# 19.660617000000002
# 19.148727000000008
# 19.558574999999962
# 19.250916000000018
# 19.14871599999998

# %%
#Set evcc time anchor in each round per stage
evcc_send_time_anchor = []
#data_length_in_each_stage = [74, 96, 189, 173, 173, 173, 185, 461, 189, 173]
wierd_packet = {}
packet_loss_testing_round_7_flag = False
packet_loss_testing_round_7_flag_2 = False
packet_loss_testing_round_10_flag = False
packet_loss_testing_round_11_flag = False
packet_loss_testing_round_14_flag = False
packet_loss_testing_round_14_flag_2 = False
packet_loss_testing_round_16_flag = False

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(evcc_send_time_anchor_each_round):
    print("Time difference: " + str(evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-1]-
                          evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        return True
    else:
        #debug
        print("\nFalse")
        print("Stage Num = " + str(stageNum))
        print("Valid Stage Num = " + str(valid_stageNum))
        print("What is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet.get(frameNum) != None):
        del wierd_packet[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_evcc_send_split)):
#for i in [7]:
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    evcc_send_time_anchor_each_round = [timelist_evcc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_evcc_send_split[i][0], info_evcc_send_split[i][0])
    stageNum = stageNum + 1
    
    for j in range(1, len(data_length_evcc_send_split[i])):
        
        #Deal with packet loss......
        if(i == 10 and packet_loss_testing_round_10_flag == False):
            evcc_send_time_anchor_each_round.append(218.03635)
            printinfo(stageNum, 35361, "Packet Loss")
            print_time_difference(evcc_send_time_anchor_each_round)
            stageNum = stageNum + 1
            packet_loss_testing_round_10_flag = True
            
        #Deal with packet loss......
        if(i == 14 and packet_loss_testing_round_14_flag == False):
            evcc_send_time_anchor_each_round.append(299.133926)
            printinfo(stageNum, 47530, "Packet Loss")
            print_time_difference(evcc_send_time_anchor_each_round)
            stageNum = stageNum + 1
            packet_loss_testing_round_14_flag = True
                    
        #Stage 2
        if(data_length_evcc_send_split[i][j] == 96 and data_length_evcc_send_split[i][j-1] != 96):
            if(checkstage_num(stageNum, 2, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 11 and packet_loss_testing_round_11_flag == False):
                    evcc_send_time_anchor_each_round.append(237.824066)
                    printinfo(stageNum, 38538, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_11_flag = True
                
                continue
                
        #Stage 3
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 3, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 4 
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            #if(info_evcc_send_split[i][j][-2:] == 'TC'):
            if(checkstage_num(stageNum, 4, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
            '''
            else: print("Stage " + str(stageNum) +
                        ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                        ", Data length " + str(data_length_evcc_send_split[i][j]) +
                        ", Info " + str(info_evcc_send_split[i][j]))
            '''
            
        #Stage 5, tricky
        if(data_length_evcc_send_split[i][j] == 173):    
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
            
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                for k in range(1, 3):
                    if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                        isTCfound = True
                        break
                
                if(not isTCfound):
                    if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1  
                                 
                        #Deal with packet loss......
                        if(i == 16 and packet_loss_testing_round_16_flag == False):
                            evcc_send_time_anchor_each_round.append(338.265151)
                            printinfo(stageNum, 56719, "Packet Loss")
                            print_time_difference(evcc_send_time_anchor_each_round)
                            stageNum = stageNum + 1
                            packet_loss_testing_round_16_flag = True

                        continue
                
        #Stage 6, tricky
        if(data_length_evcc_send_split[i][j] == 173):
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                for k in range(1, 3):
                    if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                        isTCfound = True
                        break

                if(not isTCfound):
                    if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1
                
                        continue
        
        #Stage 7
        if(data_length_evcc_send_split[i][j] == 185 and data_length_evcc_send_split[i][j-1] != 185):
            if(checkstage_num(stageNum, 7, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 8
        if(data_length_evcc_send_split[i][j] == 461 and data_length_evcc_send_split[i][j-1] != 461):
            if(checkstage_num(stageNum, 8, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 7 and packet_loss_testing_round_7_flag == False):
                    evcc_send_time_anchor_each_round.append(160.75994)
                    printinfo(stageNum, 26594, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_7_flag = True
                    
                if(i == 7 and packet_loss_testing_round_7_flag_2 == False):
                    evcc_send_time_anchor_each_round.append(160.825903)
                    printinfo(stageNum, 26621, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_7_flag_2 = True
                
                
                continue
        #Stage 9
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 9, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 14 and packet_loss_testing_round_14_flag_2 == False):
                    evcc_send_time_anchor_each_round.append(299.744518)
                    printinfo(stageNum, 47904, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_14_flag_2 = True
                
                continue
                
        #Stage 10
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                for k in range(1, 3):
                    if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                        isTCfound = True
                        break

                if(not isTCfound):
                    if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1
                
        if(stageNum == 11): break
        
    evcc_send_time_anchor.append(evcc_send_time_anchor_each_round)
# Out:
# -------- Test Round 1 --------
# -----------------------------------------
# Stage 1 finish. No. 3699, Info QoS Data, SN=2533, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 3752, Info QoS Data, SN=2534, FN=0, Flags=.p.....TC
# Time difference: 0.3570590000000031
# -----------------------------------------
# Stage 3 finish. No. 3929, Info QoS Data, SN=2544, FN=0, Flags=.p.....TC
# Time difference: 0.3241809999999994
# -----------------------------------------
# Stage 4 finish. No. 3978, Info QoS Data, SN=2546, FN=0, Flags=.p.....TC
# Time difference: 0.2411980000000007
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 4018
# Time 25.614608 #Seq 2548 Info QoS Data, SN=2548, FN=0, Flags=.p.....TC
#
#
# No. 4018 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 4018, Info QoS Data, SN=2548, FN=0, Flags=.p.....TC
# Time difference: 0.024989999999998957
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 4056
# Time 25.702614 #Seq 2550 Info QoS Data, SN=2550, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 4056
# Time 25.702614 #Seq 2550 Info QoS Data, SN=2550, FN=0, Flags=.p.....TC
#
#
# No. 4056 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 4056, Info QoS Data, SN=2550, FN=0, Flags=.p.....TC
# Time difference: 0.08800600000000003
# -----------------------------------------
# Stage 7 finish. No. 4096, Info QoS Data, SN=2553, FN=0, Flags=.p.....TC
# Time difference: 0.14644600000000096
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 4100
# Time 25.849504 #Seq 2282 Info QoS Data, SN=2282, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 4132, Info QoS Data, SN=2555, FN=0, Flags=.p.....TC
# Time difference: 0.13521699999999726
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 4172
# Time 26.021802 #Seq 2557 Info QoS Data, SN=2557, FN=0, Flags=.p.....TC
#
#
# No. 4172 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 4172, Info QoS Data, SN=2557, FN=0, Flags=.p.....TC
# Time difference: 0.03752500000000225
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 4210
# Time 26.104625 #Seq 2559 Info QoS Data, SN=2559, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 4210
# Time 26.104625 #Seq 2559 Info QoS Data, SN=2559, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 4210
# Time 26.104625 #Seq 2559 Info QoS Data, SN=2559, FN=0, Flags=.p.....TC
#
#
# No. 4210 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 4210, Info QoS Data, SN=2559, FN=0, Flags=.p.....TC
# Time difference: 0.08282299999999765
#
# -------- Test Round 2 --------
# -----------------------------------------
# Stage 1 finish. No. 5917, Info QoS Data, SN=2591, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 6061, Info QoS Data, SN=2592, FN=0, Flags=.p.....TC
# Time difference: 0.3987209999999948
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 6184
# Time 44.645708 #Seq 2600 Info QoS Data, SN=2600, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 6184
# Time 44.645708 #Seq 2600 Info QoS Data, SN=2600, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 6184
# Time 44.645708 #Seq 2600 Info QoS Data, SN=2600, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 6184
# Time 44.645708 #Seq 2600 Info QoS Data, SN=2600, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 6265, Info QoS Data, SN=2603, FN=0, Flags=.p.....TC
# Time difference: 0.1685290000000066
# -----------------------------------------
# Stage 4 finish. No. 6334, Info QoS Data, SN=2605, FN=0, Flags=.p.....TC
# Time difference: 0.07117699999999871
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 6364
# Time 44.820576 #Seq 2607 Info QoS Data, SN=2607, FN=0, Flags=.p.....TC
#
#
# No. 6364 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 6364, Info QoS Data, SN=2607, FN=0, Flags=.p.....TC
# Time difference: 0.01951700000000045
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 6406
# Time 44.884373 #Seq 2609 Info QoS Data, SN=2609, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 6406
# Time 44.884373 #Seq 2609 Info QoS Data, SN=2609, FN=0, Flags=.p.....TC
#
#
# No. 6406 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 6406, Info QoS Data, SN=2609, FN=0, Flags=.p.....TC
# Time difference: 0.06379699999999389
# -----------------------------------------
# Stage 7 finish. No. 6525, Info QoS Data, SN=2612, FN=0, Flags=.p.....TC
# Time difference: 0.13792800000000227
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 6528
# Time 45.023269 #Seq 2612 Info QoS Data, SN=2612, FN=0, Flags=.p..R..TC
#
# -----------------------------------------
# Stage 8 finish. No. 6586, Info QoS Data, SN=2614, FN=0, Flags=.p.....TC
# Time difference: 0.12915900000000136
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 6618
# Time 45.181262 #Seq 2616 Info QoS Data, SN=2616, FN=0, Flags=.p.....TC
#
#
# No. 6618 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 6618, Info QoS Data, SN=2616, FN=0, Flags=.p.....TC
# Time difference: 0.029801999999996553
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 6689
# Time 45.257699 #Seq 2618 Info QoS Data, SN=2618, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 6689
# Time 45.257699 #Seq 2618 Info QoS Data, SN=2618, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 6689
# Time 45.257699 #Seq 2618 Info QoS Data, SN=2618, FN=0, Flags=.p.....TC
#
#
# No. 6689 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 6689, Info QoS Data, SN=2618, FN=0, Flags=.p.....TC
# Time difference: 0.07643700000000564
#
# -------- Test Round 3 --------
# -----------------------------------------
# Stage 1 finish. No. 13274, Info QoS Data, SN=2650, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 13310, Info QoS Data, SN=2651, FN=0, Flags=.p.....TC
# Time difference: 0.32510000000000616
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 13442
# Time 64.093768 #Seq 2661 Info QoS Data, SN=2661, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 13442
# Time 64.093768 #Seq 2661 Info QoS Data, SN=2661, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 13442
# Time 64.093768 #Seq 2661 Info QoS Data, SN=2661, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 13442
# Time 64.093768 #Seq 2661 Info QoS Data, SN=2661, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 13485, Info QoS Data, SN=2664, FN=0, Flags=.p.....TC
# Time difference: 0.3537359999999907
# -----------------------------------------
# Stage 4 finish. No. 13519, Info QoS Data, SN=2666, FN=0, Flags=.p.....TC
# Time difference: 0.07546400000001086
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 13547
# Time 64.264648 #Seq 2520 Info QoS Data, SN=2520, FN=0, Flags=.p....F.C
#
#
# No. 13547 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 13547, Data length 173, Info QoS Data, SN=2520, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 13547, Info QoS Data, SN=2520, FN=0, Flags=.p....F.C
# Time difference: 0.019827999999989743
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 13576
# Time 64.335702 #Seq 2670 Info QoS Data, SN=2670, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 13576
# Time 64.335702 #Seq 2670 Info QoS Data, SN=2670, FN=0, Flags=.p.....TC
#
#
# No. 13576 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 13576, Info QoS Data, SN=2670, FN=0, Flags=.p.....TC
# Time difference: 0.07105400000000373
# -----------------------------------------
# Stage 7 finish. No. 13613, Info QoS Data, SN=2673, FN=0, Flags=.p.....TC
# Time difference: 0.13012400000000923
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 13618
# Time 64.466163 #Seq 2525 Info QoS Data, SN=2525, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 13647, Info QoS Data, SN=2527, FN=0, Flags=.p....F.C
# Time difference: 0.11679199999998957
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 13678
# Time 64.614697 #Seq 2529 Info QoS Data, SN=2529, FN=0, Flags=.p....F.C
#
#
# No. 13678 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 13678, Info QoS Data, SN=2529, FN=0, Flags=.p....F.C
# Time difference: 0.03207900000001018
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 13700
# Time 64.690537 #Seq 2530 Info QoS Data, SN=2530, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 13700
# Time 64.690537 #Seq 2530 Info QoS Data, SN=2530, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 13700
# Time 64.690537 #Seq 2530 Info QoS Data, SN=2530, FN=0, Flags=.p....F.C
#
#
# No. 13700 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 13700, Data length 173, Info QoS Data, SN=2530, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 13700, Info QoS Data, SN=2530, FN=0, Flags=.p....F.C
# Time difference: 0.07583999999999946
#
# -------- Test Round 4 --------
# -----------------------------------------
# Stage 1 finish. No. 16083, Info QoS Data, SN=2699, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 16132, Info QoS Data, SN=2701, FN=0, Flags=.p.....TC
# Time difference: 0.37809500000000185
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 16209
# Time 83.558952 #Seq 2710 Info QoS Data, SN=2710, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 16209
# Time 83.558952 #Seq 2710 Info QoS Data, SN=2710, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 16209
# Time 83.558952 #Seq 2710 Info QoS Data, SN=2710, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 16209
# Time 83.558952 #Seq 2710 Info QoS Data, SN=2710, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 16237
# Time 83.791747 #Seq 2716 Info QoS Data, SN=2716, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 16237
# Time 83.791747 #Seq 2716 Info QoS Data, SN=2716, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 8
# What is this packet? Data Length = 461 No. 16266
# Time 84.062953 #Seq 2721 Info QoS Data, SN=2721, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 16296, Info QoS Data, SN=2723, FN=0, Flags=.p.....TC
# Time difference: 0.8287479999999903
# -----------------------------------------
# Stage 4 finish. No. 16431, Info QoS Data, SN=2729, FN=0, Flags=.p.....TC
# Time difference: 2.1003280000000046
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 16644
# Time 88.264899 #Seq 2731 Info QoS Data, SN=2731, FN=0, Flags=.p.....TC
#
#
# No. 16644 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 16644, Info QoS Data, SN=2731, FN=0, Flags=.p.....TC
# Time difference: 2.0687089999999984
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 16882
# Time 90.312425 #Seq 2734 Info QoS Data, SN=2734, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 16882
# Time 90.312425 #Seq 2734 Info QoS Data, SN=2734, FN=0, Flags=.p.....TC
#
#
# No. 16882 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 16882, Info QoS Data, SN=2734, FN=0, Flags=.p.....TC
# Time difference: 2.047526000000005
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 17074
# Time 92.329965 #Seq 2736 Info QoS Data, SN=2736, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 17074
# Time 92.329965 #Seq 2736 Info QoS Data, SN=2736, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 17074
# Time 92.329965 #Seq 2736 Info QoS Data, SN=2736, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 17074
# Time 92.329965 #Seq 2736 Info QoS Data, SN=2736, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 17265
# Time 94.413419 #Seq 2740 Info QoS Data, SN=2740, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 17265
# Time 94.413419 #Seq 2740 Info QoS Data, SN=2740, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 17265
# Time 94.413419 #Seq 2740 Info QoS Data, SN=2740, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 17265
# Time 94.413419 #Seq 2740 Info QoS Data, SN=2740, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 17295
# Time 94.449671 #Seq 2742 Info QoS Data, SN=2742, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 17295
# Time 94.449671 #Seq 2742 Info QoS Data, SN=2742, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 17295
# Time 94.449671 #Seq 2742 Info QoS Data, SN=2742, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 17295
# Time 94.449671 #Seq 2742 Info QoS Data, SN=2742, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 17316
# Time 94.462314 #Seq 2743 Info QoS Data, SN=2743, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 17316
# Time 94.462314 #Seq 2743 Info QoS Data, SN=2743, FN=0, Flags=.p.....TC
#
#
# -------- Test Round 5 --------
# -----------------------------------------
# Stage 1 finish. No. 18933, Info QoS Data, SN=2771, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 19052, Info QoS Data, SN=2779, FN=0, Flags=.p.....TC
# Time difference: 0.510382000000007
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 19207
# Time 103.021086 #Seq 2703 Info QoS Data, SN=2703, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 19207
# Time 103.021086 #Seq 2703 Info QoS Data, SN=2703, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 19207
# Time 103.021086 #Seq 2703 Info QoS Data, SN=2703, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 19207
# Time 103.021086 #Seq 2703 Info QoS Data, SN=2703, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 19245, Info QoS Data, SN=2706, FN=0, Flags=.p....F.C
# Time difference: 0.3862749999999977
# -----------------------------------------
# Stage 4 finish. No. 19275, Info QoS Data, SN=2709, FN=0, Flags=.p....F.C
# Time difference: 0.07279299999999012
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 19325
# Time 103.192917 #Seq 2713 Info QoS Data, SN=2713, FN=0, Flags=.p....F.C
#
#
# No. 19325 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 19325, Data length 173, Info QoS Data, SN=2713, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 19325, Info QoS Data, SN=2713, FN=0, Flags=.p....F.C
# Time difference: 0.01654800000000023
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 19326
# Time 103.193073 #Seq 2713 Info QoS Data, SN=2713, FN=0, Flags=.p..R.F.C
#
#
# No. 19326 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 19326, Data length 173, Info QoS Data, SN=2713, FN=0, Flags=.p..R.F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 19326, Info QoS Data, SN=2713, FN=0, Flags=.p..R.F.C
# Time difference: 0.0001560000000040418
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 19373
# Time 103.249422 #Seq 2797 Info QoS Data, SN=2797, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 19373
# Time 103.249422 #Seq 2797 Info QoS Data, SN=2797, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 19373
# Time 103.249422 #Seq 2797 Info QoS Data, SN=2797, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 19373
# Time 103.249422 #Seq 2797 Info QoS Data, SN=2797, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 7 finish. No. 19423, Info QoS Data, SN=2800, FN=0, Flags=.p.....TC
# Time difference: 0.19113699999999767
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 19427
# Time 103.38449 #Seq 2718 Info QoS Data, SN=2718, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 19465, Info QoS Data, SN=2803, FN=0, Flags=.p.....TC
# Time difference: 0.11313499999999976
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 19492
# Time 103.527014 #Seq 2805 Info QoS Data, SN=2805, FN=0, Flags=.p.....TC
#
#
# No. 19492 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 19492, Info QoS Data, SN=2805, FN=0, Flags=.p.....TC
# Time difference: 0.02966899999999839
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 19518
# Time 103.60005 #Seq 2806 Info QoS Data, SN=2806, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 19518
# Time 103.60005 #Seq 2806 Info QoS Data, SN=2806, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 19518
# Time 103.60005 #Seq 2806 Info QoS Data, SN=2806, FN=0, Flags=.p.....TC
#
#
# No. 19518 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 19518, Info QoS Data, SN=2806, FN=0, Flags=.p.....TC
# Time difference: 0.07303600000000188
#
# -------- Test Round 6 --------
# -----------------------------------------
# Stage 1 finish. No. 22249, Info Data, SN=2496, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 22286, Info QoS Data, SN=2796, FN=0, Flags=.p....F.C
# Time difference: 0.31124900000000366
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 22385
# Time 122.062532 #Seq 2805 Info QoS Data, SN=2805, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 22385
# Time 122.062532 #Seq 2805 Info QoS Data, SN=2805, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 22385
# Time 122.062532 #Seq 2805 Info QoS Data, SN=2805, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 22385
# Time 122.062532 #Seq 2805 Info QoS Data, SN=2805, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 22424, Info QoS Data, SN=2808, FN=0, Flags=.p....F.C
# Time difference: 0.15575699999999415
# -----------------------------------------
# Stage 4 finish. No. 22453, Info QoS Data, SN=2810, FN=0, Flags=.p....F.C
# Time difference: 0.06471999999999412
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 22477
# Time 122.216088 #Seq 2812 Info QoS Data, SN=2812, FN=0, Flags=.p....F.C
#
#
# No. 22477 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 22477, Data length 173, Info QoS Data, SN=2812, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 22477, Info QoS Data, SN=2812, FN=0, Flags=.p....F.C
# Time difference: 0.012944000000004507
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 22506
# Time 122.290844 #Seq 2814 Info QoS Data, SN=2814, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 22506
# Time 122.290844 #Seq 2814 Info QoS Data, SN=2814, FN=0, Flags=.p....F.C
#
#
# No. 22506 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 22506, Data length 173, Info QoS Data, SN=2814, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 22506, Info QoS Data, SN=2814, FN=0, Flags=.p....F.C
# Time difference: 0.07475600000000782
# -----------------------------------------
# Stage 7 finish. No. 22543, Info QoS Data, SN=2817, FN=0, Flags=.p....F.C
# Time difference: 0.13657499999999345
# -----------------------------------------
# Stage 8 finish. No. 22572, Info QoS Data, SN=2819, FN=0, Flags=.p....F.C
# Time difference: 0.10838900000000251
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 22597
# Time 122.559989 #Seq 2821 Info QoS Data, SN=2821, FN=0, Flags=.p....F.C
#
#
# No. 22597 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 22597, Info QoS Data, SN=2821, FN=0, Flags=.p....F.C
# Time difference: 0.024180999999998676
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 22625
# Time 122.631432 #Seq 2823 Info QoS Data, SN=2823, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 22625
# Time 122.631432 #Seq 2823 Info QoS Data, SN=2823, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 22625
# Time 122.631432 #Seq 2823 Info QoS Data, SN=2823, FN=0, Flags=.p....F.C
#
#
# No. 22625 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 22625, Data length 173, Info QoS Data, SN=2823, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 22625, Info QoS Data, SN=2823, FN=0, Flags=.p....F.C
# Time difference: 0.07144300000000214
#
# -------- Test Round 7 --------
# -----------------------------------------
# Stage 1 finish. No. 24076, Info QoS Data, SN=2898, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 24111, Info QoS Data, SN=2899, FN=0, Flags=.p.....TC
# Time difference: 0.340629999999976
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 24220
# Time 141.2104 #Seq 2907 Info QoS Data, SN=2907, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 24220
# Time 141.2104 #Seq 2907 Info QoS Data, SN=2907, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 24220
# Time 141.2104 #Seq 2907 Info QoS Data, SN=2907, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 24220
# Time 141.2104 #Seq 2907 Info QoS Data, SN=2907, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 24263, Info QoS Data, SN=2910, FN=0, Flags=.p.....TC
# Time difference: 0.24502200000000585
# -----------------------------------------
# Stage 4 finish. No. 24295, Info QoS Data, SN=2912, FN=0, Flags=.p.....TC
# Time difference: 0.08348800000001688
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 24321
# Time 141.389197 #Seq 2914 Info QoS Data, SN=2914, FN=0, Flags=.p.....TC
#
#
# No. 24321 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 24321, Info QoS Data, SN=2914, FN=0, Flags=.p.....TC
# Time difference: 0.01584399999998709
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 24351
# Time 141.451502 #Seq 2916 Info QoS Data, SN=2916, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 24351
# Time 141.451502 #Seq 2916 Info QoS Data, SN=2916, FN=0, Flags=.p.....TC
#
#
# No. 24351 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 24351, Info QoS Data, SN=2916, FN=0, Flags=.p.....TC
# Time difference: 0.06230500000000916
# -----------------------------------------
# Stage 7 finish. No. 24389, Info QoS Data, SN=2919, FN=0, Flags=.p.....TC
# Time difference: 0.13647499999999013
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 24393
# Time 141.588306 #Seq 2867 Info QoS Data, SN=2867, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 24426, Info QoS Data, SN=2921, FN=0, Flags=.p.....TC
# Time difference: 0.11004400000001624
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 24457
# Time 141.721285 #Seq 2923 Info QoS Data, SN=2923, FN=0, Flags=.p.....TC
#
#
# No. 24457 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 24457, Info QoS Data, SN=2923, FN=0, Flags=.p.....TC
# Time difference: 0.023263999999983298
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 24486
# Time 141.787435 #Seq 2925 Info QoS Data, SN=2925, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 24486
# Time 141.787435 #Seq 2925 Info QoS Data, SN=2925, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 24486
# Time 141.787435 #Seq 2925 Info QoS Data, SN=2925, FN=0, Flags=.p.....TC
#
#
# No. 24486 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 24486, Info QoS Data, SN=2925, FN=0, Flags=.p.....TC
# Time difference: 0.06614999999999327
#
# -------- Test Round 8 --------
# -----------------------------------------
# Stage 1 finish. No. 26202, Info QoS Data, SN=2958, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 26268, Info QoS Data, SN=2959, FN=0, Flags=.p.....TC
# Time difference: 0.35850999999999544
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 26378
# Time 160.350743 #Seq 2968 Info QoS Data, SN=2968, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 26378
# Time 160.350743 #Seq 2968 Info QoS Data, SN=2968, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 26378
# Time 160.350743 #Seq 2968 Info QoS Data, SN=2968, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 26378
# Time 160.350743 #Seq 2968 Info QoS Data, SN=2968, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 26421, Info QoS Data, SN=2971, FN=0, Flags=.p.....TC
# Time difference: 0.12232000000000198
# -----------------------------------------
# Stage 4 finish. No. 26449, Info QoS Data, SN=2973, FN=0, Flags=.p.....TC
# Time difference: 0.05996999999999275
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 26475
# Time 160.454027 #Seq 2975 Info QoS Data, SN=2975, FN=0, Flags=.p.....TC
#
#
# No. 26475 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 26475, Info QoS Data, SN=2975, FN=0, Flags=.p.....TC
# Time difference: 0.009456000000000131
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 26505
# Time 160.505819 #Seq 2977 Info QoS Data, SN=2977, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 26505
# Time 160.505819 #Seq 2977 Info QoS Data, SN=2977, FN=0, Flags=.p.....TC
#
#
# No. 26505 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 26505, Info QoS Data, SN=2977, FN=0, Flags=.p.....TC
# Time difference: 0.051792000000006055
# -----------------------------------------
# Stage 7 finish. No. 26544, Info QoS Data, SN=2927, FN=0, Flags=.p....F.C
# Time difference: 0.1299850000000049
# -----------------------------------------
# Stage 8 finish. No. 26573, Info QoS Data, SN=2929, FN=0, Flags=.p....F.C
# Time difference: 0.10469999999997981
# -----------------------------------------
# Stage 9 finish. No. 26594, Info Packet Loss
# Time difference: 0.01943600000001311
# -----------------------------------------
# Stage 10 finish. No. 26621, Info Packet Loss
# Time difference: 0.06596300000001065
#
# -------- Test Round 9 --------
# -----------------------------------------
# Stage 1 finish. No. 28273, Info Data, SN=3079, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 28313, Info QoS Data, SN=2975, FN=0, Flags=.p....F.C
# Time difference: 0.4133889999999951
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 28415
# Time 179.707903 #Seq 2984 Info QoS Data, SN=2984, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 28415
# Time 179.707903 #Seq 2984 Info QoS Data, SN=2984, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 28415
# Time 179.707903 #Seq 2984 Info QoS Data, SN=2984, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 28415
# Time 179.707903 #Seq 2984 Info QoS Data, SN=2984, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 28479, Info QoS Data, SN=2988, FN=0, Flags=.p....F.C
# Time difference: 0.15573900000001117
# -----------------------------------------
# Stage 4 finish. No. 28511, Info QoS Data, SN=2990, FN=0, Flags=.p....F.C
# Time difference: 0.06154000000000792
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 28535
# Time 179.864673 #Seq 2992 Info QoS Data, SN=2992, FN=0, Flags=.p....F.C
#
#
# No. 28535 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 28535, Data length 173, Info QoS Data, SN=2992, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 28535, Info QoS Data, SN=2992, FN=0, Flags=.p....F.C
# Time difference: 0.013823000000002139
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 28563
# Time 179.921764 #Seq 2994 Info QoS Data, SN=2994, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 28563
# Time 179.921764 #Seq 2994 Info QoS Data, SN=2994, FN=0, Flags=.p....F.C
#
#
# No. 28563 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 28563, Data length 173, Info QoS Data, SN=2994, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 28563, Info QoS Data, SN=2994, FN=0, Flags=.p....F.C
# Time difference: 0.05709099999998557
# -----------------------------------------
# Stage 7 finish. No. 28603, Info QoS Data, SN=2997, FN=0, Flags=.p....F.C
# Time difference: 0.13466600000000994
# -----------------------------------------
# Stage 8 finish. No. 28638, Info QoS Data, SN=2999, FN=0, Flags=.p....F.C
# Time difference: 0.08849899999998456
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 28664
# Time 180.166746 #Seq 3001 Info QoS Data, SN=3001, FN=0, Flags=.p....F.C
#
#
# No. 28664 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 28664, Info QoS Data, SN=3001, FN=0, Flags=.p....F.C
# Time difference: 0.021816999999998643
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 28691
# Time 180.228052 #Seq 3003 Info QoS Data, SN=3003, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 28691
# Time 180.228052 #Seq 3003 Info QoS Data, SN=3003, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 28691
# Time 180.228052 #Seq 3003 Info QoS Data, SN=3003, FN=0, Flags=.p....F.C
#
#
# No. 28691 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 28691, Data length 173, Info QoS Data, SN=3003, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 28691, Info QoS Data, SN=3003, FN=0, Flags=.p....F.C
# Time difference: 0.06130600000000186
#
# -------- Test Round 10 --------
# -----------------------------------------
# Stage 1 finish. No. 31751, Info Data, SN=3279, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 31812, Info QoS Data, SN=3066, FN=0, Flags=.p....F.C
# Time difference: 0.4135080000000073
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 31911
# Time 199.069923 #Seq 3074 Info QoS Data, SN=3074, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 31911
# Time 199.069923 #Seq 3074 Info QoS Data, SN=3074, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 31911
# Time 199.069923 #Seq 3074 Info QoS Data, SN=3074, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 31911
# Time 199.069923 #Seq 3074 Info QoS Data, SN=3074, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 31954, Info QoS Data, SN=3077, FN=0, Flags=.p....F.C
# Time difference: 0.16387699999998517
# -----------------------------------------
# Stage 4 finish. No. 31988, Info QoS Data, SN=3079, FN=0, Flags=.p....F.C
# Time difference: 0.07686800000001881
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 32011
# Time 199.242355 #Seq 3081 Info QoS Data, SN=3081, FN=0, Flags=.p....F.C
#
#
# No. 32011 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 32011, Data length 173, Info QoS Data, SN=3081, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 32011, Info QoS Data, SN=3081, FN=0, Flags=.p....F.C
# Time difference: 0.01433099999999854
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 32040
# Time 199.301509 #Seq 3083 Info QoS Data, SN=3083, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 32040
# Time 199.301509 #Seq 3083 Info QoS Data, SN=3083, FN=0, Flags=.p....F.C
#
#
# No. 32040 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 32040, Data length 173, Info QoS Data, SN=3083, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 32040, Info QoS Data, SN=3083, FN=0, Flags=.p....F.C
# Time difference: 0.05915400000000659
# -----------------------------------------
# Stage 7 finish. No. 32076, Info QoS Data, SN=3086, FN=0, Flags=.p....F.C
# Time difference: 0.1338529999999878
# -----------------------------------------
# Stage 8 finish. No. 32105, Info QoS Data, SN=3088, FN=0, Flags=.p....F.C
# Time difference: 0.1013849999999934
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 32128
# Time 199.56053 #Seq 3090 Info QoS Data, SN=3090, FN=0, Flags=.p....F.C
#
#
# No. 32128 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 32128, Info QoS Data, SN=3090, FN=0, Flags=.p....F.C
# Time difference: 0.02378300000000877
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 32156
# Time 199.630064 #Seq 3092 Info QoS Data, SN=3092, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 32156
# Time 199.630064 #Seq 3092 Info QoS Data, SN=3092, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 32156
# Time 199.630064 #Seq 3092 Info QoS Data, SN=3092, FN=0, Flags=.p....F.C
#
#
# No. 32156 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 32156, Data length 173, Info QoS Data, SN=3092, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 32156, Info QoS Data, SN=3092, FN=0, Flags=.p....F.C
# Time difference: 0.06953400000000443
#
# -------- Test Round 11 --------
# -----------------------------------------
# Stage 1 finish. No. 35278, Info Data, SN=3486, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 35361, Info Packet Loss
# Time difference: 0.4163090000000125
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 35511
# Time 218.220452 #Seq 3181 Info QoS Data, SN=3181, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 35511
# Time 218.220452 #Seq 3181 Info QoS Data, SN=3181, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 35511
# Time 218.220452 #Seq 3181 Info QoS Data, SN=3181, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 35511
# Time 218.220452 #Seq 3181 Info QoS Data, SN=3181, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 35550, Info QoS Data, SN=3184, FN=0, Flags=.p....F.C
# Time difference: 0.2590769999999907
# -----------------------------------------
# Stage 4 finish. No. 35578, Info QoS Data, SN=3186, FN=0, Flags=.p....F.C
# Time difference: 0.059648000000009915
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 35602
# Time 218.363494 #Seq 3188 Info QoS Data, SN=3188, FN=0, Flags=.p....F.C
#
#
# No. 35602 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 35602, Data length 173, Info QoS Data, SN=3188, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 35602, Info QoS Data, SN=3188, FN=0, Flags=.p....F.C
# Time difference: 0.008419000000003507
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 35630
# Time 218.418209 #Seq 3190 Info QoS Data, SN=3190, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 35630
# Time 218.418209 #Seq 3190 Info QoS Data, SN=3190, FN=0, Flags=.p....F.C
#
#
# No. 35630 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 35630, Data length 173, Info QoS Data, SN=3190, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 35630, Info QoS Data, SN=3190, FN=0, Flags=.p....F.C
# Time difference: 0.05471499999998741
# -----------------------------------------
# Stage 7 finish. No. 35665, Info QoS Data, SN=3193, FN=0, Flags=.p....F.C
# Time difference: 0.1326310000000035
# -----------------------------------------
# Stage 8 finish. No. 35695, Info QoS Data, SN=3195, FN=0, Flags=.p....F.C
# Time difference: 0.10457300000001624
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 35720
# Time 218.676195 #Seq 3197 Info QoS Data, SN=3197, FN=0, Flags=.p....F.C
#
#
# No. 35720 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 35720, Info QoS Data, SN=3197, FN=0, Flags=.p....F.C
# Time difference: 0.02078199999999697
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 35745
# Time 218.748046 #Seq 3199 Info QoS Data, SN=3199, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 35745
# Time 218.748046 #Seq 3199 Info QoS Data, SN=3199, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 35745
# Time 218.748046 #Seq 3199 Info QoS Data, SN=3199, FN=0, Flags=.p....F.C
#
#
# No. 35745 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 35745, Data length 173, Info QoS Data, SN=3199, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 35745, Info QoS Data, SN=3199, FN=0, Flags=.p....F.C
# Time difference: 0.07185099999998101
#
# -------- Test Round 12 --------
# -----------------------------------------
# Stage 1 finish. No. 38347, Info Data, SN=3695, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 38406, Info QoS Data, SN=3260, FN=0, Flags=.p....F.C
# Time difference: 0.5199000000000069
# -----------------------------------------
# Stage 3 finish. No. 38538, Info Packet Loss
# Time difference: 0.3276389999999765
# -----------------------------------------
# Stage 4 finish. No. 38597, Info QoS Data, SN=3274, FN=0, Flags=.p....F.C
# Time difference: 0.27861100000001215
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 38617
# Time 238.118612 #Seq 3276 Info QoS Data, SN=3276, FN=0, Flags=.p....F.C
#
#
# No. 38617 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 38617, Data length 173, Info QoS Data, SN=3276, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 38617, Info QoS Data, SN=3276, FN=0, Flags=.p....F.C
# Time difference: 0.015935000000013133
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 38644
# Time 238.194897 #Seq 3278 Info QoS Data, SN=3278, FN=0, Flags=.p....F.C
#
#
# No. 38644 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 38644, Data length 173, Info QoS Data, SN=3278, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 38644, Info QoS Data, SN=3278, FN=0, Flags=.p....F.C
# Time difference: 0.0762849999999844
# -----------------------------------------
# Stage 7 finish. No. 38721, Info QoS Data, SN=3281, FN=0, Flags=.p....F.C
# Time difference: 0.23455699999999524
# -----------------------------------------
# Stage 8 finish. No. 38793, Info QoS Data, SN=3283, FN=0, Flags=.p....F.C
# Time difference: 0.19785200000001169
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 38820
# Time 238.708363 #Seq 3285 Info QoS Data, SN=3285, FN=0, Flags=.p....F.C
#
#
# No. 38820 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 38820, Info QoS Data, SN=3285, FN=0, Flags=.p....F.C
# Time difference: 0.08105699999998706
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 38889
# Time 238.929782 #Seq 3287 Info QoS Data, SN=3287, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 38889
# Time 238.929782 #Seq 3287 Info QoS Data, SN=3287, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 38889
# Time 238.929782 #Seq 3287 Info QoS Data, SN=3287, FN=0, Flags=.p..R.F.C
#
#
# No. 38889 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 38889, Data length 173, Info QoS Data, SN=3287, FN=0, Flags=.p..R.F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 38889, Info QoS Data, SN=3287, FN=0, Flags=.p..R.F.C
# Time difference: 0.22141899999999737
#
# -------- Test Round 13 --------
# -----------------------------------------
# Stage 1 finish. No. 42716, Info Data, SN=3944, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 42765, Info QoS Data, SN=3354, FN=0, Flags=.p....F.C
# Time difference: 0.4107810000000427
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 43095
# Time 259.52469 #Seq 3369 Info QoS Data, SN=3369, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 43095
# Time 259.52469 #Seq 3369 Info QoS Data, SN=3369, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 43095
# Time 259.52469 #Seq 3369 Info QoS Data, SN=3369, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 43095
# Time 259.52469 #Seq 3369 Info QoS Data, SN=3369, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 43134
# Time 259.612389 #Seq 3370 Info QoS Data, SN=3370, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 43134
# Time 259.612389 #Seq 3370 Info QoS Data, SN=3370, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 43178
# Time 259.851841 #Seq 3373 Info QoS Data, SN=3373, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 8
# What is this packet? Data Length = 461 No. 43224
# Time 260.016987 #Seq 3375 Info QoS Data, SN=3375, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 43261, Info QoS Data, SN=3377, FN=0, Flags=.p....F.C
# Time difference: 1.378407999999979
# -----------------------------------------
# Stage 4 finish. No. 43349, Info QoS Data, SN=3379, FN=0, Flags=.p....F.C
# Time difference: 0.2641039999999748
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 43437
# Time 260.671895 #Seq 3382 Info QoS Data, SN=3382, FN=0, Flags=.p....F.C
#
#
# No. 43437 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 43437, Data length 173, Info QoS Data, SN=3382, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 43437, Info QoS Data, SN=3382, FN=0, Flags=.p....F.C
# Time difference: 0.3431740000000332
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 43448
# Time 260.691853 #Seq 3384 Info QoS Data, SN=3384, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 43448
# Time 260.691853 #Seq 3384 Info QoS Data, SN=3384, FN=0, Flags=.p....F.C
#
#
# No. 43448 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 43448, Data length 173, Info QoS Data, SN=3384, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 43448, Info QoS Data, SN=3384, FN=0, Flags=.p....F.C
# ...
# Time 319.333102 #Seq 3795 Info QoS Data, SN=3795, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 52499
# Time 319.333102 #Seq 3795 Info QoS Data, SN=3795, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 52499
# Time 319.333102 #Seq 3795 Info QoS Data, SN=3795, FN=0, Flags=.p....F.C
#
#
# No. 52499 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 52499, Data length 173, Info QoS Data, SN=3795, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 52499, Info QoS Data, SN=3795, FN=0, Flags=.p....F.C
# Time difference: 0.061896999999987656
#
# -------- Test Round 17 --------
# -----------------------------------------
# Stage 1 finish. No. 56307, Info Data, SN=650, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 56360, Info QoS Data, SN=3993, FN=0, Flags=.p....F.C
# Time difference: 0.4158149999999523
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 56541
# Time 338.021732 #Seq 4003 Info QoS Data, SN=4003, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 56541
# Time 338.021732 #Seq 4003 Info QoS Data, SN=4003, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 56541
# Time 338.021732 #Seq 4003 Info QoS Data, SN=4003, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 56541
# Time 338.021732 #Seq 4003 Info QoS Data, SN=4003, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 56604, Info QoS Data, SN=4006, FN=0, Flags=.p....F.C
# Time difference: 0.2674140000000307
# -----------------------------------------
# Stage 4 finish. No. 56650, Info QoS Data, SN=4008, FN=0, Flags=.p....F.C
# Time difference: 0.06564400000002024
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 56685
# Time 338.201096 #Seq 4010 Info QoS Data, SN=4010, FN=0, Flags=.p....F.C
#
#
# No. 56685 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 56685, Data length 173, Info QoS Data, SN=4010, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 56685, Info QoS Data, SN=4010, FN=0, Flags=.p....F.C
# Time difference: 0.02472899999997935
# -----------------------------------------
# Stage 6 finish. No. 56719, Info Packet Loss
# Time difference: 0.0640549999999962
# -----------------------------------------
# Stage 7 finish. No. 56754, Info QoS Data, SN=4015, FN=0, Flags=.p....F.C
# Time difference: 0.12926399999997784
# -----------------------------------------
# Stage 8 finish. No. 56782, Info QoS Data, SN=4017, FN=0, Flags=.p....F.C
# Time difference: 0.10562900000002173
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 56807
# Time 338.52441 #Seq 4019 Info QoS Data, SN=4019, FN=0, Flags=.p....F.C
#
#
# No. 56807 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 56807, Info QoS Data, SN=4019, FN=0, Flags=.p....F.C
# Time difference: 0.024365999999986343
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 56835
# Time 338.594305 #Seq 4021 Info QoS Data, SN=4021, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 56835
# Time 338.594305 #Seq 4021 Info QoS Data, SN=4021, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 56835
# Time 338.594305 #Seq 4021 Info QoS Data, SN=4021, FN=0, Flags=.p....F.C
#
#
# No. 56835 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 56835, Data length 173, Info QoS Data, SN=4021, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 56835, Info QoS Data, SN=4021, FN=0, Flags=.p....F.C
# Time difference: 0.0698950000000309
#
# -------- Test Round 18 --------
# -----------------------------------------
# Stage 1 finish. No. 58797, Info Data, SN=852, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 58850, Info QoS Data, SN=4076, FN=0, Flags=.p....F.C
# Time difference: 0.42742000000004055
# -----------------------------------------
# Stage 3 finish. No. 58989, Info QoS Data, SN=4087, FN=0, Flags=.p....F.C
# Time difference: 0.18847399999998515
# -----------------------------------------
# Stage 4 finish. No. 59022, Info QoS Data, SN=4089, FN=0, Flags=.p....F.C
# Time difference: 0.07822999999996227
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 59046
# Time 357.695843 #Seq 4091 Info QoS Data, SN=4091, FN=0, Flags=.p....F.C
#
#
# No. 59046 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 59046, Data length 173, Info QoS Data, SN=4091, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 59046, Info QoS Data, SN=4091, FN=0, Flags=.p....F.C
# Time difference: 0.015650000000050568
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 59081
# Time 357.759916 #Seq 4093 Info QoS Data, SN=4093, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 59081
# Time 357.759916 #Seq 4093 Info QoS Data, SN=4093, FN=0, Flags=.p....F.C
#
#
# No. 59081 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 59081, Data length 173, Info QoS Data, SN=4093, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 59081, Info QoS Data, SN=4093, FN=0, Flags=.p....F.C
# Time difference: 0.06407299999995075
# -----------------------------------------
# Stage 7 finish. No. 59128, Info QoS Data, SN=0, FN=0, Flags=.p....F.C
# Time difference: 0.14334700000000566
# -----------------------------------------
# Stage 8 finish. No. 59162, Info QoS Data, SN=2, FN=0, Flags=.p....F.C
# Time difference: 0.09775700000000143
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 59188
# Time 358.018781 #Seq 4 Info QoS Data, SN=4, FN=0, Flags=.p....F.C
#
#
# No. 59188 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 59188, Info QoS Data, SN=4, FN=0, Flags=.p....F.C
# Time difference: 0.017761000000007243
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 59215
# Time 358.082015 #Seq 6 Info QoS Data, SN=6, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 59215
# Time 358.082015 #Seq 6 Info QoS Data, SN=6, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 59215
# Time 358.082015 #Seq 6 Info QoS Data, SN=6, FN=0, Flags=.p....F.C
#
#
# No. 59215 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 59215, Data length 173, Info QoS Data, SN=6, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 59215, Info QoS Data, SN=6, FN=0, Flags=.p....F.C
# Time difference: 0.06323400000002266
#
# -------- Test Round 19 --------
# -----------------------------------------
# Stage 1 finish. No. 62219, Info Data, SN=1041, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 62259, Info QoS Data, SN=65, FN=0, Flags=.p....F.C
# Time difference: 0.413250000000005
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 62357
# Time 376.727411 #Seq 73 Info QoS Data, SN=73, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 62357
# Time 376.727411 #Seq 73 Info QoS Data, SN=73, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 62357
# Time 376.727411 #Seq 73 Info QoS Data, SN=73, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 62357
# Time 376.727411 #Seq 73 Info QoS Data, SN=73, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 62398, Info QoS Data, SN=76, FN=0, Flags=.p....F.C
# Time difference: 0.15386499999999614
# -----------------------------------------
# Stage 4 finish. No. 62429, Info QoS Data, SN=78, FN=0, Flags=.p....F.C
# Time difference: 0.06346200000001545
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 62453
# Time 376.880934 #Seq 80 Info QoS Data, SN=80, FN=0, Flags=.p....F.C
#
#
# No. 62453 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 62453, Data length 173, Info QoS Data, SN=80, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 62453, Info QoS Data, SN=80, FN=0, Flags=.p....F.C
# Time difference: 0.013372000000003936
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 62481
# Time 376.944776 #Seq 82 Info QoS Data, SN=82, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 62481
# Time 376.944776 #Seq 82 Info QoS Data, SN=82, FN=0, Flags=.p....F.C
#
#
# No. 62481 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 62481, Data length 173, Info QoS Data, SN=82, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 62481, Info QoS Data, SN=82, FN=0, Flags=.p....F.C
# Time difference: 0.06384199999996554
# -----------------------------------------
# Stage 7 finish. No. 62522, Info QoS Data, SN=85, FN=0, Flags=.p....F.C
# Time difference: 0.13707099999999173
# -----------------------------------------
# Stage 8 finish. No. 62555, Info QoS Data, SN=87, FN=0, Flags=.p....F.C
# Time difference: 0.08692999999999529
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 62580
# Time 377.185742 #Seq 89 Info QoS Data, SN=89, FN=0, Flags=.p....F.C
#
#
# No. 62580 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 62580, Info QoS Data, SN=89, FN=0, Flags=.p....F.C
# Time difference: 0.01696500000002743
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 62605
# Time 377.247183 #Seq 91 Info QoS Data, SN=91, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 62605
# Time 377.247183 #Seq 91 Info QoS Data, SN=91, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 62605
# Time 377.247183 #Seq 91 Info QoS Data, SN=91, FN=0, Flags=.p....F.C
#
#
# No. 62605 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 62605, Data length 173, Info QoS Data, SN=91, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 62605, Info QoS Data, SN=91, FN=0, Flags=.p....F.C
# Time difference: 0.06144100000000208
#
# -------- Test Round 20 --------
# -----------------------------------------
# Stage 1 finish. No. 64348, Info Data, SN=1229, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 64390, Info QoS Data, SN=120, FN=0, Flags=.p....F.C
# Time difference: 0.4166050000000041
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 64491
# Time 395.974446 #Seq 128 Info QoS Data, SN=128, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 64491
# Time 395.974446 #Seq 128 Info QoS Data, SN=128, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 64491
# Time 395.974446 #Seq 128 Info QoS Data, SN=128, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 64491
# Time 395.974446 #Seq 128 Info QoS Data, SN=128, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 64539, Info QoS Data, SN=131, FN=0, Flags=.p....F.C
# Time difference: 0.2522920000000113
# -----------------------------------------
# Stage 4 finish. No. 64567, Info QoS Data, SN=133, FN=0, Flags=.p....F.C
# Time difference: 0.073566000000028
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 64591
# Time 396.13998 #Seq 135 Info QoS Data, SN=135, FN=0, Flags=.p....F.C
#
#
# No. 64591 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 64591, Data length 173, Info QoS Data, SN=135, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 64591, Info QoS Data, SN=135, FN=0, Flags=.p....F.C
# Time difference: 0.01181599999995342
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 64618
# Time 396.205072 #Seq 137 Info QoS Data, SN=137, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 64618
# Time 396.205072 #Seq 137 Info QoS Data, SN=137, FN=0, Flags=.p....F.C
#
#
# No. 64618 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 64618, Data length 173, Info QoS Data, SN=137, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 64618, Info QoS Data, SN=137, FN=0, Flags=.p....F.C
# Time difference: 0.06509199999999282
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 64619
# Time 396.205408 #Seq 137 Info QoS Data, SN=137, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 64619
# Time 396.205408 #Seq 137 Info QoS Data, SN=137, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 64620
# Time 396.205688 #Seq 137 Info QoS Data, SN=137, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 64620
# Time 396.205688 #Seq 137 Info QoS Data, SN=137, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 64621
# Time 396.206572 #Seq 137 Info QoS Data, SN=137, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 64621
# Time 396.206572 #Seq 137 Info QoS Data, SN=137, FN=0, Flags=.p..R.F.C
#
# -----------------------------------------
# Stage 7 finish. No. 64660, Info QoS Data, SN=140, FN=0, Flags=.p....F.C
# Time difference: 0.12840600000004088
# -----------------------------------------
# Stage 8 finish. No. 64692, Info QoS Data, SN=142, FN=0, Flags=.p....F.C
# Time difference: 0.10572300000001178
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 64718
# Time 396.460893 #Seq 144 Info QoS Data, SN=144, FN=0, Flags=.p....F.C
#
#
# No. 64718 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 64718, Info QoS Data, SN=144, FN=0, Flags=.p....F.C
# Time difference: 0.021691999999973177
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 64747
# Time 396.530907 #Seq 146 Info QoS Data, SN=146, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 64747
# Time 396.530907 #Seq 146 Info QoS Data, SN=146, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 64747
# Time 396.530907 #Seq 146 Info QoS Data, SN=146, FN=0, Flags=.p....F.C
#
#
# No. 64747 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 64747, Data length 173, Info QoS Data, SN=146, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 64747, Info QoS Data, SN=146, FN=0, Flags=.p....F.C
# Time difference: 0.07001400000001468

# %%
#for debug
print(str(len(evcc_send_time_anchor)) + '\n')
for i in range(0, len(evcc_send_time_anchor)):
    print("i = " + str(i))
    print(len(evcc_send_time_anchor[i]))
# Out:
# 20
#
# i = 0
# 10
# i = 1
# 10
# i = 2
# 10
# i = 3
# 6
# i = 4
# 10
# i = 5
# 10
# i = 6
# 10
# i = 7
# 10
# i = 8
# 10
# i = 9
# 10
# i = 10
# 10
# i = 11
# 10
# i = 12
# 6
# i = 13
# 6
# i = 14
# 10
# i = 15
# 10
# i = 16
# 10
# i = 17
# 10
# i = 18
# 10
# i = 19
# 10

# %%
#for debug
for i in range(0, len(evcc_send_time_anchor)):
    print("i = " + str(i))
    print(evcc_send_time_anchor[i][len(evcc_send_time_anchor[i])-1]-evcc_send_time_anchor[i][0])
# Out:
# i = 0
# 1.4374450000000003
# i = 1
# 1.0950670000000002
# i = 2
# 1.2000170000000097
# i = 3
# 7.423406
# i = 4
# 1.3931309999999968
# i = 5
# 0.960014000000001
# i = 6
# 1.083221999999978
# i = 7
# 0.9221320000000048
# i = 8
# 1.007869999999997
# i = 9
# 1.0562930000000108
# i = 10
# 1.1280050000000017
# i = 11
# 1.9532549999999844
# i = 12
# 2.416425000000004
# i = 13
# 1.2670239999999922
# i = 14
# 1.1263680000000136
# i = 15
# 1.0543349999999805
# i = 16
# 1.1668109999999956
# i = 17
# 1.0959460000000263
# i = 18
# 1.0101980000000026
# i = 19
# 1.1452060000000301

# %%
#Processing secc send
with open('csv/DataLink/no_interf/secc_send_no_interf.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_secc_send = []
    seq_num_secc_send = []
    data_length_secc_send = []
    info_secc_send = []
    frame_num_secc_send = []
    
    for row in rows:
        timelist_secc_send.append(float(row['Time']))
        seq_num_secc_send.append(int(row['Sequence number']))
        data_length_secc_send.append(int(row['Data Length']))
        info_secc_send.append(str(row['Info']))
        frame_num_secc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_secc_send) != len(seq_num_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(data_length_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(info_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(frame_num_secc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send))
# Out:
# 1246

# %%
timelist_secc_send_split = []
seq_num_secc_send_split = []
data_length_secc_send_split = []
info_secc_send_split = []
frame_num_secc_send_split = []

round_start_point = 0
round_end_point = 0

sdpres_index_list = []
#Fetch first packet index of data length = 92 (SDP response) in each round
for i in range(0, len(data_length_secc_send)):
    if(i == 0 and data_length_secc_send[i] == 92):
        sdpres_index_list.append(i)
    if(i > 0 and data_length_secc_send[i] == 92 and data_length_secc_send[i-1] != 92):
        sdpres_index_list.append(i)
sdpres_index_list.append(len(data_length_secc_send)) #Add the end of list index

for i in range(0, len(sdpres_index_list)-1):
        timelist_secc_send_split.append([timelist_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        seq_num_secc_send_split.append([seq_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        data_length_secc_send_split.append([data_length_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        info_secc_send_split.append([info_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        frame_num_secc_send_split.append([frame_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])

# %%
#for debug
if(len(timelist_secc_send_split) != len(seq_num_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(data_length_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(info_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(frame_num_secc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i))
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0
# 86
# i = 1
# 47
# i = 2
# 51
# i = 3
# 32
# i = 4
# 52
# i = 5
# 50
# i = 6
# 51
# i = 7
# 50
# i = 8
# 50
# i = 9
# 63
# i = 10
# 55
# i = 11
# 65
# i = 12
# 125
# i = 13
# 71
# i = 14
# 76
# i = 15
# 59
# i = 16
# 113
# i = 17
# 50
# i = 18
# 52
# i = 19
# 48

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 19.527537999999996
# 19.268093
# 19.453468
# 19.356639
# 19.352867000000003
# 19.045466999999988
# 19.250875000000008
# 19.251598
# 19.38032899999999
# 19.019340999999997
# 19.363537000000008
# 21.290701999999982
# 20.78558400000003
# 19.55245500000001
# 19.678656999999987
# 19.13521400000002
# 19.569443999999976
# 19.239013999999997
# 19.158953999999994

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i) + ' ', end = '')
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0 86
# i = 1 47
# i = 2 51
# i = 3 32
# i = 4 52
# i = 5 50
# i = 6 51
# i = 7 50
# i = 8 50
# i = 9 63
# i = 10 55
# i = 11 65
# i = 12 125
# i = 13 71
# i = 14 76
# i = 15 59
# i = 16 113
# i = 17 50
# i = 18 52
# i = 19 48

# %%
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 19.527537999999996
# 19.268093
# 19.453468
# 19.356639
# 19.352867000000003
# 19.045466999999988
# 19.250875000000008
# 19.251598
# 19.38032899999999
# 19.019340999999997
# 19.363537000000008
# 21.290701999999982
# 20.78558400000003
# 19.55245500000001
# 19.678656999999987
# 19.13521400000002
# 19.569443999999976
# 19.239013999999997
# 19.158953999999994

# %%
#Set secc time anchor in each round per stage
secc_send_time_anchor = []
#data_length_in_each_stage = [92, 173, 157, 189, 253, 173, 189, 173, 493, 173]
wierd_packet_secc = {}
packet_loss_testing_round_14_flag = False
packet_loss_testing_round_8_flag = False
packet_loss_testing_round_9_flag = False
packet_loss_testing_round_19_flag = False

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(secc_send_time_anchor_each_round):
    print("Time difference: " + str(secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-1]-
                          secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        return True
    else:
        #debug
        print("\nWhat is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet_secc[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet_secc.get(frameNum) != None):
        del wierd_packet_secc[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_secc_send_split)):
#for i in [19]:
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    secc_send_time_anchor_each_round = [timelist_secc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_secc_send_split[i][0], info_secc_send_split[i][0])
    stageNum = stageNum + 1
    
    for j in range(1, len(data_length_secc_send_split[i])):
        #Stage 2
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 2, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 3
        if(data_length_secc_send_split[i][j] == 157 and data_length_secc_send_split[i][j-1] != 157):
            if(checkstage_num(stageNum, 3, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 4
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 4, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                    
                continue
                
        #Stage 5
        if(data_length_secc_send_split[i][j] == 253 and data_length_secc_send_split[i][j-1] != 253):
            if(checkstage_num(stageNum, 5, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 6
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 6, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 7
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 7, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 8
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 8, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    #Deal with packet loss......
                    if(i == 14 and packet_loss_testing_round_14_flag == False):
                        secc_send_time_anchor_each_round.append(299.682)
                        printinfo(stageNum, 47893, "Packet Loss")
                        print_time_difference(secc_send_time_anchor_each_round)
                        stageNum = stageNum + 1
                        packet_loss_testing_round_14_flag = True
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 9
        if(data_length_secc_send_split[i][j] == 493 and data_length_secc_send_split[i][j-1] != 493):
            if(checkstage_num(stageNum, 9, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 8 and packet_loss_testing_round_8_flag == False):
                    secc_send_time_anchor_each_round.append(180.237289)
                    printinfo(stageNum, 28705, "Packet Loss")
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_8_flag = True
                    
                #Deal with packet loss......
                if(i == 9 and packet_loss_testing_round_9_flag == False):
                    secc_send_time_anchor_each_round.append(199.635738)
                    printinfo(stageNum, 32170, "Packet Loss")
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_9_flag = True
                    
                #Deal with packet loss......
                if(i == 19 and packet_loss_testing_round_19_flag == False):
                    secc_send_time_anchor_each_round.append(396.538744)
                    printinfo(stageNum, 64764, "Packet Loss")
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_19_flag = True
                
                continue
                
        #Stage 10
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        
        if(stageNum == 11): break
        
    secc_send_time_anchor.append(secc_send_time_anchor_each_round)
# Out:
# -------- Test Round 1 --------
# -----------------------------------------
# Stage 1 finish. No. 3708, Info QoS Data, SN=3646, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 3915, Info QoS Data, SN=3658, FN=0, Flags=.p.....TC
# Time difference: 0.5954239999999977
# -----------------------------------------
# Stage 3 finish. No. 3954, Info QoS Data, SN=3660, FN=0, Flags=.p.....TC
# Time difference: 0.18634899999999988
# -----------------------------------------
# Stage 4 finish. No. 4001, Info QoS Data, SN=3662, FN=0, Flags=.p.....TC
# Time difference: 0.1023510000000023
# -----------------------------------------
# Stage 5 finish. No. 4040, Info QoS Data, SN=3664, FN=0, Flags=.p.....TC
# Time difference: 0.03285800000000094
#
# What is this packet? Data Length = 173 No. 4073
# Time 25.717797 #Seq 3666 Info QoS Data, SN=3666, FN=0, Flags=.p.....TC
#
#
# No. 4073 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 4073, Info QoS Data, SN=3666, FN=0, Flags=.p.....TC
# Time difference: 0.07928899999999928
#
# What is this packet? Data Length = 189 No. 4116
# Time 25.914922 #Seq 3668 Info QoS Data, SN=3668, FN=0, Flags=.p.....TC
#
#
# No. 4116 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 4116, Info QoS Data, SN=3668, FN=0, Flags=.p.....TC
# Time difference: 0.19712499999999977
#
# What is this packet? Data Length = 173 No. 4155
# Time 26.013819 #Seq 3670 Info QoS Data, SN=3670, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 4155
# Time 26.013819 #Seq 3670 Info QoS Data, SN=3670, FN=0, Flags=.p.....TC
#
#
# No. 4155 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 4155, Info QoS Data, SN=3670, FN=0, Flags=.p.....TC
# Time difference: 0.0988970000000009
# -----------------------------------------
# Stage 9 finish. No. 4192, Info QoS Data, SN=3672, FN=0, Flags=.p.....TC
# Time difference: 0.033693999999997004
#
# What is this packet? Data Length = 173 No. 4228
# Time 26.118678 #Seq 3674 Info QoS Data, SN=3674, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 4228
# Time 26.118678 #Seq 3674 Info QoS Data, SN=3674, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 4228
# Time 26.118678 #Seq 3674 Info QoS Data, SN=3674, FN=0, Flags=.p.....TC
#
#
# No. 4228 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 4228, Info QoS Data, SN=3674, FN=0, Flags=.p.....TC
# Time difference: 0.07116500000000059
#
# -------- Test Round 2 --------
# -----------------------------------------
# Stage 1 finish. No. 5972, Info QoS Data, SN=3703, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 6247, Info QoS Data, SN=3715, FN=0, Flags=.p.....TC
# Time difference: 0.449893000000003
# -----------------------------------------
# Stage 3 finish. No. 6275, Info QoS Data, SN=3717, FN=0, Flags=.p.....TC
# Time difference: 0.04450599999999838
# -----------------------------------------
# Stage 4 finish. No. 6349, Info QoS Data, SN=3719, FN=0, Flags=.p.....TC
# Time difference: 0.06969800000000248
# -----------------------------------------
# Stage 5 finish. No. 6384, Info QoS Data, SN=3722, FN=0, Flags=.p.....TC
# Time difference: 0.020103999999996347
#
# What is this packet? Data Length = 173 No. 6421
# Time 44.895208 #Seq 3724 Info QoS Data, SN=3724, FN=0, Flags=.p.....TC
#
#
# No. 6421 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 6421, Info QoS Data, SN=3724, FN=0, Flags=.p.....TC
# Time difference: 0.061942999999999415
#
# What is this packet? Data Length = 189 No. 6566
# Time 45.06718 #Seq 3727 Info QoS Data, SN=3727, FN=0, Flags=.p.....TC
#
#
# No. 6566 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 6566, Info QoS Data, SN=3727, FN=0, Flags=.p.....TC
# Time difference: 0.1719720000000038
#
# What is this packet? Data Length = 173 No. 6603
# Time 45.173644 #Seq 3729 Info QoS Data, SN=3729, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 6603
# Time 45.173644 #Seq 3729 Info QoS Data, SN=3729, FN=0, Flags=.p.....TC
#
#
# No. 6603 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 6603, Info QoS Data, SN=3729, FN=0, Flags=.p.....TC
# Time difference: 0.10646400000000256
# -----------------------------------------
# Stage 9 finish. No. 6633, Info QoS Data, SN=3731, FN=0, Flags=.p.....TC
# Time difference: 0.031137999999998556
#
# What is this packet? Data Length = 173 No. 6705
# Time 45.263721 #Seq 3733 Info QoS Data, SN=3733, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 6705
# Time 45.263721 #Seq 3733 Info QoS Data, SN=3733, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 6705
# Time 45.263721 #Seq 3733 Info QoS Data, SN=3733, FN=0, Flags=.p.....TC
#
#
# No. 6705 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 6705, Info QoS Data, SN=3733, FN=0, Flags=.p.....TC
# Time difference: 0.05893899999999519
#
# -------- Test Round 3 --------
# -----------------------------------------
# Stage 1 finish. No. 13280, Info QoS Data, SN=3800, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 13474, Info QoS Data, SN=3813, FN=0, Flags=.p.....TC
# Time difference: 0.6244240000000048
# -----------------------------------------
# Stage 3 finish. No. 13501, Info QoS Data, SN=3815, FN=0, Flags=.p.....TC
# Time difference: 0.03812200000000132
# -----------------------------------------
# Stage 4 finish. No. 13535, Info QoS Data, SN=3817, FN=0, Flags=.p.....TC
# Time difference: 0.07525699999999347
# -----------------------------------------
# Stage 5 finish. No. 13561, Info QoS Data, SN=3819, FN=0, Flags=.p.....TC
# Time difference: 0.02847500000000025
#
# What is this packet? Data Length = 173 No. 13591
# Time 64.341578 #Seq 3821 Info QoS Data, SN=3821, FN=0, Flags=.p.....TC
#
#
# No. 13591 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 13591, Info QoS Data, SN=3821, FN=0, Flags=.p.....TC
# Time difference: 0.058143000000001166
#
# What is this packet? Data Length = 189 No. 13632
# Time 64.507294 #Seq 3823 Info QoS Data, SN=3823, FN=0, Flags=.p.....TC
#
#
# No. 13632 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 13632, Info QoS Data, SN=3823, FN=0, Flags=.p.....TC
# Time difference: 0.1657160000000033
#
# What is this packet? Data Length = 173 No. 13663
# Time 64.59737 #Seq 3825 Info QoS Data, SN=3825, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 13663
# Time 64.59737 #Seq 3825 Info QoS Data, SN=3825, FN=0, Flags=.p.....TC
#
#
# No. 13663 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 13663, Info QoS Data, SN=3825, FN=0, Flags=.p.....TC
# Time difference: 0.09007599999999627
# -----------------------------------------
# Stage 9 finish. No. 13692, Info QoS Data, SN=3827, FN=0, Flags=.p.....TC
# Time difference: 0.03780799999999829
#
# What is this packet? Data Length = 173 No. 13713
# Time 64.700528 #Seq 3829 Info QoS Data, SN=3829, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 13713
# Time 64.700528 #Seq 3829 Info QoS Data, SN=3829, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 13713
# Time 64.700528 #Seq 3829 Info QoS Data, SN=3829, FN=0, Flags=.p.....TC
#
#
# No. 13713 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 13713, Info QoS Data, SN=3829, FN=0, Flags=.p.....TC
# Time difference: 0.06535000000000935
#
# -------- Test Round 4 --------
# -----------------------------------------
# Stage 1 finish. No. 16098, Info QoS Data, SN=3858, FN=0, Flags=.p.....TC
#
# What is this packet? Data Length = 189 No. 16254
# Time 83.9804 #Seq 3881 Info QoS Data, SN=3881, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 189 No. 16254
# Time 83.9804 #Seq 3881 Info QoS Data, SN=3881, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 2 finish. No. 16284, Info QoS Data, SN=3884, FN=0, Flags=.p.....TC
# Time difference: 1.116575999999995
#
# What is this packet? Data Length = 173 No. 17310
# Time 94.457689 #Seq 3905 Info QoS Data, SN=3905, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 17310
# Time 94.457689 #Seq 3905 Info QoS Data, SN=3905, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 17310
# Time 94.457689 #Seq 3905 Info QoS Data, SN=3905, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 17310
# Time 94.457689 #Seq 3905 Info QoS Data, SN=3905, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 17331
# Time 94.467485 #Seq 3907 Info QoS Data, SN=3907, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 17331
# Time 94.467485 #Seq 3907 Info QoS Data, SN=3907, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 17331
# Time 94.467485 #Seq 3907 Info QoS Data, SN=3907, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 17331
# Time 94.467485 #Seq 3907 Info QoS Data, SN=3907, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 18442, Info QoS Data, SN=3911, FN=0, Flags=.p.....TC
# Time difference: 15.391013000000001
#
# -------- Test Round 5 --------
# -----------------------------------------
# Stage 1 finish. No. 18947, Info QoS Data, SN=3914, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 19232, Info QoS Data, SN=3931, FN=0, Flags=.p.....TC
# Time difference: 0.742440000000002
# -----------------------------------------
# Stage 3 finish. No. 19258, Info QoS Data, SN=3933, FN=0, Flags=.p.....TC
# Time difference: 0.043784000000002266
# -----------------------------------------
# Stage 4 finish. No. 19287, Info QoS Data, SN=3935, FN=0, Flags=.p.....TC
# Time difference: 0.06804499999999791
# -----------------------------------------
# Stage 5 finish. No. 19343, Info QoS Data, SN=3937, FN=0, Flags=.p.....TC
# Time difference: 0.016773000000000593
#
# What is this packet? Data Length = 173 No. 19392
# Time 103.253812 #Seq 3940 Info QoS Data, SN=3940, FN=0, Flags=.p.....TC
#
#
# No. 19392 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 19392, Info QoS Data, SN=3940, FN=0, Flags=.p.....TC
# Time difference: 0.05550599999999406
#
# What is this packet? Data Length = 189 No. 19441
# Time 103.424801 #Seq 3942 Info QoS Data, SN=3942, FN=0, Flags=.p.....TC
#
#
# No. 19441 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 19441, Info QoS Data, SN=3942, FN=0, Flags=.p.....TC
# Time difference: 0.17098900000000583
#
# What is this packet? Data Length = 173 No. 19480
# Time 103.518974 #Seq 3944 Info QoS Data, SN=3944, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 19480
# Time 103.518974 #Seq 3944 Info QoS Data, SN=3944, FN=0, Flags=.p.....TC
#
#
# No. 19480 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 19480, Info QoS Data, SN=3944, FN=0, Flags=.p.....TC
# Time difference: 0.09417299999999784
# -----------------------------------------
# Stage 9 finish. No. 19508, Info QoS Data, SN=3946, FN=0, Flags=.p.....TC
# Time difference: 0.027833000000001107
#
# What is this packet? Data Length = 173 No. 19533
# Time 103.60957 #Seq 3948 Info QoS Data, SN=3948, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 19533
# Time 103.60957 #Seq 3948 Info QoS Data, SN=3948, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 19533
# Time 103.60957 #Seq 3948 Info QoS Data, SN=3948, FN=0, Flags=.p.....TC
#
#
# No. 19533 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 19533, Info QoS Data, SN=3948, FN=0, Flags=.p.....TC
# Time difference: 0.0627630000000039
#
# -------- Test Round 6 --------
# -----------------------------------------
# Stage 1 finish. No. 22252, Info QoS Data, SN=3989, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 22413, Info QoS Data, SN=4001, FN=0, Flags=.p.....TC
# Time difference: 0.4302199999999914
# -----------------------------------------
# Stage 3 finish. No. 22437, Info QoS Data, SN=4003, FN=0, Flags=.p.....TC
# Time difference: 0.03717300000000989
# -----------------------------------------
# Stage 4 finish. No. 22466, Info QoS Data, SN=4005, FN=0, Flags=.p.....TC
# Time difference: 0.06329999999999814
# -----------------------------------------
# Stage 5 finish. No. 22492, Info QoS Data, SN=4007, FN=0, Flags=.p.....TC
# Time difference: 0.013885999999999399
#
# What is this packet? Data Length = 173 No. 22521
# Time 122.295066 #Seq 4009 Info QoS Data, SN=4009, FN=0, Flags=.p.....TC
#
#
# No. 22521 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 22521, Info QoS Data, SN=4009, FN=0, Flags=.p.....TC
# Time difference: 0.07035600000000386
#
# What is this packet? Data Length = 189 No. 22556
# Time 122.466234 #Seq 4011 Info QoS Data, SN=4011, FN=0, Flags=.p.....TC
#
#
# No. 22556 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 22556, Info QoS Data, SN=4011, FN=0, Flags=.p.....TC
# Time difference: 0.17116799999999444
#
# What is this packet? Data Length = 173 No. 22585
# Time 122.552765 #Seq 4013 Info QoS Data, SN=4013, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 22585
# Time 122.552765 #Seq 4013 Info QoS Data, SN=4013, FN=0, Flags=.p.....TC
#
#
# No. 22585 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 22585, Info QoS Data, SN=4013, FN=0, Flags=.p.....TC
# Time difference: 0.0865309999999937
# -----------------------------------------
# Stage 9 finish. No. 22611, Info QoS Data, SN=4015, FN=0, Flags=.p.....TC
# Time difference: 0.02349000000000956
#
# What is this packet? Data Length = 173 No. 22638
# Time 122.640354 #Seq 4017 Info QoS Data, SN=4017, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 22638
# Time 122.640354 #Seq 4017 Info QoS Data, SN=4017, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 22638
# Time 122.640354 #Seq 4017 Info QoS Data, SN=4017, FN=0, Flags=.p.....TC
#
#
# No. 22638 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 22638, Info QoS Data, SN=4017, FN=0, Flags=.p.....TC
# Time difference: 0.0640989999999988
#
# -------- Test Round 7 --------
# -----------------------------------------
# Stage 1 finish. No. 24083, Info QoS Data, SN=4043, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 24252, Info QoS Data, SN=4055, FN=0, Flags=.p.....TC
# Time difference: 0.535460999999998
# -----------------------------------------
# Stage 3 finish. No. 24279, Info QoS Data, SN=4057, FN=0, Flags=.p.....TC
# Time difference: 0.03692900000001487
# -----------------------------------------
# Stage 4 finish. No. 24310, Info QoS Data, SN=4059, FN=0, Flags=.p.....TC
# Time difference: 0.08013199999999188
# -----------------------------------------
# Stage 5 finish. No. 24336, Info QoS Data, SN=4061, FN=0, Flags=.p.....TC
# Time difference: 0.016354000000006863
#
# What is this packet? Data Length = 173 No. 24366
# Time 141.459143 #Seq 4063 Info QoS Data, SN=4063, FN=0, Flags=.p.....TC
#
#
# No. 24366 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 24366, Info QoS Data, SN=4063, FN=0, Flags=.p.....TC
# Time difference: 0.06466900000000919
#
# What is this packet? Data Length = 189 No. 24409
# Time 141.625297 #Seq 4065 Info QoS Data, SN=4065, FN=0, Flags=.p.....TC
#
#
# No. 24409 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 24409, Info QoS Data, SN=4065, FN=0, Flags=.p.....TC
# Time difference: 0.1661539999999775
#
# What is this packet? Data Length = 173 No. 24445
# Time 141.713318 #Seq 4067 Info QoS Data, SN=4067, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 24445
# Time 141.713318 #Seq 4067 Info QoS Data, SN=4067, FN=0, Flags=.p.....TC
#
#
# No. 24445 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 24445, Info QoS Data, SN=4067, FN=0, Flags=.p.....TC
# Time difference: 0.08802099999999768
# -----------------------------------------
# Stage 9 finish. No. 24472, Info QoS Data, SN=4069, FN=0, Flags=.p.....TC
# Time difference: 0.018267000000008693
#
# What is this packet? Data Length = 173 No. 24501
# Time 141.797443 #Seq 4071 Info QoS Data, SN=4071, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 24501
# Time 141.797443 #Seq 4071 Info QoS Data, SN=4071, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 24501
# Time 141.797443 #Seq 4071 Info QoS Data, SN=4071, FN=0, Flags=.p.....TC
#
#
# No. 24501 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 24501, Info QoS Data, SN=4071, FN=0, Flags=.p.....TC
# Time difference: 0.06585799999999153
#
# -------- Test Round 8 --------
# -----------------------------------------
# Stage 1 finish. No. 26214, Info QoS Data, SN=2, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 26407, Info QoS Data, SN=19, FN=0, Flags=.p.....TC
# Time difference: 0.3791569999999922
# -----------------------------------------
# Stage 3 finish. No. 26436, Info QoS Data, SN=21, FN=0, Flags=.p.....TC
# Time difference: 0.03342800000001489
# -----------------------------------------
# Stage 4 finish. No. 26464, Info QoS Data, SN=23, FN=0, Flags=.p.....TC
# Time difference: 0.05991799999998193
# -----------------------------------------
# Stage 5 finish. No. 26491, Info QoS Data, SN=25, FN=0, Flags=.p.....TC
# Time difference: 0.009333000000026459
#
# What is this packet? Data Length = 173 No. 26520
# Time 160.510418 #Seq 27 Info QoS Data, SN=27, FN=0, Flags=.p.....TC
#
#
# No. 26520 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 26520, Info QoS Data, SN=27, FN=0, Flags=.p.....TC
# Time difference: 0.052108999999973094
#
# What is this packet? Data Length = 189 No. 26559
# Time 160.673109 #Seq 29 Info QoS Data, SN=29, FN=0, Flags=.p.....TC
#
#
# No. 26559 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 26559, Info QoS Data, SN=29, FN=0, Flags=.p.....TC
# Time difference: 0.16269100000002368
#
# What is this packet? Data Length = 173 No. 26587
# Time 160.756981 #Seq 31 Info QoS Data, SN=31, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 26587
# Time 160.756981 #Seq 31 Info QoS Data, SN=31, FN=0, Flags=.p.....TC
#
#
# No. 26587 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 26587, Info QoS Data, SN=31, FN=0, Flags=.p.....TC
# Time difference: 0.08387199999998529
# -----------------------------------------
# Stage 9 finish. No. 26611, Info QoS Data, SN=33, FN=0, Flags=.p.....TC
# Time difference: 0.025159000000002152
#
# What is this packet? Data Length = 173 No. 26630
# Time 160.84845 #Seq 35 Info QoS Data, SN=35, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 26630
# Time 160.84845 #Seq 35 Info QoS Data, SN=35, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 26630
# Time 160.84845 #Seq 35 Info QoS Data, SN=35, FN=0, Flags=.p.....TC
#
#
# No. 26630 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 26630, Info QoS Data, SN=35, FN=0, Flags=.p.....TC
# Time difference: 0.06631000000001563
#
# -------- Test Round 9 --------
# -----------------------------------------
# Stage 1 finish. No. 28276, Info QoS Data, SN=72, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 28466, Info QoS Data, SN=84, FN=0, Flags=.p.....TC
# Time difference: 0.5285900000000083
# -----------------------------------------
# Stage 3 finish. No. 28492, Info QoS Data, SN=86, FN=0, Flags=.p.....TC
# Time difference: 0.04115600000000086
# -----------------------------------------
# Stage 4 finish. No. 28524, Info QoS Data, SN=88, FN=0, Flags=.p.....TC
# Time difference: 0.060997999999983676
# -----------------------------------------
# Stage 5 finish. No. 28549, Info QoS Data, SN=90, FN=0, Flags=.p.....TC
# Time difference: 0.013654999999999973
#
# What is this packet? Data Length = 173 No. 28576
# Time 179.929016 #Seq 92 Info QoS Data, SN=92, FN=0, Flags=.p.....TC
#
#
# No. 28576 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 28576, Info QoS Data, SN=92, FN=0, Flags=.p.....TC
# Time difference: 0.05654599999999732
#
# What is this packet? Data Length = 189 No. 28619
# Time 180.078413 #Seq 95 Info QoS Data, SN=95, FN=0, Flags=.p.....TC
#
#
# No. 28619 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 28619, Info QoS Data, SN=95, FN=0, Flags=.p.....TC
# Time difference: 0.14939700000002176
#
# What is this packet? Data Length = 173 No. 28653
# Time 180.160349 #Seq 97 Info QoS Data, SN=97, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 28653
# Time 180.160349 #Seq 97 Info QoS Data, SN=97, FN=0, Flags=.p.....TC
#
#
# No. 28653 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 28653, Info QoS Data, SN=97, FN=0, Flags=.p.....TC
# Time difference: 0.08193599999998469
# -----------------------------------------
# Stage 9 finish. No. 28678, Info QoS Data, SN=99, FN=0, Flags=.p.....TC
# Time difference: 0.015569999999996753
# -----------------------------------------
# Stage 10 finish. No. 28705, Info Packet Loss
# Time difference: 0.061370000000010805
#
# -------- Test Round 10 --------
# -----------------------------------------
# Stage 1 finish. No. 31758, Info QoS Data, SN=129, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 31941, Info QoS Data, SN=141, FN=0, Flags=.p.....TC
# Time difference: 0.5109390000000076
# -----------------------------------------
# Stage 3 finish. No. 31967, Info QoS Data, SN=143, FN=0, Flags=.p.....TC
# Time difference: 0.03576000000001045
# -----------------------------------------
# Stage 4 finish. No. 32000, Info QoS Data, SN=145, FN=0, Flags=.p.....TC
# Time difference: 0.08011399999998048
# -----------------------------------------
# Stage 5 finish. No. 32024, Info QoS Data, SN=147, FN=0, Flags=.p.....TC
# Time difference: 0.015848000000005413
#
# What is this packet? Data Length = 173 No. 32053
# Time 199.308849 #Seq 149 Info QoS Data, SN=149, FN=0, Flags=.p.....TC
#
#
# No. 32053 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 32053, Info QoS Data, SN=149, FN=0, Flags=.p.....TC
# Time difference: 0.05778800000001638
#
# What is this packet? Data Length = 189 No. 32090
# Time 199.470921 #Seq 151 Info QoS Data, SN=151, FN=0, Flags=.p.....TC
#
#
# No. 32090 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 32090, Info QoS Data, SN=151, FN=0, Flags=.p.....TC
# Time difference: 0.1620719999999949
#
# What is this packet? Data Length = 173 No. 32118
# Time 199.553649 #Seq 153 Info QoS Data, SN=153, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 32118
# Time 199.553649 #Seq 153 Info QoS Data, SN=153, FN=0, Flags=.p.....TC
#
#
# No. 32118 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 32118, Info QoS Data, SN=153, FN=0, Flags=.p.....TC
# Time difference: 0.08272800000000302
# -----------------------------------------
# Stage 9 finish. No. 32142, Info QoS Data, SN=155, FN=0, Flags=.p.....TC
# Time difference: 0.022334999999998217
# -----------------------------------------
# Stage 10 finish. No. 32170, Info Packet Loss
# Time difference: 0.059753999999998086
#
# -------- Test Round 11 --------
# -----------------------------------------
# Stage 1 finish. No. 35282, Info QoS Data, SN=191, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 35536, Info QoS Data, SN=204, FN=0, Flags=.p.....TC
# Time difference: 0.6396530000000098
# -----------------------------------------
# Stage 3 finish. No. 35563, Info QoS Data, SN=206, FN=0, Flags=.p.....TC
# Time difference: 0.03208399999999756
# -----------------------------------------
# Stage 4 finish. No. 35591, Info QoS Data, SN=208, FN=0, Flags=.p.....TC
# Time difference: 0.05879300000000853
# -----------------------------------------
# Stage 5 finish. No. 35615, Info QoS Data, SN=210, FN=0, Flags=.p.....TC
# Time difference: 0.009269999999986567
#
# What is this packet? Data Length = 173 No. 35643
# Time 218.425731 #Seq 212 Info QoS Data, SN=212, FN=0, Flags=.p.....TC
#
#
# No. 35643 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 35643, Info QoS Data, SN=212, FN=0, Flags=.p.....TC
# Time difference: 0.05819000000002461
#
# What is this packet? Data Length = 189 No. 35679
# Time 218.58981 #Seq 214 Info QoS Data, SN=214, FN=0, Flags=.p.....TC
#
#
# No. 35679 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 35679, Info QoS Data, SN=214, FN=0, Flags=.p.....TC
# Time difference: 0.16407899999998676
#
# What is this packet? Data Length = 173 No. 35708
# Time 218.666043 #Seq 216 Info QoS Data, SN=216, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 35708
# Time 218.666043 #Seq 216 Info QoS Data, SN=216, FN=0, Flags=.p.....TC
#
#
# No. 35708 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 35708, Info QoS Data, SN=216, FN=0, Flags=.p.....TC
# Time difference: 0.076233000000002
# -----------------------------------------
# Stage 9 finish. No. 35732, Info QoS Data, SN=218, FN=0, Flags=.p.....TC
# Time difference: 0.020542000000006055
#
# What is this packet? Data Length = 173 No. 35758
# Time 218.752105 #Seq 220 Info QoS Data, SN=220, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 35758
# Time 218.752105 #Seq 220 Info QoS Data, SN=220, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 35758
# Time 218.752105 #Seq 220 Info QoS Data, SN=220, FN=0, Flags=.p.....TC
#
#
# No. 35758 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 35758, Info QoS Data, SN=220, FN=0, Flags=.p.....TC
# Time difference: 0.06551999999999225
#
# -------- Test Round 12 --------
# -----------------------------------------
# Stage 1 finish. No. 38351, Info QoS Data, SN=268, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 38528, Info QoS Data, SN=280, FN=0, Flags=.p.....TC
# Time difference: 0.7883020000000158
# -----------------------------------------
# Stage 3 finish. No. 38550, Info QoS Data, SN=282, FN=0, Flags=.p.....TC
# Time difference: 0.060120999999980995
# -----------------------------------------
# Stage 4 finish. No. 38608, Info QoS Data, SN=285, FN=0, Flags=.p.....TC
# Time difference: 0.2707410000000152
# -----------------------------------------
# Stage 5 finish. No. 38629, Info QoS Data, SN=287, FN=0, Flags=.p.....TC
# Time difference: 0.01575299999998947
#
# What is this packet? Data Length = 173 No. 38654
# Time 238.202428 #Seq 290 Info QoS Data, SN=290, FN=0, Flags=.p.....TC
#
#
# No. 38654 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 38654, Info QoS Data, SN=290, FN=0, Flags=.p.....TC
# Time difference: 0.076233000000002
#
# What is this packet? Data Length = 189 No. 38749
# Time 238.470584 #Seq 292 Info QoS Data, SN=292, FN=0, Flags=.p.....TC
#
#
# No. 38749 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 38749, Info QoS Data, SN=292, FN=0, Flags=.p.....TC
# Time difference: 0.2681560000000047
#
# What is this packet? Data Length = 173 No. 38804
# Time 238.643491 #Seq 294 Info QoS Data, SN=294, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 38804
# Time 238.643491 #Seq 294 Info QoS Data, SN=294, FN=0, Flags=.p.....TC
#
#
# No. 38804 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 38804, Info QoS Data, SN=294, FN=0, Flags=.p.....TC
# Time difference: 0.17290700000000925
# -----------------------------------------
# Stage 9 finish. No. 38831, Info QoS Data, SN=296, FN=0, Flags=.p.....TC
# Time difference: 0.07522699999998395
#
# What is this packet? Data Length = 173 No. 38904
# Time 238.974618 #Seq 298 Info QoS Data, SN=298, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 38904
# Time 238.974618 #Seq 298 Info QoS Data, SN=298, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 38904
# Time 238.974618 #Seq 298 Info QoS Data, SN=298, FN=0, Flags=.p.....TC
#
#
# No. 38904 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 38904, Info QoS Data, SN=298, FN=0, Flags=.p.....TC
# Time difference: 0.2558999999999969
#
# -------- Test Round 13 --------
# -----------------------------------------
# Stage 1 finish. No. 42720, Info QoS Data, SN=334, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 42954, Info QoS Data, SN=346, FN=0, Flags=.p.....TC
# Time difference: 1.0021690000000376
# -----------------------------------------
# Stage 3 finish. No. 43009, Info QoS Data, SN=348, FN=0, Flags=.p.....TC
# Time difference: 0.09619199999997363
# -----------------------------------------
# Stage 4 finish. No. 43067, Info QoS Data, SN=350, FN=0, Flags=.p.....TC
# Time difference: 0.08429899999998725
# -----------------------------------------
# Stage 5 finish. No. 43111, Info QoS Data, SN=352, FN=0, Flags=.p.....TC
# Time difference: 0.06728000000003931
#
# What is this packet? Data Length = 173 No. 43148
# Time 259.61946 #Seq 354 Info QoS Data, SN=354, FN=0, Flags=.p.....TC
#
#
# No. 43148 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 43148, Info QoS Data, SN=354, FN=0, Flags=.p.....TC
# Time difference: 0.08753999999998996
#
# What is this packet? Data Length = 189 No. 43199
# Time 259.899115 #Seq 356 Info QoS Data, SN=356, FN=0, Flags=.p.....TC
#
#
# No. 43199 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 43199, Info QoS Data, SN=356, FN=0, Flags=.p.....TC
# Time difference: 0.2796549999999911
#
# What is this packet? Data Length = 173 No. 43241
# Time 260.037516 #Seq 358 Info QoS Data, SN=358, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 43241
# Time 260.037516 #Seq 358 Info QoS Data, SN=358, FN=0, Flags=.p.....TC
#
#
# No. 43241 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 43241, Info QoS Data, SN=358, FN=0, Flags=.p.....TC
# Time difference: 0.13840099999998756
# -----------------------------------------
# Stage 9 finish. No. 43275, Info QoS Data, SN=360, FN=0, Flags=.p.....TC
# Time difference: 0.042212000000006356
#
# What is this packet? Data Length = 173 No. 43358
# Time 260.334382 #Seq 363 Info QoS Data, SN=363, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 43358
# Time 260.334382 #Seq 363 Info QoS Data, SN=363, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 43358
# Time 260.334382 #Seq 363 Info QoS Data, SN=363, FN=0, Flags=.p.....TC
#
#
# No. 43358 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 43358, Info QoS Data, SN=363, FN=0, Flags=.p.....TC
# Time difference: 0.25465400000001637
#
# -------- Test Round 14 --------
# -----------------------------------------
# Stage 1 finish. No. 45243, Info QoS Data, SN=392, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 45457, Info QoS Data, SN=404, FN=0, Flags=.p.....TC
# Time difference: 0.7363080000000082
# -----------------------------------------
# Stage 3 finish. No. 45481, Info QoS Data, SN=406, FN=0, Flags=.p.....TC
# Time difference: 0.03607299999998759
# -----------------------------------------
# Stage 4 finish. No. 45504, Info QoS Data, SN=408, FN=0, Flags=.p.....TC
# Time difference: 0.06176099999998996
# -----------------------------------------
# Stage 5 finish. No. 45524, Info QoS Data, SN=410, FN=0, Flags=.p.....TC
# Time difference: 0.010516999999993004
#
# What is this packet? Data Length = 173 No. 45552
# Time 279.974298 #Seq 412 Info QoS Data, SN=412, FN=0, Flags=.p..R..TC
#
#
# No. 45552 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 45552, Info QoS Data, SN=412, FN=0, Flags=.p..R..TC
# Time difference: 0.062074999999993
#
# What is this packet? Data Length = 189 No. 45626
# Time 280.164019 #Seq 419 Info QoS Data, SN=419, FN=0, Flags=.p.....TC
#
#
# No. 45626 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 45626, Info QoS Data, SN=419, FN=0, Flags=.p.....TC
# Time difference: 0.18972100000002
#
# What is this packet? Data Length = 173 No. 45656
# Time 280.249297 #Seq 421 Info QoS Data, SN=421, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 45656
# Time 280.249297 #Seq 421 Info QoS Data, SN=421, FN=0, Flags=.p.....TC
#
#
# No. 45656 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 45656, Info QoS Data, SN=421, FN=0, Flags=.p.....TC
# Time difference: 0.08527800000001662
# -----------------------------------------
# Stage 9 finish. No. 45682, Info QoS Data, SN=423, FN=0, Flags=.p.....TC
# Time difference: 0.020804999999995744
#
# What is this packet? Data Length = 173 No. 45709
# Time 280.330446 #Seq 425 Info QoS Data, SN=425, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 45709
# Time 280.330446 #Seq 425 Info QoS Data, SN=425, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 45709
# Time 280.330446 #Seq 425 Info QoS Data, SN=425, FN=0, Flags=.p.....TC
#
#
# No. 45709 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 45709, Info QoS Data, SN=425, FN=0, Flags=.p.....TC
# Time difference: 0.06034399999998641
#
# -------- Test Round 15 --------
# -----------------------------------------
# Stage 1 finish. No. 47470, Info QoS Data, SN=462, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 47651, Info QoS Data, SN=475, FN=0, Flags=.p.....TC
# Time difference: 0.6439290000000142
# -----------------------------------------
# Stage 3 finish. No. 47676, Info QoS Data, SN=477, FN=0, Flags=.p.....TC
# Time difference: 0.038815999999997075
# -----------------------------------------
# Stage 4 finish. No. 47704, Info QoS Data, SN=479, FN=0, Flags=.p.....TC
# Time difference: 0.061216000000001713
# -----------------------------------------
# Stage 5 finish. No. 47728, Info QoS Data, SN=481, FN=0, Flags=.p.....TC
# Time difference: 0.016093999999952757
#
# What is this packet? Data Length = 173 No. 47755
# Time 299.438039 #Seq 483 Info QoS Data, SN=483, FN=0, Flags=.p.....TC
#
#
# No. 47755 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 47755, Info QoS Data, SN=483, FN=0, Flags=.p.....TC
# Time difference: 0.05796500000002425
#
# What is this packet? Data Length = 189 No. 47806
# Time 299.587145 #Seq 486 Info QoS Data, SN=486, FN=0, Flags=.p.....TC
#
#
# No. 47806 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 47806, Info QoS Data, SN=486, FN=0, Flags=.p.....TC
# Time difference: 0.1491060000000175
#
# What is this packet? Data Length = 173 No. 47851
# Time 299.665667 #Seq 488 Info QoS Data, SN=488, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 47851
# Time 299.665667 #Seq 488 Info QoS Data, SN=488, FN=0, Flags=.p.....TC
#
#
# No. 47851 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 47851, Info QoS Data, SN=488, FN=0, Flags=.p.....TC
# Time difference: 0.07852199999996401
# -----------------------------------------
# Stage 9 finish. No. 47893, Info Packet Loss
# Time difference: 0.01633300000003146
#
# What is this packet? Data Length = 173 No. 47919
# Time 299.752597 #Seq 492 Info QoS Data, SN=492, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 47919
# Time 299.752597 #Seq 492 Info QoS Data, SN=492, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 47919
# Time 299.752597 #Seq 492 Info QoS Data, SN=492, FN=0, Flags=.p.....TC
#
#
# No. 47919 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 47919, Info QoS Data, SN=492, FN=0, Flags=.p.....TC
# Time difference: 0.07059699999996383
#
# -------- Test Round 16 --------
# -----------------------------------------
# Stage 1 finish. No. 51998, Info QoS Data, SN=684, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 52240, Info QoS Data, SN=697, FN=0, Flags=.p.....TC
# Time difference: 0.5219430000000216
# -----------------------------------------
# Stage 3 finish. No. 52269, Info QoS Data, SN=699, FN=0, Flags=.p.....TC
# Time difference: 0.03736199999997325
# -----------------------------------------
# Stage 4 finish. No. 52305, Info QoS Data, SN=701, FN=0, Flags=.p.....TC
# Time difference: 0.06038899999998648
# -----------------------------------------
# Stage 5 finish. No. 52338, Info QoS Data, SN=703, FN=0, Flags=.p.....TC
# Time difference: 0.01423800000003439
#
# What is this packet? Data Length = 173 No. 52368
# Time 319.012324 #Seq 705 Info QoS Data, SN=705, FN=0, Flags=.p.....TC
#
#
# No. 52368 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 52368, Info QoS Data, SN=705, FN=0, Flags=.p.....TC
# Time difference: 0.07971599999996215
#
# What is this packet? Data Length = 189 No. 52426
# Time 319.173714 #Seq 707 Info QoS Data, SN=707, FN=0, Flags=.p.....TC
#
#
# No. 52426 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 52426, Info QoS Data, SN=707, FN=0, Flags=.p.....TC
# Time difference: 0.1613900000000399
#
# What is this packet? Data Length = 173 No. 52458
# Time 319.263514 #Seq 709 Info QoS Data, SN=709, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 52458
# Time 319.263514 #Seq 709 Info QoS Data, SN=709, FN=0, Flags=.p.....TC
#
#
# No. 52458 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 52458, Info QoS Data, SN=709, FN=0, Flags=.p.....TC
# Time difference: 0.08979999999996835
# -----------------------------------------
# Stage 9 finish. No. 52483, Info QoS Data, SN=711, FN=0, Flags=.p.....TC
# Time difference: 0.015944999999987886
#
# What is this packet? Data Length = 173 No. 52516
# Time 319.339893 #Seq 713 Info QoS Data, SN=713, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 52516
# Time 319.339893 #Seq 713 Info QoS Data, SN=713, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 52516
# Time 319.339893 #Seq 713 Info QoS Data, SN=713, FN=0, Flags=.p.....TC
#
#
# No. 52516 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 52516, Info QoS Data, SN=713, FN=0, Flags=.p.....TC
# Time difference: 0.0604340000000434
#
# -------- Test Round 17 --------
# -----------------------------------------
# Stage 1 finish. No. 56310, Info QoS Data, SN=790, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 56581, Info QoS Data, SN=803, FN=0, Flags=.p.....TC
# Time difference: 0.6375620000000026
# -----------------------------------------
# Stage 3 finish. No. 56629, Info QoS Data, SN=805, FN=0, Flags=.p.....TC
# Time difference: 0.04786299999994981
# -----------------------------------------
# Stage 4 finish. No. 56665, Info QoS Data, SN=807, FN=0, Flags=.p.....TC
# Time difference: 0.06340600000004315
# -----------------------------------------
# Stage 5 finish. No. 56704, Info QoS Data, SN=809, FN=0, Flags=.p.....TC
# Time difference: 0.025175999999987653
#
# What is this packet? Data Length = 173 No. 56731
# Time 338.268617 #Seq 811 Info QoS Data, SN=811, FN=0, Flags=.p.....TC
#
#
# No. 56731 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 56731, Info QoS Data, SN=811, FN=0, Flags=.p.....TC
# Time difference: 0.06072000000000344
#
# What is this packet? Data Length = 189 No. 56768
# Time 338.431091 #Seq 813 Info QoS Data, SN=813, FN=0, Flags=.p.....TC
#
#
# No. 56768 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 56768, Info QoS Data, SN=813, FN=0, Flags=.p.....TC
# Time difference: 0.1624739999999747
#
# What is this packet? Data Length = 173 No. 56796
# Time 338.51642 #Seq 815 Info QoS Data, SN=815, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 56796
# Time 338.51642 #Seq 815 Info QoS Data, SN=815, FN=0, Flags=.p.....TC
#
#
# No. 56796 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 56796, Info QoS Data, SN=815, FN=0, Flags=.p.....TC
# Time difference: 0.08532900000000154
# -----------------------------------------
# Stage 9 finish. No. 56822, Info QoS Data, SN=817, FN=0, Flags=.p.....TC
# Time difference: 0.02461199999999053
#
# What is this packet? Data Length = 173 No. 56849
# Time 338.599177 #Seq 819 Info QoS Data, SN=819, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 56849
# Time 338.599177 #Seq 819 Info QoS Data, SN=819, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 56849
# Time 338.599177 #Seq 819 Info QoS Data, SN=819, FN=0, Flags=.p.....TC
#
#
# No. 56849 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 56849, Info QoS Data, SN=819, FN=0, Flags=.p.....TC
# Time difference: 0.05814500000002454
#
# -------- Test Round 18 --------
# -----------------------------------------
# Stage 1 finish. No. 58801, Info QoS Data, SN=863, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 58972, Info QoS Data, SN=874, FN=0, Flags=.p.....TC
# Time difference: 0.5657180000000039
# -----------------------------------------
# Stage 3 finish. No. 59002, Info QoS Data, SN=876, FN=0, Flags=.p.....TC
# Time difference: 0.04027899999999818
# -----------------------------------------
# Stage 4 finish. No. 59034, Info QoS Data, SN=878, FN=0, Flags=.p.....TC
# Time difference: 0.07758799999999155
# -----------------------------------------
# Stage 5 finish. No. 59061, Info QoS Data, SN=880, FN=0, Flags=.p.....TC
# Time difference: 0.019585000000006403
#
# What is this packet? Data Length = 173 No. 59097
# Time 357.770687 #Seq 882 Info QoS Data, SN=882, FN=0, Flags=.p.....TC
#
#
# No. 59097 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 59097, Info QoS Data, SN=882, FN=0, Flags=.p.....TC
# Time difference: 0.06418300000001409
#
# What is this packet? Data Length = 189 No. 59145
# Time 357.925286 #Seq 885 Info QoS Data, SN=885, FN=0, Flags=.p.....TC
#
#
# No. 59145 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 59145, Info QoS Data, SN=885, FN=0, Flags=.p.....TC
# Time difference: 0.1545990000000188
#
# What is this packet? Data Length = 173 No. 59177
# Time 358.012439 #Seq 887 Info QoS Data, SN=887, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 59177
# Time 358.012439 #Seq 887 Info QoS Data, SN=887, FN=0, Flags=.p.....TC
#
#
# No. 59177 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 59177, Info QoS Data, SN=887, FN=0, Flags=.p.....TC
# Time difference: 0.08715299999994386
# -----------------------------------------
# Stage 9 finish. No. 59201, Info QoS Data, SN=889, FN=0, Flags=.p.....TC
# Time difference: 0.014041000000020176
#
# What is this packet? Data Length = 173 No. 59229
# Time 358.089202 #Seq 891 Info QoS Data, SN=891, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 59229
# Time 358.089202 #Seq 891 Info QoS Data, SN=891, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 59229
# Time 358.089202 #Seq 891 Info QoS Data, SN=891, FN=0, Flags=.p.....TC
#
#
# No. 59229 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 59229, Info QoS Data, SN=891, FN=0, Flags=.p.....TC
# Time difference: 0.06272200000000794
#
# -------- Test Round 19 --------
# -----------------------------------------
# Stage 1 finish. No. 62224, Info QoS Data, SN=923, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 62384, Info QoS Data, SN=935, FN=0, Flags=.p.....TC
# Time difference: 0.5336490000000254
# -----------------------------------------
# Stage 3 finish. No. 62414, Info QoS Data, SN=937, FN=0, Flags=.p.....TC
# Time difference: 0.03753000000000384
# -----------------------------------------
# Stage 4 finish. No. 62442, Info QoS Data, SN=939, FN=0, Flags=.p.....TC
# Time difference: 0.06064499999996542
# -----------------------------------------
# Stage 5 finish. No. 62467, Info QoS Data, SN=941, FN=0, Flags=.p.....TC
# Time difference: 0.015156999999987875
#
# What is this packet? Data Length = 173 No. 62495
# Time 376.951114 #Seq 943 Info QoS Data, SN=943, FN=0, Flags=.p.....TC
#
#
# No. 62495 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 62495, Info QoS Data, SN=943, FN=0, Flags=.p.....TC
# Time difference: 0.061785000000043055
#
# What is this packet? Data Length = 189 No. 62540
# Time 377.102511 #Seq 946 Info QoS Data, SN=946, FN=0, Flags=.p.....TC
#
#
# No. 62540 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 62540, Info QoS Data, SN=946, FN=0, Flags=.p.....TC
# Time difference: 0.15139699999997447
#
# What is this packet? Data Length = 173 No. 62569
# Time 377.17815 #Seq 948 Info QoS Data, SN=948, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 62569
# Time 377.17815 #Seq 948 Info QoS Data, SN=948, FN=0, Flags=.p.....TC
#
#
# No. 62569 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 62569, Info QoS Data, SN=948, FN=0, Flags=.p.....TC
# Time difference: 0.07563900000002377
# -----------------------------------------
# Stage 9 finish. No. 62592, Info QoS Data, SN=950, FN=0, Flags=.p.....TC
# Time difference: 0.01492999999999256
#
# What is this packet? Data Length = 173 No. 62619
# Time 377.254742 #Seq 952 Info QoS Data, SN=952, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 62619
# Time 377.254742 #Seq 952 Info QoS Data, SN=952, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 62619
# Time 377.254742 #Seq 952 Info QoS Data, SN=952, FN=0, Flags=.p.....TC
#
#
# No. 62619 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 62619, Info QoS Data, SN=952, FN=0, Flags=.p.....TC
# Time difference: 0.06166200000001254
#
# -------- Test Round 20 --------
# -----------------------------------------
# Stage 1 finish. No. 64351, Info QoS Data, SN=978, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 64527, Info QoS Data, SN=990, FN=0, Flags=.p.....TC
# Time difference: 0.6253000000000384
# -----------------------------------------
# Stage 3 finish. No. 64552, Info QoS Data, SN=992, FN=0, Flags=.p.....TC
# Time difference: 0.03523699999999508
# -----------------------------------------
# Stage 4 finish. No. 64580, Info QoS Data, SN=994, FN=0, Flags=.p.....TC
# Time difference: 0.07251899999999978
# -----------------------------------------
# Stage 5 finish. No. 64604, Info QoS Data, SN=996, FN=0, Flags=.p.....TC
# Time difference: 0.013194999999996071
#
# What is this packet? Data Length = 173 No. 64634
# Time 396.209884 #Seq 998 Info QoS Data, SN=998, FN=0, Flags=.p.....TC
#
#
# No. 64634 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 64634, Info QoS Data, SN=998, FN=0, Flags=.p.....TC
# Time difference: 0.06233099999997194
#
# What is this packet? Data Length = 189 No. 64677
# Time 396.370671 #Seq 1000 Info QoS Data, SN=1000, FN=0, Flags=.p.....TC
#
#
# No. 64677 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 64677, Info QoS Data, SN=1000, FN=0, Flags=.p.....TC
# Time difference: 0.16078700000002755
#
# What is this packet? Data Length = 173 No. 64706
# Time 396.454956 #Seq 1002 Info QoS Data, SN=1002, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 64706
# Time 396.454956 #Seq 1002 Info QoS Data, SN=1002, FN=0, Flags=.p.....TC
#
#
# No. 64706 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 64706, Info QoS Data, SN=1002, FN=0, Flags=.p.....TC
# Time difference: 0.08428499999996575
# -----------------------------------------
# Stage 9 finish. No. 64731, Info QoS Data, SN=1004, FN=0, Flags=.p.....TC
# Time difference: 0.019511000000022705
# -----------------------------------------
# Stage 10 finish. No. 64764, Info Packet Loss
# Time difference: 0.06427700000000414

# %%
#for debug
print(str(len(secc_send_time_anchor)) + '\n')
for i in range(0, len(secc_send_time_anchor)):
    print(str(i) + ": " + str(len(secc_send_time_anchor[i])))
# Out:
# 20
#
# 0: 10
# 1: 10
# 2: 10
# 3: 3
# 4: 10
# 5: 10
# 6: 10
# 7: 10
# 8: 10
# 9: 10
# 10: 10
# 11: 10
# 12: 10
# 13: 10
# 14: 10
# 15: 10
# 16: 10
# 17: 10
# 18: 10
# 19: 10

# %%
#for debug
for i in range(0, len(secc_send_time_anchor)):
    print(secc_send_time_anchor[i][len(secc_send_time_anchor[i])-1]-secc_send_time_anchor[i][0])
# Out:
# 1.3971519999999984
# 1.0146569999999997
# 1.1833710000000082
# 16.507588999999996
# 1.2823060000000055
# 0.9602229999999992
# 1.0718449999999962
# 0.8719770000000153
# 1.0092180000000042
# 1.0273380000000145
# 1.1243640000000141
# 1.9833399999999983
# 2.052402000000029
# 1.2628819999999905
# 1.1325779999999668
# 1.0412170000000174
# 1.165286999999978
# 1.085868000000005
# 1.0123940000000289
# 1.1374420000000214

# %%
#BLOCK ACK processing
#Time evcc sends blockACK after secc send
evcc_blockAck_time_anchor = []

blockack_index = 0
for i in range(0, len(secc_send_time_anchor)):
    evcc_blockAck_time_anchor_in_each_round = []
    
    for j in range(0, len(secc_send_time_anchor[i])):
        while(timelist_block_ack[blockack_index] < secc_send_time_anchor[i][j]):
            blockack_index = blockack_index + 1
        evcc_blockAck_time_anchor_in_each_round.append(timelist_block_ack[blockack_index])
        #print("ACK time difference = " + str(
        #timelist_block_ack[blockack_index] - secc_send_time_anchor[i][j]))
    
    evcc_blockAck_time_anchor.append(evcc_blockAck_time_anchor_in_each_round)

# %%
#SECC Packet Loss dict & Block Ack Loss
#secc_packet_loss_dict[i] = {stageNum}
# i = 5, j = 0 is packet loss of evcc BLOCK ACK
# i = 3, j = 9 is packet loss of evcc BLOCK ACK
secc_packet_loss_dict = {}
secc_packet_loss_dict[11] = {7}
secc_packet_loss_dict[19] = {0, 9}
secc_packet_loss_dict[14] = {8}
secc_packet_loss_dict[8] = {9}
secc_packet_loss_dict[9] = {9}
#secc_packet_loss_dict[5] = {0, 1, 2, 3, 4}

#for i in secc_packet_loss_dict.get(5): print(i)
#7 in secc_packet_loss_dict.get(5)

# %%
#Calculate the avg. block ack latency
sum_latency = 0
cnt = 0
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) == None):
            sum_latency = sum_latency + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
            cnt = cnt + 1
        elif(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)): continue
            else:
                sum_latency = sum_latency + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
                cnt = cnt + 1
        else: continue
avg_blockAck_latency = sum_latency/cnt
print("Avg Block Ack latency = " + str(avg_blockAck_latency) + " s")
print(cnt)
# Out:
# Avg Block Ack latency = 0.010001631016041878 s
# 187

# %%
#For curiousity
#Calculate the avg. block ack latency of the appending packet loss packets
sum_latency_2 = 0
cnt = 0
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)):
                sum_latency_2 = sum_latency_2 + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
                cnt = cnt + 1
        else: continue
avg_blockAck_latency_2 = sum_latency_2/cnt
print("Avg Block Ack latency = " + str(avg_blockAck_latency_2) + " s")
print(cnt)
# Out:
# Avg Block Ack latency = 0.0977424999999954 s
# 6

# %%
#For debug. Can see testing round 6 (i = 5) has longer block ack latency due to packet loss.
# I only append the secc send time, but didn't append the block time.
from statistics import mean

for i in range(0, len(evcc_blockAck_time_anchor)):
    print("i = " + str(i) + ": " + str(mean(evcc_blockAck_time_anchor[i])-mean(secc_send_time_anchor[i])))
# Out:
# i = 0: 0.0025311999999999557
# i = 1: 0.002089300000001515
# i = 2: 0.001136500000001206
# i = 3: 0.0009033333333405835
# i = 4: 0.012360299999997437
# i = 5: 0.0005318999999985863
# i = 6: 0.0011216000000047188
# i = 7: 0.0009751999999991767
# i = 8: 0.010062500000003638
# i = 9: 0.007320899999967878
# i = 10: 0.007045099999999138
# i = 11: 0.08589830000002507
# i = 12: 0.0365575000000149
# i = 13: 0.01051830000000109
# i = 14: 0.0017922999999768763
# i = 15: 0.0005236000000081731
# i = 16: 0.0024065000000064174
# i = 17: 0.010446000000001732
# i = 18: 0.001928700000007666
# i = 19: 0.05015930000001845

# %%
#For debug
for j in range(0, 10):
    print(evcc_blockAck_time_anchor[0][j]-secc_send_time_anchor[0][j])
# Out:
# 0.0010219999999989682
# 0.00039400000000000546
# 0.017918000000001655
# 0.0011359999999989157
# 0.0004029999999985989
# 0.0006299999999974659
# 0.0003869999999999152
# 0.0011299999999998533
# 0.0012230000000030827
# 0.0010690000000010969

# %%
#Use the avg. block ack latency for the lost secc sent packets
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)):
                evcc_blockAck_time_anchor[i][j] = secc_send_time_anchor[i][j] + avg_blockAck_latency
                print("i = " + str(i))
                print("j = " + str(j))
        else: continue
# Out:
# i = 8
# j = 9
# i = 9
# j = 9
# i = 11
# j = 7
# i = 14
# j = 8
# i = 19
# j = 0
# i = 19
# j = 9

# %%
#Test Round 4: evcc send too many lost packets... but no timeout
#Test Round 12, 13: evcc send wierd order

for i in [13, 12, 3]:
    del evcc_send_time_anchor[i]
    del secc_send_time_anchor[i]
    del evcc_blockAck_time_anchor[i]


#for debug
print(str(len(evcc_send_time_anchor)) + '\n')
for i in range(0, len(evcc_send_time_anchor)):
    print(len(evcc_send_time_anchor[i]))
print('\n')    
    
#for debug
print(str(len(secc_send_time_anchor)) + '\n')
for i in range(0, len(secc_send_time_anchor)):
    print(len(secc_send_time_anchor[i]))
print('\n')
    
#for debug
print(str(len(evcc_blockAck_time_anchor)) + '\n')
for i in range(0, len(evcc_blockAck_time_anchor)):
    print(len(evcc_blockAck_time_anchor[i]))
# Out:
# 17
#
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
#
#
# 17
#
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
#
#
# 17
#
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
#for debug check wierd value
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_send_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))
        if(evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))

# %%
#For debug
i = 10
for j in [7]:
    print("Stage " + str(j+1))
    print(evcc_send_time_anchor[i][j])
    print(secc_send_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j]-evcc_send_time_anchor[i][j])
    print("\n")
# Out:
# Stage 8
# 238.627306
# 238.643491
# 238.65349263101606
# 0.02618663101605989

# %%
path = 'time_record/no_interf_80211.txt'
f = open(path, 'w')
for i in range(0, len(evcc_send_time_anchor)):
    for j in range(0, len(evcc_send_time_anchor[i])):
        print((evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j])*1000, file=f, end="")
        f.writelines('\t')
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][len(evcc_blockAck_time_anchor[i])-1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    f.writelines('20')
    f.writelines('\t')
    f.writelines('0')
    f.writelines('\t')
    f.writelines('\n')
f.close()
