# %%
#Processing evcc block ack
import csv
import numpy as np

with open('csv/DataLink/max_interf/evcc_blockack_max.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    startint_seq_num_block_ack = []
    timelist_block_ack = []
    
    for row in rows:
        startint_seq_num_block_ack.append(int(row['Starting Sequence Number']))
        timelist_block_ack.append(float(row['Time']))

# %%
#for debug
if(len(startint_seq_num_block_ack) != len(timelist_block_ack)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_block_ack))
# Out:
# 986

# %%
#Processing evcc send
with open('csv/DataLink/max_interf/evcc_send_max.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_evcc_send = []
    seq_num_evcc_send = []
    data_length_evcc_send = []
    info_evcc_send = []
    frame_num_evcc_send = []
    
    for row in rows:
        timelist_evcc_send.append(float(row['Time']))
        seq_num_evcc_send.append(int(row['Sequence number']))
        data_length_evcc_send.append(int(row['Data Length']))
        info_evcc_send.append(str(row['Info']))
        frame_num_evcc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_evcc_send) != len(seq_num_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(data_length_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(info_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(frame_num_evcc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send))
# Out:
# 1517

# %%
timelist_evcc_send_split = []
seq_num_evcc_send_split = []
data_length_evcc_send_split = []
info_evcc_send_split = []
frame_num_evcc_send_split = []

round_start_point = 0
round_end_point = 0

sdpreq_index_list = []
#Fetch first packet index of data length = 74 (SDP request) in each round
for i in range(0, len(data_length_evcc_send)):
    if(i == 0 and data_length_evcc_send[i] == 74):
        sdpreq_index_list.append(i)
    if(i > 0 and data_length_evcc_send[i] == 74 and data_length_evcc_send[i-1] != 74):
        sdpreq_index_list.append(i)
sdpreq_index_list.append(len(data_length_evcc_send)) #Add the end of list index

for i in range(0, len(sdpreq_index_list)-1):
    timelist_evcc_send_split.append([timelist_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    seq_num_evcc_send_split.append([seq_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    data_length_evcc_send_split.append([data_length_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    info_evcc_send_split.append([info_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    frame_num_evcc_send_split.append([frame_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])

# %%
#for debug
if(len(timelist_evcc_send_split) != len(seq_num_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(data_length_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(info_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(frame_num_evcc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_evcc_send_split)):
    print(timelist_evcc_send_split[i][0]-timelist_evcc_send_split[i-1][0])
# Out:
# 21.419687
# 21.973245999999996
# 22.919047000000006
# 21.173198999999997
# 22.798350000000013
# 22.320474999999988
# 21.305890000000005
# 22.321897000000007
# 22.170615999999995
# 22.234062999999992
# 22.069951999999972
# 21.284245000000055
# 21.60061399999995
# 20.104599000000007
# 21.995933000000036
# 21.59201299999995
# 22.530367000000012
# 21.47176300000001
# 21.181276000000025

# %%
#Set evcc time anchor in each round per stage
evcc_send_time_anchor = []
#data_length_in_each_stage = [74, 96, 189, 173, 173, 173, 185, 461, 189, 173]
wierd_packet = {}
packet_loss_testing_round_5_flag = False
packet_loss_testing_round_13_flag = False
packet_loss_testing_round_13_1_flag = False
packet_loss_testing_round_13_2_flag = False
packet_loss_testing_round_13_3_flag = False

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(evcc_send_time_anchor_each_round):
    print("Time difference: " + str(evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-1]-
                          evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        return True
    else:
        #debug
        print("\nFalse")
        print("Stage Num = " + str(stageNum))
        print("Valid Stage Num = " + str(valid_stageNum))
        print("What is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet.get(frameNum) != None):
        del wierd_packet[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_evcc_send_split)):
#for i in [2]:
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    evcc_send_time_anchor_each_round = [timelist_evcc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_evcc_send_split[i][0], info_evcc_send_split[i][0])
    stageNum = stageNum + 1
    
    for j in range(1, len(data_length_evcc_send_split[i])):

        #Deal with packet loss......
        if(i == 5 and packet_loss_testing_round_5_flag == False):
            evcc_send_time_anchor_each_round.append(135.6)
            printinfo(stageNum, 679483, "Packet Loss")
            print_time_difference(evcc_send_time_anchor_each_round)
            stageNum = stageNum + 1
            packet_loss_testing_round_5_flag = True
        
        #Stage 2
        if(data_length_evcc_send_split[i][j] == 96 and data_length_evcc_send_split[i][j-1] != 96):
            if(checkstage_num(stageNum, 2, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 3
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 3, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 4 
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            #if(info_evcc_send_split[i][j][-2:] == 'TC'):
            if(checkstage_num(stageNum, 4, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
           
        #Stage 5, tricky
        if(data_length_evcc_send_split[i][j] == 173):    
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
            
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                if(i == 1):
                    for k in range(1, 4):
                        if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                            isTCfound = True
                            break
                else:
                    for k in range(1, 3):
                        if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                            isTCfound = True
                            break
                
                if(not isTCfound):
                    if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1  
                        
                        #Deal with packet loss......
                        if(i == 13 and packet_loss_testing_round_13_flag == False):
                            evcc_send_time_anchor_each_round.append(311.399807)
                            printinfo(stageNum, 1652776, "Packet Loss")
                            print_time_difference(evcc_send_time_anchor_each_round)
                            stageNum = stageNum + 1
                            packet_loss_testing_round_13_flag = True
                                 
                        continue
                
        #Stage 6, tricky
        if(data_length_evcc_send_split[i][j] == 173):
            
            #Avoid TCP retransmission packet
            if(i != 2 or (i == 2 and seq_num_evcc_send_split[i][j] == 2263)):
            
                if(info_evcc_send_split[i][j][-2:] == 'TC'):
                    if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                          timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                          seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1

                        continue

                else: #info_evcc_send_split[i][j][-2:] == 'FC'
                    #Backward checking 2 packets
                    isTCfound = False
                    for k in range(1, 3):
                        if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                            isTCfound = True
                            break

                    if(not isTCfound):
                        if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                          timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                          seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                            print("Stage " + str(stageNum) +
                                ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                                ", Data length " + str(data_length_evcc_send_split[i][j]) +
                                ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                            evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                            printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                            print_time_difference(evcc_send_time_anchor_each_round)
                            stageNum = stageNum + 1

                            continue

        #Stage 7
        if(data_length_evcc_send_split[i][j] == 185 and data_length_evcc_send_split[i][j-1] != 185):
            if(checkstage_num(stageNum, 7, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 13 and packet_loss_testing_round_13_1_flag == False):
                    evcc_send_time_anchor_each_round.append(311.701577)
                    printinfo(stageNum, 1654007, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_13_1_flag = True
                #Deal with packet loss......
                if(i == 13 and packet_loss_testing_round_13_2_flag == False):
                    evcc_send_time_anchor_each_round.append(311.837217)
                    printinfo(stageNum, 1654514, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_13_2_flag = True
                #Deal with packet loss......
                if(i == 13 and packet_loss_testing_round_13_3_flag == False):
                    evcc_send_time_anchor_each_round.append(311.886181)
                    printinfo(stageNum, 1654723, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_13_3_flag = True
                
                continue
                
        #Stage 8
        if(data_length_evcc_send_split[i][j] == 461 and data_length_evcc_send_split[i][j-1] != 461):
            if(checkstage_num(stageNum, 8, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
        #Stage 9
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 9, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 10
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                for k in range(1, 3):
                    if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                        isTCfound = True
                        break

                if(not isTCfound):
                    if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1
                
        if(stageNum == 11): break
        
    evcc_send_time_anchor.append(evcc_send_time_anchor_each_round)
# Out:
# -------- Test Round 1 --------
# -----------------------------------------
# Stage 1 finish. No. 92526, Info QoS Data, SN=1973, FN=0, Flags=.p..R..TC
#
# False
# Stage Num = 2
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 95340
# Time 26.322231 #Seq 1985 Info QoS Data, SN=1985, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 95340
# Time 26.322231 #Seq 1985 Info QoS Data, SN=1985, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 96077
# Time 26.550282 #Seq 1987 Info QoS Data, SN=1987, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 96077
# Time 26.550282 #Seq 1987 Info QoS Data, SN=1987, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 96077
# Time 26.550282 #Seq 1987 Info QoS Data, SN=1987, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 96077
# Time 26.550282 #Seq 1987 Info QoS Data, SN=1987, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 96805
# Time 26.916956 #Seq 2096 Info QoS Data, SN=2096, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 2
# Valid Stage Num = 8
# What is this packet? Data Length = 461 No. 97432
# Time 27.114189 #Seq 1997 Info QoS Data, SN=1997, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 97863
# Time 27.342987 #Seq 2003 Info QoS Data, SN=2003, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 97863
# Time 27.342987 #Seq 2003 Info QoS Data, SN=2003, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 97863
# Time 27.342987 #Seq 2003 Info QoS Data, SN=2003, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 97863
# Time 27.342987 #Seq 2003 Info QoS Data, SN=2003, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 97868
# Time 27.345838 #Seq 2104 Info QoS Data, SN=2104, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 98052
# Time 27.367767 #Seq 2003 Info QoS Data, SN=2003, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 98052
# Time 27.367767 #Seq 2003 Info QoS Data, SN=2003, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 98056
# Time 27.369381 #Seq 2003 Info QoS Data, SN=2003, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 98056
# Time 27.369381 #Seq 2003 Info QoS Data, SN=2003, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 98590
# Time 27.591378 #Seq 2004 Info QoS Data, SN=2004, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 98590
# Time 27.591378 #Seq 2004 Info QoS Data, SN=2004, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 110729
# Time 29.697479 #Seq 2006 Info QoS Data, SN=2006, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 110729
# Time 29.697479 #Seq 2006 Info QoS Data, SN=2006, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 124236
# Time 31.923391 #Seq 2011 Info QoS Data, SN=2011, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 124236
# Time 31.923391 #Seq 2011 Info QoS Data, SN=2011, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 124236
# Time 31.923391 #Seq 2011 Info QoS Data, SN=2011, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 124236
# Time 31.923391 #Seq 2011 Info QoS Data, SN=2011, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 137349
# Time 34.109791 #Seq 2014 Info QoS Data, SN=2014, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 137349
# Time 34.109791 #Seq 2014 Info QoS Data, SN=2014, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 137349
# Time 34.109791 #Seq 2014 Info QoS Data, SN=2014, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 137349
# Time 34.109791 #Seq 2014 Info QoS Data, SN=2014, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 137466
# Time 34.120116 #Seq 2014 Info QoS Data, SN=2014, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 137466
# Time 34.120116 #Seq 2014 Info QoS Data, SN=2014, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 150089
# Time 36.194677 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 150089
# Time 36.194677 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 150089
# Time 36.194677 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 150089
# Time 36.194677 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 150090
# Time 36.194733 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 150090
# Time 36.194733 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 150106
# Time 36.196307 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 150106
# Time 36.196307 #Seq 2016 Info QoS Data, SN=2016, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 164419
# Time 38.499093 #Seq 2018 Info QoS Data, SN=2018, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 164419
# Time 38.499093 #Seq 2018 Info QoS Data, SN=2018, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 164419
# Time 38.499093 #Seq 2018 Info QoS Data, SN=2018, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 164419
# Time 38.499093 #Seq 2018 Info QoS Data, SN=2018, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 164973
# Time 38.588164 #Seq 2020 Info QoS Data, SN=2020, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 164973
# Time 38.588164 #Seq 2020 Info QoS Data, SN=2020, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 164973
# Time 38.588164 #Seq 2020 Info QoS Data, SN=2020, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 164973
# Time 38.588164 #Seq 2020 Info QoS Data, SN=2020, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 165324
# Time 38.661667 #Seq 2123 Info QoS Data, SN=2123, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 165324
# Time 38.661667 #Seq 2123 Info QoS Data, SN=2123, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 165324
# Time 38.661667 #Seq 2123 Info QoS Data, SN=2123, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 2
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 165324
# Time 38.661667 #Seq 2123 Info QoS Data, SN=2123, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 165490
# Time 38.683868 #Seq 2021 Info QoS Data, SN=2021, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 165490
# Time 38.683868 #Seq 2021 Info QoS Data, SN=2021, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 165491
# Time 38.684421 #Seq 2021 Info QoS Data, SN=2021, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 165491
# Time 38.684421 #Seq 2021 Info QoS Data, SN=2021, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 165502
# Time 38.685795 #Seq 2021 Info QoS Data, SN=2021, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 2
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 165502
# Time 38.685795 #Seq 2021 Info QoS Data, SN=2021, FN=0, Flags=.p..R..TC
#
#
# -------- Test Round 2 --------
# -----------------------------------------
# Stage 1 finish. No. 212578, Info QoS Data, SN=2026, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 215022, Info QoS Data, SN=2027, FN=0, Flags=.p.....TC
# Time difference: 0.43011200000000116
# -----------------------------------------
# Stage 3 finish. No. 220843, Info QoS Data, SN=2050, FN=0, Flags=.p.....TC
# Time difference: 0.9524789999999967
# -----------------------------------------
# Stage 4 finish. No. 222434, Info QoS Data, SN=2053, FN=0, Flags=.p.....TC
# Time difference: 0.2584060000000008
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 222450
# Time 48.12746 #Seq 2164 Info QoS Data, SN=2164, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 222450
# Time 48.12746 #Seq 2164 Info QoS Data, SN=2164, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 222450
# Time 48.12746 #Seq 2164 Info QoS Data, SN=2164, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 223020
# Time 48.214036 #Seq 2055 Info QoS Data, SN=2055, FN=0, Flags=.p.....TC
#
#
# No. 223020 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 223020, Info QoS Data, SN=2055, FN=0, Flags=.p.....TC
# Time difference: 0.08866700000000094
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 223129
# Time 48.236884 #Seq 2167 Info QoS Data, SN=2167, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 224036
# Time 48.366725 #Seq 2057 Info QoS Data, SN=2057, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 224036
# Time 48.366725 #Seq 2057 Info QoS Data, SN=2057, FN=0, Flags=.p..R..TC
#
#
# No. 224036 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 224036, Info QoS Data, SN=2057, FN=0, Flags=.p..R..TC
# Time difference: 0.1526890000000023
#
# False
# Stage Num = 7
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 224042
# Time 48.371848 #Seq 2057 Info QoS Data, SN=2057, FN=0, Flags=.p..R..TC
#
#
# False
# Stage Num = 7
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 224042
# Time 48.371848 #Seq 2057 Info QoS Data, SN=2057, FN=0, Flags=.p..R..TC
#
# -----------------------------------------
# Stage 7 finish. No. 225263, Info QoS Data, SN=2060, FN=0, Flags=.p..R..TC
# Time difference: 0.1687869999999947
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 225460
# Time 48.58015 #Seq 2172 Info QoS Data, SN=2172, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 226283, Info QoS Data, SN=2062, FN=0, Flags=.p.....TC
# Time difference: 0.18548200000000037
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 228693
# Time 49.102698 #Seq 2064 Info QoS Data, SN=2064, FN=0, Flags=.p.....TC
#
#
# No. 228693 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 228693, Info QoS Data, SN=2064, FN=0, Flags=.p.....TC
# Time difference: 0.38170399999999916
#
# False
# Stage Num = 10
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 229131
# Time 49.164228 #Seq 2179 Info QoS Data, SN=2179, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 229131
# Time 49.164228 #Seq 2179 Info QoS Data, SN=2179, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 230088
# Time 49.310166 #Seq 2066 Info QoS Data, SN=2066, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 230088
# Time 49.310166 #Seq 2066 Info QoS Data, SN=2066, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 230088
# Time 49.310166 #Seq 2066 Info QoS Data, SN=2066, FN=0, Flags=.p.....TC
#
#
# No. 230088 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 230088, Info QoS Data, SN=2066, FN=0, Flags=.p.....TC
# Time difference: 0.20746800000000576
#
# -------- Test Round 3 --------
# -----------------------------------------
# Stage 1 finish. No. 319800, Info QoS Data, SN=2099, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 323642, Info QoS Data, SN=2101, FN=0, Flags=.p..R..TC
# Time difference: 0.5675310000000025
# -----------------------------------------
# Stage 3 finish. No. 327337, Info QoS Data, SN=2255, FN=0, Flags=.p....F.C
# Time difference: 0.7225459999999941
# -----------------------------------------
# Stage 4 finish. No. 329223, Info QoS Data, SN=2257, FN=0, Flags=.p....F.C
# Time difference: 0.3166390000000092
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 330584
# Time 70.364364 #Seq 2259 Info QoS Data, SN=2259, FN=0, Flags=.p....F.C
#
#
# No. 330584 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 330584, Data length 173, Info QoS Data, SN=2259, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 330584, Info QoS Data, SN=2259, FN=0, Flags=.p....F.C
# Time difference: 0.30002999999999247
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 330745
# Time 70.385688 #Seq 2261 Info QoS Data, SN=2261, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 330745
# Time 70.385688 #Seq 2261 Info QoS Data, SN=2261, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 330745
# Time 70.385688 #Seq 2261 Info QoS Data, SN=2261, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 330746
# Time 70.385744 #Seq 2261 Info QoS Data, SN=2261, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 330747
# Time 70.385838 #Seq 2261 Info QoS Data, SN=2261, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 330748
# Time 70.386084 #Seq 2261 Info QoS Data, SN=2261, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 331224
# Time 70.490289 #Seq 2263 Info QoS Data, SN=2263, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 331224
# Time 70.490289 #Seq 2263 Info QoS Data, SN=2263, FN=0, Flags=.p....F.C
#
#
# No. 331224 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 331224, Data length 173, Info QoS Data, SN=2263, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 331224, Info QoS Data, SN=2263, FN=0, Flags=.p....F.C
# Time difference: 0.1259250000000094
# -----------------------------------------
# Stage 7 finish. No. 333441, Info QoS Data, SN=2266, FN=0, Flags=.p....F.C
# Time difference: 0.3992250000000013
# -----------------------------------------
# Stage 8 finish. No. 334622, Info QoS Data, SN=2270, FN=0, Flags=.p....F.C
# Time difference: 0.2207819999999998
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 335206
# Time 71.212116 #Seq 2272 Info QoS Data, SN=2272, FN=0, Flags=.p....F.C
#
#
# No. 335206 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 335206, Info QoS Data, SN=2272, FN=0, Flags=.p....F.C
# Time difference: 0.10181999999998936
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 336348
# Time 71.374402 #Seq 2274 Info QoS Data, SN=2274, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 336348
# Time 71.374402 #Seq 2274 Info QoS Data, SN=2274, FN=0, Flags=.p....F.C
#
#
# No. 336348 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 336348, Data length 173, Info QoS Data, SN=2274, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 336348, Info QoS Data, SN=2274, FN=0, Flags=.p....F.C
# Time difference: 0.1622860000000088
#
# -------- Test Round 4 --------
# -----------------------------------------
# Stage 1 finish. No. 438155, Info Data, SN=2271, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 441481, Info QoS Data, SN=2309, FN=0, Flags=.p....F.C
# Time difference: 0.5326340000000016
# -----------------------------------------
# Stage 3 finish. No. 444507, Info QoS Data, SN=2320, FN=0, Flags=.p....F.C
# Time difference: 0.4922940000000011
# -----------------------------------------
# Stage 4 finish. No. 445547, Info QoS Data, SN=2322, FN=0, Flags=.p....F.C
# Time difference: 0.13902699999999868
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 445784
# Time 92.578997 #Seq 2324 Info QoS Data, SN=2324, FN=0, Flags=.p....F.C
#
#
# No. 445784 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 445784, Data length 173, Info QoS Data, SN=2324, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 445784, Info QoS Data, SN=2324, FN=0, Flags=.p....F.C
# Time difference: 0.038376999999997
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 446612
# Time 92.728828 #Seq 2327 Info QoS Data, SN=2327, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 446612
# Time 92.728828 #Seq 2327 Info QoS Data, SN=2327, FN=0, Flags=.p....F.C
#
#
# No. 446612 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 446612, Data length 173, Info QoS Data, SN=2327, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 446612, Info QoS Data, SN=2327, FN=0, Flags=.p....F.C
# Time difference: 0.14983099999999183
# -----------------------------------------
# Stage 7 finish. No. 447884, Info QoS Data, SN=2330, FN=0, Flags=.p....F.C
# Time difference: 0.19048200000000293
# -----------------------------------------
# Stage 8 finish. No. 450167, Info QoS Data, SN=2332, FN=0, Flags=.p....F.C
# Time difference: 0.36815500000000156
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 450820
# Time 93.390089 #Seq 2336 Info QoS Data, SN=2336, FN=0, Flags=.p....F.C
#
#
# No. 450820 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 450820, Info QoS Data, SN=2336, FN=0, Flags=.p....F.C
# Time difference: 0.10262400000000582
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 451959
# Time 93.601849 #Seq 2338 Info QoS Data, SN=2338, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 451959
# Time 93.601849 #Seq 2338 Info QoS Data, SN=2338, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 451959
# Time 93.601849 #Seq 2338 Info QoS Data, SN=2338, FN=0, Flags=.p....F.C
#
#
# No. 451959 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 451959, Data length 173, Info QoS Data, SN=2338, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 451959, Info QoS Data, SN=2338, FN=0, Flags=.p....F.C
# Time difference: 0.21175999999999817
#
# -------- Test Round 5 --------
# -----------------------------------------
# Stage 1 finish. No. 549567, Info Data, SN=2483, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 553960, Info QoS Data, SN=2396, FN=0, Flags=.p....F.C
# Time difference: 0.6718379999999939
# -----------------------------------------
# Stage 3 finish. No. 563557, Info QoS Data, SN=2406, FN=0, Flags=.p....F.C
# Time difference: 1.3919800000000038
# -----------------------------------------
# Stage 4 finish. No. 565794, Info QoS Data, SN=2408, FN=0, Flags=.p....F.C
# Time difference: 0.3228019999999958
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 566174
# Time 114.964141 #Seq 2411 Info QoS Data, SN=2411, FN=0, Flags=.p....F.C
#
#
# No. 566174 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 566174, Data length 173, Info QoS Data, SN=2411, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 566174, Info QoS Data, SN=2411, FN=0, Flags=.p....F.C
# Time difference: 0.027657000000004928
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 566866
# Time 115.079315 #Seq 2413 Info QoS Data, SN=2413, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 566866
# Time 115.079315 #Seq 2413 Info QoS Data, SN=2413, FN=0, Flags=.p....F.C
#
#
# No. 566866 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 566866, Data length 173, Info QoS Data, SN=2413, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 566866, Info QoS Data, SN=2413, FN=0, Flags=.p....F.C
# Time difference: 0.11517399999999611
# -----------------------------------------
# Stage 7 finish. No. 567810, Info QoS Data, SN=2416, FN=0, Flags=.p....F.C
# Time difference: 0.1470030000000122
# -----------------------------------------
# Stage 8 finish. No. 569014, Info QoS Data, SN=2419, FN=0, Flags=.p....F.C
# Time difference: 0.19558899999999824
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 569602
# Time 115.510186 #Seq 2421 Info QoS Data, SN=2421, FN=0, Flags=.p....F.C
#
#
# No. 569602 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 569602, Info QoS Data, SN=2421, FN=0, Flags=.p....F.C
# Time difference: 0.088279
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 571629
# Time 115.81536 #Seq 2422 Info QoS Data, SN=2422, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 571629
# Time 115.81536 #Seq 2422 Info QoS Data, SN=2422, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 571629
# Time 115.81536 #Seq 2422 Info QoS Data, SN=2422, FN=0, Flags=.p....F.C
#
#
# No. 571629 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 571629, Data length 173, Info QoS Data, SN=2422, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 571629, Info QoS Data, SN=2422, FN=0, Flags=.p....F.C
# Time difference: 0.30517399999999384
#
# -------- Test Round 6 --------
# -----------------------------------------
# Stage 1 finish. No. 678368, Info Data, SN=2712, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 679483, Info Packet Loss
# Time difference: 0.2517859999999814
# -----------------------------------------
# Stage 3 finish. No. 686542, Info QoS Data, SN=2473, FN=0, Flags=.p....F.C
# Time difference: 1.2831999999999937
# -----------------------------------------
# Stage 4 finish. No. 687698, Info QoS Data, SN=2475, FN=0, Flags=.p....F.C
# Time difference: 0.16564300000001708
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 688098
# Time 137.102309 #Seq 2477 Info QoS Data, SN=2477, FN=0, Flags=.p....F.C
#
#
# No. 688098 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 688098, Data length 173, Info QoS Data, SN=2477, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 688098, Info QoS Data, SN=2477, FN=0, Flags=.p....F.C
# Time difference: 0.053465999999986025
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 688980
# Time 137.237628 #Seq 2479 Info QoS Data, SN=2479, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 688980
# Time 137.237628 #Seq 2479 Info QoS Data, SN=2479, FN=0, Flags=.p....F.C
#
#
# No. 688980 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 688980, Data length 173, Info QoS Data, SN=2479, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 688980, Info QoS Data, SN=2479, FN=0, Flags=.p....F.C
# Time difference: 0.13531900000000974
# -----------------------------------------
# Stage 7 finish. No. 689850, Info QoS Data, SN=2482, FN=0, Flags=.p....F.C
# Time difference: 0.15539899999998852
# -----------------------------------------
# Stage 8 finish. No. 691488, Info QoS Data, SN=2484, FN=0, Flags=.p....F.C
# Time difference: 0.22877900000000295
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 693025
# Time 137.872614 #Seq 2487 Info QoS Data, SN=2487, FN=0, Flags=.p....F.C
#
#
# No. 693025 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 693025, Info QoS Data, SN=2487, FN=0, Flags=.p....F.C
# Time difference: 0.25080800000000636
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 694179
# Time 138.183843 #Seq 2489 Info QoS Data, SN=2489, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 694179
# Time 138.183843 #Seq 2489 Info QoS Data, SN=2489, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 694179
# Time 138.183843 #Seq 2489 Info QoS Data, SN=2489, FN=0, Flags=.p....F.C
#
#
# No. 694179 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 694179, Data length 173, Info QoS Data, SN=2489, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 694179, Info QoS Data, SN=2489, FN=0, Flags=.p....F.C
# Time difference: 0.3112289999999973
#
# -------- Test Round 7 --------
# -----------------------------------------
# Stage 1 finish. No. 793597, Info Data, SN=2935, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 796644, Info QoS Data, SN=2515, FN=0, Flags=.p....F.C
# Time difference: 0.5321140000000071
#
# False
# Stage Num = 3
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 798113
# Time 158.543058 #Seq 2524 Info QoS Data, SN=2524, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 798113
# Time 158.543058 #Seq 2524 Info QoS Data, SN=2524, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 798113
# Time 158.543058 #Seq 2524 Info QoS Data, SN=2524, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 3
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 798113
# Time 158.543058 #Seq 2524 Info QoS Data, SN=2524, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 3 finish. No. 798800, Info QoS Data, SN=2527, FN=0, Flags=.p....F.C
# Time difference: 0.47232599999998115
# -----------------------------------------
# Stage 4 finish. No. 799454, Info QoS Data, SN=2529, FN=0, Flags=.p....F.C
# Time difference: 0.14126900000002252
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 799699
# Time 158.856495 #Seq 2531 Info QoS Data, SN=2531, FN=0, Flags=.p....F.C
#
#
# No. 799699 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 799699, Data length 173, Info QoS Data, SN=2531, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 799699, Info QoS Data, SN=2531, FN=0, Flags=.p....F.C
# Time difference: 0.042096999999984064
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 800319
# Time 158.971803 #Seq 2533 Info QoS Data, SN=2533, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 800319
# Time 158.971803 #Seq 2533 Info QoS Data, SN=2533, FN=0, Flags=.p....F.C
#
#
# No. 800319 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 800319, Data length 173, Info QoS Data, SN=2533, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 800319, Info QoS Data, SN=2533, FN=0, Flags=.p....F.C
# Time difference: 0.11530799999999886
# -----------------------------------------
# Stage 7 finish. No. 801394, Info QoS Data, SN=2536, FN=0, Flags=.p....F.C
# Time difference: 0.21615400000001728
# -----------------------------------------
# Stage 8 finish. No. 802125, Info QoS Data, SN=2538, FN=0, Flags=.p....F.C
# Time difference: 0.16122299999997836
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 802818
# Time 159.476477 #Seq 2540 Info QoS Data, SN=2540, FN=0, Flags=.p....F.C
#
#
# No. 802818 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 802818, Info QoS Data, SN=2540, FN=0, Flags=.p....F.C
# Time difference: 0.12729699999999866
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 803391
# Time 159.600705 #Seq 2542 Info QoS Data, SN=2542, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 803391
# Time 159.600705 #Seq 2542 Info QoS Data, SN=2542, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 803391
# Time 159.600705 #Seq 2542 Info QoS Data, SN=2542, FN=0, Flags=.p....F.C
#
#
# No. 803391 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 803391, Data length 173, Info QoS Data, SN=2542, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 803391, Info QoS Data, SN=2542, FN=0, Flags=.p....F.C
# Time difference: 0.12422800000001644
#
# -------- Test Round 8 --------
# -----------------------------------------
# Stage 1 finish. No. 909621, Info Data, SN=3145, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 913055, Info QoS Data, SN=2589, FN=0, Flags=.p....F.C
# Time difference: 0.6259489999999914
# -----------------------------------------
# Stage 3 finish. No. 917623, Info QoS Data, SN=2600, FN=0, Flags=.p....F.C
# Time difference: 0.8096960000000024
# -----------------------------------------
# Stage 4 finish. No. 919069, Info QoS Data, SN=2602, FN=0, Flags=.p....F.C
# Time difference: 0.2216449999999952
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 919970
# Time 180.777446 #Seq 2604 Info QoS Data, SN=2604, FN=0, Flags=.p....F.C
#
#
# No. 919970 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 919970, Data length 173, Info QoS Data, SN=2604, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 919970, Info QoS Data, SN=2604, FN=0, Flags=.p....F.C
# Time difference: 0.14557700000000295
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 920873
# Time 180.915477 #Seq 2606 Info QoS Data, SN=2606, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 920873
# Time 180.915477 #Seq 2606 Info QoS Data, SN=2606, FN=0, Flags=.p....F.C
#
#
# No. 920873 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 920873, Data length 173, Info QoS Data, SN=2606, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 920873, Info QoS Data, SN=2606, FN=0, Flags=.p....F.C
# Time difference: 0.13803100000001223
# -----------------------------------------
# Stage 7 finish. No. 922896, Info QoS Data, SN=2610, FN=0, Flags=.p....F.C
# Time difference: 0.33739499999998657
# -----------------------------------------
# Stage 8 finish. No. 926179, Info QoS Data, SN=2612, FN=0, Flags=.p....F.C
# Time difference: 0.5449380000000019
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 926748
# Time 181.89963 #Seq 2614 Info QoS Data, SN=2614, FN=0, Flags=.p....F.C
#
#
# No. 926748 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 926748, Info QoS Data, SN=2614, FN=0, Flags=.p....F.C
# Time difference: 0.10182000000000357
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 928843
# Time 182.279449 #Seq 2616 Info QoS Data, SN=2616, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 928843
# Time 182.279449 #Seq 2616 Info QoS Data, SN=2616, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 928843
# Time 182.279449 #Seq 2616 Info QoS Data, SN=2616, FN=0, Flags=.p....F.C
#
#
# No. 928843 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 928843, Data length 173, Info QoS Data, SN=2616, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 928843, Info QoS Data, SN=2616, FN=0, Flags=.p....F.C
# Time difference: 0.3798189999999977
#
# -------- Test Round 9 --------
# -----------------------------------------
# Stage 1 finish. No. 1014530, Info QoS Data, SN=2479, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1017687, Info QoS Data, SN=2481, FN=0, Flags=.p.....TC
# Time difference: 0.5135559999999941
# -----------------------------------------
# Stage 3 finish. No. 1022908, Info QoS Data, SN=2493, FN=0, Flags=.p.....TC
# Time difference: 0.8683149999999955
# -----------------------------------------
# Stage 4 finish. No. 1023380, Info QoS Data, SN=2495, FN=0, Flags=.p.....TC
# Time difference: 0.09694300000001022
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1023428
# Time 202.793465 #Seq 2697 Info QoS Data, SN=2697, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1023690
# Time 202.860029 #Seq 2497 Info QoS Data, SN=2497, FN=0, Flags=.p.....TC
#
#
# No. 1023690 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 1023690, Info QoS Data, SN=2497, FN=0, Flags=.p.....TC
# Time difference: 0.0847389999999848
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1024001
# Time 202.919351 #Seq 2499 Info QoS Data, SN=2499, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1024001
# Time 202.919351 #Seq 2499 Info QoS Data, SN=2499, FN=0, Flags=.p.....TC
#
#
# No. 1024001 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1024001, Info QoS Data, SN=2499, FN=0, Flags=.p.....TC
# Time difference: 0.05932200000000876
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1024384
# Time 202.998376 #Seq 2701 Info QoS Data, SN=2701, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 7 finish. No. 1026140, Info QoS Data, SN=2502, FN=0, Flags=.p.....TC
# Time difference: 0.3925789999999836
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 1026238
# Time 203.34573 #Seq 2704 Info QoS Data, SN=2704, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 1026972, Info QoS Data, SN=2505, FN=0, Flags=.p.....TC
# Time difference: 0.16015000000001578
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1028223
# Time 203.701323 #Seq 2507 Info QoS Data, SN=2507, FN=0, Flags=.p.....TC
#
#
# No. 1028223 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1028223, Info QoS Data, SN=2507, FN=0, Flags=.p.....TC
# Time difference: 0.22924299999999675
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1029281
# Time 203.904589 #Seq 2509 Info QoS Data, SN=2509, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1029281
# Time 203.904589 #Seq 2509 Info QoS Data, SN=2509, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1029281
# Time 203.904589 #Seq 2509 Info QoS Data, SN=2509, FN=0, Flags=.p.....TC
#
#
# No. 1029281 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1029281, Info QoS Data, SN=2509, FN=0, Flags=.p.....TC
# Time difference: 0.20326599999998507
#
# -------- Test Round 10 --------
# -----------------------------------------
# Stage 1 finish. No. 1135476, Info QoS Data, SN=2544, FN=0, Flags=.p..R..TC
# -----------------------------------------
# Stage 2 finish. No. 1138126, Info QoS Data, SN=2545, FN=0, Flags=.p.....TC
# Time difference: 0.3846529999999859
# -----------------------------------------
# Stage 3 finish. No. 1142578, Info QoS Data, SN=2556, FN=0, Flags=.p.....TC
# Time difference: 0.7336750000000052
#
# False
# Stage Num = 4
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1142905
# Time 224.642869 #Seq 2750 Info QoS Data, SN=2750, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 4
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 1142905
# Time 224.642869 #Seq 2750 Info QoS Data, SN=2750, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 4 finish. No. 1143397, Info QoS Data, SN=2559, FN=0, Flags=.p.....TC
# Time difference: 0.14019500000000562
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1143936
# Time 224.837222 #Seq 2561 Info QoS Data, SN=2561, FN=0, Flags=.p.....TC
#
#
# No. 1143936 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 1143936, Info QoS Data, SN=2561, FN=0, Flags=.p.....TC
# Time difference: 0.11160699999999224
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1144363
# Time 224.947966 #Seq 2563 Info QoS Data, SN=2563, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1144363
# Time 224.947966 #Seq 2563 Info QoS Data, SN=2563, FN=0, Flags=.p.....TC
#
#
# No. 1144363 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1144363, Info QoS Data, SN=2563, FN=0, Flags=.p.....TC
# Time difference: 0.11074400000001106
# -----------------------------------------
# Stage 7 finish. No. 1144690, Info QoS Data, SN=2566, FN=0, Flags=.p.....TC
# Time difference: 0.13763199999999642
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 1144703
# Time 225.087902 #Seq 2760 Info QoS Data, SN=2760, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 1149059, Info QoS Data, SN=2570, FN=0, Flags=.p.....TC
# Time difference: 0.7721829999999841
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1151110
# Time 226.237174 #Seq 2572 Info QoS Data, SN=2572, FN=0, Flags=.p.....TC
#
#
# No. 1151110 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1151110, Info QoS Data, SN=2572, FN=0, Flags=.p.....TC
# Time difference: 0.37939300000002163
#
# False
# Stage Num = 10
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1151420
# Time 226.294964 #Seq 2767 Info QoS Data, SN=2767, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 1151420
# Time 226.294964 #Seq 2767 Info QoS Data, SN=2767, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1152126
# Time 226.433296 #Seq 2575 Info QoS Data, SN=2575, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1152126
# Time 226.433296 #Seq 2575 Info QoS Data, SN=2575, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1152126
# Time 226.433296 #Seq 2575 Info QoS Data, SN=2575, FN=0, Flags=.p.....TC
#
#
# No. 1152126 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1152126, Info QoS Data, SN=2575, FN=0, Flags=.p.....TC
# Time difference: 0.19612200000000257
#
# -------- Test Round 11 --------
# -----------------------------------------
# Stage 1 finish. No. 1271973, Info QoS Data, SN=2609, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1275799, Info QoS Data, SN=2611, FN=0, Flags=.p.....TC
# Time difference: 0.6129549999999995
# -----------------------------------------
# Stage 3 finish. No. 1281525, Info QoS Data, SN=2622, FN=0, Flags=.p.....TC
# Time difference: 0.8701460000000054
# -----------------------------------------
# Stage 4 finish. No. 1283234, Info QoS Data, SN=2624, FN=0, Flags=.p.....TC
# Time difference: 0.26212300000000255
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1283734
# Time 247.510376 #Seq 2822 Info QoS Data, SN=2822, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1284522
# Time 247.636621 #Seq 2627 Info QoS Data, SN=2627, FN=0, Flags=.p.....TC
#
#
# No. 1284522 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 1284522, Info QoS Data, SN=2627, FN=0, Flags=.p.....TC
# Time difference: 0.1902419999999836
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1284552
# Time 247.643436 #Seq 2825 Info QoS Data, SN=2825, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1285264
# Time 247.748138 #Seq 2629 Info QoS Data, SN=2629, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1285264
# Time 247.748138 #Seq 2629 Info QoS Data, SN=2629, FN=0, Flags=.p.....TC
#
#
# No. 1285264 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1285264, Info QoS Data, SN=2629, FN=0, Flags=.p.....TC
# Time difference: 0.11151700000002052
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1285381
# Time 247.775072 #Seq 2827 Info QoS Data, SN=2827, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 7 finish. No. 1286376, Info QoS Data, SN=2632, FN=0, Flags=.p.....TC
# Time difference: 0.1875569999999982
# -----------------------------------------
# Stage 8 finish. No. 1287988, Info QoS Data, SN=2634, FN=0, Flags=.p.....TC
# Time difference: 0.22196199999999067
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1289008
# Time 248.312586 #Seq 2637 Info QoS Data, SN=2637, FN=0, Flags=.p.....TC
#
#
# No. 1289008 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1289008, Info QoS Data, SN=2637, FN=0, Flags=.p.....TC
# Time difference: 0.15492900000000986
#
# False
# Stage Num = 10
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1289402
# Time 248.353844 #Seq 2835 Info QoS Data, SN=2835, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 1289402
# Time 248.353844 #Seq 2835 Info QoS Data, SN=2835, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1289873
# Time 248.443382 #Seq 2639 Info QoS Data, SN=2639, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1289873
# Time 248.443382 #Seq 2639 Info QoS Data, SN=2639, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1289873
# Time 248.443382 #Seq 2639 Info QoS Data, SN=2639, FN=0, Flags=.p.....TC
#
#
# No. 1289873 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1289873, Info QoS Data, SN=2639, FN=0, Flags=.p.....TC
# Time difference: 0.1307960000000037
#
# -------- Test Round 12 --------
# -----------------------------------------
# Stage 1 finish. No. 1412513, Info QoS Data, SN=2678, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1415547, Info QoS Data, SN=2679, FN=0, Flags=.p.....TC
# Time difference: 0.4727720000000204
# -----------------------------------------
# Stage 3 finish. No. 1419296, Info QoS Data, SN=2886, FN=0, Flags=.p....F.C
# Time difference: 0.5847430000000031
# -----------------------------------------
# Stage 4 finish. No. 1419773, Info QoS Data, SN=2692, FN=0, Flags=.p.....TC
# Time difference: 0.06693400000000338
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1420429
# Time 268.988637 #Seq 2891 Info QoS Data, SN=2891, FN=0, Flags=.p....F.C
#
#
# No. 1420429 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 1420429, Data length 173, Info QoS Data, SN=2891, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 1420429, Info QoS Data, SN=2891, FN=0, Flags=.p....F.C
# Time difference: 0.09308099999998376
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1420924
# Time 269.096127 #Seq 2892 Info QoS Data, SN=2892, FN=0, Flags=.p....F.C
#
#
# No. 1420924 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 1420924, Data length 173, Info QoS Data, SN=2892, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 1420924, Info QoS Data, SN=2892, FN=0, Flags=.p....F.C
# Time difference: 0.10749000000004116
# -----------------------------------------
# Stage 7 finish. No. 1422192, Info QoS Data, SN=2895, FN=0, Flags=.p....F.C
# Time difference: 0.19793499999997266
# -----------------------------------------
# Stage 8 finish. No. 1423628, Info QoS Data, SN=2897, FN=0, Flags=.p..R.F.C
# Time difference: 0.20236399999998866
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 1424826
# Time 269.660238 #Seq 2899 Info QoS Data, SN=2899, FN=0, Flags=.p....F.C
#
#
# No. 1424826 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 1424826, Info QoS Data, SN=2899, FN=0, Flags=.p....F.C
# ...
# Time 364.017867 #Seq 3228 Info QoS Data, SN=3228, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 1924738
# Time 364.017867 #Seq 3228 Info QoS Data, SN=3228, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1938317
# Time 366.290367 #Seq 3230 Info QoS Data, SN=3230, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1938317
# Time 366.290367 #Seq 3230 Info QoS Data, SN=3230, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1938317
# Time 366.290367 #Seq 3230 Info QoS Data, SN=3230, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 1938317
# Time 366.290367 #Seq 3230 Info QoS Data, SN=3230, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1938937
# Time 366.380279 #Seq 3232 Info QoS Data, SN=3232, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1938937
# Time 366.380279 #Seq 3232 Info QoS Data, SN=3232, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1938937
# Time 366.380279 #Seq 3232 Info QoS Data, SN=3232, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 10
# What is this packet? Data Length = 173 No. 1938937
# Time 366.380279 #Seq 3232 Info QoS Data, SN=3232, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1939311
# Time 366.442731 #Seq 3233 Info QoS Data, SN=3233, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 9
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 1939311
# Time 366.442731 #Seq 3233 Info QoS Data, SN=3233, FN=0, Flags=.p....F.C
#
#
# -------- Test Round 17 --------
# -----------------------------------------
# Stage 1 finish. No. 1989329, Info Data, SN=1000, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 1992728, Info QoS Data, SN=3255, FN=0, Flags=.p....F.C
# Time difference: 0.5395550000000071
# -----------------------------------------
# Stage 3 finish. No. 1997633, Info QoS Data, SN=3267, FN=0, Flags=.p....F.C
# Time difference: 0.7694130000000428
# -----------------------------------------
# Stage 4 finish. No. 1998496, Info QoS Data, SN=3269, FN=0, Flags=.p....F.C
# Time difference: 0.15326499999997623
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1998821
# Time 375.859731 #Seq 3271 Info QoS Data, SN=3271, FN=0, Flags=.p....F.C
#
#
# No. 1998821 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 1998821, Data length 173, Info QoS Data, SN=3271, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 1998821, Info QoS Data, SN=3271, FN=0, Flags=.p....F.C
# Time difference: 0.048987000000010994
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 1999657
# Time 376.009962 #Seq 3273 Info QoS Data, SN=3273, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 1999657
# Time 376.009962 #Seq 3273 Info QoS Data, SN=3273, FN=0, Flags=.p....F.C
#
#
# No. 1999657 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 1999657, Data length 173, Info QoS Data, SN=3273, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 1999657, Info QoS Data, SN=3273, FN=0, Flags=.p....F.C
# Time difference: 0.15023099999996248
# -----------------------------------------
# Stage 7 finish. No. 2000984, Info QoS Data, SN=3276, FN=0, Flags=.p....F.C
# Time difference: 0.1999290000000542
# -----------------------------------------
# Stage 8 finish. No. 2002418, Info QoS Data, SN=3278, FN=0, Flags=.p....F.C
# Time difference: 0.2125819999999976
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2003123
# Time 376.518457 #Seq 3280 Info QoS Data, SN=3280, FN=0, Flags=.p..R.F.C
#
#
# No. 2003123 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 2003123, Info QoS Data, SN=3280, FN=0, Flags=.p..R.F.C
# Time difference: 0.09598399999998719
#
# False
# Stage Num = 10
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2003126
# Time 376.518627 #Seq 3280 Info QoS Data, SN=3280, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 2003126
# Time 376.518627 #Seq 3280 Info QoS Data, SN=3280, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2003131
# Time 376.519939 #Seq 3280 Info QoS Data, SN=3280, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 2003131
# Time 376.519939 #Seq 3280 Info QoS Data, SN=3280, FN=0, Flags=.p..R.F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2004638
# Time 376.74057 #Seq 3282 Info QoS Data, SN=3282, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2004638
# Time 376.74057 #Seq 3282 Info QoS Data, SN=3282, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 2004638
# Time 376.74057 #Seq 3282 Info QoS Data, SN=3282, FN=0, Flags=.p....F.C
#
#
# No. 2004638 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 2004638, Data length 173, Info QoS Data, SN=3282, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 2004638, Info QoS Data, SN=3282, FN=0, Flags=.p....F.C
# Time difference: 0.2221129999999789
#
# -------- Test Round 18 --------
# -----------------------------------------
# Stage 1 finish. No. 2137738, Info Data, SN=1221, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 2 finish. No. 2141176, Info QoS Data, SN=3310, FN=0, Flags=.p....F.C
# Time difference: 0.5363100000000145
# -----------------------------------------
# Stage 3 finish. No. 2146303, Info QoS Data, SN=3321, FN=0, Flags=.p....F.C
# Time difference: 0.8149109999999951
# -----------------------------------------
# Stage 4 finish. No. 2148603, Info QoS Data, SN=3324, FN=0, Flags=.p....F.C
# Time difference: 0.3471270000000004
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2148845
# Time 398.612251 #Seq 3326 Info QoS Data, SN=3326, FN=0, Flags=.p....F.C
#
#
# No. 2148845 has been found. Delete from wierd list.
#
# Stage 5, Not TC? No. 2148845, Data length 173, Info QoS Data, SN=3326, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 5 finish. No. 2148845, Info QoS Data, SN=3326, FN=0, Flags=.p....F.C
# Time difference: 0.035025000000018736
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2149426
# Time 398.682275 #Seq 3327 Info QoS Data, SN=3327, FN=0, Flags=.p....F.C
#
#
# No. 2149426 has been found. Delete from wierd list.
#
# Stage 6, Not TC? No. 2149426, Data length 173, Info QoS Data, SN=3327, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 6 finish. No. 2149426, Info QoS Data, SN=3327, FN=0, Flags=.p....F.C
# Time difference: 0.07002399999998943
# -----------------------------------------
# Stage 7 finish. No. 2150594, Info QoS Data, SN=3330, FN=0, Flags=.p....F.C
# Time difference: 0.20730099999997265
# -----------------------------------------
# Stage 8 finish. No. 2151589, Info QoS Data, SN=3332, FN=0, Flags=.p....F.C
# Time difference: 0.1490800000000263
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2151976
# Time 399.083893 #Seq 3334 Info QoS Data, SN=3334, FN=0, Flags=.p....F.C
#
#
# No. 2151976 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 2151976, Info QoS Data, SN=3334, FN=0, Flags=.p....F.C
# Time difference: 0.04523699999998598
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2152409
# Time 399.170521 #Seq 3336 Info QoS Data, SN=3336, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2152409
# Time 399.170521 #Seq 3336 Info QoS Data, SN=3336, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 2152409
# Time 399.170521 #Seq 3336 Info QoS Data, SN=3336, FN=0, Flags=.p....F.C
#
#
# No. 2152409 has been found. Delete from wierd list.
#
# Stage 10, Not TC? No. 2152409, Data length 173, Info QoS Data, SN=3336, FN=0, Flags=.p....F.C , Count FC because TC cannot be found.
# -----------------------------------------
# Stage 10 finish. No. 2152409, Info QoS Data, SN=3336, FN=0, Flags=.p....F.C
# Time difference: 0.0866280000000188
#
# -------- Test Round 19 --------
# -----------------------------------------
# Stage 1 finish. No. 2278420, Info QoS Data, SN=3107, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2280630, Info QoS Data, SN=3108, FN=0, Flags=.p.....TC
# Time difference: 0.3729950000000031
# -----------------------------------------
# Stage 3 finish. No. 2283937, Info QoS Data, SN=3118, FN=0, Flags=.p.....TC
# Time difference: 0.541766999999993
# -----------------------------------------
# Stage 4 finish. No. 2284672, Info QoS Data, SN=3120, FN=0, Flags=.p.....TC
# Time difference: 0.10715199999998504
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2284842
# Time 419.402558 #Seq 3382 Info QoS Data, SN=3382, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2285291
# Time 419.467695 #Seq 3122 Info QoS Data, SN=3122, FN=0, Flags=.p.....TC
#
#
# No. 2285291 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 2285291, Info QoS Data, SN=3122, FN=0, Flags=.p.....TC
# Time difference: 0.09514000000001488
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2285295
# Time 419.468558 #Seq 3384 Info QoS Data, SN=3384, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2285838
# Time 419.541861 #Seq 3123 Info QoS Data, SN=3123, FN=0, Flags=.p.....TC
#
#
# No. 2285838 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2285838, Info QoS Data, SN=3123, FN=0, Flags=.p.....TC
# Time difference: 0.07416599999999107
# -----------------------------------------
# Stage 7 finish. No. 2287898, Info QoS Data, SN=3126, FN=0, Flags=.p.....TC
# Time difference: 0.3232409999999959
#
# False
# Stage Num = 8
# Valid Stage Num = 7
# What is this packet? Data Length = 185 No. 2288107
# Time 419.909727 #Seq 3388 Info QoS Data, SN=3388, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 8 finish. No. 2289077, Info QoS Data, SN=3128, FN=0, Flags=.p.....TC
# Time difference: 0.1897260000000074
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2290158
# Time 420.239638 #Seq 3130 Info QoS Data, SN=3130, FN=0, Flags=.p.....TC
#
#
# No. 2290158 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 2290158, Info QoS Data, SN=3130, FN=0, Flags=.p.....TC
# Time difference: 0.18481000000002723
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2290987
# Time 420.376486 #Seq 3132 Info QoS Data, SN=3132, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2290987
# Time 420.376486 #Seq 3132 Info QoS Data, SN=3132, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 2290987
# Time 420.376486 #Seq 3132 Info QoS Data, SN=3132, FN=0, Flags=.p.....TC
#
#
# No. 2290987 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2290987, Info QoS Data, SN=3132, FN=0, Flags=.p.....TC
# Time difference: 0.13684799999998631
#
# -------- Test Round 20 --------
# -----------------------------------------
# Stage 1 finish. No. 2405173, Info QoS Data, SN=3156, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2407477, Info QoS Data, SN=3157, FN=0, Flags=.p.....TC
# Time difference: 0.34688399999998865
# -----------------------------------------
# Stage 3 finish. No. 2415215, Info QoS Data, SN=3169, FN=0, Flags=.p.....TC
# Time difference: 1.1791450000000054
#
# False
# Stage Num = 4
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2415835
# Time 441.154946 #Seq 3453 Info QoS Data, SN=3453, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 4
# Valid Stage Num = 9
# What is this packet? Data Length = 189 No. 2415835
# Time 441.154946 #Seq 3453 Info QoS Data, SN=3453, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 4 finish. No. 2416893, Info QoS Data, SN=3171, FN=0, Flags=.p.....TC
# Time difference: 0.24455399999999372
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2416950
# Time 441.309717 #Seq 3455 Info QoS Data, SN=3455, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 5
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2417312
# Time 441.376564 #Seq 3173 Info QoS Data, SN=3173, FN=0, Flags=.p.....TC
#
#
# No. 2417312 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 2417312, Info QoS Data, SN=3173, FN=0, Flags=.p.....TC
# Time difference: 0.07406399999996438
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2417602
# Time 441.411069 #Seq 3457 Info QoS Data, SN=3457, FN=0, Flags=.p....F.C
#
#
# False
# Stage Num = 6
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2418979
# Time 441.62917 #Seq 3175 Info QoS Data, SN=3175, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 6
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2418979
# Time 441.62917 #Seq 3175 Info QoS Data, SN=3175, FN=0, Flags=.p.....TC
#
#
# No. 2418979 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2418979, Info QoS Data, SN=3175, FN=0, Flags=.p.....TC
# Time difference: 0.2526060000000143
#
# False
# Stage Num = 7
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2419053
# Time 441.643682 #Seq 3459 Info QoS Data, SN=3459, FN=0, Flags=.p....F.C
#
# -----------------------------------------
# Stage 7 finish. No. 2420199, Info QoS Data, SN=3178, FN=0, Flags=.p.....TC
# Time difference: 0.1774639999999863
# -----------------------------------------
# Stage 8 finish. No. 2420865, Info QoS Data, SN=3180, FN=0, Flags=.p.....TC
# Time difference: 0.1214750000000322
#
# False
# Stage Num = 9
# Valid Stage Num = 3
# What is this packet? Data Length = 189 No. 2422047
# Time 442.160492 #Seq 3182 Info QoS Data, SN=3182, FN=0, Flags=.p.....TC
#
#
# No. 2422047 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 2422047, Info QoS Data, SN=3182, FN=0, Flags=.p.....TC
# Time difference: 0.23238299999997025
#
# False
# Stage Num = 10
# Valid Stage Num = 4
# What is this packet? Data Length = 173 No. 2425902
# Time 442.725804 #Seq 3184 Info QoS Data, SN=3184, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 5
# What is this packet? Data Length = 173 No. 2425902
# Time 442.725804 #Seq 3184 Info QoS Data, SN=3184, FN=0, Flags=.p.....TC
#
#
# False
# Stage Num = 10
# Valid Stage Num = 6
# What is this packet? Data Length = 173 No. 2425902
# Time 442.725804 #Seq 3184 Info QoS Data, SN=3184, FN=0, Flags=.p.....TC
#
#
# No. 2425902 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2425902, Info QoS Data, SN=3184, FN=0, Flags=.p.....TC
# Time difference: 0.5653120000000058

# %%
#for debug
print(str(len(evcc_send_time_anchor)) + '\n')
for i in range(0, len(evcc_send_time_anchor)):
    print("i = " + str(i))
    print(len(evcc_send_time_anchor[i]))
# Out:
# 20
#
# i = 0
# 1
# i = 1
# 10
# i = 2
# 10
# i = 3
# 10
# i = 4
# 10
# i = 5
# 10
# i = 6
# 10
# i = 7
# 10
# i = 8
# 10
# i = 9
# 10
# i = 10
# 10
# i = 11
# 10
# i = 12
# 10
# i = 13
# 10
# i = 14
# 10
# i = 15
# 8
# i = 16
# 10
# i = 17
# 10
# i = 18
# 10
# i = 19
# 10

# %%
#for debug
for i in range(0, len(evcc_send_time_anchor)):
    print("i = " + str(i))
    print(evcc_send_time_anchor[i][len(evcc_send_time_anchor[i])-1]-evcc_send_time_anchor[i][0])
# Out:
# i = 0
# 0.0
# i = 1
# 2.825794000000002
# i = 2
# 2.916784000000007
# i = 3
# 2.2251839999999987
# i = 4
# 3.265495999999999
# i = 5
# 2.835628999999983
# i = 6
# 1.9320160000000044
# i = 7
# 3.304869999999994
# i = 8
# 2.6081129999999746
# i = 9
# 2.9662040000000047
# i = 10
# 2.742227000000014
# i = 11
# 2.0673830000000066
# i = 12
# 2.2568409999999517
# i = 13
# 1.2302150000000438
# i = 14
# 2.2061140000000137
# i = 15
# 1.937896999999964
# i = 16
# 2.3920590000000175
# i = 17
# 2.291643000000022
# i = 18
# 2.025845000000004
# i = 19
# 3.193886999999961

# %%
#Processing secc send
with open('csv/DataLink/max_interf/secc_send_max_add_1_round_SDP_res.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_secc_send = []
    seq_num_secc_send = []
    data_length_secc_send = []
    info_secc_send = []
    frame_num_secc_send = []
    
    for row in rows:
        timelist_secc_send.append(float(row['Time']))
        seq_num_secc_send.append(int(row['Sequence number']))
        data_length_secc_send.append(int(row['Data Length']))
        info_secc_send.append(str(row['Info']))
        frame_num_secc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_secc_send) != len(seq_num_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(data_length_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(info_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(frame_num_secc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send))
# Out:
# 1070

# %%
timelist_secc_send_split = []
seq_num_secc_send_split = []
data_length_secc_send_split = []
info_secc_send_split = []
frame_num_secc_send_split = []

round_start_point = 0
round_end_point = 0

sdpres_index_list = []
#Fetch first packet index of data length = 92 (SDP response) in each round
for i in range(0, len(data_length_secc_send)):
    if(i == 0 and data_length_secc_send[i] == 92):
        sdpres_index_list.append(i)
    if(i > 0 and data_length_secc_send[i] == 92 and data_length_secc_send[i-1] != 92):
        sdpres_index_list.append(i)
sdpres_index_list.append(len(data_length_secc_send)) #Add the end of list index

for i in range(0, len(sdpres_index_list)-1):
        timelist_secc_send_split.append([timelist_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        seq_num_secc_send_split.append([seq_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        data_length_secc_send_split.append([data_length_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        info_secc_send_split.append([info_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        frame_num_secc_send_split.append([frame_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])

# %%
#for debug
if(len(timelist_secc_send_split) != len(seq_num_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(data_length_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(info_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(frame_num_secc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i))
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0
# 36
# i = 1
# 49
# i = 2
# 57
# i = 3
# 50
# i = 4
# 55
# i = 5
# 53
# i = 6
# 57
# i = 7
# 52
# i = 8
# 56
# i = 9
# 57
# i = 10
# 59
# i = 11
# 58
# i = 12
# 54
# i = 13
# 50
# i = 14
# 57
# i = 15
# 45
# i = 16
# 56
# i = 17
# 54
# i = 18
# 56
# i = 19
# 59

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 26.550628000000003
# 22.028153000000003
# 22.81058399999999
# 21.360501999999997
# 22.804158
# 22.130099
# 21.304294999999996
# 22.422740000000005
# 22.114607000000007
# 22.22235599999999
# 22.12243300000003
# 21.201747999999952
# 21.59241700000001
# 20.185448000000008
# 21.99704300000002
# 21.51047299999999
# 22.554220999999984
# 21.485689000000036
# 21.190412999999978

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i) + ' ', end = '')
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0 36
# i = 1 49
# i = 2 57
# i = 3 50
# i = 4 55
# i = 5 53
# i = 6 57
# i = 7 52
# i = 8 56
# i = 9 57
# i = 10 59
# i = 11 58
# i = 12 54
# i = 13 50
# i = 14 57
# i = 15 45
# i = 16 56
# i = 17 54
# i = 18 56
# i = 19 59

# %%
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 26.550628000000003
# 22.028153000000003
# 22.81058399999999
# 21.360501999999997
# 22.804158
# 22.130099
# 21.304294999999996
# 22.422740000000005
# 22.114607000000007
# 22.22235599999999
# 22.12243300000003
# 21.201747999999952
# 21.59241700000001
# 20.185448000000008
# 21.99704300000002
# 21.51047299999999
# 22.554220999999984
# 21.485689000000036
# 21.190412999999978

# %%
#Set secc time anchor in each round per stage
secc_send_time_anchor = []
#data_length_in_each_stage = [92, 173, 157, 189, 253, 173, 189, 173, 493, 173]
wierd_packet_secc = {}
packet_loss_testing_round_1_flag = False
packet_loss_testing_round_4_flag = False
packet_loss_testing_round_7_flag = False

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(secc_send_time_anchor_each_round):
    print("Time difference: " + str(secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-1]-
                          secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        return True
    else:
        #debug
        print("\nWhat is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet_secc[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet_secc.get(frameNum) != None):
        del wierd_packet_secc[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_secc_send_split)):
#for i in [7]:
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    secc_send_time_anchor_each_round = [timelist_secc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_secc_send_split[i][0], info_secc_send_split[i][0])
    stageNum = stageNum + 1
    
    #Deal with packet loss......
    if(i == 1 and packet_loss_testing_round_1_flag == False):
        secc_send_time_anchor_each_round.append(47.83142)
        printinfo(stageNum, 220571, "Packet Loss")
        print_time_difference(secc_send_time_anchor_each_round)
        stageNum = stageNum + 1
        packet_loss_testing_round_1_flag = True
        
    #Deal with packet loss......
    if(i == 4 and packet_loss_testing_round_4_flag == False):
        secc_send_time_anchor_each_round.append(114.408053)
        printinfo(stageNum, 562244, "Packet Loss")
        print_time_difference(secc_send_time_anchor_each_round)
        stageNum = stageNum + 1
        packet_loss_testing_round_4_flag = True
    
    
    for j in range(1, len(data_length_secc_send_split[i])):
        #Stage 2
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 2, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 3
        if(data_length_secc_send_split[i][j] == 157 and data_length_secc_send_split[i][j-1] != 157):
            if(checkstage_num(stageNum, 3, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 4
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 4, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                    
                continue
                
        #Stage 5
        if(data_length_secc_send_split[i][j] == 253 and data_length_secc_send_split[i][j-1] != 253):
            if(checkstage_num(stageNum, 5, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 6
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 6, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 7
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 7, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 7 and packet_loss_testing_round_7_flag == False):
                    secc_send_time_anchor_each_round.append(181.844227)
                    printinfo(stageNum, 926419, "Packet Loss")
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_7_flag = True
                
                continue
                
        #Stage 8
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 8, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 9
        if(data_length_secc_send_split[i][j] == 493 and data_length_secc_send_split[i][j-1] != 493):
            if(checkstage_num(stageNum, 9, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 10
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        
        if(stageNum == 11): break
        
    secc_send_time_anchor.append(secc_send_time_anchor_each_round)
# Out:
# -------- Test Round 1 --------
# -----------------------------------------
# Stage 1 finish. No. 0, Info QoS Data, SN=2652, FN=0, Flags=.p.....TC
#
# What is this packet? Data Length = 189 No. 96150
# Time 26.56558 #Seq 2614 Info QoS Data, SN=2614, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 189 No. 96150
# Time 26.56558 #Seq 2614 Info QoS Data, SN=2614, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 2 finish. No. 96282, Info QoS Data, SN=2618, FN=0, Flags=.p.....TC
# Time difference: 6.713229999999999
#
# What is this packet? Data Length = 189 No. 97390
# Time 26.987199 #Seq 2620 Info QoS Data, SN=2620, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 189 No. 97390
# Time 26.987199 #Seq 2620 Info QoS Data, SN=2620, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97619
# Time 27.144891 #Seq 2622 Info QoS Data, SN=2622, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97619
# Time 27.144891 #Seq 2622 Info QoS Data, SN=2622, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97619
# Time 27.144891 #Seq 2622 Info QoS Data, SN=2622, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97619
# Time 27.144891 #Seq 2622 Info QoS Data, SN=2622, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97753
# Time 27.324476 #Seq 2626 Info QoS Data, SN=2626, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97753
# Time 27.324476 #Seq 2626 Info QoS Data, SN=2626, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97753
# Time 27.324476 #Seq 2626 Info QoS Data, SN=2626, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97753
# Time 27.324476 #Seq 2626 Info QoS Data, SN=2626, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 165399
# Time 38.673204 #Seq 2642 Info QoS Data, SN=2642, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 165399
# Time 38.673204 #Seq 2642 Info QoS Data, SN=2642, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 165399
# Time 38.673204 #Seq 2642 Info QoS Data, SN=2642, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 165399
# Time 38.673204 #Seq 2642 Info QoS Data, SN=2642, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 165627
# Time 38.704479 #Seq 2644 Info QoS Data, SN=2644, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 165627
# Time 38.704479 #Seq 2644 Info QoS Data, SN=2644, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 165627
# Time 38.704479 #Seq 2644 Info QoS Data, SN=2644, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 165627
# Time 38.704479 #Seq 2644 Info QoS Data, SN=2644, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 3 finish. No. 198117, Info QoS Data, SN=2647, FN=0, Flags=.p.....TC
# Time difference: 17.395869
#
# -------- Test Round 2 --------
# -----------------------------------------
# Stage 1 finish. No. 212977, Info QoS Data, SN=2652, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 220571, Info Packet Loss
# Time difference: 1.2807919999999982
# -----------------------------------------
# Stage 3 finish. No. 221092, Info QoS Data, SN=2668, FN=0, Flags=.p.....TC
# Time difference: 0.06418099999999782
# -----------------------------------------
# Stage 4 finish. No. 222550, Info QoS Data, SN=2670, FN=0, Flags=.p.....TC
# Time difference: 0.2508580000000009
# -----------------------------------------
# Stage 5 finish. No. 223328, Info QoS Data, SN=2672, FN=0, Flags=.p.....TC
# Time difference: 0.11282899999999785
#
# What is this packet? Data Length = 173 No. 224162
# Time 48.389373 #Seq 2674 Info QoS Data, SN=2674, FN=0, Flags=.p.....TC
#
#
# No. 224162 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 224162, Info QoS Data, SN=2674, FN=0, Flags=.p.....TC
# Time difference: 0.13008500000000112
#
# What is this packet? Data Length = 189 No. 225825
# Time 48.635671 #Seq 2676 Info QoS Data, SN=2676, FN=0, Flags=.p.....TC
#
#
# No. 225825 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 225825, Info QoS Data, SN=2676, FN=0, Flags=.p.....TC
# Time difference: 0.24629800000000301
#
# What is this packet? Data Length = 173 No. 226905
# Time 48.828954 #Seq 2678 Info QoS Data, SN=2678, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 226905
# Time 48.828954 #Seq 2678 Info QoS Data, SN=2678, FN=0, Flags=.p.....TC
#
#
# No. 226905 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 226905, Info QoS Data, SN=2678, FN=0, Flags=.p.....TC
# Time difference: 0.19328300000000098
# -----------------------------------------
# Stage 9 finish. No. 229352, Info QoS Data, SN=2680, FN=0, Flags=.p.....TC
# Time difference: 0.3695669999999964
#
# What is this packet? Data Length = 173 No. 230216
# Time 49.323497 #Seq 2682 Info QoS Data, SN=2682, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 230216
# Time 49.323497 #Seq 2682 Info QoS Data, SN=2682, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 230216
# Time 49.323497 #Seq 2682 Info QoS Data, SN=2682, FN=0, Flags=.p.....TC
#
#
# No. 230216 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 230216, Info QoS Data, SN=2682, FN=0, Flags=.p.....TC
# Time difference: 0.12497600000000375
#
# -------- Test Round 3 --------
# -----------------------------------------
# Stage 1 finish. No. 320557, Info QoS Data, SN=2720, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 326113, Info QoS Data, SN=2732, FN=0, Flags=.p.....TC
# Time difference: 0.9517290000000003
# -----------------------------------------
# Stage 3 finish. No. 327923, Info QoS Data, SN=2735, FN=0, Flags=.p.....TC
# Time difference: 0.3208389999999923
# -----------------------------------------
# Stage 4 finish. No. 329724, Info QoS Data, SN=2738, FN=0, Flags=.p.....TC
# Time difference: 0.3311080000000004
# -----------------------------------------
# Stage 5 finish. No. 330837, Info QoS Data, SN=2741, FN=0, Flags=.p.....TC
# Time difference: 0.21650999999999954
#
# What is this packet? Data Length = 173 No. 331269
# Time 70.499881 #Seq 2743 Info QoS Data, SN=2743, FN=0, Flags=.p.....TC
#
#
# No. 331269 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 331269, Info QoS Data, SN=2743, FN=0, Flags=.p.....TC
# Time difference: 0.10091400000000306
#
# What is this packet? Data Length = 189 No. 333626
# Time 70.935069 #Seq 2746 Info QoS Data, SN=2746, FN=0, Flags=.p.....TC
#
#
# No. 333626 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 333626, Info QoS Data, SN=2746, FN=0, Flags=.p.....TC
# Time difference: 0.4351879999999966
#
# What is this packet? Data Length = 173 No. 334758
# Time 71.133516 #Seq 2749 Info QoS Data, SN=2749, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 334758
# Time 71.133516 #Seq 2749 Info QoS Data, SN=2749, FN=0, Flags=.p.....TC
#
#
# No. 334758 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 334758, Info QoS Data, SN=2749, FN=0, Flags=.p.....TC
# Time difference: 0.1984470000000016
# -----------------------------------------
# Stage 9 finish. No. 335415, Info QoS Data, SN=2751, FN=0, Flags=.p.....TC
# Time difference: 0.11544800000000066
#
# What is this packet? Data Length = 173 No. 336581
# Time 71.400428 #Seq 2753 Info QoS Data, SN=2753, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 336581
# Time 71.400428 #Seq 2753 Info QoS Data, SN=2753, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 336581
# Time 71.400428 #Seq 2753 Info QoS Data, SN=2753, FN=0, Flags=.p.....TC
#
#
# No. 336581 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 336581, Info QoS Data, SN=2753, FN=0, Flags=.p.....TC
# Time difference: 0.15146400000000426
#
# -------- Test Round 4 --------
# -----------------------------------------
# Stage 1 finish. No. 438233, Info QoS Data, SN=2777, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 444295, Info QoS Data, SN=2789, FN=0, Flags=.p.....TC
# Time difference: 0.9713550000000026
# -----------------------------------------
# Stage 3 finish. No. 444811, Info QoS Data, SN=2791, FN=0, Flags=.p.....TC
# Time difference: 0.08190299999999695
# -----------------------------------------
# Stage 4 finish. No. 445604, Info QoS Data, SN=2793, FN=0, Flags=.p.....TC
# Time difference: 0.11020800000000008
# -----------------------------------------
# Stage 5 finish. No. 445815, Info QoS Data, SN=2795, FN=0, Flags=.p.....TC
# Time difference: 0.03624600000000555
#
# What is this packet? Data Length = 173 No. 446776
# Time 92.74407 #Seq 2797 Info QoS Data, SN=2797, FN=0, Flags=.p.....TC
#
#
# No. 446776 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 446776, Info QoS Data, SN=2797, FN=0, Flags=.p.....TC
# Time difference: 0.1549929999999904
#
# What is this packet? Data Length = 189 No. 448270
# Time 92.973082 #Seq 2799 Info QoS Data, SN=2799, FN=0, Flags=.p.....TC
#
#
# No. 448270 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 448270, Info QoS Data, SN=2799, FN=0, Flags=.p.....TC
# Time difference: 0.22901200000001154
#
# What is this packet? Data Length = 189 No. 449540
# Time 93.183624 #Seq 2800 Info QoS Data, SN=2800, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 189 No. 449540
# Time 93.183624 #Seq 2800 Info QoS Data, SN=2800, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 450518
# Time 93.347931 #Seq 2802 Info QoS Data, SN=2802, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 450518
# Time 93.347931 #Seq 2802 Info QoS Data, SN=2802, FN=0, Flags=.p.....TC
#
#
# No. 450518 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 450518, Info QoS Data, SN=2802, FN=0, Flags=.p.....TC
# Time difference: 0.37484899999999755
# -----------------------------------------
# Stage 9 finish. No. 451183, Info QoS Data, SN=2804, FN=0, Flags=.p.....TC
# Time difference: 0.09099499999999239
#
# What is this packet? Data Length = 173 No. 452076
# Time 93.624631 #Seq 2806 Info QoS Data, SN=2806, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 452076
# Time 93.624631 #Seq 2806 Info QoS Data, SN=2806, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 452076
# Time 93.624631 #Seq 2806 Info QoS Data, SN=2806, FN=0, Flags=.p.....TC
#
#
# No. 452076 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 452076, Info QoS Data, SN=2806, FN=0, Flags=.p.....TC
# Time difference: 0.18570499999999868
#
# -------- Test Round 5 --------
# -----------------------------------------
# Stage 1 finish. No. 550804, Info QoS Data, SN=2838, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 562244, Info Packet Loss
# Time difference: 1.6581860000000006
# -----------------------------------------
# Stage 3 finish. No. 563642, Info QoS Data, SN=2853, FN=0, Flags=.p.....TC
# Time difference: 0.21636200000000372
# -----------------------------------------
# Stage 4 finish. No. 566034, Info QoS Data, SN=2856, FN=0, Flags=.p.....TC
# Time difference: 0.3275950000000023
# -----------------------------------------
# Stage 5 finish. No. 566302, Info QoS Data, SN=2858, FN=0, Flags=.p.....TC
# Time difference: 0.02545700000000295
#
# What is this packet? Data Length = 173 No. 566904
# Time 115.088103 #Seq 2860 Info QoS Data, SN=2860, FN=0, Flags=.p.....TC
#
#
# No. 566904 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 566904, Info QoS Data, SN=2860, FN=0, Flags=.p.....TC
# Time difference: 0.11063599999999951
#
# What is this packet? Data Length = 189 No. 568336
# Time 115.299432 #Seq 2862 Info QoS Data, SN=2862, FN=0, Flags=.p.....TC
#
#
# No. 568336 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 568336, Info QoS Data, SN=2862, FN=0, Flags=.p.....TC
# Time difference: 0.2113289999999921
#
# What is this packet? Data Length = 173 No. 569202
# Time 115.444046 #Seq 2864 Info QoS Data, SN=2864, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 569202
# Time 115.444046 #Seq 2864 Info QoS Data, SN=2864, FN=0, Flags=.p.....TC
#
#
# No. 569202 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 569202, Info QoS Data, SN=2864, FN=0, Flags=.p.....TC
# Time difference: 0.14461400000000424
# -----------------------------------------
# Stage 9 finish. No. 569768, Info QoS Data, SN=2866, FN=0, Flags=.p.....TC
# Time difference: 0.08767400000000691
#
# What is this packet? Data Length = 173 No. 571710
# Time 115.824353 #Seq 2869 Info QoS Data, SN=2869, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 571710
# Time 115.824353 #Seq 2869 Info QoS Data, SN=2869, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 571710
# Time 115.824353 #Seq 2869 Info QoS Data, SN=2869, FN=0, Flags=.p.....TC
#
#
# No. 571710 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 571710, Info QoS Data, SN=2869, FN=0, Flags=.p.....TC
# Time difference: 0.29263299999999504
#
# -------- Test Round 6 --------
# -----------------------------------------
# Stage 1 finish. No. 679362, Info QoS Data, SN=2903, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 686104, Info QoS Data, SN=2915, FN=0, Flags=.p.....TC
# Time difference: 1.2577940000000183
# -----------------------------------------
# Stage 3 finish. No. 686599, Info QoS Data, SN=2917, FN=0, Flags=.p.....TC
# Time difference: 0.08242499999997221
# -----------------------------------------
# Stage 4 finish. No. 687839, Info QoS Data, SN=2919, FN=0, Flags=.p.....TC
# Time difference: 0.17108500000000504
# -----------------------------------------
# Stage 5 finish. No. 688162, Info QoS Data, SN=2921, FN=0, Flags=.p.....TC
# Time difference: 0.04666199999999776
#
# What is this packet? Data Length = 173 No. 689043
# Time 137.250676 #Seq 2923 Info QoS Data, SN=2923, FN=0, Flags=.p..R..TC
#
#
# No. 689043 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 689043, Info QoS Data, SN=2923, FN=0, Flags=.p..R..TC
# Time difference: 0.1386850000000095
#
# What is this packet? Data Length = 189 No. 690240
# Time 137.433554 #Seq 2925 Info QoS Data, SN=2925, FN=0, Flags=.p.....TC
#
#
# No. 690240 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 690240, Info QoS Data, SN=2925, FN=0, Flags=.p.....TC
# Time difference: 0.1828779999999881
#
# What is this packet? Data Length = 173 No. 691730
# Time 137.643303 #Seq 2927 Info QoS Data, SN=2927, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 691730
# Time 137.643303 #Seq 2927 Info QoS Data, SN=2927, FN=0, Flags=.p.....TC
#
#
# No. 691730 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 691730, Info QoS Data, SN=2927, FN=0, Flags=.p.....TC
# Time difference: 0.2097490000000164
# -----------------------------------------
# Stage 9 finish. No. 693130, Info QoS Data, SN=2929, FN=0, Flags=.p.....TC
# Time difference: 0.2473139999999887
#
# What is this packet? Data Length = 173 No. 694374
# Time 138.25573 #Seq 2932 Info QoS Data, SN=2932, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 694374
# Time 138.25573 #Seq 2932 Info QoS Data, SN=2932, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 694374
# Time 138.25573 #Seq 2932 Info QoS Data, SN=2932, FN=0, Flags=.p.....TC
#
#
# No. 694374 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 694374, Info QoS Data, SN=2932, FN=0, Flags=.p.....TC
# Time difference: 0.365113000000008
#
# -------- Test Round 7 --------
# -----------------------------------------
# Stage 1 finish. No. 793696, Info QoS Data, SN=2955, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 798587, Info QoS Data, SN=2968, FN=0, Flags=.p.....TC
# Time difference: 0.9412800000000061
# -----------------------------------------
# Stage 3 finish. No. 799135, Info QoS Data, SN=2970, FN=0, Flags=.p.....TC
# Time difference: 0.11115599999999404
# -----------------------------------------
# Stage 4 finish. No. 799627, Info QoS Data, SN=2972, FN=0, Flags=.p.....TC
# Time difference: 0.10325800000001095
# -----------------------------------------
# Stage 5 finish. No. 799909, Info QoS Data, SN=2974, FN=0, Flags=.p.....TC
# Time difference: 0.04850099999998747
#
# What is this packet? Data Length = 173 No. 800416
# Time 158.99013 #Seq 2976 Info QoS Data, SN=2976, FN=0, Flags=.p.....TC
#
#
# No. 800416 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 800416, Info QoS Data, SN=2976, FN=0, Flags=.p.....TC
# Time difference: 0.10181099999999788
#
# What is this packet? Data Length = 189 No. 801737
# Time 159.250723 #Seq 2978 Info QoS Data, SN=2978, FN=0, Flags=.p.....TC
#
#
# No. 801737 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 801737, Info QoS Data, SN=2978, FN=0, Flags=.p.....TC
# Time difference: 0.2605930000000001
#
# What is this packet? Data Length = 173 No. 802486
# Time 159.416371 #Seq 2980 Info QoS Data, SN=2980, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 802486
# Time 159.416371 #Seq 2980 Info QoS Data, SN=2980, FN=0, Flags=.p.....TC
#
#
# No. 802486 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 802486, Info QoS Data, SN=2980, FN=0, Flags=.p.....TC
# Time difference: 0.16564800000000446
# -----------------------------------------
# Stage 9 finish. No. 802878, Info QoS Data, SN=2982, FN=0, Flags=.p.....TC
# Time difference: 0.07571500000000242
#
# What is this packet? Data Length = 173 No. 803680
# Time 159.659281 #Seq 2984 Info QoS Data, SN=2984, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 803680
# Time 159.659281 #Seq 2984 Info QoS Data, SN=2984, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 803680
# Time 159.659281 #Seq 2984 Info QoS Data, SN=2984, FN=0, Flags=.p.....TC
#
#
# No. 803680 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 803680, Info QoS Data, SN=2984, FN=0, Flags=.p.....TC
# Time difference: 0.16719499999999243
#
# -------- Test Round 8 --------
# -----------------------------------------
# Stage 1 finish. No. 909690, Info QoS Data, SN=3010, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 917023, Info QoS Data, SN=3022, FN=0, Flags=.p.....TC
# Time difference: 1.3251260000000116
# -----------------------------------------
# Stage 3 finish. No. 917673, Info QoS Data, SN=3024, FN=0, Flags=.p.....TC
# Time difference: 0.10542300000000182
#
# What is this packet? Data Length = 157 No. 917935
# Time 180.464488 #Seq 3024 Info QoS Data, SN=3024, FN=0, Flags=.p..R..TC
#
# -----------------------------------------
# Stage 4 finish. No. 919113, Info QoS Data, SN=3026, FN=0, Flags=.p.....TC
# Time difference: 0.22360999999997944
# -----------------------------------------
# Stage 5 finish. No. 920082, Info QoS Data, SN=3028, FN=0, Flags=.p.....TC
# Time difference: 0.14404000000001815
#
# What is this packet? Data Length = 173 No. 920890
# Time 180.923445 #Seq 3030 Info QoS Data, SN=3030, FN=0, Flags=.p.....TC
#
#
# No. 920890 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 920890, Info QoS Data, SN=3030, FN=0, Flags=.p.....TC
# Time difference: 0.1368269999999825
#
# What is this packet? Data Length = 189 No. 924290
# Time 181.510675 #Seq 3032 Info QoS Data, SN=3032, FN=0, Flags=.p.....TC
#
#
# No. 924290 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 924290, Info QoS Data, SN=3032, FN=0, Flags=.p.....TC
# Time difference: 0.5872300000000052
# -----------------------------------------
# Stage 8 finish. No. 926419, Info Packet Loss
# Time difference: 0.3335519999999974
# -----------------------------------------
# Stage 9 finish. No. 926961, Info QoS Data, SN=3037, FN=0, Flags=.p.....TC
# Time difference: 0.08308300000001623
#
# What is this packet? Data Length = 173 No. 928949
# Time 182.294365 #Seq 3040 Info QoS Data, SN=3040, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 928949
# Time 182.294365 #Seq 3040 Info QoS Data, SN=3040, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 928949
# Time 182.294365 #Seq 3040 Info QoS Data, SN=3040, FN=0, Flags=.p.....TC
#
#
# No. 928949 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 928949, Info QoS Data, SN=3040, FN=0, Flags=.p.....TC
# Time difference: 0.36705499999999347
#
# -------- Test Round 9 --------
# -----------------------------------------
# Stage 1 finish. No. 1015315, Info QoS Data, SN=3095, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1021575, Info QoS Data, SN=3108, FN=0, Flags=.p.....TC
# Time difference: 1.048451
# -----------------------------------------
# Stage 3 finish. No. 1023076, Info QoS Data, SN=3111, FN=0, Flags=.p.....TC
# Time difference: 0.2466280000000154
# -----------------------------------------
# Stage 4 finish. No. 1023602, Info QoS Data, SN=3114, FN=0, Flags=.p.....TC
# Time difference: 0.10991199999998003
# -----------------------------------------
# Stage 5 finish. No. 1023717, Info QoS Data, SN=3116, FN=0, Flags=.p.....TC
# Time difference: 0.05155200000001514
#
# What is this packet? Data Length = 173 No. 1024500
# Time 203.013668 #Seq 3118 Info QoS Data, SN=3118, FN=0, Flags=.p.....TC
#
#
# No. 1024500 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1024500, Info QoS Data, SN=3118, FN=0, Flags=.p.....TC
# Time difference: 0.14596599999998716
#
# What is this packet? Data Length = 189 No. 1026478
# Time 203.380662 #Seq 3121 Info QoS Data, SN=3121, FN=0, Flags=.p.....TC
#
#
# No. 1026478 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1026478, Info QoS Data, SN=3121, FN=0, Flags=.p.....TC
# Time difference: 0.36699400000000537
#
# What is this packet? Data Length = 173 No. 1027268
# Time 203.514406 #Seq 3123 Info QoS Data, SN=3123, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1027268
# Time 203.514406 #Seq 3123 Info QoS Data, SN=3123, FN=0, Flags=.p.....TC
#
#
# No. 1027268 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1027268, Info QoS Data, SN=3123, FN=0, Flags=.p.....TC
# Time difference: 0.1337440000000072
# -----------------------------------------
# Stage 9 finish. No. 1028785, Info QoS Data, SN=3125, FN=0, Flags=.p.....TC
# Time difference: 0.2909129999999891
#
# What is this packet? Data Length = 173 No. 1029806
# Time 204.007027 #Seq 3127 Info QoS Data, SN=3127, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 1029806
# Time 204.007027 #Seq 3127 Info QoS Data, SN=3127, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 1029806
# Time 204.007027 #Seq 3127 Info QoS Data, SN=3127, FN=0, Flags=.p..R..TC
#
#
# No. 1029806 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1029806, Info QoS Data, SN=3127, FN=0, Flags=.p..R..TC
# Time difference: 0.20170799999999645
#
# -------- Test Round 10 --------
# -----------------------------------------
# Stage 1 finish. No. 1135864, Info QoS Data, SN=3153, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1141504, Info QoS Data, SN=3165, FN=0, Flags=.p.....TC
# Time difference: 0.8627129999999852
# -----------------------------------------
# Stage 3 finish. No. 1142965, Info QoS Data, SN=3168, FN=0, Flags=.p.....TC
# Time difference: 0.2677280000000053
# -----------------------------------------
# Stage 4 finish. No. 1143757, Info QoS Data, SN=3170, FN=0, Flags=.p.....TC
# Time difference: 0.14404100000001563
# -----------------------------------------
# Stage 5 finish. No. 1144159, Info QoS Data, SN=3172, FN=0, Flags=.p.....TC
# Time difference: 0.08205699999999183
#
# What is this packet? Data Length = 173 No. 1144378
# Time 224.953406 #Seq 3174 Info QoS Data, SN=3174, FN=0, Flags=.p.....TC
#
#
# No. 1144378 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1144378, Info QoS Data, SN=3174, FN=0, Flags=.p.....TC
# Time difference: 0.07110099999999875
#
# What is this packet? Data Length = 189 No. 1147358
# Time 225.550215 #Seq 3176 Info QoS Data, SN=3176, FN=0, Flags=.p.....TC
#
#
# No. 1147358 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1147358, Info QoS Data, SN=3176, FN=0, Flags=.p.....TC
# Time difference: 0.5968090000000075
#
# What is this packet? Data Length = 173 No. 1150248
# Time 226.098315 #Seq 3180 Info QoS Data, SN=3180, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1150248
# Time 226.098315 #Seq 3180 Info QoS Data, SN=3180, FN=0, Flags=.p.....TC
#
#
# No. 1150248 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1150248, Info QoS Data, SN=3180, FN=0, Flags=.p.....TC
# Time difference: 0.5481000000000051
# -----------------------------------------
# Stage 9 finish. No. 1151586, Info QoS Data, SN=3183, FN=0, Flags=.p..R..TC
# Time difference: 0.22494899999998097
#
# What is this packet? Data Length = 173 No. 1152262
# Time 226.466351 #Seq 3185 Info QoS Data, SN=3185, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1152262
# Time 226.466351 #Seq 3185 Info QoS Data, SN=3185, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1152262
# Time 226.466351 #Seq 3185 Info QoS Data, SN=3185, FN=0, Flags=.p.....TC
#
#
# No. 1152262 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1152262, Info QoS Data, SN=3185, FN=0, Flags=.p.....TC
# Time difference: 0.1430870000000084
#
# -------- Test Round 11 --------
# -----------------------------------------
# Stage 1 finish. No. 1272242, Info QoS Data, SN=3209, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1280686, Info QoS Data, SN=3223, FN=0, Flags=.p.....TC
# Time difference: 1.3282409999999913
# -----------------------------------------
# Stage 3 finish. No. 1281850, Info QoS Data, SN=3225, FN=0, Flags=.p.....TC
# Time difference: 0.1413270000000182
# -----------------------------------------
# Stage 4 finish. No. 1284111, Info QoS Data, SN=3228, FN=0, Flags=.p.....TC
# Time difference: 0.35591999999999757
# -----------------------------------------
# Stage 5 finish. No. 1284645, Info QoS Data, SN=3230, FN=0, Flags=.p.....TC
# Time difference: 0.07734899999999811
#
# What is this packet? Data Length = 173 No. 1285470
# Time 247.787459 #Seq 3232 Info QoS Data, SN=3232, FN=0, Flags=.p.....TC
#
#
# No. 1285470 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1285470, Info QoS Data, SN=3232, FN=0, Flags=.p.....TC
# Time difference: 0.13650000000001228
#
# What is this packet? Data Length = 189 No. 1287211
# Time 248.056318 #Seq 3235 Info QoS Data, SN=3235, FN=0, Flags=.p.....TC
#
#
# No. 1287211 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1287211, Info QoS Data, SN=3235, FN=0, Flags=.p.....TC
# Time difference: 0.26885899999999197
#
# What is this packet? Data Length = 173 No. 1288377
# Time 248.22054 #Seq 3237 Info QoS Data, SN=3237, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1288377
# Time 248.22054 #Seq 3237 Info QoS Data, SN=3237, FN=0, Flags=.p.....TC
#
#
# No. 1288377 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1288377, Info QoS Data, SN=3237, FN=0, Flags=.p.....TC
# Time difference: 0.1642219999999952
# -----------------------------------------
# Stage 9 finish. No. 1289483, Info QoS Data, SN=3239, FN=0, Flags=.p.....TC
# Time difference: 0.1519869999999912
#
# What is this packet? Data Length = 173 No. 1290208
# Time 248.486402 #Seq 3241 Info QoS Data, SN=3241, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1290208
# Time 248.486402 #Seq 3241 Info QoS Data, SN=3241, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1290208
# Time 248.486402 #Seq 3241 Info QoS Data, SN=3241, FN=0, Flags=.p.....TC
#
#
# No. 1290208 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1290208, Info QoS Data, SN=3241, FN=0, Flags=.p.....TC
# Time difference: 0.11387500000000728
#
# -------- Test Round 12 --------
# -----------------------------------------
# Stage 1 finish. No. 1413160, Info QoS Data, SN=3278, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1418313, Info QoS Data, SN=3289, FN=0, Flags=.p.....TC
# Time difference: 0.8193969999999808
# -----------------------------------------
# Stage 3 finish. No. 1419344, Info QoS Data, SN=3292, FN=0, Flags=.p.....TC
# Time difference: 0.14671599999996943
# -----------------------------------------
# Stage 4 finish. No. 1420088, Info QoS Data, SN=3294, FN=0, Flags=.p.....TC
# Time difference: 0.09427500000003874
# -----------------------------------------
# Stage 5 finish. No. 1420477, Info QoS Data, SN=3296, FN=0, Flags=.p.....TC
# Time difference: 0.06623700000000099
#
# What is this packet? Data Length = 173 No. 1421015
# Time 269.107534 #Seq 3298 Info QoS Data, SN=3298, FN=0, Flags=.p.....TC
#
#
# No. 1421015 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1421015, Info QoS Data, SN=3298, FN=0, Flags=.p.....TC
# Time difference: 0.11035399999997253
#
# What is this packet? Data Length = 189 No. 1422595
# Time 269.361129 #Seq 3301 Info QoS Data, SN=3301, FN=0, Flags=.p.....TC
#
#
# No. 1422595 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1422595, Info QoS Data, SN=3301, FN=0, Flags=.p.....TC
# Time difference: 0.25359500000001844
#
# What is this packet? Data Length = 173 No. 1424003
# Time 269.540001 #Seq 3303 Info QoS Data, SN=3303, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1424003
# Time 269.540001 #Seq 3303 Info QoS Data, SN=3303, FN=0, Flags=.p.....TC
#
#
# No. 1424003 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1424003, Info QoS Data, SN=3303, FN=0, Flags=.p.....TC
# Time difference: 0.17887200000001258
# -----------------------------------------
# Stage 9 finish. No. 1424929, Info QoS Data, SN=3305, FN=0, Flags=.p.....TC
# Time difference: 0.13960199999996803
#
# What is this packet? Data Length = 173 No. 1426030
# Time 269.845735 #Seq 3307 Info QoS Data, SN=3307, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1426030
# Time 269.845735 #Seq 3307 Info QoS Data, SN=3307, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1426030
# Time 269.845735 #Seq 3307 Info QoS Data, SN=3307, FN=0, Flags=.p.....TC
#
#
# No. 1426030 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1426030, Info QoS Data, SN=3307, FN=0, Flags=.p.....TC
# Time difference: 0.1661320000000046
#
# -------- Test Round 13 --------
# -----------------------------------------
# Stage 1 finish. No. 1547286, Info QoS Data, SN=3332, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1555104, Info QoS Data, SN=3344, FN=0, Flags=.p.....TC
# Time difference: 1.199984000000029
# -----------------------------------------
# Stage 3 finish. No. 1555644, Info QoS Data, SN=3346, FN=0, Flags=.p.....TC
# Time difference: 0.08009599999996908
# -----------------------------------------
# Stage 4 finish. No. 1556684, Info QoS Data, SN=3348, FN=0, Flags=.p.....TC
# Time difference: 0.16859600000003638
# -----------------------------------------
# Stage 5 finish. No. 1557284, Info QoS Data, SN=3350, FN=0, Flags=.p.....TC
# Time difference: 0.09789200000000164
#
# What is this packet? Data Length = 173 No. 1558134
# Time 290.791288 #Seq 3352 Info QoS Data, SN=3352, FN=0, Flags=.p.....TC
#
#
# No. 1558134 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1558134, Info QoS Data, SN=3352, FN=0, Flags=.p.....TC
# Time difference: 0.17241699999999582
#
# What is this packet? Data Length = 189 No. 1559840
# Time 291.055633 #Seq 3354 Info QoS Data, SN=3354, FN=0, Flags=.p.....TC
#
#
# No. 1559840 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1559840, Info QoS Data, SN=3354, FN=0, Flags=.p.....TC
# Time difference: 0.2643449999999916
#
# What is this packet? Data Length = 173 No. 1559883
# Time 291.149071 #Seq 3356 Info QoS Data, SN=3356, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1559883
# Time 291.149071 #Seq 3356 Info QoS Data, SN=3356, FN=0, Flags=.p.....TC
#
#
# No. 1559883 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1559883, Info QoS Data, SN=3356, FN=0, Flags=.p.....TC
# Time difference: 0.09343799999999192
# -----------------------------------------
# Stage 9 finish. No. 1559919, Info QoS Data, SN=3358, FN=0, Flags=.p.....TC
# Time difference: 0.028256999999996424
#
# What is this packet? Data Length = 173 No. 1560677
# Time 291.32022 #Seq 3360 Info QoS Data, SN=3360, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1560677
# Time 291.32022 #Seq 3360 Info QoS Data, SN=3360, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1560677
# Time 291.32022 #Seq 3360 Info QoS Data, SN=3360, FN=0, Flags=.p.....TC
#
#
# No. 1560677 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1560677, Info QoS Data, SN=3360, FN=0, Flags=.p.....TC
# Time difference: 0.14289200000001756
#
# -------- Test Round 14 --------
# -----------------------------------------
# Stage 1 finish. No. 1651172, Info QoS Data, SN=3436, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1652045, Info QoS Data, SN=3448, FN=0, Flags=.p.....TC
# Time difference: 0.5724559999999883
# -----------------------------------------
# Stage 3 finish. No. 1652072, Info QoS Data, SN=3450, FN=0, Flags=.p.....TC
# Time difference: 0.04074800000000778
# -----------------------------------------
# Stage 4 finish. No. 1652592, Info QoS Data, SN=3452, FN=0, Flags=.p.....TC
# Time difference: 0.08113000000003012
# -----------------------------------------
# Stage 5 finish. No. 1652764, Info QoS Data, SN=3454, FN=0, Flags=.p.....TC
# Time difference: 0.03994799999998122
#
# What is this packet? Data Length = 173 No. 1653017
# Time 311.465944 #Seq 3456 Info QoS Data, SN=3456, FN=0, Flags=.p.....TC
#
#
# No. 1653017 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1653017, Info QoS Data, SN=3456, FN=0, Flags=.p.....TC
# Time difference: 0.06694199999998318
#
# What is this packet? Data Length = 189 No. 1653776
# Time 311.648947 #Seq 3458 Info QoS Data, SN=3458, FN=0, Flags=.p.....TC
#
#
# No. 1653776 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1653776, Info QoS Data, SN=3458, FN=0, Flags=.p.....TC
# Time difference: 0.183003000000042
#
# What is this packet? Data Length = 173 No. 1654463
# Time 311.817407 #Seq 3462 Info QoS Data, SN=3462, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1654463
# Time 311.817407 #Seq 3462 Info QoS Data, SN=3462, FN=0, Flags=.p.....TC
#
#
# No. 1654463 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1654463, Info QoS Data, SN=3462, FN=0, Flags=.p.....TC
# Time difference: 0.16845999999998185
# -----------------------------------------
# Stage 9 finish. No. 1654706, Info QoS Data, SN=3465, FN=0, Flags=.p.....TC
# Time difference: 0.058403999999995904
#
# What is this packet? Data Length = 173 No. 1655171
# Time 311.999835 #Seq 3469 Info QoS Data, SN=3469, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1655171
# Time 311.999835 #Seq 3469 Info QoS Data, SN=3469, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1655171
# Time 311.999835 #Seq 3469 Info QoS Data, SN=3469, FN=0, Flags=.p.....TC
#
#
# No. 1655171 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1655171, Info QoS Data, SN=3469, FN=0, Flags=.p.....TC
# Time difference: 0.1240240000000199
#
# -------- Test Round 15 --------
# -----------------------------------------
# Stage 1 finish. No. 1756078, Info QoS Data, SN=3496, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1760294, Info QoS Data, SN=3508, FN=0, Flags=.p.....TC
# Time difference: 0.8325009999999793
# -----------------------------------------
# Stage 3 finish. No. 1761424, Info QoS Data, SN=3511, FN=0, Flags=.p.....TC
# Time difference: 0.21269100000000662
# -----------------------------------------
# Stage 4 finish. No. 1761955, Info QoS Data, SN=3513, FN=0, Flags=.p.....TC
# Time difference: 0.14488000000000056
# -----------------------------------------
# Stage 5 finish. No. 1762418, Info QoS Data, SN=3515, FN=0, Flags=.p.....TC
# Time difference: 0.09528199999999742
#
# What is this packet? Data Length = 173 No. 1763121
# Time 332.296854 #Seq 3518 Info QoS Data, SN=3518, FN=0, Flags=.p.....TC
#
#
# No. 1763121 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1763121, Info QoS Data, SN=3518, FN=0, Flags=.p.....TC
# Time difference: 0.1613320000000158
#
# What is this packet? Data Length = 173 No. 1763381
# Time 332.353191 #Seq 3518 Info QoS Data, SN=3518, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 1763381
# Time 332.353191 #Seq 3518 Info QoS Data, SN=3518, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 1763381
# Time 332.353191 #Seq 3518 Info QoS Data, SN=3518, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 1763381
# Time 332.353191 #Seq 3518 Info QoS Data, SN=3518, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 189 No. 1764478
# Time 332.551474 #Seq 3521 Info QoS Data, SN=3521, FN=0, Flags=.p.....TC
#
#
# No. 1764478 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1764478, Info QoS Data, SN=3521, FN=0, Flags=.p.....TC
# Time difference: 0.2546199999999885
#
# What is this packet? Data Length = 173 No. 1765357
# Time 332.726864 #Seq 3523 Info QoS Data, SN=3523, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1765357
# Time 332.726864 #Seq 3523 Info QoS Data, SN=3523, FN=0, Flags=.p.....TC
#
#
# No. 1765357 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1765357, Info QoS Data, SN=3523, FN=0, Flags=.p.....TC
# Time difference: 0.17538999999999305
# -----------------------------------------
# Stage 9 finish. No. 1765822, Info QoS Data, SN=3525, FN=0, Flags=.p.....TC
# Time difference: 0.09953699999999799
#
# What is this packet? Data Length = 173 No. 1766498
# Time 332.993897 #Seq 3527 Info QoS Data, SN=3527, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1766498
# Time 332.993897 #Seq 3527 Info QoS Data, SN=3527, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1766498
# Time 332.993897 #Seq 3527 Info QoS Data, SN=3527, FN=0, Flags=.p.....TC
#
#
# No. 1766498 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1766498, Info QoS Data, SN=3527, FN=0, Flags=.p.....TC
# Time difference: 0.1674960000000283
#
# -------- Test Round 16 --------
# -----------------------------------------
# Stage 1 finish. No. 1869469, Info QoS Data, SN=3552, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1875347, Info QoS Data, SN=3564, FN=0, Flags=.p.....TC
# Time difference: 0.9260659999999916
# -----------------------------------------
# Stage 3 finish. No. 1875921, Info QoS Data, SN=3566, FN=0, Flags=.p.....TC
# Time difference: 0.07780900000000202
#
# What is this packet? Data Length = 253 No. 1878371
# Time 354.233964 #Seq 3570 Info QoS Data, SN=3570, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1879487
# Time 354.411282 #Seq 3573 Info QoS Data, SN=3573, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1879487
# Time 354.411282 #Seq 3573 Info QoS Data, SN=3573, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1879487
# Time 354.411282 #Seq 3573 Info QoS Data, SN=3573, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1879487
# Time 354.411282 #Seq 3573 Info QoS Data, SN=3573, FN=0, Flags=.p.....TC
#
# -----------------------------------------
# Stage 4 finish. No. 1880819, Info QoS Data, SN=3575, FN=0, Flags=.p..R..TC
# Time difference: 0.7596219999999789
#
# What is this packet? Data Length = 173 No. 1881684
# Time 354.995175 #Seq 3581 Info QoS Data, SN=3581, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1881684
# Time 354.995175 #Seq 3581 Info QoS Data, SN=3581, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1881684
# Time 354.995175 #Seq 3581 Info QoS Data, SN=3581, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1881684
# Time 354.995175 #Seq 3581 Info QoS Data, SN=3581, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1939149
# Time 366.405821 #Seq 3601 Info QoS Data, SN=3601, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1939149
# Time 366.405821 #Seq 3601 Info QoS Data, SN=3601, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1939149
# Time 366.405821 #Seq 3601 Info QoS Data, SN=3601, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1939149
# Time 366.405821 #Seq 3601 Info QoS Data, SN=3601, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1939513
# Time 366.477753 #Seq 3603 Info QoS Data, SN=3603, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1939513
# Time 366.477753 #Seq 3603 Info QoS Data, SN=3603, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1939513
# Time 366.477753 #Seq 3603 Info QoS Data, SN=3603, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1939513
# Time 366.477753 #Seq 3603 Info QoS Data, SN=3603, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 157 No. 1970912
# Time 371.467296 #Seq 3606 Info QoS Data, SN=3606, FN=0, Flags=.p.....TC
#
#
# -------- Test Round 17 --------
# -----------------------------------------
# Stage 1 finish. No. 1989393, Info QoS Data, SN=3623, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1997347, Info QoS Data, SN=3636, FN=0, Flags=.p.....TC
# Time difference: 1.238619999999969
# -----------------------------------------
# Stage 3 finish. No. 1997770, Info QoS Data, SN=3638, FN=0, Flags=.p.....TC
# Time difference: 0.09297900000001391
# -----------------------------------------
# Stage 4 finish. No. 1998610, Info QoS Data, SN=3640, FN=0, Flags=.p.....TC
# Time difference: 0.13751999999999498
# -----------------------------------------
# Stage 5 finish. No. 1998933, Info QoS Data, SN=3642, FN=0, Flags=.p.....TC
# Time difference: 0.05006500000001779
#
# What is this packet? Data Length = 173 No. 1999745
# Time 376.022622 #Seq 3644 Info QoS Data, SN=3644, FN=0, Flags=.p.....TC
#
#
# No. 1999745 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1999745, Info QoS Data, SN=3644, FN=0, Flags=.p.....TC
# Time difference: 0.14575400000001082
#
# What is this packet? Data Length = 189 No. 2001211
# Time 376.252098 #Seq 3646 Info QoS Data, SN=3646, FN=0, Flags=.p.....TC
#
#
# No. 2001211 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2001211, Info QoS Data, SN=3646, FN=0, Flags=.p.....TC
# Time difference: 0.22947599999997692
#
# What is this packet? Data Length = 173 No. 2002631
# Time 376.446177 #Seq 3648 Info QoS Data, SN=3648, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2002631
# Time 376.446177 #Seq 3648 Info QoS Data, SN=3648, FN=0, Flags=.p.....TC
#
#
# No. 2002631 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2002631, Info QoS Data, SN=3648, FN=0, Flags=.p.....TC
# Time difference: 0.1940789999999879
# -----------------------------------------
# Stage 9 finish. No. 2003310, Info QoS Data, SN=3650, FN=0, Flags=.p.....TC
# Time difference: 0.09889000000003989
#
# What is this packet? Data Length = 173 No. 2004901
# Time 376.791717 #Seq 3652 Info QoS Data, SN=3652, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2004901
# Time 376.791717 #Seq 3652 Info QoS Data, SN=3652, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2004901
# Time 376.791717 #Seq 3652 Info QoS Data, SN=3652, FN=0, Flags=.p.....TC
#
#
# No. 2004901 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2004901, Info QoS Data, SN=3652, FN=0, Flags=.p.....TC
# Time difference: 0.24664999999998827
#
# -------- Test Round 18 --------
# -----------------------------------------
# Stage 1 finish. No. 2137993, Info QoS Data, SN=3679, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2144072, Info QoS Data, SN=3691, FN=0, Flags=.p.....TC
# Time difference: 0.9754780000000096
# -----------------------------------------
# Stage 3 finish. No. 2146529, Info QoS Data, SN=3694, FN=0, Flags=.p.....TC
# Time difference: 0.3640439999999785
# -----------------------------------------
# Stage 4 finish. No. 2148680, Info QoS Data, SN=3697, FN=0, Flags=.p.....TC
# Time difference: 0.3383720000000494
# -----------------------------------------
# Stage 5 finish. No. 2148900, Info QoS Data, SN=3699, FN=0, Flags=.p.....TC
# Time difference: 0.030712999999991553
#
# What is this packet? Data Length = 173 No. 2149601
# Time 398.712711 #Seq 3701 Info QoS Data, SN=3701, FN=0, Flags=.p.....TC
#
#
# No. 2149601 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2149601, Info QoS Data, SN=3701, FN=0, Flags=.p.....TC
# Time difference: 0.0921989999999937
#
# What is this packet? Data Length = 189 No. 2150902
# Time 398.934558 #Seq 3703 Info QoS Data, SN=3703, FN=0, Flags=.p.....TC
#
#
# No. 2150902 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2150902, Info QoS Data, SN=3703, FN=0, Flags=.p.....TC
# Time difference: 0.22184699999996838
#
# What is this packet? Data Length = 173 No. 2151767
# Time 399.06284 #Seq 3705 Info QoS Data, SN=3705, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2151767
# Time 399.06284 #Seq 3705 Info QoS Data, SN=3705, FN=0, Flags=.p.....TC
#
#
# No. 2151767 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2151767, Info QoS Data, SN=3705, FN=0, Flags=.p.....TC
# Time difference: 0.12828200000001289
# -----------------------------------------
# Stage 9 finish. No. 2152094, Info QoS Data, SN=3707, FN=0, Flags=.p.....TC
# Time difference: 0.03812199999998711
#
# What is this packet? Data Length = 173 No. 2152599
# Time 399.199977 #Seq 3709 Info QoS Data, SN=3709, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2152599
# Time 399.199977 #Seq 3709 Info QoS Data, SN=3709, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2152599
# Time 399.199977 #Seq 3709 Info QoS Data, SN=3709, FN=0, Flags=.p.....TC
#
#
# No. 2152599 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2152599, Info QoS Data, SN=3709, FN=0, Flags=.p.....TC
# Time difference: 0.09901500000000851
#
# -------- Test Round 19 --------
# -----------------------------------------
# Stage 1 finish. No. 2278545, Info QoS Data, SN=3734, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2283759, Info QoS Data, SN=3745, FN=0, Flags=.p.....TC
# Time difference: 0.8339159999999879
# -----------------------------------------
# Stage 3 finish. No. 2284087, Info QoS Data, SN=3747, FN=0, Flags=.p.....TC
# Time difference: 0.053474999999991724
# -----------------------------------------
# Stage 4 finish. No. 2285064, Info QoS Data, SN=3749, FN=0, Flags=.p.....TC
# Time difference: 0.14397500000001173
# -----------------------------------------
# Stage 5 finish. No. 2285402, Info QoS Data, SN=3751, FN=0, Flags=.p.....TC
# Time difference: 0.04714999999998781
#
# What is this packet? Data Length = 173 No. 2286083
# Time 419.585086 #Seq 3753 Info QoS Data, SN=3753, FN=0, Flags=.p.....TC
#
#
# No. 2286083 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2286083, Info QoS Data, SN=3753, FN=0, Flags=.p.....TC
# Time difference: 0.1089759999999842
#
# What is this packet? Data Length = 173 No. 2286172
# Time 419.593977 #Seq 3753 Info QoS Data, SN=3753, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 2286172
# Time 419.593977 #Seq 3753 Info QoS Data, SN=3753, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 2286172
# Time 419.593977 #Seq 3753 Info QoS Data, SN=3753, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 2286172
# Time 419.593977 #Seq 3753 Info QoS Data, SN=3753, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 189 No. 2288498
# Time 419.956346 #Seq 3756 Info QoS Data, SN=3756, FN=0, Flags=.p.....TC
#
#
# No. 2288498 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2288498, Info QoS Data, SN=3756, FN=0, Flags=.p.....TC
# Time difference: 0.3712600000000066
#
# What is this packet? Data Length = 173 No. 2289442
# Time 420.116196 #Seq 3758 Info QoS Data, SN=3758, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2289442
# Time 420.116196 #Seq 3758 Info QoS Data, SN=3758, FN=0, Flags=.p.....TC
#
#
# No. 2289442 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2289442, Info QoS Data, SN=3758, FN=0, Flags=.p.....TC
# Time difference: 0.15985000000000582
# -----------------------------------------
# Stage 9 finish. No. 2290513, Info QoS Data, SN=3760, FN=0, Flags=.p.....TC
# Time difference: 0.16587600000002567
#
# What is this packet? Data Length = 173 No. 2291112
# Time 420.393311 #Seq 3762 Info QoS Data, SN=3762, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2291112
# Time 420.393311 #Seq 3762 Info QoS Data, SN=3762, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2291112
# Time 420.393311 #Seq 3762 Info QoS Data, SN=3762, FN=0, Flags=.p.....TC
#
#
# No. 2291112 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2291112, Info QoS Data, SN=3762, FN=0, Flags=.p.....TC
# Time difference: 0.11123899999995501
#
# -------- Test Round 20 --------
# -----------------------------------------
# Stage 1 finish. No. 2405549, Info QoS Data, SN=3795, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2411447, Info QoS Data, SN=3808, FN=0, Flags=.p.....TC
# Time difference: 0.8799359999999865
# -----------------------------------------
# Stage 3 finish. No. 2416187, Info QoS Data, SN=3811, FN=0, Flags=.p.....TC
# Time difference: 0.7094420000000241
# -----------------------------------------
# Stage 4 finish. No. 2417053, Info QoS Data, SN=3813, FN=0, Flags=.p.....TC
# Time difference: 0.15391199999999117
# -----------------------------------------
# Stage 5 finish. No. 2417808, Info QoS Data, SN=3815, FN=0, Flags=.p.....TC
# Time difference: 0.11670900000001438
#
# What is this packet? Data Length = 173 No. 2419263
# Time 441.667623 #Seq 3817 Info QoS Data, SN=3817, FN=0, Flags=.p.....TC
#
#
# No. 2419263 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2419263, Info QoS Data, SN=3817, FN=0, Flags=.p.....TC
# Time difference: 0.21961699999997109
#
# What is this packet? Data Length = 189 No. 2420405
# Time 441.848625 #Seq 3820 Info QoS Data, SN=3820, FN=0, Flags=.p.....TC
#
#
# No. 2420405 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2420405, Info QoS Data, SN=3820, FN=0, Flags=.p.....TC
# Time difference: 0.18100200000003497
#
# What is this packet? Data Length = 173 No. 2421467
# Time 442.012942 #Seq 3822 Info QoS Data, SN=3822, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2421467
# Time 442.012942 #Seq 3822 Info QoS Data, SN=3822, FN=0, Flags=.p.....TC
#
#
# No. 2421467 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2421467, Info QoS Data, SN=3822, FN=0, Flags=.p.....TC
# Time difference: 0.16431699999998273
#
# What is this packet? Data Length = 173 No. 2421477
# Time 442.017064 #Seq 3822 Info QoS Data, SN=3822, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 2421477
# Time 442.017064 #Seq 3822 Info QoS Data, SN=3822, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 2421477
# Time 442.017064 #Seq 3822 Info QoS Data, SN=3822, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 2421477
# Time 442.017064 #Seq 3822 Info QoS Data, SN=3822, FN=0, Flags=.p..R..TC
#
# -----------------------------------------
# Stage 9 finish. No. 2422650, Info QoS Data, SN=3824, FN=0, Flags=.p.....TC
# Time difference: 0.2136499999999728
#
# What is this packet? Data Length = 173 No. 2426156
# Time 442.755615 #Seq 3827 Info QoS Data, SN=3827, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2426156
# Time 442.755615 #Seq 3827 Info QoS Data, SN=3827, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2426156
# Time 442.755615 #Seq 3827 Info QoS Data, SN=3827, FN=0, Flags=.p.....TC
#
#
# No. 2426156 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2426156, Info QoS Data, SN=3827, FN=0, Flags=.p.....TC
# Time difference: 0.5290229999999951

# %%
#for debug
print(str(len(secc_send_time_anchor)) + '\n')
for i in range(0, len(secc_send_time_anchor)):
    print(str(i) + ": " + str(len(secc_send_time_anchor[i])))
# Out:
# 20
#
# 0: 3
# 1: 10
# 2: 10
# 3: 10
# 4: 10
# 5: 10
# 6: 10
# 7: 10
# 8: 10
# 9: 10
# 10: 10
# 11: 10
# 12: 10
# 13: 10
# 14: 10
# 15: 4
# 16: 10
# 17: 10
# 18: 10
# 19: 10

# %%
#for debug
for i in range(0, len(secc_send_time_anchor)):
    print(secc_send_time_anchor[i][len(secc_send_time_anchor[i])-1]-secc_send_time_anchor[i][0])
# Out:
# 24.109099
# 2.772869
# 2.8216469999999987
# 2.2352659999999958
# 3.0744860000000074
# 2.701705000000004
# 1.9751569999999958
# 3.305946000000006
# 2.595867999999996
# 2.9405849999999987
# 2.738280000000003
# 1.9751799999999662
# 2.2479170000000295
# 1.3351150000000302
# 2.1437290000000075
# 1.7634969999999726
# 2.4340329999999994
# 2.2880719999999997
# 1.9957169999999564
# 3.167607999999973

# %%
#BLOCK ACK processing
#Time evcc sends blockACK after secc send
evcc_blockAck_time_anchor = []

blockack_index = 0
for i in range(0, len(secc_send_time_anchor)):
    evcc_blockAck_time_anchor_in_each_round = []
    
    for j in range(0, len(secc_send_time_anchor[i])):
        while(timelist_block_ack[blockack_index] < secc_send_time_anchor[i][j]):
            blockack_index = blockack_index + 1
        evcc_blockAck_time_anchor_in_each_round.append(timelist_block_ack[blockack_index])
        #print("ACK time difference = " + str(
        #timelist_block_ack[blockack_index] - secc_send_time_anchor[i][j]))
    
    evcc_blockAck_time_anchor.append(evcc_blockAck_time_anchor_in_each_round)

# %%
#SECC Packet Loss dict & Block Ack Loss
#secc_packet_loss_dict[i] = {stageNum}
# i = 5, j = 0 is packet loss of evcc BLOCK ACK
# i = 3, j = 9 is packet loss of evcc BLOCK ACK
secc_packet_loss_dict = {}
secc_packet_loss_dict[2] = {5}
secc_packet_loss_dict[1] = {1, 3, 4, 5}
secc_packet_loss_dict[4] = {1}
secc_packet_loss_dict[7] = {7}


#for i in secc_packet_loss_dict.get(5): print(i)
#7 in secc_packet_loss_dict.get(5)

# %%
#Calculate the avg. block ack latency
sum_latency = 0
cnt = 0
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) == None):
            sum_latency = sum_latency + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
            cnt = cnt + 1
        elif(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)): continue
            else:
                sum_latency = sum_latency + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
                cnt = cnt + 1
        else: continue
avg_blockAck_latency = sum_latency/cnt
print("Avg Block Ack latency = " + str(avg_blockAck_latency) + " s")
print(cnt)
# Out:
# Avg Block Ack latency = 0.08593851111111366 s
# 180

# %%
#For curiousity
#Calculate the avg. block ack latency of the appending packet loss packets
sum_latency_2 = 0
cnt = 0
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)):
                sum_latency_2 = sum_latency_2 + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
                cnt = cnt + 1
        else: continue
avg_blockAck_latency_2 = sum_latency_2/cnt
print("Avg Block Ack latency = " + str(avg_blockAck_latency_2) + " s")
print(cnt)
# Out:
# Avg Block Ack latency = 0.1844141428571433 s
# 7

# %%
#For debug. Can see testing round 6 (i = 5) has longer block ack latency due to packet loss.
# I only append the secc send time, but didn't append the block time.
from statistics import mean

for i in range(0, len(evcc_blockAck_time_anchor)):
    print("i = " + str(i) + ": " + str(mean(evcc_blockAck_time_anchor[i])-mean(secc_send_time_anchor[i])))
# Out:
# i = 0: 1.7933803333333316
# i = 1: 0.1131196999999986
# i = 2: 0.1325743000000017
# i = 3: 0.07842660000000024
# i = 4: 0.06599009999999339
# i = 5: 0.048772299999995994
# i = 6: 0.034205700000001116
# i = 7: 0.09362169999999992
# i = 8: 0.08498069999998847
# i = 9: 0.07000110000001314
# i = 10: 0.06513179999998897
# i = 11: 0.04307069999998703
# i = 12: 0.036978099999998904
# i = 13: 0.009402000000022781
# i = 14: 0.03518860000002633
# i = 15: 0.05435749999998052
# i = 16: 0.03496380000001409
# i = 17: 0.049999899999988884
# i = 18: 0.03877399999998943
# i = 19: 0.08102489999998852

# %%
#Use the avg. block ack latency for the lost secc sent packets
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)):
                evcc_blockAck_time_anchor[i][j] = secc_send_time_anchor[i][j] + avg_blockAck_latency
                print("i = " + str(i))
                print("j = " + str(j))
        else: continue
# Out:
# i = 1
# j = 1
# i = 1
# j = 3
# i = 1
# j = 4
# i = 1
# j = 5
# i = 2
# j = 5
# i = 4
# j = 1
# i = 7
# j = 7

# %%
#Test Round 1, 16: evcc send Too many lost packets... but no timeout

for i in [15, 0]:
    del evcc_send_time_anchor[i]
    del secc_send_time_anchor[i]
    del evcc_blockAck_time_anchor[i]


#for debug
print(str(len(evcc_send_time_anchor)) + '\n')
for i in range(0, len(evcc_send_time_anchor)):
    print(len(evcc_send_time_anchor[i]))
print('\n')    
    
#for debug
print(str(len(secc_send_time_anchor)) + '\n')
for i in range(0, len(secc_send_time_anchor)):
    print(len(secc_send_time_anchor[i]))
print('\n')
    
#for debug
print(str(len(evcc_blockAck_time_anchor)) + '\n')
for i in range(0, len(evcc_blockAck_time_anchor)):
    print(len(evcc_blockAck_time_anchor[i]))
# Out:
# 18
#
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
#
#
# 18
#
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
#
#
# 18
#
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
#for debug check wierd value
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_send_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))
        if(evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))

# %%
#For debug
i = 1
for j in [5]:
    print("Stage " + str(j+1))
    print(evcc_send_time_anchor[i][j])
    print(secc_send_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j]-evcc_send_time_anchor[i][j])
# Out:
# Stage 6
# 70.490289
# 70.499881
# 70.58581951111111
# 0.09553051111110733

# %%
path = 'time_record/max_interf_80211.txt'
f = open(path, 'w')
for i in range(0, len(evcc_send_time_anchor)):
    for j in range(0, len(evcc_send_time_anchor[i])):
        print((evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j])*1000, file=f, end="")
        f.writelines('\t')
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][len(evcc_blockAck_time_anchor[i])-1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    f.writelines('20')
    f.writelines('\t')
    f.writelines('0')
    f.writelines('\t')
    f.writelines('\n')
f.close()

# %%
#如果 TCP 有 retransmission，在 Data Link Layer seq 會往下傳送，很難抓取
