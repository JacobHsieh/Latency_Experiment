# %%
import csv

def read_int_from_file(file_location):
    numbers = []
    with open(file_location) as tsv:
        for column in zip(*[line for line in csv.reader(tsv, dialect="excel-tab")]):
            for num in column:
                numbers.append(num)
    while '' in numbers:
        numbers.remove('')

    print(file_location + " has " + str(len(numbers)) + " of entries.")
    numbers_int = map(int, numbers)
    numbers_int_list = list(numbers_int)
    
    return numbers_int_list

def read_float_from_file(file_location):
    numbers = []
    with open(file_location) as tsv:
        for column in zip(*[line for line in csv.reader(tsv, dialect="excel-tab")]):
            for num in column:
                numbers.append(num)
    while '' in numbers:
        numbers.remove('')
    
    print(file_location + " has " + str(len(numbers)) + " of entries.")
    numbers_float = map(float, numbers)
    numbers_float_list = list(numbers_float)
    
    return numbers_float_list

interference_no_list = read_int_from_file("time_record/no_interf_time_record_raw.txt")
interference_no_VI_list = read_int_from_file("time_record/no_interf_VI_time_record_raw.txt")
interference_no_VO_list = read_int_from_file("time_record/no_interf_VO_time_record_raw.txt")
interference_max_list = read_int_from_file("time_record/max_interf_time_record_raw.txt")
interference_max_VI_list = read_int_from_file("time_record/max_interf_VI_time_record_raw.txt")
interference_max_VO_list = read_int_from_file("time_record/max_interf_VO_time_record_raw.txt")

interference_no_list_chunks = [interference_no_list[x:x+20] for x in range(0, len(interference_no_list), 20)]
interference_no_VI_list_chunks = [interference_no_VI_list[x:x+20] for x in range(0, len(interference_no_VI_list), 20)]
interference_no_VO_list_chunks = [interference_no_VO_list[x:x+20] for x in range(0, len(interference_no_VO_list), 20)]
interference_max_list_chunks = [interference_max_list[x:x+20] for x in range(0, len(interference_max_list), 20)]
interference_max_VI_list_chunks = [interference_max_VI_list[x:x+20] for x in range(0, len(interference_max_VI_list), 20)]
interference_max_VO_list_chunks = [interference_max_VO_list[x:x+20] for x in range(0, len(interference_max_VO_list), 20)]

interference_no_list_TCP = read_float_from_file("time_record/no_evcc_TCP_UDP.txt")
interference_no_VI_list_TCP = read_float_from_file("time_record/no_VI_evcc_TCP_UDP.txt")
interference_no_VO_list_TCP = read_float_from_file("time_record/no_VO_evcc_TCP_UDP.txt")
interference_max_list_TCP = read_float_from_file("time_record/max_evcc_TCP_UDP.txt")
interference_max_VI_list_TCP = read_float_from_file("time_record/max_VI_evcc_TCP_UDP.txt")
interference_max_VO_list_TCP = read_float_from_file("time_record/max_evcc_VO_TCP_UDP.txt")

interference_no_list_TCP_chunks = [interference_no_list_TCP[x:x+20] for x in range(0, len(interference_no_list_TCP), 20)]
interference_no_VI_list_TCP_chunks = [interference_no_VI_list_TCP[x:x+20] for x in range(0, len(interference_no_VI_list_TCP), 20)]
interference_no_VO_list_TCP_chunks = [interference_no_VO_list_TCP[x:x+20] for x in range(0, len(interference_no_VO_list_TCP), 20)]
interference_max_list_TCP_chunks = [interference_max_list_TCP[x:x+20] for x in range(0, len(interference_max_list_TCP), 20)]
interference_max_VI_list_TCP_chunks = [interference_max_VI_list_TCP[x:x+20] for x in range(0, len(interference_max_VI_list_TCP), 20)]
interference_max_VO_list_TCP_chunks = [interference_max_VO_list_TCP[x:x+20] for x in range(0, len(interference_max_VO_list_TCP), 20)]

'''
interference_no_list_80211 = read_float_from_file("time_record/no_inter_80211_processing.txt")
interference_max_list_80211 = read_float_from_file("time_record/max_80211_processing.txt")

interference_no_list_80211_chunks = [interference_no_list_80211[x:x+20] for x in range(0, len(interference_no_list_80211), 20)]
interference_max_list_80211_chunks = [interference_max_list_80211[x:x+18] for x in range(0, len(interference_max_list_80211), 18)]
'''
# Out:
# time_record/no_interf_time_record_raw.txt has 280 of entries.
# time_record/no_interf_VI_time_record_raw.txt has 280 of entries.
# time_record/no_interf_VO_time_record_raw.txt has 280 of entries.
# time_record/max_interf_time_record_raw.txt has 280 of entries.
# time_record/max_interf_VI_time_record_raw.txt has 280 of entries.
# time_record/max_interf_VO_time_record_raw.txt has 280 of entries.
# time_record/no_evcc_TCP_UDP.txt has 280 of entries.
# time_record/no_VI_evcc_TCP_UDP.txt has 280 of entries.
# time_record/no_VO_evcc_TCP_UDP.txt has 280 of entries.
# time_record/max_evcc_TCP_UDP.txt has 280 of entries.
# time_record/max_VI_evcc_TCP_UDP.txt has 280 of entries.
# time_record/max_evcc_VO_TCP_UDP.txt has 280 of entries.
# ...

# %%
#Plot each single instance
import numpy as np
import matplotlib.pyplot as plt

def plot_each_step_latency(chunks_array):
    fig, ax = plt.subplots()
    fig.set_size_inches(20, 8)
    plt.grid(which='minor', axis='both')
    plt.ylabel('Latency (ms)', fontsize=12)
    
    ax.boxplot(chunks_array[0:10])
    ax.set_xticklabels([
        "Start\n<->\nSECC Discovery",
        "SECC Discovery\n<->\nSession Initialized",
        "Session Initialized\n<->\nSupportedAppProtocol",
        "SupportedAppProtocol\n<->\nSessionSetup",
        "SessionSetup\n<->\nServiceDiscovery",
        "ServiceDiscovery\n<->\nPaymentServiceSelection",
        "PaymentServiceSelection\n<->\nPaymentDetail",
        "PaymentDetail\n<->\nAuthorization",
        "Authorization\n<->\nChargeParameterDiscovery",
        "ChargeParameterDiscovery\n<->\nStart Charging"
        ], fontsize=10)
    plt.grid()
    plt.show()

# %%
plot_each_step_latency(interference_no_list_chunks)

# %%
import pandas as pd

def construct_dataframe(list_chunk, interference_str, index, type_str):
    return pd.DataFrame({'Latency (ms)': list_chunk[index],
                         'Interference': [interference_str for _ in range(len(list_chunk[index]))],
                         'Stage': [index+1 for _ in range(len(list_chunk[index]))],
                         'Type': type_str
                        })

stage_num = 10
interference_no_df = {i: construct_dataframe(interference_no_list_chunks, 'no-interf (AC=BE)', i, "Application") for i in range(0, stage_num)}
interference_no_VI_df = {i: construct_dataframe(interference_no_VI_list_chunks, 'no-interf (AC=VI)', i, "Application") for i in range(0, stage_num)}
interference_no_VO_df = {i: construct_dataframe(interference_no_VO_list_chunks, 'no-interf (AC=VO)', i, "Application") for i in range(0, stage_num)}
interference_max_df = {i: construct_dataframe(interference_max_list_chunks, 'max-interf (AC=BE)', i, "Application") for i in range(0, stage_num)}
interference_max_VI_df = {i: construct_dataframe(interference_max_VI_list_chunks, 'max-interf (AC=VI)', i, "Application") for i in range(0, stage_num)}
interference_max_VO_df = {i: construct_dataframe(interference_max_VO_list_chunks, 'max-interf (AC=VO)', i, "Application") for i in range(0, stage_num)}

interference_no_df_all = pd.concat(interference_no_df[i] for i in range(0, stage_num))
interference_no_VI_df_all = pd.concat(interference_no_VI_df[i] for i in range(0, stage_num))
interference_no_VO_df_all = pd.concat(interference_no_VO_df[i] for i in range(0, stage_num))
interference_max_df_all = pd.concat(interference_max_df[i] for i in range(0, stage_num))
interference_max_VI_df_all = pd.concat(interference_max_VI_df[i] for i in range(0, stage_num))
interference_max_VO_df_all = pd.concat(interference_max_VO_df[i] for i in range(0, stage_num))


dataframe_App_all = pd.concat([interference_no_df_all,
                           interference_no_VI_df_all,
                           interference_no_VO_df_all,
                           interference_max_df_all,
                           interference_max_VI_df_all,
                           interference_max_VO_df_all])

interference_no_TCP_df = {i: construct_dataframe(interference_no_list_TCP_chunks, 'no-interf (AC=BE)', i, "TCP") for i in range(0, stage_num)}
interference_no_VI_TCP_df = {i: construct_dataframe(interference_no_VI_list_TCP_chunks, 'no-interf (AC=VI)', i, "TCP") for i in range(0, stage_num)}
interference_no_VO_TCP_df = {i: construct_dataframe(interference_no_VO_list_TCP_chunks, 'no-interf (AC=VO)', i, "TCP") for i in range(0, stage_num)}
interference_max_TCP_df = {i: construct_dataframe(interference_max_list_TCP_chunks, 'max-interf (AC=BE)', i, "TCP") for i in range(0, stage_num)}
interference_max_VI_TCP_df = {i: construct_dataframe(interference_max_VI_list_TCP_chunks, 'max-interf (AC=VI)', i, "TCP") for i in range(0, stage_num)}
interference_max_VO_TCP_df = {i: construct_dataframe(interference_max_VO_list_TCP_chunks, 'max-interf (AC=VO)', i, "TCP") for i in range(0, stage_num)}

interference_no_TCP_df_all = pd.concat(interference_no_TCP_df[i] for i in range(0, stage_num))
interference_no_VI_TCP_df_all = pd.concat(interference_no_VI_TCP_df[i] for i in range(0, stage_num))
interference_no_VO_TCP_df_all = pd.concat(interference_no_VO_TCP_df[i] for i in range(0, stage_num))
interference_max_TCP_df_all = pd.concat(interference_max_TCP_df[i] for i in range(0, stage_num))
interference_max_VI_TCP_df_all = pd.concat(interference_max_VI_TCP_df[i] for i in range(0, stage_num))
interference_max_VO_TCP_df_all = pd.concat(interference_max_VO_TCP_df[i] for i in range(0, stage_num))

dataframe_TCP_all = pd.concat([interference_no_TCP_df_all,
                               interference_no_VI_TCP_df_all,
                               interference_no_VO_TCP_df_all,
                               interference_max_TCP_df_all,
                               interference_max_VI_TCP_df_all,
                               interference_max_VO_TCP_df_all])

'''
interference_no_80211_df = {i: construct_dataframe(interference_no_list_80211_chunks, 'no interference', i, "Data Link") for i in range(0, stage_num)}
interference_max_80211_df = {i: construct_dataframe(interference_max_list_80211_chunks, 'max interference', i, "Data Link") for i in range(0, stage_num)}
qos_10_80211_df = {i: construct_dataframe(qos_10_list_80211_chunks, 'max interference-10 Mbps QoS', i, "Data Link") for i in range(0, stage_num)}
qos_30_80211_df = {i: construct_dataframe(qos_30_list_80211_chunks, 'max interference-30 Mbps QoS', i, "Data Link") for i in range(0, stage_num)}

interference_no_80211_df_all = pd.concat(interference_no_80211_df[i] for i in range(0, stage_num))
interference_max_80211_df_df_all = pd.concat(interference_max_80211_df[i] for i in range(0, stage_num))
qos_10_80211_df_all = pd.concat(qos_10_80211_df[i] for i in range(0, stage_num))
qos_30_80211_df_all = pd.concat(qos_30_80211_df[i] for i in range(0, stage_num))

dataframe_80211_all = pd.concat([interference_no_80211_df_all,
                                interference_max_80211_df_df_all,
                                qos_10_80211_df_all,
                                qos_30_80211_df_all])
'''
# Out:
# '\ninterference_no_80211_df = {i: construct_dataframe(interference_no_list_80211_chunks, \'no interference\', i, "Data Link") for i in range(0, stage_num)}\ninterference_max_80211_df = {i: construct_dataframe(interference_max_list_80211_chunks, \'max interference\', i, "Data Link") for i in range(0, stage_num)}\nqos_10_80211_df = {i: construct_dataframe(qos_10_list_80211_chunks, \'max interference-10 Mbps QoS\', i, "Data Link") for i in range(0, stage_num)}\nqos_30_80211_df = {i: construct_dataframe(qos_30_list_80211_chunks, \'max interference-30 Mbps QoS\', i, "Data Link") for i in range(0, stage_num)}\n\ninterference_no_80211_df_all = pd.concat(interference_no_80211_df[i] for i in range(0, stage_num))\ninterference_max_80211_df_df_all = pd.concat(interference_max_80211_df[i] for i in range(0, stage_num))\nqos_10_80211_df_all = pd.concat(qos_10_80211_df[i] for i in range(0, stage_num))\nqos_30_80211_df_all = pd.concat(qos_30_80211_df[i] for i in range(0, stage_num))\n\ndataframe_802
# ...

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(16,8)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
g1 = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_App_all, hue="Interference", width=0.6, linewidth=1.0, palette="Set1")
g1.set_ylabel("Application Round Trip Latency (ms)")
g1.set_xticklabels([
    "Start\n<->\nSECC Discovery",
    "SECC Discovery\n<->\nSession Initialized",
    "Session Initialized\n<->\nSupportedAppProtocol",
    "SupportedAppProtocol\n<->\nSessionSetup",
    "SessionSetup\n<->\nServiceDiscovery",
    "ServiceDiscovery\n<->\nPaymentServiceSelection",
    "PaymentServiceSelection\n<->\nPaymentDetail",
    "PaymentDetail\n<->\nAuthorization",
    "Authorization\n<->\nChargeParameterDiscovery",
    "ChargeParameterDiscovery\n<->\nStart Charging"
    ], fontsize=9)
#第一個 stage 因為 broadcast 的封包 (SECC Discovery Req.) 無法訂 access category，所以看起來是否加入 QoS 並沒有明顯差別
#使用 AC = VI 或 AC = VO 可以使 max-interf 下的 latancy 下降，使用哪一種類別看起來差異不大
# Out:
# [Text(0, 0, 'Start\n<->\nSECC Discovery'),
#  Text(1, 0, 'SECC Discovery\n<->\nSession Initialized'),
#  Text(2, 0, 'Session Initialized\n<->\nSupportedAppProtocol'),
#  Text(3, 0, 'SupportedAppProtocol\n<->\nSessionSetup'),
#  Text(4, 0, 'SessionSetup\n<->\nServiceDiscovery'),
#  Text(5, 0, 'ServiceDiscovery\n<->\nPaymentServiceSelection'),
#  Text(6, 0, 'PaymentServiceSelection\n<->\nPaymentDetail'),
#  Text(7, 0, 'PaymentDetail\n<->\nAuthorization'),
#  Text(8, 0, 'Authorization\n<->\nChargeParameterDiscovery'),
#  Text(9, 0, 'ChargeParameterDiscovery\n<->\nStart Charging')]

# %%
#TCP
sns.set(rc={'figure.figsize':(16,8)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
g1_TCP = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_TCP_all, hue="Interference", width=0.6, linewidth=1.0, palette="Set1")
g1_TCP.set_ylabel("TCP Round Trip Latency (ms)")
g1_TCP.set_xticklabels([
    "Start\n<->\nSECC Discovery",
    "SECC Discovery\n<->\nSession Initialized",
    "Session Initialized\n<->\nSupportedAppProtocol",
    "SupportedAppProtocol\n<->\nSessionSetup",
    "SessionSetup\n<->\nServiceDiscovery",
    "ServiceDiscovery\n<->\nPaymentServiceSelection",
    "PaymentServiceSelection\n<->\nPaymentDetail",
    "PaymentDetail\n<->\nAuthorization",
    "Authorization\n<->\nChargeParameterDiscovery",
    "ChargeParameterDiscovery\n<->\nStart Charging"
    ], fontsize=9)
# Out:
# [Text(0, 0, 'Start\n<->\nSECC Discovery'),
#  Text(1, 0, 'SECC Discovery\n<->\nSession Initialized'),
#  Text(2, 0, 'Session Initialized\n<->\nSupportedAppProtocol'),
#  Text(3, 0, 'SupportedAppProtocol\n<->\nSessionSetup'),
#  Text(4, 0, 'SessionSetup\n<->\nServiceDiscovery'),
#  Text(5, 0, 'ServiceDiscovery\n<->\nPaymentServiceSelection'),
#  Text(6, 0, 'PaymentServiceSelection\n<->\nPaymentDetail'),
#  Text(7, 0, 'PaymentDetail\n<->\nAuthorization'),
#  Text(8, 0, 'Authorization\n<->\nChargeParameterDiscovery'),
#  Text(9, 0, 'ChargeParameterDiscovery\n<->\nStart Charging')]

# %%
#802.11
sns.set(rc={'figure.figsize':(16,8)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
g1_TCP = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_80211_all, hue="Interference", width=0.6, linewidth=1.0, palette="Set1")
g1_TCP.set_ylabel("Data Link Layer Round Trip Latency (ms)")
g1_TCP.set_xticklabels([
    "Start\n<->\nSECC Discovery",
    "SECC Discovery\n<->\nSession Initialized",
    "Session Initialized\n<->\nSupportedAppProtocol",
    "SupportedAppProtocol\n<->\nSessionSetup",
    "SessionSetup\n<->\nServiceDiscovery",
    "ServiceDiscovery\n<->\nPaymentServiceSelection",
    "PaymentServiceSelection\n<->\nPaymentDetail",
    "PaymentDetail\n<->\nAuthorization",
    "Authorization\n<->\nChargeParameterDiscovery",
    "ChargeParameterDiscovery\n<->\nStart Charging"
    ], fontsize=9)
# Out:
# [Text(0, 0, 'Start\n<->\nSECC Discovery'),
#  Text(1, 0, 'SECC Discovery\n<->\nSession Initialized'),
#  Text(2, 0, 'Session Initialized\n<->\nSupportedAppProtocol'),
#  Text(3, 0, 'SupportedAppProtocol\n<->\nSessionSetup'),
#  Text(4, 0, 'SessionSetup\n<->\nServiceDiscovery'),
#  Text(5, 0, 'ServiceDiscovery\n<->\nPaymentServiceSelection'),
#  Text(6, 0, 'PaymentServiceSelection\n<->\nPaymentDetail'),
#  Text(7, 0, 'PaymentDetail\n<->\nAuthorization'),
#  Text(8, 0, 'Authorization\n<->\nChargeParameterDiscovery'),
#  Text(9, 0, 'ChargeParameterDiscovery\n<->\nStart Charging')]

# %%
#Application vs. TCP vs. 802.11
dataframe_Application_TCP_80211_max = pd.concat([interference_max_df_all,
                                               interference_max_TCP_df_all,
                                              interference_max_80211_df_df_all])

dataframe_Application_TCP_80211_no = pd.concat([interference_no_df_all,
                                               interference_no_TCP_df_all,
                                               interference_no_80211_df_all])

dataframe_Application_TCP_80211_qos_10 = pd.concat([qos_10_df_all,
                                                    qos_10_TCP_df_all,
                                                    qos_10_80211_df_all])

dataframe_Application_TCP_80211_qos_30 = pd.concat([qos_30_df_all,
                                                    qos_30_TCP_df_all,
                                                    qos_30_80211_df_all])

# %%
#Application vs. TCP vs. 802.11 plot
sns.set(rc={'figure.figsize':(16,8)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
App_TCP_0 = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_Application_TCP_80211_max, hue="Type", width=0.6, linewidth=1.0, palette="Set1")
App_TCP_0.set_xlabel("Max. Interference")
App_TCP_0.set_ylabel("Round Trip Latency (ms)")
App_TCP_0.set_xticklabels([
    "Start\n<->\nSECC Discovery",
    "SECC Discovery\n<->\nSession Initialized",
    "Session Initialized\n<->\nSupportedAppProtocol",
    "SupportedAppProtocol\n<->\nSessionSetup",
    "SessionSetup\n<->\nServiceDiscovery",
    "ServiceDiscovery\n<->\nPaymentServiceSelection",
    "PaymentServiceSelection\n<->\nPaymentDetail",
    "PaymentDetail\n<->\nAuthorization",
    "Authorization\n<->\nChargeParameterDiscovery",
    "ChargeParameterDiscovery\n<->\nStart Charging"
    ], fontsize=9)
# Out:
# [Text(0, 0, 'Start\n<->\nSECC Discovery'),
#  Text(1, 0, 'SECC Discovery\n<->\nSession Initialized'),
#  Text(2, 0, 'Session Initialized\n<->\nSupportedAppProtocol'),
#  Text(3, 0, 'SupportedAppProtocol\n<->\nSessionSetup'),
#  Text(4, 0, 'SessionSetup\n<->\nServiceDiscovery'),
#  Text(5, 0, 'ServiceDiscovery\n<->\nPaymentServiceSelection'),
#  Text(6, 0, 'PaymentServiceSelection\n<->\nPaymentDetail'),
#  Text(7, 0, 'PaymentDetail\n<->\nAuthorization'),
#  Text(8, 0, 'Authorization\n<->\nChargeParameterDiscovery'),
#  Text(9, 0, 'ChargeParameterDiscovery\n<->\nStart Charging')]

# %%
#Application vs. TCP vs. 802.11 plot
sns.set(rc={'figure.figsize':(16,8)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
App_TCP_2 = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_Application_TCP_80211_no, hue="Type", width=0.6, linewidth=1.0, palette="Set1")
App_TCP_2.set_xlabel("No Inference (Background)")
App_TCP_2.set_ylabel("Round Trip Latency (ms)")
App_TCP_2.set_xticklabels([
    "Start\n<->\nSECC Discovery",
    "SECC Discovery\n<->\nSession Initialized",
    "Session Initialized\n<->\nSupportedAppProtocol",
    "SupportedAppProtocol\n<->\nSessionSetup",
    "SessionSetup\n<->\nServiceDiscovery",
    "ServiceDiscovery\n<->\nPaymentServiceSelection",
    "PaymentServiceSelection\n<->\nPaymentDetail",
    "PaymentDetail\n<->\nAuthorization",
    "Authorization\n<->\nChargeParameterDiscovery",
    "ChargeParameterDiscovery\n<->\nStart Charging"
    ], fontsize=9)
# Out:
# [Text(0, 0, 'Start\n<->\nSECC Discovery'),
#  Text(1, 0, 'SECC Discovery\n<->\nSession Initialized'),
#  Text(2, 0, 'Session Initialized\n<->\nSupportedAppProtocol'),
#  Text(3, 0, 'SupportedAppProtocol\n<->\nSessionSetup'),
#  Text(4, 0, 'SessionSetup\n<->\nServiceDiscovery'),
#  Text(5, 0, 'ServiceDiscovery\n<->\nPaymentServiceSelection'),
#  Text(6, 0, 'PaymentServiceSelection\n<->\nPaymentDetail'),
#  Text(7, 0, 'PaymentDetail\n<->\nAuthorization'),
#  Text(8, 0, 'Authorization\n<->\nChargeParameterDiscovery'),
#  Text(9, 0, 'ChargeParameterDiscovery\n<->\nStart Charging')]

# %%
#Application vs. TCP vs. 802.11 plot
sns.set(rc={'figure.figsize':(16,8)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
App_TCP_2 = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_Application_TCP_80211_qos_10, hue="Type", width=0.6, linewidth=1.0, palette="Set1")
App_TCP_2.set_xlabel("Max. Inference with QoS 10 Mbps")
App_TCP_2.set_ylabel("Round Trip Latency (ms)")
App_TCP_2.set_xticklabels([
    "Start\n<->\nSECC Discovery",
    "SECC Discovery\n<->\nSession Initialized",
    "Session Initialized\n<->\nSupportedAppProtocol",
    "SupportedAppProtocol\n<->\nSessionSetup",
    "SessionSetup\n<->\nServiceDiscovery",
    "ServiceDiscovery\n<->\nPaymentServiceSelection",
    "PaymentServiceSelection\n<->\nPaymentDetail",
    "PaymentDetail\n<->\nAuthorization",
    "Authorization\n<->\nChargeParameterDiscovery",
    "ChargeParameterDiscovery\n<->\nStart Charging"
    ], fontsize=9)
# Out:
# [Text(0, 0, 'Start\n<->\nSECC Discovery'),
#  Text(1, 0, 'SECC Discovery\n<->\nSession Initialized'),
#  Text(2, 0, 'Session Initialized\n<->\nSupportedAppProtocol'),
#  Text(3, 0, 'SupportedAppProtocol\n<->\nSessionSetup'),
#  Text(4, 0, 'SessionSetup\n<->\nServiceDiscovery'),
#  Text(5, 0, 'ServiceDiscovery\n<->\nPaymentServiceSelection'),
#  Text(6, 0, 'PaymentServiceSelection\n<->\nPaymentDetail'),
#  Text(7, 0, 'PaymentDetail\n<->\nAuthorization'),
#  Text(8, 0, 'Authorization\n<->\nChargeParameterDiscovery'),
#  Text(9, 0, 'ChargeParameterDiscovery\n<->\nStart Charging')]

# %%
#Application vs. TCP vs. 802.11 plot
sns.set(rc={'figure.figsize':(16,8)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
App_TCP_2 = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_Application_TCP_80211_qos_30, hue="Type", width=0.6, linewidth=1.0, palette="Set1")
App_TCP_2.set_xlabel("Max. Inference with QoS 30 Mbps")
App_TCP_2.set_ylabel("Round Trip Latency (ms)")
App_TCP_2.set_xticklabels([
    "Start\n<->\nSECC Discovery",
    "SECC Discovery\n<->\nSession Initialized",
    "Session Initialized\n<->\nSupportedAppProtocol",
    "SupportedAppProtocol\n<->\nSessionSetup",
    "SessionSetup\n<->\nServiceDiscovery",
    "ServiceDiscovery\n<->\nPaymentServiceSelection",
    "PaymentServiceSelection\n<->\nPaymentDetail",
    "PaymentDetail\n<->\nAuthorization",
    "Authorization\n<->\nChargeParameterDiscovery",
    "ChargeParameterDiscovery\n<->\nStart Charging"
    ], fontsize=9)
# Out:
# [Text(0, 0, 'Start\n<->\nSECC Discovery'),
#  Text(1, 0, 'SECC Discovery\n<->\nSession Initialized'),
#  Text(2, 0, 'Session Initialized\n<->\nSupportedAppProtocol'),
#  Text(3, 0, 'SupportedAppProtocol\n<->\nSessionSetup'),
#  Text(4, 0, 'SessionSetup\n<->\nServiceDiscovery'),
#  Text(5, 0, 'ServiceDiscovery\n<->\nPaymentServiceSelection'),
#  Text(6, 0, 'PaymentServiceSelection\n<->\nPaymentDetail'),
#  Text(7, 0, 'PaymentDetail\n<->\nAuthorization'),
#  Text(8, 0, 'Authorization\n<->\nChargeParameterDiscovery'),
#  Text(9, 0, 'ChargeParameterDiscovery\n<->\nStart Charging')]

# %%
#Plot each stage latency normalized to timeout value

#stage 15: communication setup
def construct_dataframe_comm_setup_normalized(list_chunk, interference_num):
    return pd.DataFrame({'Latency/Timeout': [sum(x)/(20*2000) for x in zip(list_chunk[0],
                                                              list_chunk[1],
                                                              list_chunk[2],
                                                              list_chunk[3])],
                         'Interference': [interference_num for _ in range(len(list_chunk[0]))],
                         'Stage': [-1 for _ in range(len(list_chunk[0]))]
                        })

timeout_value = [2000, 2000, 2000, 2000, 5000, 2000, 2000, 5000]
def construct_dataframe_normalized(list_chunk, interference_num, index):
    return pd.DataFrame({'Latency/Timeout': [x/timeout_value[index-2] for x in list_chunk[index]],
                         'Interference': [interference_num for _ in range(len(list_chunk[index]))],
                         'Stage': [index+1 for _ in range(len(list_chunk[index]))]
                        })

stage_num = 10
interference_0_df_normalized_comm_setup = construct_dataframe_comm_setup_normalized(interference_0_list_chunks, 0)
interference_0_df_normalized = {i: construct_dataframe_normalized(interference_0_list_chunks, 0, i) for i in range(2, stage_num)}

interference_2_df_normalized_comm_setup = construct_dataframe_comm_setup_normalized(interference_2_list_chunks, 2)
interference_2_df_normalized = {i: construct_dataframe_normalized(interference_2_list_chunks, 2, i) for i in range(2, stage_num)}

interference_4_df_normalized_comm_setup = construct_dataframe_comm_setup_normalized(interference_4_list_chunks, 4)
interference_4_df_normalized = {i: construct_dataframe_normalized(interference_4_list_chunks, 4, i) for i in range(2, stage_num)}

interference_0_df_normalized_all = pd.concat(interference_0_df_normalized[i] for i in range(2, stage_num))
interference_2_df_normalized_all = pd.concat(interference_2_df_normalized[i] for i in range(2, stage_num))
interference_4_df_normalized_all = pd.concat(interference_4_df_normalized[i] for i in range(2, stage_num))

dataframe_all_normalized = pd.concat([interference_0_df_normalized_comm_setup,
                                      interference_0_df_normalized_all,
                                      interference_2_df_normalized_comm_setup,
                                      interference_2_df_normalized_all,
                                      interference_4_df_normalized_comm_setup,
                                      interference_4_df_normalized_all])

# %%
sns.set(rc={'figure.figsize':(14,8)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
g_normalized = sns.boxplot(x="Stage", y="Latency/Timeout", data=dataframe_all_normalized, hue="Interference", width=0.6, linewidth=1.0, palette="Set1")

g_normalized.set_xticklabels([
    "Communication Setup",
    "Session Initialized\n<->\nSupportedAppProtocol",
    "SupportedAppProtocol\n<->\nSessionSetup",
    "SessionSetup\n<->\nServiceDiscovery",
    "ServiceDiscovery\n<->\nPaymentServiceSelection",
    "PaymentServiceSelection\n<->\nPaymentDetail",
    "PaymentDetail\n<->\nAuthorization",
    "Authorization\n<->\nChargeParameterDiscovery",
    "ChargeParameterDiscovery\n<->\nStart Charging"
    ], fontsize=10)
# Out:
# [Text(0, 0, 'Communication Setup'),
#  Text(1, 0, 'Session Initialized\n<->\nSupportedAppProtocol'),
#  Text(2, 0, 'SupportedAppProtocol\n<->\nSessionSetup'),
#  Text(3, 0, 'SessionSetup\n<->\nServiceDiscovery'),
#  Text(4, 0, 'ServiceDiscovery\n<->\nPaymentServiceSelection'),
#  Text(5, 0, 'PaymentServiceSelection\n<->\nPaymentDetail'),
#  Text(6, 0, 'PaymentDetail\n<->\nAuthorization'),
#  Text(7, 0, 'Authorization\n<->\nChargeParameterDiscovery'),
#  Text(8, 0, 'ChargeParameterDiscovery\n<->\nStart Charging')]

# %%
#This graph is not used
sns.boxplot(x="Interference", y="Latency (ms)", data=dataframe_all, hue="Stage", width=0.5, linewidth=1.0, palette="Set1")

# %%
#Get the current setting
sns.plotting_context()

# %%
#Timeout in each stage is different. Discard this graph.
sns.boxplot(x=dataframe_all["Latency (ms)"],data=dataframe_all)

# %%
def plot_general_latency(chunks_array):
    fig, ax = plt.subplots()
    fig.set_size_inches(10, 8)
    data = [chunks_array[10], chunks_array[11], chunks_array[13]]
    ax.boxplot(data)
    plt.grid()
    plt.show()

plot_general_latency(interference_0_list_chunks)

# %%
#General Latency
def construct_dataframe(list_chunk, interference_num, index):
    return pd.DataFrame({'Latency (ms)': list_chunk[index],
                         'Interference': [interference_num for _ in range(len(list_chunk[index]))],
                         'Stage': [index+1 for _ in range(len(list_chunk[index]))]
                        })

general_stage_num = 3
interference_0_df_general = pd.concat([construct_dataframe(interference_0_list_chunks, 0, 10),
                                       construct_dataframe(interference_0_list_chunks, 0, 11)
                                       ])
interference_2_df_general = pd.concat([construct_dataframe(interference_2_list_chunks, 2, 10),
                                       construct_dataframe(interference_2_list_chunks, 2, 11)
                                       ])
interference_4_df_general = pd.concat([construct_dataframe(interference_4_list_chunks, 4, 10),
                                       construct_dataframe(interference_4_list_chunks, 4, 11)
                                       ])

dataframe_all_general = pd.concat([interference_0_df_general,
                                   interference_2_df_general,
                                   interference_4_df_general])

# %%
sns.set(rc={'figure.figsize':(8,6)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
sns.set_context('talk')
g3 = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_all_general, hue="Interference", width=0.5, linewidth=1.0, palette="Set1")

g3.set_xticklabels([
    "Start\n<->\nSession Initialized",
    "Start\n<->\nStart Charging"],
    fontsize=9)
# Out:
# [Text(0, 0, 'Start\n<->\nSession Initialized'),
#  Text(1, 0, 'Start\n<->\nStart Charging')]

# %%
interference_0_df_general_last = construct_dataframe(interference_0_list_chunks, 0, 13)
interference_2_df_general_last = construct_dataframe(interference_2_list_chunks, 2, 13)
interference_4_df_general_last = construct_dataframe(interference_4_list_chunks, 4, 13)

dataframe_all_general_last = pd.concat([interference_0_df_general_last,
                                   interference_2_df_general_last,
                                   interference_4_df_general_last])

sns.set(rc={'figure.figsize':(4,6)})
#darkgrid, dark, whitegrid, white, ticks
sns.set_style('whitegrid')

#paper, notebook, talk, poster
# sns.set_context('talk')
g4 = sns.boxplot(x="Stage", y="Latency (ms)", data=dataframe_all_general_last, hue="Interference", width=0.5, linewidth=1.0, palette="Set1")


g4.set_xticklabels(["Stop Charging\n<->\nSession Close"],fontsize=9)
# Out:
# [Text(0, 0, 'Stop Charging\n<->\nSession Close')]

# %%
#Plot per stage delay CDF
plt.rcParams["figure.figsize"] = [10, 6]
plt.rcParams["legend.loc"] = 'best'
plt.rcParams["figure.autolayout"] = True

stage_to_string = [
    "Start <-> SECC Discovery",
    "SECC Discovery <-> Session Initialized",
    "Session Initialized <-> SupportedAppProtocol",
    "SupportedAppProtocol <-> SessionSetup",
    "SessionSetup <-> ServiceDiscovery",
    "ServiceDiscovery <-> PaymentServiceSelection",
    "PaymentServiceSelection <-> PaymentDetail",
    "PaymentDetail <-> Authorization",
    "Authorization <-> ChargeParameterDiscovery",
    "ChargeParameterDiscovery <-> Start Charging"
    ]

# bins can be treated like "precision"
# Number of the data must be big enough for cdf starting from near zero

def plot_each_stage_cdf(interference_chunk, stage_num):
    count, bins_count = np.histogram(interference_chunk[stage_num], bins=20)
    pdf = count / sum(count)
    cdf = np.cumsum(pdf)
    plt.plot(bins_count[1:], cdf)
    plt.title("Stage: " + str(stage_to_string[stage_num]), fontsize = 18)
    plt.xlabel("Latency (ms)" , fontsize = 14)
    plt.ylabel("Probability", fontsize = 14)
    #plt.legend(["0 Interference","2 Interference", "4 Interference"])

# timeout_val in ms
def plot_cdf(stage_num, timeout_val):
    plot_each_stage_cdf(interference_0_list_chunks, stage_num)
    plot_each_stage_cdf(interference_2_list_chunks, stage_num)
    plot_each_stage_cdf(interference_4_list_chunks, stage_num)
    if(timeout_val):
        plt.axvline(x= timeout_val, color='r', linestyle='-', label='Timeout', linewidth=2)
        plt.legend(["0 Interference","2 Interference", "4 Interference", "Timeout"])
    else:
        plt.legend(["0 Interference","2 Interference", "4 Interference"])

# %%
plot_cdf(0, None)

# %%
plot_cdf(1, None)

# %%
plot_cdf(2, 2000)

# %%
plot_cdf(3, 2000)

# %%
plot_cdf(4, 2000)

# %%
plot_cdf(5, 2000)

# %%
plot_cdf(6, 5000)

# %%
plot_cdf(7, 2000)

# %%
plot_cdf(8, 2000)

# %%
plot_cdf(9, 5000)

# %%
#Plot EVCC Communication Setup Timer 20 s
def plot_communication_setup_cdf(interference_chunk):
    interference_chunk_setup_comm_list = [sum(x) for x in zip(interference_chunk[0],
                                                              interference_chunk[1],
                                                              interference_chunk[2],
                                                              interference_chunk[3])]
    #for debug
    print((interference_chunk_setup_comm_list))
    count, bins_count = np.histogram(interference_chunk_setup_comm_list, bins=20)
    pdf = count / sum(count)
    cdf = np.cumsum(pdf)
    plt.plot(bins_count[1:], cdf)
    plt.title("Communication Setup: Start <-> Session Setup", fontsize = 18)
    plt.xlabel("Latency (ms)" , fontsize = 14)
    plt.ylabel("Probability", fontsize = 14)

plot_communication_setup_cdf(interference_0_list_chunks)
plot_communication_setup_cdf(interference_2_list_chunks)
plot_communication_setup_cdf(interference_4_list_chunks)
plt.axvline(x= 20*1000, color='r', linestyle='-', label='Timeout', linewidth=2)
plt.legend(["0 Interference","2 Interference", "4 Interference", "Timeout"])
# Out:
# [3952, 3988, 2806, 2805, 2768, 3027, 3684, 2911, 2417, 4495, 3482, 3047, 3578, 2647, 3381, 3058, 3146, 2690, 3311, 3686]
# [5697, 3439, 3326, 6893, 3262, 3731, 3341, 4751, 3015, 3007, 4786, 6998, 3367, 3076, 9263, 4812, 2843]
# [4424, 4500, 4721, 3997, 7059, 3694, 4486, 3697, 4932, 4154, 5389, 3974, 5387, 8781, 5714, 6325, 3608]
