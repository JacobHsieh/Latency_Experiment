# %%
#Processing evcc block ack
import csv
import numpy as np

with open('csv/DataLink/qos_10Mbps/qos_10Mbps_evcc_blockack.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    startint_seq_num_block_ack = []
    timelist_block_ack = []
    
    for row in rows:
        startint_seq_num_block_ack.append(int(row['Starting Sequence Number']))
        timelist_block_ack.append(float(row['Time']))

# %%
#for debug
if(len(startint_seq_num_block_ack) != len(timelist_block_ack)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_block_ack))
# Out:
# 1032

# %%
#Processing evcc send
#Append missing SECC Discovery Req. time = 51.312512
with open('csv/DataLink/qos_10Mbps/qos_10Mbps_evcc_send.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_evcc_send = []
    seq_num_evcc_send = []
    data_length_evcc_send = []
    info_evcc_send = []
    frame_num_evcc_send = []
    
    for row in rows:
        timelist_evcc_send.append(float(row['Time']))
        seq_num_evcc_send.append(int(row['Sequence number']))
        data_length_evcc_send.append(int(row['Data Length']))
        info_evcc_send.append(str(row['Info']))
        frame_num_evcc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_evcc_send) != len(seq_num_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(data_length_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(info_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(frame_num_evcc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send))
# Out:
# 1574

# %%
timelist_evcc_send_split = []
seq_num_evcc_send_split = []
data_length_evcc_send_split = []
info_evcc_send_split = []
frame_num_evcc_send_split = []

round_start_point = 0
round_end_point = 0

sdpreq_index_list = []
#Fetch first packet index of data length = 74 (SDP request) in each round
for i in range(0, len(data_length_evcc_send)):
    if(i == 0 and data_length_evcc_send[i] == 74):
        sdpreq_index_list.append(i)
    if(i > 0 and data_length_evcc_send[i] == 74 and data_length_evcc_send[i-1] != 74):
        sdpreq_index_list.append(i)
sdpreq_index_list.append(len(data_length_evcc_send)) #Add the end of list index

for i in range(0, len(sdpreq_index_list)-1):
    timelist_evcc_send_split.append([timelist_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    seq_num_evcc_send_split.append([seq_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    data_length_evcc_send_split.append([data_length_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    info_evcc_send_split.append([info_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    frame_num_evcc_send_split.append([frame_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])

# %%
#for debug
if(len(timelist_evcc_send_split) != len(seq_num_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(data_length_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(info_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(frame_num_evcc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_evcc_send_split)):
    print("i = " + str(i) + ", "  + str(timelist_evcc_send_split[i][0]-timelist_evcc_send_split[i-1][0]))
# Out:
# i = 1, 23.830886
# i = 2, 22.227897999999996
# i = 3, 22.214015000000003
# i = 4, 22.325983000000008
# i = 5, 22.320202999999992
# i = 6, 23.385221
# i = 7, 21.37629100000001
# i = 8, 21.772766999999988
# i = 9, 20.910994000000017
# i = 10, 29.26652199999998
# i = 11, 21.937408000000033
# i = 12, 21.503593999999964
# i = 13, 21.582200999999998
# i = 14, 22.187864999999988
# i = 15, 22.076782000000037
# i = 16, 21.295191999999986
# i = 17, 21.889339000000007
# i = 18, 22.806348000000014
# i = 19, 21.996389999999963

# %%
#for debug
for i in range(0, len(timelist_evcc_send_split)):
    print("i = " + str(i) + ", " + str(timelist_evcc_send_split[i][0]))
# Out:
# i = 0, 19.90215
# i = 1, 43.733036
# i = 2, 65.960934
# i = 3, 88.174949
# i = 4, 110.500932
# i = 5, 132.821135
# i = 6, 156.206356
# i = 7, 177.582647
# i = 8, 199.355414
# i = 9, 220.266408
# i = 10, 249.53293
# i = 11, 271.470338
# i = 12, 292.973932
# i = 13, 314.556133
# i = 14, 336.743998
# i = 15, 358.82078
# i = 16, 380.115972
# i = 17, 402.005311
# i = 18, 424.811659
# i = 19, 446.808049

# %%
#Set evcc time anchor in each round per stage
evcc_send_time_anchor = []
#data_length_in_each_stage = [74, 96, 189, 173, 173, 173, 185, 461, 189, 173]
wierd_packet = {}
#packet_loss_testing_round_3_flag = False

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(evcc_send_time_anchor_each_round):
    print("Time difference: " + str(evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-1]-
                          evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        return True
    else:
        #debug
        print("\nFalse")
        print("Stage Num = " + str(stageNum))
        print("Valid Stage Num = " + str(valid_stageNum))
        print("What is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet.get(frameNum) != None):
        del wierd_packet[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_evcc_send_split)):
#for i in [5]:
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    evcc_send_time_anchor_each_round = [timelist_evcc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_evcc_send_split[i][0], info_evcc_send_split[i][0])
    stageNum = stageNum + 1
    
    for j in range(1, len(data_length_evcc_send_split[i])):
        #Stage 2
        if(data_length_evcc_send_split[i][j] == 96 and data_length_evcc_send_split[i][j-1] != 96):
            if(checkstage_num(stageNum, 2, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 3
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 3, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 4 
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            #if(info_evcc_send_split[i][j][-2:] == 'TC'):
            if(checkstage_num(stageNum, 4, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
            
        #Stage 5, tricky
        if(data_length_evcc_send_split[i][j] == 173):    
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
            
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                for k in range(1, 3):
                    if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                        isTCfound = True
                        break
                if(info_evcc_send_split[i][j][-5:] == 'R.F.C' and i != 18 and i != 5):
                    isTCfound = True
                
                if(not isTCfound):
                    if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1    
                        
                        continue
                
        #Stage 6, tricky
        if(data_length_evcc_send_split[i][j] == 173):
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                for k in range(1, 3):
                    if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                        isTCfound = True
                        break

                if(not isTCfound):
                    if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1

                        continue
        
        #Stage 7
        if(data_length_evcc_send_split[i][j] == 185 and data_length_evcc_send_split[i][j-1] != 185):
            if(checkstage_num(stageNum, 7, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 8
        if(data_length_evcc_send_split[i][j] == 461 and data_length_evcc_send_split[i][j-1] != 461):
            if(checkstage_num(stageNum, 8, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
        #Stage 9
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 9, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                '''
                #Deal with packet loss......
                if(i == 2 and packet_loss_testing_round_3_flag == False):
                    evcc_send_time_anchor_each_round.append(62.693)
                    printinfo(stageNum, 271589, "Packet Loss")
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_3_flag = True
                '''
                continue
                
        #Stage 10
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            if(info_evcc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
            else: #info_evcc_send_split[i][j][-2:] == 'FC'
                #Backward checking 2 packets
                isTCfound = False
                for k in range(1, 3):
                    if(data_length_evcc_send_split[i][j-k] == 173 and info_evcc_send_split[i][j-k][-2:] == 'TC'):
                        isTCfound = True
                        break

                if(not isTCfound):
                    if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                        print("Stage " + str(stageNum) +
                            ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                            ", Data length " + str(data_length_evcc_send_split[i][j]) +
                            ", Info " + str(info_evcc_send_split[i][j]) + " , Count FC because TC cannot be found.")
                        evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                        printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                        print_time_difference(evcc_send_time_anchor_each_round)
                        stageNum = stageNum + 1
                
        if(stageNum == 11): break
        
    evcc_send_time_anchor.append(evcc_send_time_anchor_each_round)

# %%
#for debug
print(str(len(evcc_send_time_anchor)) + '\n')
for i in range(0, len(evcc_send_time_anchor)):
    print("i = " + str(i) + ", " + str(len(evcc_send_time_anchor[i])))
# Out:
# 20
#
# i = 0, 10
# i = 1, 10
# i = 2, 10
# i = 3, 10
# i = 4, 10
# i = 5, 10
# i = 6, 10
# i = 7, 10
# i = 8, 10
# i = 9, 10
# i = 10, 10
# i = 11, 10
# i = 12, 10
# i = 13, 10
# i = 14, 10
# i = 15, 10
# i = 16, 10
# i = 17, 10
# i = 18, 10
# i = 19, 10

# %%
wierd_packet
# Out:
# {91560: [189, 5],
#  93669: [173, 7],
#  93717: [173, 7],
#  93798: [173, 7],
#  94422: [173, 7],
#  96251: [185, 8],
#  98257: [189, 10],
#  334580: [173, 7],
#  334933: [173, 7],
#  449153: [173, 7],
#  681353: [173, 7],
#  800006: [189, 4],
#  801327: [173, 7],
#  801951: [173, 7],
#  801952: [173, 7],
#  801961: [173, 7],
#  802480: [173, 7],
#  806767: [189, 10],
#  903167: [173, 5],
#  904069: [173, 7],
#  904088: [173, 7],
#  904097: [173, 7],
#  904577: [173, 7],
#  905499: [185, 8],
#  907949: [189, 10],
#  999411: [173, 7],
#  999412: [173, 7],
#  999708: [173, 7],
#  1000413: [185, 8],
#  1094280: [189, 4],
#  1095331: [173, 7],
#  1095373: [173, 7],
#  1096313: [185, 8],
#  1097207: [189, 10],
#  1236460: [189, 4],
#  1238099: [173, 5],
#  1239282: [173, 6],
#  1240586: [173, 7],
#  1243846: [189, 10],
#  1454210: [189, 10],
#  1535503: [173, 5],
#  1537093: [173, 7],
#  1538218: [185, 8],
#  1957162: [173, 5],
#  1958088: [173, 7],
#  1958418: [173, 7],
#  1959586: [185, 8],
#  1961371: [461, 9],
#  1962090: [189, 10],
#  2156463: [173, 6],
#  2156786: [173, 7],
#  2157082: [173, 7],
#  2159894: [189, 10]}

# %%
len(wierd_packet)
# Out:
# 53

# %%
#for debug
for i in range(0, len(evcc_send_time_anchor)):
    print(evcc_send_time_anchor[i][len(evcc_send_time_anchor[i])-1]-evcc_send_time_anchor[i][0])
# Out:
# 3.4804410000000026
# 2.484245999999999
# 3.2921340000000043
# 2.822213000000005
# 2.799061999999992
# 3.636020000000002
# 2.3464720000000057
# 2.372930999999994
# 2.0069660000000056
# 4.248138999999981
# 2.8011439999999936
# 2.3298549999999523
# 2.5292029999999954
# 2.8756500000000074
# 2.798861000000045
# 2.4228009999999927
# 2.418089000000009
# 2.633609999999976
# 2.3026069999999663
# 2.1327740000000404

# %%
#Processing secc send
with open('csv/DataLink/qos_10Mbps/qos_10Mbps_secc_send_append_missing_seccdisres.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_secc_send = []
    seq_num_secc_send = []
    data_length_secc_send = []
    info_secc_send = []
    frame_num_secc_send = []
    
    for row in rows:
        timelist_secc_send.append(float(row['Time']))
        seq_num_secc_send.append(int(row['Sequence number']))
        data_length_secc_send.append(int(row['Data Length']))
        info_secc_send.append(str(row['Info']))
        frame_num_secc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_secc_send) != len(seq_num_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(data_length_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(info_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(frame_num_secc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send))
# Out:
# 1163

# %%
#Append missing SECC Discovery Response time = 110.565075, Frame# 547539
timelist_secc_send_split = []
seq_num_secc_send_split = []
data_length_secc_send_split = []
info_secc_send_split = []
frame_num_secc_send_split = []

round_start_point = 0
round_end_point = 0

sdpres_index_list = []
#Fetch first packet index of data length = 92 (SDP response) in each round
for i in range(0, len(data_length_secc_send)):
    if(i == 0 and data_length_secc_send[i] == 92):
        sdpres_index_list.append(i)
    if(i > 0 and data_length_secc_send[i] == 92 and data_length_secc_send[i-1] != 92):
        sdpres_index_list.append(i)
sdpres_index_list.append(len(data_length_secc_send)) #Add the end of list index

for i in range(0, len(sdpres_index_list)-1):
        timelist_secc_send_split.append([timelist_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        seq_num_secc_send_split.append([seq_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        data_length_secc_send_split.append([data_length_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        info_secc_send_split.append([info_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        frame_num_secc_send_split.append([frame_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])

# %%
#for debug
if(len(timelist_secc_send_split) != len(seq_num_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(data_length_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(info_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(frame_num_secc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i))
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0
# 73
# i = 1
# 60
# i = 2
# 68
# i = 3
# 65
# i = 4
# 55
# i = 5
# 59
# i = 6
# 49
# i = 7
# 54
# i = 8
# 57
# i = 9
# 60
# i = 10
# 61
# i = 11
# 60
# i = 12
# 53
# i = 13
# 58
# i = 14
# 55
# i = 15
# 55
# i = 16
# 51
# i = 17
# 53
# i = 18
# 53
# i = 19
# 64

# %%
#for debug, this is ideally the time of each testing round
for i in range(0, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0])
# Out:
# 20.032586
# 43.74553
# 65.991724
# 88.18362
# 110.565075
# 132.874222
# 156.284414
# 177.691951
# 199.4065
# 220.386335
# 249.574985
# 271.483801
# 292.981691
# 314.689854
# 336.835647
# 358.841528
# 380.135727
# 402.049122
# 424.890878
# 446.906621

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i) + ' ', end = '')
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0 73
# i = 1 60
# i = 2 68
# i = 3 65
# i = 4 55
# i = 5 59
# i = 6 49
# i = 7 54
# i = 8 57
# i = 9 60
# i = 10 61
# i = 11 60
# i = 12 53
# i = 13 58
# i = 14 55
# i = 15 55
# i = 16 51
# i = 17 53
# i = 18 53
# i = 19 64

# %%
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 23.712944000000004
# 22.246194000000003
# 22.191896
# 22.38145499999999
# 22.30914700000001
# 23.410191999999995
# 21.40753699999999
# 21.714549000000005
# 20.97983500000001
# 29.188649999999996
# 21.90881600000003
# 21.497889999999984
# 21.708163000000013
# 22.14579299999997
# 22.005880999999988
# 21.294198999999992
# 21.913395000000037
# 22.841755999999975
# 22.015742999999986

# %%
#Set secc time anchor in each round per stage
secc_send_time_anchor = []
#data_length_in_each_stage = [92, 173, 157, 189, 253, 173, 189, 173, 493, 173]
wierd_packet_secc = {}
packet_loss_testing_round_19_flag = False
packet_loss_testing_round_13_flag = False

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(secc_send_time_anchor_each_round):
    print("Time difference: " + str(secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-1]-
                          secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        return True
    else:
        #debug
        print("\nWhat is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet_secc[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet_secc.get(frameNum) != None):
        del wierd_packet_secc[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_secc_send_split)):
#for i in [18]:
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    secc_send_time_anchor_each_round = [timelist_secc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_secc_send_split[i][0], info_secc_send_split[i][0])
    stageNum = stageNum + 1
    
    for j in range(1, len(data_length_secc_send_split[i])):
        #Stage 2
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 2, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    #Deal with packet loss......
                    if(i == 18 and packet_loss_testing_round_19_flag == False):
                        secc_send_time_anchor_each_round.append(425.854)
                        printinfo(stageNum, 2057406, "Packet Loss")
                        print_time_difference(secc_send_time_anchor_each_round)
                        stageNum = stageNum + 1
                        packet_loss_testing_round_20_flag = True
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 3
        if(data_length_secc_send_split[i][j] == 157 and data_length_secc_send_split[i][j-1] != 157):
            if(checkstage_num(stageNum, 3, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 4
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 4, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                    
                continue
                
        #Stage 5
        if(data_length_secc_send_split[i][j] == 253 and data_length_secc_send_split[i][j-1] != 253):
            if(checkstage_num(stageNum, 5, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 6
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 6, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 7
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 7, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                continue
                
        #Stage 8
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 8, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 9
        if(data_length_secc_send_split[i][j] == 493 and data_length_secc_send_split[i][j-1] != 493):
            if(checkstage_num(stageNum, 9, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 12 and packet_loss_testing_round_13_flag == False):
                    secc_send_time_anchor_each_round.append(295.518403)
                    printinfo(stageNum, 1455097, "Packet Loss")
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_20_flag = True
                
                continue
                
        #Stage 10
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    
                    continue
                    
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        
        if(stageNum == 11): break
        
    secc_send_time_anchor.append(secc_send_time_anchor_each_round)
# Out:
# -------- Test Round 1 --------
# -----------------------------------------
# Stage 1 finish. No. 84689, Info QoS Data, SN=1301, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 89074, Info QoS Data, SN=1312, FN=0, Flags=.p.....TC
# Time difference: 0.9628910000000026
# -----------------------------------------
# Stage 3 finish. No. 90059, Info QoS Data, SN=1314, FN=0, Flags=.p.....TC
# Time difference: 0.20076199999999744
# -----------------------------------------
# Stage 4 finish. No. 91816, Info QoS Data, SN=1318, FN=0, Flags=.p.....TC
# Time difference: 0.38888600000000295
# -----------------------------------------
# Stage 5 finish. No. 94070, Info QoS Data, SN=1321, FN=0, Flags=.p.....TC
# Time difference: 0.529947
#
# What is this packet? Data Length = 173 No. 94728
# Time 22.268581 #Seq 1323 Info QoS Data, SN=1323, FN=0, Flags=.p.....TC
#
#
# No. 94728 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 94728, Info QoS Data, SN=1323, FN=0, Flags=.p.....TC
# Time difference: 0.15350899999999967
#
# What is this packet? Data Length = 189 No. 96611
# Time 22.704273 #Seq 1325 Info QoS Data, SN=1325, FN=0, Flags=.p.....TC
#
#
# No. 96611 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 96611, Info QoS Data, SN=1325, FN=0, Flags=.p.....TC
# Time difference: 0.4356919999999995
#
# What is this packet? Data Length = 173 No. 97522
# Time 22.918878 #Seq 1327 Info QoS Data, SN=1327, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 97522
# Time 22.918878 #Seq 1327 Info QoS Data, SN=1327, FN=0, Flags=.p.....TC
#
#
# No. 97522 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 97522, Info QoS Data, SN=1327, FN=0, Flags=.p.....TC
# Time difference: 0.21460499999999882
# -----------------------------------------
# Stage 9 finish. No. 98393, Info QoS Data, SN=1329, FN=0, Flags=.p.....TC
# Time difference: 0.1722929999999998
#
# What is this packet? Data Length = 173 No. 100034
# Time 23.424302 #Seq 1339 Info QoS Data, SN=1339, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 100034
# Time 23.424302 #Seq 1339 Info QoS Data, SN=1339, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 100034
# Time 23.424302 #Seq 1339 Info QoS Data, SN=1339, FN=0, Flags=.p.....TC
#
#
# No. 100034 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 100034, Info QoS Data, SN=1339, FN=0, Flags=.p.....TC
# Time difference: 0.3331310000000016
#
# -------- Test Round 2 --------
# -----------------------------------------
# Stage 1 finish. No. 197934, Info QoS Data, SN=1365, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 204226, Info QoS Data, SN=1377, FN=0, Flags=.p.....TC
# Time difference: 1.066367999999997
# -----------------------------------------
# Stage 3 finish. No. 204956, Info QoS Data, SN=1379, FN=0, Flags=.p.....TC
# Time difference: 0.12013199999999813
# -----------------------------------------
# Stage 4 finish. No. 205990, Info QoS Data, SN=1381, FN=0, Flags=.p.....TC
# Time difference: 0.18398600000000442
# -----------------------------------------
# Stage 5 finish. No. 206334, Info QoS Data, SN=1383, FN=0, Flags=.p.....TC
# Time difference: 0.08170299999999742
#
# What is this packet? Data Length = 173 No. 207024
# Time 45.314055 #Seq 1385 Info QoS Data, SN=1385, FN=0, Flags=.p.....TC
#
#
# No. 207024 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 207024, Info QoS Data, SN=1385, FN=0, Flags=.p.....TC
# Time difference: 0.11633600000000399
#
# What is this packet? Data Length = 189 No. 208874
# Time 45.639 #Seq 1387 Info QoS Data, SN=1387, FN=0, Flags=.p.....TC
#
#
# No. 208874 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 208874, Info QoS Data, SN=1387, FN=0, Flags=.p.....TC
# Time difference: 0.3249449999999996
#
# What is this packet? Data Length = 173 No. 209958
# Time 45.829571 #Seq 1389 Info QoS Data, SN=1389, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 209958
# Time 45.829571 #Seq 1389 Info QoS Data, SN=1389, FN=0, Flags=.p.....TC
#
#
# No. 209958 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 209958, Info QoS Data, SN=1389, FN=0, Flags=.p.....TC
# Time difference: 0.1905709999999985
# -----------------------------------------
# Stage 9 finish. No. 210869, Info QoS Data, SN=1391, FN=0, Flags=.p.....TC
# Time difference: 0.1269619999999989
#
# What is this packet? Data Length = 173 No. 212655
# Time 46.241981 #Seq 1393 Info QoS Data, SN=1393, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 212655
# Time 46.241981 #Seq 1393 Info QoS Data, SN=1393, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 212655
# Time 46.241981 #Seq 1393 Info QoS Data, SN=1393, FN=0, Flags=.p.....TC
#
#
# No. 212655 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 212655, Info QoS Data, SN=1393, FN=0, Flags=.p.....TC
# Time difference: 0.28544800000000237
#
# -------- Test Round 3 --------
# -----------------------------------------
# Stage 1 finish. No. 326475, Info QoS Data, SN=1423, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 331466, Info QoS Data, SN=1434, FN=0, Flags=.p.....TC
# Time difference: 1.0999899999999911
# -----------------------------------------
# Stage 3 finish. No. 331970, Info QoS Data, SN=1436, FN=0, Flags=.p.....TC
# Time difference: 0.10550500000000795
# -----------------------------------------
# Stage 4 finish. No. 332932, Info QoS Data, SN=1438, FN=0, Flags=.p.....TC
# Time difference: 0.17499300000000062
# -----------------------------------------
# Stage 5 finish. No. 333519, Info QoS Data, SN=1440, FN=0, Flags=.p.....TC
# Time difference: 0.08734899999998902
#
# What is this packet? Data Length = 173 No. 335087
# Time 67.756165 #Seq 1442 Info QoS Data, SN=1442, FN=0, Flags=.p.....TC
#
#
# No. 335087 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 335087, Info QoS Data, SN=1442, FN=0, Flags=.p.....TC
# Time difference: 0.2966040000000021
#
# What is this packet? Data Length = 189 No. 337414
# Time 68.172722 #Seq 1444 Info QoS Data, SN=1444, FN=0, Flags=.p.....TC
#
#
# No. 337414 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 337414, Info QoS Data, SN=1444, FN=0, Flags=.p.....TC
# Time difference: 0.4165569999999974
#
# What is this packet? Data Length = 173 No. 341941
# Time 69.003639 #Seq 1446 Info QoS Data, SN=1446, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 341941
# Time 69.003639 #Seq 1446 Info QoS Data, SN=1446, FN=0, Flags=.p.....TC
#
#
# No. 341941 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 341941, Info QoS Data, SN=1446, FN=0, Flags=.p.....TC
# Time difference: 0.8309170000000137
# -----------------------------------------
# Stage 9 finish. No. 342676, Info QoS Data, SN=1448, FN=0, Flags=.p.....TC
# Time difference: 0.13918899999998757
#
# What is this packet? Data Length = 173 No. 343371
# Time 69.270864 #Seq 1450 Info QoS Data, SN=1450, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 343371
# Time 69.270864 #Seq 1450 Info QoS Data, SN=1450, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 343371
# Time 69.270864 #Seq 1450 Info QoS Data, SN=1450, FN=0, Flags=.p.....TC
#
#
# No. 343371 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 343371, Info QoS Data, SN=1450, FN=0, Flags=.p.....TC
# Time difference: 0.1280360000000087
#
# -------- Test Round 4 --------
# -----------------------------------------
# Stage 1 finish. No. 438689, Info QoS Data, SN=1478, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 446825, Info QoS Data, SN=1488, FN=0, Flags=.p.....TC
# Time difference: 1.7275969999999887
# -----------------------------------------
# Stage 3 finish. No. 447652, Info QoS Data, SN=1490, FN=0, Flags=.p.....TC
# Time difference: 0.1820770000000067
# -----------------------------------------
# Stage 4 finish. No. 448453, Info QoS Data, SN=1492, FN=0, Flags=.p.....TC
# Time difference: 0.14414499999999464
# -----------------------------------------
# Stage 5 finish. No. 448609, Info QoS Data, SN=1494, FN=0, Flags=.p.....TC
# Time difference: 0.039422000000001844
#
# What is this packet? Data Length = 173 No. 449040
# Time 90.364161 #Seq 1496 Info QoS Data, SN=1496, FN=0, Flags=.p.....TC
#
#
# No. 449040 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 449040, Info QoS Data, SN=1496, FN=0, Flags=.p.....TC
# Time difference: 0.08729999999999905
#
# What is this packet? Data Length = 189 No. 450801
# Time 90.725035 #Seq 1498 Info QoS Data, SN=1498, FN=0, Flags=.p.....TC
#
#
# No. 450801 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 450801, Info QoS Data, SN=1498, FN=0, Flags=.p.....TC
# Time difference: 0.3608740000000097
#
# What is this packet? Data Length = 173 No. 451059
# Time 90.870851 #Seq 1500 Info QoS Data, SN=1500, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 451059
# Time 90.870851 #Seq 1500 Info QoS Data, SN=1500, FN=0, Flags=.p.....TC
#
#
# No. 451059 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 451059, Info QoS Data, SN=1500, FN=0, Flags=.p.....TC
# Time difference: 0.1458159999999964
# -----------------------------------------
# Stage 9 finish. No. 451089, Info QoS Data, SN=1502, FN=0, Flags=.p.....TC
# Time difference: 0.031683000000001016
#
# What is this packet? Data Length = 173 No. 451523
# Time 91.002621 #Seq 1504 Info QoS Data, SN=1504, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 451523
# Time 91.002621 #Seq 1504 Info QoS Data, SN=1504, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 451523
# Time 91.002621 #Seq 1504 Info QoS Data, SN=1504, FN=0, Flags=.p.....TC
#
#
# No. 451523 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 451523, Info QoS Data, SN=1504, FN=0, Flags=.p.....TC
# Time difference: 0.10008700000000204
#
# -------- Test Round 5 --------
# -----------------------------------------
# Stage 1 finish. No. 547539, Info QoS Data, SN=1301, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 552788, Info QoS Data, SN=1544, FN=0, Flags=.p.....TC
# Time difference: 1.3304470000000066
# -----------------------------------------
# Stage 3 finish. No. 554133, Info QoS Data, SN=1546, FN=0, Flags=.p..R..TC
# Time difference: 0.23307300000000453
# -----------------------------------------
# Stage 4 finish. No. 555236, Info QoS Data, SN=1548, FN=0, Flags=.p.....TC
# Time difference: 0.18214799999999798
# -----------------------------------------
# Stage 5 finish. No. 555863, Info QoS Data, SN=1551, FN=0, Flags=.p.....TC
# Time difference: 0.09475399999999468
#
# What is this packet? Data Length = 173 No. 556801
# Time 112.582486 #Seq 1553 Info QoS Data, SN=1553, FN=0, Flags=.p.....TC
#
#
# No. 556801 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 556801, Info QoS Data, SN=1553, FN=0, Flags=.p.....TC
# Time difference: 0.17698900000000606
#
# What is this packet? Data Length = 189 No. 558647
# Time 112.899057 #Seq 1556 Info QoS Data, SN=1556, FN=0, Flags=.p.....TC
#
#
# No. 558647 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 558647, Info QoS Data, SN=1556, FN=0, Flags=.p.....TC
# Time difference: 0.31657099999999616
#
# What is this packet? Data Length = 173 No. 559696
# Time 113.095214 #Seq 1558 Info QoS Data, SN=1558, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 559696
# Time 113.095214 #Seq 1558 Info QoS Data, SN=1558, FN=0, Flags=.p.....TC
#
#
# No. 559696 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 559696, Info QoS Data, SN=1558, FN=0, Flags=.p.....TC
# Time difference: 0.19615699999999947
# -----------------------------------------
# Stage 9 finish. No. 560435, Info QoS Data, SN=1560, FN=0, Flags=.p.....TC
# Time difference: 0.10365300000000843
#
# What is this packet? Data Length = 173 No. 561232
# Time 113.314625 #Seq 1562 Info QoS Data, SN=1562, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 561232
# Time 113.314625 #Seq 1562 Info QoS Data, SN=1562, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 561232
# Time 113.314625 #Seq 1562 Info QoS Data, SN=1562, FN=0, Flags=.p.....TC
#
#
# No. 561232 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 561232, Info QoS Data, SN=1562, FN=0, Flags=.p.....TC
# Time difference: 0.11575799999999958
#
# -------- Test Round 6 --------
# -----------------------------------------
# Stage 1 finish. No. 671046, Info QoS Data, SN=1591, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 677087, Info QoS Data, SN=1603, FN=0, Flags=.p.....TC
# Time difference: 1.1459979999999916
# -----------------------------------------
# Stage 3 finish. No. 677760, Info QoS Data, SN=1605, FN=0, Flags=.p.....TC
# Time difference: 0.15188200000000052
# -----------------------------------------
# Stage 4 finish. No. 678460, Info QoS Data, SN=1608, FN=0, Flags=.p.....TC
# Time difference: 0.16087500000000432
# -----------------------------------------
# Stage 5 finish. No. 678825, Info QoS Data, SN=1610, FN=0, Flags=.p.....TC
# Time difference: 0.07633200000000784
#
# What is this packet? Data Length = 173 No. 679900
# Time 134.641147 #Seq 1612 Info QoS Data, SN=1612, FN=0, Flags=.p.....TC
#
#
# No. 679900 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 679900, Info QoS Data, SN=1612, FN=0, Flags=.p.....TC
# Time difference: 0.231837999999982
#
# What is this packet? Data Length = 173 No. 680383
# Time 134.736533 #Seq 1612 Info QoS Data, SN=1612, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 680383
# Time 134.736533 #Seq 1612 Info QoS Data, SN=1612, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 680383
# Time 134.736533 #Seq 1612 Info QoS Data, SN=1612, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 680383
# Time 134.736533 #Seq 1612 Info QoS Data, SN=1612, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 189 No. 682669
# Time 135.264224 #Seq 1617 Info QoS Data, SN=1617, FN=0, Flags=.p.....TC
#
#
# No. 682669 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 682669, Info QoS Data, SN=1617, FN=0, Flags=.p.....TC
# Time difference: 0.6230770000000234
#
# What is this packet? Data Length = 173 No. 684602
# Time 135.73322 #Seq 1619 Info QoS Data, SN=1619, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 684602
# Time 135.73322 #Seq 1619 Info QoS Data, SN=1619, FN=0, Flags=.p.....TC
#
#
# No. 684602 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 684602, Info QoS Data, SN=1619, FN=0, Flags=.p.....TC
# Time difference: 0.46899599999997577
# -----------------------------------------
# Stage 9 finish. No. 686034, Info QoS Data, SN=1621, FN=0, Flags=.p.....TC
# Time difference: 0.3349410000000148
#
# What is this packet? Data Length = 173 No. 687901
# Time 136.59357 #Seq 1623 Info QoS Data, SN=1623, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 687901
# Time 136.59357 #Seq 1623 Info QoS Data, SN=1623, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 687901
# Time 136.59357 #Seq 1623 Info QoS Data, SN=1623, FN=0, Flags=.p.....TC
#
#
# No. 687901 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 687901, Info QoS Data, SN=1623, FN=0, Flags=.p.....TC
# Time difference: 0.5254089999999962
#
# -------- Test Round 7 --------
# -----------------------------------------
# Stage 1 finish. No. 793277, Info QoS Data, SN=1649, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 799525, Info QoS Data, SN=1660, FN=0, Flags=.p.....TC
# Time difference: 1.0191059999999936
# -----------------------------------------
# Stage 3 finish. No. 800128, Info QoS Data, SN=1662, FN=0, Flags=.p.....TC
# Time difference: 0.09792300000000864
# -----------------------------------------
# Stage 4 finish. No. 801148, Info QoS Data, SN=1664, FN=0, Flags=.p.....TC
# Time difference: 0.14874499999999102
# -----------------------------------------
# Stage 5 finish. No. 801339, Info QoS Data, SN=1666, FN=0, Flags=.p.....TC
# Time difference: 0.04177400000000375
#
# What is this packet? Data Length = 173 No. 802518
# Time 157.785859 #Seq 1668 Info QoS Data, SN=1668, FN=0, Flags=.p.....TC
#
#
# No. 802518 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 802518, Info QoS Data, SN=1668, FN=0, Flags=.p.....TC
# Time difference: 0.19389699999999266
#
# What is this packet? Data Length = 189 No. 804941
# Time 158.173384 #Seq 1670 Info QoS Data, SN=1670, FN=0, Flags=.p.....TC
#
#
# No. 804941 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 804941, Info QoS Data, SN=1670, FN=0, Flags=.p.....TC
# Time difference: 0.3875250000000108
#
# What is this packet? Data Length = 173 No. 805923
# Time 158.341213 #Seq 1672 Info QoS Data, SN=1672, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 805923
# Time 158.341213 #Seq 1672 Info QoS Data, SN=1672, FN=0, Flags=.p.....TC
#
#
# No. 805923 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 805923, Info QoS Data, SN=1672, FN=0, Flags=.p.....TC
# Time difference: 0.16782900000001177
# -----------------------------------------
# Stage 9 finish. No. 806883, Info QoS Data, SN=1674, FN=0, Flags=.p.....TC
# Time difference: 0.1520039999999767
#
# What is this packet? Data Length = 173 No. 807755
# Time 158.618989 #Seq 1676 Info QoS Data, SN=1676, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 807755
# Time 158.618989 #Seq 1676 Info QoS Data, SN=1676, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 807755
# Time 158.618989 #Seq 1676 Info QoS Data, SN=1676, FN=0, Flags=.p.....TC
#
#
# No. 807755 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 807755, Info QoS Data, SN=1676, FN=0, Flags=.p.....TC
# Time difference: 0.12577200000001199
#
# -------- Test Round 8 --------
# -----------------------------------------
# Stage 1 finish. No. 897996, Info QoS Data, SN=1701, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 902164, Info QoS Data, SN=1714, FN=0, Flags=.p.....TC
# Time difference: 0.8680940000000135
# -----------------------------------------
# Stage 3 finish. No. 902661, Info QoS Data, SN=1716, FN=0, Flags=.p.....TC
# Time difference: 0.10458800000000679
# -----------------------------------------
# Stage 4 finish. No. 903228, Info QoS Data, SN=1718, FN=0, Flags=.p.....TC
# Time difference: 0.1083929999999782
# -----------------------------------------
# Stage 5 finish. No. 903421, Info QoS Data, SN=1720, FN=0, Flags=.p.....TC
# Time difference: 0.054385000000024775
#
# What is this packet? Data Length = 173 No. 904306
# Time 178.9811 #Seq 1722 Info QoS Data, SN=1722, FN=0, Flags=.p.....TC
#
#
# No. 904306 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 904306, Info QoS Data, SN=1722, FN=0, Flags=.p.....TC
# Time difference: 0.15368899999998575
#
# What is this packet? Data Length = 189 No. 905673
# Time 179.263127 #Seq 1724 Info QoS Data, SN=1724, FN=0, Flags=.p.....TC
#
#
# No. 905673 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 905673, Info QoS Data, SN=1724, FN=0, Flags=.p.....TC
# Time difference: 0.28202699999999936
#
# What is this packet? Data Length = 173 No. 906627
# Time 179.471458 #Seq 1726 Info QoS Data, SN=1726, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 906627
# Time 179.471458 #Seq 1726 Info QoS Data, SN=1726, FN=0, Flags=.p.....TC
#
#
# No. 906627 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 906627, Info QoS Data, SN=1726, FN=0, Flags=.p.....TC
# Time difference: 0.20833100000001537
# -----------------------------------------
# Stage 9 finish. No. 908142, Info QoS Data, SN=1728, FN=0, Flags=.p.....TC
# Time difference: 0.30674099999998816
#
# What is this packet? Data Length = 173 No. 909045
# Time 179.965964 #Seq 1730 Info QoS Data, SN=1730, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 909045
# Time 179.965964 #Seq 1730 Info QoS Data, SN=1730, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 909045
# Time 179.965964 #Seq 1730 Info QoS Data, SN=1730, FN=0, Flags=.p.....TC
#
#
# No. 909045 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 909045, Info QoS Data, SN=1730, FN=0, Flags=.p.....TC
# Time difference: 0.18776500000001306
#
# -------- Test Round 9 --------
# -----------------------------------------
# Stage 1 finish. No. 994434, Info QoS Data, SN=1757, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 998225, Info QoS Data, SN=1769, FN=0, Flags=.p.....TC
# Time difference: 0.9072639999999978
# -----------------------------------------
# Stage 3 finish. No. 998612, Info QoS Data, SN=1771, FN=0, Flags=.p.....TC
# Time difference: 0.08342799999999784
# -----------------------------------------
# Stage 4 finish. No. 998963, Info QoS Data, SN=1773, FN=0, Flags=.p.....TC
# Time difference: 0.09665200000000596
# -----------------------------------------
# Stage 5 finish. No. 999136, Info QoS Data, SN=1775, FN=0, Flags=.p.....TC
# Time difference: 0.047074000000009164
#
# What is this packet? Data Length = 173 No. 999836
# Time 200.693054 #Seq 1777 Info QoS Data, SN=1777, FN=0, Flags=.p.....TC
#
#
# No. 999836 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 999836, Info QoS Data, SN=1777, FN=0, Flags=.p.....TC
# Time difference: 0.1521359999999845
#
# What is this packet? Data Length = 189 No. 1000671
# Time 200.88484 #Seq 1779 Info QoS Data, SN=1779, FN=0, Flags=.p.....TC
#
#
# No. 1000671 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1000671, Info QoS Data, SN=1779, FN=0, Flags=.p.....TC
# Time difference: 0.19178600000000756
#
# What is this packet? Data Length = 173 No. 1001946
# Time 201.182579 #Seq 1781 Info QoS Data, SN=1781, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1001946
# Time 201.182579 #Seq 1781 Info QoS Data, SN=1781, FN=0, Flags=.p.....TC
#
#
# No. 1001946 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1001946, Info QoS Data, SN=1781, FN=0, Flags=.p.....TC
# Time difference: 0.2977390000000071
# -----------------------------------------
# Stage 9 finish. No. 1002473, Info QoS Data, SN=1783, FN=0, Flags=.p.....TC
# Time difference: 0.12608399999999165
#
# What is this packet? Data Length = 173 No. 1002857
# Time 201.391935 #Seq 1785 Info QoS Data, SN=1785, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1002857
# Time 201.391935 #Seq 1785 Info QoS Data, SN=1785, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1002857
# Time 201.391935 #Seq 1785 Info QoS Data, SN=1785, FN=0, Flags=.p.....TC
#
#
# No. 1002857 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1002857, Info QoS Data, SN=1785, FN=0, Flags=.p.....TC
# Time difference: 0.0832719999999938
#
# -------- Test Round 10 --------
# -----------------------------------------
# Stage 1 finish. No. 1079506, Info QoS Data, SN=1814, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1092994, Info QoS Data, SN=1828, FN=0, Flags=.p.....TC
# Time difference: 3.0963059999999984
# -----------------------------------------
# Stage 3 finish. No. 1094328, Info QoS Data, SN=1830, FN=0, Flags=.p.....TC
# Time difference: 0.2918119999999931
# -----------------------------------------
# Stage 4 finish. No. 1094836, Info QoS Data, SN=1832, FN=0, Flags=.p.....TC
# Time difference: 0.11572000000001026
# -----------------------------------------
# Stage 5 finish. No. 1094984, Info QoS Data, SN=1834, FN=0, Flags=.p.....TC
# Time difference: 0.03027099999999905
#
# What is this packet? Data Length = 173 No. 1095599
# Time 224.049432 #Seq 1836 Info QoS Data, SN=1836, FN=0, Flags=.p.....TC
#
#
# No. 1095599 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1095599, Info QoS Data, SN=1836, FN=0, Flags=.p.....TC
# Time difference: 0.12898799999999255
#
# What is this packet? Data Length = 189 No. 1096556
# Time 224.26425 #Seq 1838 Info QoS Data, SN=1838, FN=0, Flags=.p.....TC
#
#
# No. 1096556 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1096556, Info QoS Data, SN=1838, FN=0, Flags=.p.....TC
# Time difference: 0.21481800000000817
#
# What is this packet? Data Length = 173 No. 1097079
# Time 224.389947 #Seq 1840 Info QoS Data, SN=1840, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1097079
# Time 224.389947 #Seq 1840 Info QoS Data, SN=1840, FN=0, Flags=.p.....TC
#
#
# No. 1097079 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1097079, Info QoS Data, SN=1840, FN=0, Flags=.p.....TC
# Time difference: 0.1256970000000024
# -----------------------------------------
# Stage 9 finish. No. 1097326, Info QoS Data, SN=1842, FN=0, Flags=.p.....TC
# Time difference: 0.041240999999985206
#
# What is this packet? Data Length = 173 No. 1098078
# Time 224.597628 #Seq 1844 Info QoS Data, SN=1844, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1098078
# Time 224.597628 #Seq 1844 Info QoS Data, SN=1844, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1098078
# Time 224.597628 #Seq 1844 Info QoS Data, SN=1844, FN=0, Flags=.p.....TC
#
#
# No. 1098078 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1098078, Info QoS Data, SN=1844, FN=0, Flags=.p.....TC
# Time difference: 0.16643999999999437
#
# -------- Test Round 11 --------
# -----------------------------------------
# Stage 1 finish. No. 1229142, Info QoS Data, SN=1875, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1235602, Info QoS Data, SN=1886, FN=0, Flags=.p.....TC
# Time difference: 1.2395870000000002
# -----------------------------------------
# Stage 3 finish. No. 1236486, Info QoS Data, SN=1888, FN=0, Flags=.p.....TC
# Time difference: 0.15790899999998942
# -----------------------------------------
# Stage 4 finish. No. 1238247, Info QoS Data, SN=1890, FN=0, Flags=.p.....TC
# Time difference: 0.2866520000000037
# -----------------------------------------
# Stage 5 finish. No. 1239667, Info QoS Data, SN=1892, FN=0, Flags=.p..R..TC
# Time difference: 0.24785099999999716
#
# What is this packet? Data Length = 173 No. 1240630
# Time 251.707678 #Seq 1894 Info QoS Data, SN=1894, FN=0, Flags=.p.....TC
#
#
# No. 1240630 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1240630, Info QoS Data, SN=1894, FN=0, Flags=.p.....TC
# Time difference: 0.2006939999999986
#
# What is this packet? Data Length = 189 No. 1241890
# Time 251.916001 #Seq 1897 Info QoS Data, SN=1897, FN=0, Flags=.p.....TC
#
#
# No. 1241890 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1241890, Info QoS Data, SN=1897, FN=0, Flags=.p.....TC
# Time difference: 0.20832300000000714
#
# What is this packet? Data Length = 173 No. 1243365
# Time 252.156694 #Seq 1899 Info QoS Data, SN=1899, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1243365
# Time 252.156694 #Seq 1899 Info QoS Data, SN=1899, FN=0, Flags=.p.....TC
#
#
# No. 1243365 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1243365, Info QoS Data, SN=1899, FN=0, Flags=.p.....TC
# Time difference: 0.24069299999999316
# -----------------------------------------
# Stage 9 finish. No. 1243966, Info QoS Data, SN=1901, FN=0, Flags=.p.....TC
# Time difference: 0.10493100000002187
#
# What is this packet? Data Length = 173 No. 1244676
# Time 252.39206 #Seq 1903 Info QoS Data, SN=1903, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 1244676
# Time 252.39206 #Seq 1903 Info QoS Data, SN=1903, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 173 No. 1244676
# Time 252.39206 #Seq 1903 Info QoS Data, SN=1903, FN=0, Flags=.p..R..TC
#
#
# No. 1244676 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1244676, Info QoS Data, SN=1903, FN=0, Flags=.p..R..TC
# Time difference: 0.1304349999999772
#
# -------- Test Round 12 --------
# -----------------------------------------
# Stage 1 finish. No. 1344855, Info QoS Data, SN=1930, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1352345, Info QoS Data, SN=1942, FN=0, Flags=.p.....TC
# Time difference: 1.212336999999991
# -----------------------------------------
# Stage 3 finish. No. 1353228, Info QoS Data, SN=1944, FN=0, Flags=.p.....TC
# Time difference: 0.14264199999996663
# -----------------------------------------
# Stage 4 finish. No. 1353823, Info QoS Data, SN=1946, FN=0, Flags=.p.....TC
# Time difference: 0.08442900000000009
# -----------------------------------------
# Stage 5 finish. No. 1354428, Info QoS Data, SN=1948, FN=0, Flags=.p.....TC
# Time difference: 0.07909499999999525
#
# What is this packet? Data Length = 173 No. 1355581
# Time 273.203232 #Seq 1950 Info QoS Data, SN=1950, FN=0, Flags=.p.....TC
#
#
# No. 1355581 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1355581, Info QoS Data, SN=1950, FN=0, Flags=.p.....TC
# Time difference: 0.20092800000003308
#
# What is this packet? Data Length = 189 No. 1356750
# Time 273.406803 #Seq 1954 Info QoS Data, SN=1954, FN=0, Flags=.p.....TC
#
#
# No. 1356750 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1356750, Info QoS Data, SN=1954, FN=0, Flags=.p.....TC
# Time difference: 0.20357100000001083
#
# What is this packet? Data Length = 173 No. 1357917
# Time 273.577673 #Seq 1957 Info QoS Data, SN=1957, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1357917
# Time 273.577673 #Seq 1957 Info QoS Data, SN=1957, FN=0, Flags=.p.....TC
#
#
# No. 1357917 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1357917, Info QoS Data, SN=1957, FN=0, Flags=.p.....TC
# Time difference: 0.17086999999997943
# -----------------------------------------
# Stage 9 finish. No. 1358756, Info QoS Data, SN=1959, FN=0, Flags=.p.....TC
# Time difference: 0.11834499999997661
#
# What is this packet? Data Length = 173 No. 1359485
# Time 273.804352 #Seq 1961 Info QoS Data, SN=1961, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1359485
# Time 273.804352 #Seq 1961 Info QoS Data, SN=1961, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1359485
# Time 273.804352 #Seq 1961 Info QoS Data, SN=1961, FN=0, Flags=.p.....TC
#
#
# No. 1359485 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1359485, Info QoS Data, SN=1961, FN=0, Flags=.p.....TC
# Time difference: 0.10833400000001348
#
# -------- Test Round 13 --------
# -----------------------------------------
# Stage 1 finish. No. 1443201, Info QoS Data, SN=1988, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1447279, Info QoS Data, SN=1999, FN=0, Flags=.p.....TC
# Time difference: 0.8371449999999641
# -----------------------------------------
# Stage 3 finish. No. 1447695, Info QoS Data, SN=2001, FN=0, Flags=.p.....TC
# Time difference: 0.059320000000013806
# -----------------------------------------
# Stage 4 finish. No. 1448266, Info QoS Data, SN=2003, FN=0, Flags=.p.....TC
# Time difference: 0.16001199999999471
# -----------------------------------------
# Stage 5 finish. No. 1449161, Info QoS Data, SN=2005, FN=0, Flags=.p.....TC
# Time difference: 0.20178700000002436
#
# What is this packet? Data Length = 173 No. 1450642
# Time 294.569439 #Seq 2008 Info QoS Data, SN=2008, FN=0, Flags=.p.....TC
#
#
# No. 1450642 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1450642, Info QoS Data, SN=2008, FN=0, Flags=.p.....TC
# Time difference: 0.32948399999997946
#
# What is this packet? Data Length = 189 No. 1451899
# Time 294.818791 #Seq 2011 Info QoS Data, SN=2011, FN=0, Flags=.p.....TC
#
#
# No. 1451899 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1451899, Info QoS Data, SN=2011, FN=0, Flags=.p.....TC
# Time difference: 0.24935199999998758
#
# What is this packet? Data Length = 173 No. 1453875
# Time 295.271769 #Seq 2014 Info QoS Data, SN=2014, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1453875
# Time 295.271769 #Seq 2014 Info QoS Data, SN=2014, FN=0, Flags=.p.....TC
#
#
# No. 1453875 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1453875, Info QoS Data, SN=2014, FN=0, Flags=.p.....TC
# Time difference: 0.4529780000000301
# -----------------------------------------
# Stage 9 finish. No. 1454147, Info QoS Data, SN=2016, FN=0, Flags=.p.....TC
# Time difference: 0.04807199999999057
# -----------------------------------------
# Stage 10 finish. No. 1455097, Info Packet Loss
# Time difference: 0.19856199999998125
#
# -------- Test Round 14 --------
# -----------------------------------------
# Stage 1 finish. No. 1527257, Info QoS Data, SN=2054, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1531386, Info QoS Data, SN=2065, FN=0, Flags=.p.....TC
# Time difference: 0.8275669999999877
# -----------------------------------------
# Stage 3 finish. No. 1531909, Info QoS Data, SN=2067, FN=0, Flags=.p.....TC
# Time difference: 0.12279000000000906
# -----------------------------------------
# Stage 4 finish. No. 1535586, Info QoS Data, SN=2071, FN=0, Flags=.p.....TC
# Time difference: 0.6951959999999531
# -----------------------------------------
# Stage 5 finish. No. 1536684, Info QoS Data, SN=2073, FN=0, Flags=.p.....TC
# Time difference: 0.20962100000002692
#
# What is this packet? Data Length = 173 No. 1537308
# Time 316.659019 #Seq 2075 Info QoS Data, SN=2075, FN=0, Flags=.p.....TC
#
#
# No. 1537308 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1537308, Info QoS Data, SN=2075, FN=0, Flags=.p.....TC
# Time difference: 0.11399099999999862
#
# What is this packet? Data Length = 189 No. 1538719
# Time 316.906229 #Seq 2078 Info QoS Data, SN=2078, FN=0, Flags=.p.....TC
#
#
# No. 1538719 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1538719, Info QoS Data, SN=2078, FN=0, Flags=.p.....TC
# Time difference: 0.2472099999999955
#
# What is this packet? Data Length = 173 No. 1540353
# Time 317.196634 #Seq 2080 Info QoS Data, SN=2080, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1540353
# Time 317.196634 #Seq 2080 Info QoS Data, SN=2080, FN=0, Flags=.p.....TC
#
#
# No. 1540353 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1540353, Info QoS Data, SN=2080, FN=0, Flags=.p.....TC
# Time difference: 0.2904050000000211
# -----------------------------------------
# Stage 9 finish. No. 1540842, Info QoS Data, SN=2082, FN=0, Flags=.p.....TC
# Time difference: 0.08512099999995826
#
# What is this packet? Data Length = 173 No. 1541867
# Time 317.47138 #Seq 2084 Info QoS Data, SN=2084, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1541867
# Time 317.47138 #Seq 2084 Info QoS Data, SN=2084, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1541867
# Time 317.47138 #Seq 2084 Info QoS Data, SN=2084, FN=0, Flags=.p.....TC
#
#
# No. 1541867 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1541867, Info QoS Data, SN=2084, FN=0, Flags=.p.....TC
# Time difference: 0.18962500000003502
#
# -------- Test Round 15 --------
# -----------------------------------------
# Stage 1 finish. No. 1643592, Info QoS Data, SN=2111, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1652172, Info QoS Data, SN=2123, FN=0, Flags=.p.....TC
# Time difference: 1.3488219999999842
# -----------------------------------------
# Stage 3 finish. No. 1653584, Info QoS Data, SN=2125, FN=0, Flags=.p.....TC
# Time difference: 0.1800630000000183
# -----------------------------------------
# Stage 4 finish. No. 1655168, Info QoS Data, SN=2128, FN=0, Flags=.p.....TC
# Time difference: 0.3069879999999898
#
# What is this packet? Data Length = 189 No. 1655172
# Time 338.671824 #Seq 2128 Info QoS Data, SN=2128, FN=0, Flags=.p..R..TC
#
#
# What is this packet? Data Length = 189 No. 1655172
# Time 338.671824 #Seq 2128 Info QoS Data, SN=2128, FN=0, Flags=.p..R..TC
#
# -----------------------------------------
# Stage 5 finish. No. 1656161, Info QoS Data, SN=2130, FN=0, Flags=.p.....TC
# Time difference: 0.14782400000001417
#
# What is this packet? Data Length = 173 No. 1656770
# Time 338.915219 #Seq 2132 Info QoS Data, SN=2132, FN=0, Flags=.p.....TC
#
#
# No. 1656770 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1656770, Info QoS Data, SN=2132, FN=0, Flags=.p.....TC
# Time difference: 0.09587499999997817
#
# What is this packet? Data Length = 189 No. 1658468
# Time 339.193577 #Seq 2134 Info QoS Data, SN=2134, FN=0, Flags=.p.....TC
#
#
# No. 1658468 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1658468, Info QoS Data, SN=2134, FN=0, Flags=.p.....TC
# Time difference: 0.27835800000002564
#
# What is this packet? Data Length = 173 No. 1659592
# Time 339.375151 #Seq 2136 Info QoS Data, SN=2136, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1659592
# Time 339.375151 #Seq 2136 Info QoS Data, SN=2136, FN=0, Flags=.p.....TC
#
#
# No. 1659592 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1659592, Info QoS Data, SN=2136, FN=0, Flags=.p.....TC
# Time difference: 0.1815740000000119
# -----------------------------------------
# Stage 9 finish. No. 1660000, Info QoS Data, SN=2139, FN=0, Flags=.p.....TC
# Time difference: 0.04371799999995574
#
# What is this packet? Data Length = 173 No. 1660633
# Time 339.565865 #Seq 2141 Info QoS Data, SN=2141, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1660633
# Time 339.565865 #Seq 2141 Info QoS Data, SN=2141, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1660633
# Time 339.565865 #Seq 2141 Info QoS Data, SN=2141, FN=0, Flags=.p.....TC
#
#
# No. 1660633 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1660633, Info QoS Data, SN=2141, FN=0, Flags=.p.....TC
# Time difference: 0.14699600000000146
#
# -------- Test Round 16 --------
# -----------------------------------------
# Stage 1 finish. No. 1750914, Info QoS Data, SN=2170, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1754834, Info QoS Data, SN=2181, FN=0, Flags=.p.....TC
# Time difference: 0.995806000000016
# -----------------------------------------
# Stage 3 finish. No. 1755491, Info QoS Data, SN=2183, FN=0, Flags=.p.....TC
# Time difference: 0.18913800000001402
# -----------------------------------------
# Stage 4 finish. No. 1756033, Info QoS Data, SN=2185, FN=0, Flags=.p.....TC
# Time difference: 0.14983799999998837
# -----------------------------------------
# Stage 5 finish. No. 1756385, Info QoS Data, SN=2187, FN=0, Flags=.p.....TC
# Time difference: 0.07418999999998732
#
# What is this packet? Data Length = 173 No. 1757136
# Time 360.558804 #Seq 2190 Info QoS Data, SN=2190, FN=0, Flags=.p.....TC
#
#
# No. 1757136 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1757136, Info QoS Data, SN=2190, FN=0, Flags=.p.....TC
# Time difference: 0.308304000000021
#
# What is this packet? Data Length = 189 No. 1757980
# Time 360.767221 #Seq 2193 Info QoS Data, SN=2193, FN=0, Flags=.p.....TC
#
#
# No. 1757980 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1757980, Info QoS Data, SN=2193, FN=0, Flags=.p.....TC
# Time difference: 0.2084169999999972
#
# What is this packet? Data Length = 173 No. 1758958
# Time 360.988914 #Seq 2196 Info QoS Data, SN=2196, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1758958
# Time 360.988914 #Seq 2196 Info QoS Data, SN=2196, FN=0, Flags=.p.....TC
#
#
# No. 1758958 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1758958, Info QoS Data, SN=2196, FN=0, Flags=.p.....TC
# Time difference: 0.22169300000001613
# -----------------------------------------
# Stage 9 finish. No. 1759318, Info QoS Data, SN=2198, FN=0, Flags=.p.....TC
# Time difference: 0.0919399999999655
#
# What is this packet? Data Length = 173 No. 1760174
# Time 361.283421 #Seq 2201 Info QoS Data, SN=2201, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1760174
# Time 361.283421 #Seq 2201 Info QoS Data, SN=2201, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1760174
# Time 361.283421 #Seq 2201 Info QoS Data, SN=2201, FN=0, Flags=.p.....TC
#
#
# No. 1760174 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1760174, Info QoS Data, SN=2201, FN=0, Flags=.p.....TC
# Time difference: 0.20256699999998773
#
# -------- Test Round 17 --------
# -----------------------------------------
# Stage 1 finish. No. 1853875, Info QoS Data, SN=2223, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1858801, Info QoS Data, SN=2235, FN=0, Flags=.p.....TC
# Time difference: 1.1509920000000307
# -----------------------------------------
# Stage 3 finish. No. 1859186, Info QoS Data, SN=2237, FN=0, Flags=.p.....TC
# Time difference: 0.07704100000000835
# -----------------------------------------
# Stage 4 finish. No. 1859571, Info QoS Data, SN=2239, FN=0, Flags=.p.....TC
# Time difference: 0.10317599999996219
# -----------------------------------------
# Stage 5 finish. No. 1860095, Info QoS Data, SN=2241, FN=0, Flags=.p.....TC
# Time difference: 0.08949400000000196
#
# What is this packet? Data Length = 173 No. 1860990
# Time 381.737394 #Seq 2243 Info QoS Data, SN=2243, FN=0, Flags=.p.....TC
#
#
# No. 1860990 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1860990, Info QoS Data, SN=2243, FN=0, Flags=.p.....TC
# Time difference: 0.18096400000001722
#
# What is this packet? Data Length = 189 No. 1862180
# Time 381.959737 #Seq 2245 Info QoS Data, SN=2245, FN=0, Flags=.p.....TC
#
#
# No. 1862180 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1862180, Info QoS Data, SN=2245, FN=0, Flags=.p.....TC
# Time difference: 0.2223430000000235
#
# What is this packet? Data Length = 173 No. 1863893
# Time 382.295723 #Seq 2247 Info QoS Data, SN=2247, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1863893
# Time 382.295723 #Seq 2247 Info QoS Data, SN=2247, FN=0, Flags=.p.....TC
#
#
# No. 1863893 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1863893, Info QoS Data, SN=2247, FN=0, Flags=.p.....TC
# Time difference: 0.33598599999999124
# -----------------------------------------
# Stage 9 finish. No. 1864561, Info QoS Data, SN=2249, FN=0, Flags=.p.....TC
# Time difference: 0.10609299999998711
#
# What is this packet? Data Length = 173 No. 1865539
# Time 382.551623 #Seq 2251 Info QoS Data, SN=2251, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1865539
# Time 382.551623 #Seq 2251 Info QoS Data, SN=2251, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1865539
# Time 382.551623 #Seq 2251 Info QoS Data, SN=2251, FN=0, Flags=.p.....TC
#
#
# No. 1865539 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1865539, Info QoS Data, SN=2251, FN=0, Flags=.p.....TC
# Time difference: 0.1498070000000098
#
# -------- Test Round 18 --------
# -----------------------------------------
# Stage 1 finish. No. 1951181, Info QoS Data, SN=2275, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 1956208, Info QoS Data, SN=2286, FN=0, Flags=.p.....TC
# Time difference: 1.1813619999999787
# -----------------------------------------
# Stage 3 finish. No. 1956457, Info QoS Data, SN=2291, FN=0, Flags=.p.....TC
# Time difference: 0.06022500000000264
# -----------------------------------------
# Stage 4 finish. No. 1957498, Info QoS Data, SN=2298, FN=0, Flags=.p.....TC
# Time difference: 0.2431789999999978
# -----------------------------------------
# Stage 5 finish. No. 1957754, Info QoS Data, SN=2306, FN=0, Flags=.p.....TC
# Time difference: 0.027782000000001972
#
# What is this packet? Data Length = 173 No. 1958463
# Time 403.728973 #Seq 2309 Info QoS Data, SN=2309, FN=0, Flags=.p.....TC
#
#
# No. 1958463 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 1958463, Info QoS Data, SN=2309, FN=0, Flags=.p.....TC
# Time difference: 0.16730300000000398
#
# What is this packet? Data Length = 189 No. 1959716
# Time 403.991243 #Seq 2311 Info QoS Data, SN=2311, FN=0, Flags=.p.....TC
#
#
# No. 1959716 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 1959716, Info QoS Data, SN=2311, FN=0, Flags=.p.....TC
# Time difference: 0.2622700000000009
#
# What is this packet? Data Length = 173 No. 1961772
# Time 404.413866 #Seq 2314 Info QoS Data, SN=2314, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1961772
# Time 404.413866 #Seq 2314 Info QoS Data, SN=2314, FN=0, Flags=.p.....TC
#
#
# No. 1961772 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 1961772, Info QoS Data, SN=2314, FN=0, Flags=.p.....TC
# Time difference: 0.4226229999999873
# -----------------------------------------
# Stage 9 finish. No. 1962155, Info QoS Data, SN=2316, FN=0, Flags=.p.....TC
# Time difference: 0.08336600000001226
#
# What is this packet? Data Length = 173 No. 1963057
# Time 404.687654 #Seq 2318 Info QoS Data, SN=2318, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1963057
# Time 404.687654 #Seq 2318 Info QoS Data, SN=2318, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 1963057
# Time 404.687654 #Seq 2318 Info QoS Data, SN=2318, FN=0, Flags=.p.....TC
#
#
# No. 1963057 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 1963057, Info QoS Data, SN=2318, FN=0, Flags=.p.....TC
# Time difference: 0.1904220000000123
#
# -------- Test Round 19 --------
# -----------------------------------------
# Stage 1 finish. No. 2053069, Info QoS Data, SN=2350, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2057033, Info QoS Data, SN=2362, FN=0, Flags=.p.....TC
# Time difference: 0.9032119999999964
# -----------------------------------------
# Stage 3 finish. No. 2057406, Info Packet Loss
# Time difference: 0.05991000000000213
# -----------------------------------------
# Stage 4 finish. No. 2057879, Info QoS Data, SN=2366, FN=0, Flags=.p.....TC
# Time difference: 0.111266999999998
# -----------------------------------------
# Stage 5 finish. No. 2058262, Info QoS Data, SN=2368, FN=0, Flags=.p.....TC
# Time difference: 0.09416200000003982
#
# What is this packet? Data Length = 173 No. 2058862
# Time 426.184213 #Seq 2370 Info QoS Data, SN=2370, FN=0, Flags=.p.....TC
#
#
# No. 2058862 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2058862, Info QoS Data, SN=2370, FN=0, Flags=.p.....TC
# Time difference: 0.12478399999997691
#
# What is this packet? Data Length = 189 No. 2060355
# Time 426.531462 #Seq 2373 Info QoS Data, SN=2373, FN=0, Flags=.p.....TC
#
#
# No. 2060355 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2060355, Info QoS Data, SN=2373, FN=0, Flags=.p.....TC
# Time difference: 0.3472489999999766
#
# What is this packet? Data Length = 173 No. 2062015
# Time 426.890826 #Seq 2375 Info QoS Data, SN=2375, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2062015
# Time 426.890826 #Seq 2375 Info QoS Data, SN=2375, FN=0, Flags=.p.....TC
#
#
# No. 2062015 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2062015, Info QoS Data, SN=2375, FN=0, Flags=.p.....TC
# Time difference: 0.3593640000000278
# -----------------------------------------
# Stage 9 finish. No. 2062321, Info QoS Data, SN=2377, FN=0, Flags=.p.....TC
# Time difference: 0.06979899999998906
#
# What is this packet? Data Length = 173 No. 2063018
# Time 427.121512 #Seq 2379 Info QoS Data, SN=2379, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2063018
# Time 427.121512 #Seq 2379 Info QoS Data, SN=2379, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2063018
# Time 427.121512 #Seq 2379 Info QoS Data, SN=2379, FN=0, Flags=.p.....TC
#
#
# No. 2063018 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2063018, Info QoS Data, SN=2379, FN=0, Flags=.p.....TC
# Time difference: 0.16088700000000244
#
# -------- Test Round 20 --------
# -----------------------------------------
# Stage 1 finish. No. 2151271, Info QoS Data, SN=2407, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 2154855, Info QoS Data, SN=2418, FN=0, Flags=.p.....TC
# Time difference: 0.8686640000000239
# -----------------------------------------
# Stage 3 finish. No. 2155448, Info QoS Data, SN=2420, FN=0, Flags=.p.....TC
# Time difference: 0.1298229999999876
# -----------------------------------------
# Stage 4 finish. No. 2156605, Info QoS Data, SN=2423, FN=0, Flags=.p.....TC
# Time difference: 0.24058100000002014
# -----------------------------------------
# Stage 5 finish. No. 2156807, Info QoS Data, SN=2425, FN=0, Flags=.p.....TC
# Time difference: 0.04813000000001466
#
# What is this packet? Data Length = 173 No. 2157317
# Time 448.320443 #Seq 2427 Info QoS Data, SN=2427, FN=0, Flags=.p.....TC
#
#
# No. 2157317 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 2157317, Info QoS Data, SN=2427, FN=0, Flags=.p.....TC
# Time difference: 0.12662399999999252
#
# What is this packet? Data Length = 189 No. 2158546
# Time 448.576947 #Seq 2430 Info QoS Data, SN=2430, FN=0, Flags=.p.....TC
#
#
# No. 2158546 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 7 finish. No. 2158546, Info QoS Data, SN=2430, FN=0, Flags=.p.....TC
# Time difference: 0.2565040000000067
#
# What is this packet? Data Length = 173 No. 2159618
# Time 448.797089 #Seq 2432 Info QoS Data, SN=2432, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2159618
# Time 448.797089 #Seq 2432 Info QoS Data, SN=2432, FN=0, Flags=.p.....TC
#
#
# No. 2159618 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 8 finish. No. 2159618, Info QoS Data, SN=2432, FN=0, Flags=.p.....TC
# Time difference: 0.22014200000000983
# -----------------------------------------
# Stage 9 finish. No. 2159926, Info QoS Data, SN=2434, FN=0, Flags=.p.....TC
# Time difference: 0.06969699999996237
#
# What is this packet? Data Length = 173 No. 2160618
# Time 448.99972 #Seq 2436 Info QoS Data, SN=2436, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2160618
# Time 448.99972 #Seq 2436 Info QoS Data, SN=2436, FN=0, Flags=.p.....TC
#
#
# What is this packet? Data Length = 173 No. 2160618
# Time 448.99972 #Seq 2436 Info QoS Data, SN=2436, FN=0, Flags=.p.....TC
#
#
# No. 2160618 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 2160618, Info QoS Data, SN=2436, FN=0, Flags=.p.....TC
# Time difference: 0.1329340000000343

# %%
#for debug
print(str(len(secc_send_time_anchor)) + '\n')
for i in range(0, len(secc_send_time_anchor)):
    print(str(i) + ": " + str(len(secc_send_time_anchor[i])))
# Out:
# 20
#
# 0: 10
# 1: 10
# 2: 10
# 3: 10
# 4: 10
# 5: 10
# 6: 10
# 7: 10
# 8: 10
# 9: 10
# 10: 10
# 11: 10
# 12: 10
# 13: 10
# 14: 10
# 15: 10
# 16: 10
# 17: 10
# 18: 10
# 19: 10

# %%
#for debug
for i in range(0, len(secc_send_time_anchor)):
    print(secc_send_time_anchor[i][len(secc_send_time_anchor[i])-1]-secc_send_time_anchor[i][0])
# Out:
# 3.3917160000000024
# 2.4964510000000004
# 3.279139999999998
# 2.819001
# 2.7495500000000135
# 3.7193479999999965
# 2.334575000000001
# 2.274013000000025
# 1.9854349999999954
# 4.2112929999999835
# 2.8170749999999884
# 2.3205509999999663
# 2.536711999999966
# 2.7815259999999853
# 2.7302179999999794
# 2.441892999999993
# 2.415896000000032
# 2.638531999999998
# 2.230634000000009
# 2.093099000000052

# %%
#BLOCK ACK processing
#Time evcc sends blockACK after secc send
evcc_blockAck_time_anchor = []

blockack_index = 0
for i in range(0, len(secc_send_time_anchor)):
    evcc_blockAck_time_anchor_in_each_round = []
    
    for j in range(0, len(secc_send_time_anchor[i])):
        while(timelist_block_ack[blockack_index] < secc_send_time_anchor[i][j]):
            blockack_index = blockack_index + 1
        evcc_blockAck_time_anchor_in_each_round.append(timelist_block_ack[blockack_index])
        print("ACK time difference = " + str(
        timelist_block_ack[blockack_index] - secc_send_time_anchor[i][j]))
    
    evcc_blockAck_time_anchor.append(evcc_blockAck_time_anchor_in_each_round)

# %%
#SECC Packet Loss dict
#secc_packet_loss_dict[i] = {stageNum}
# i = 5, j = 0 is packet loss of evcc BLOCK ACK
# i = 3, j = 9 is packet loss of evcc BLOCK ACK
secc_packet_loss_dict = {}

secc_packet_loss_dict[18] = {2}
secc_packet_loss_dict[12] = {9}
#secc_packet_loss_dict[5] = {0, 1, 2, 3, 4}

#for i in secc_packet_loss_dict.get(5): print(i)
#7 in secc_packet_loss_dict.get(5)

# %%
#Calculate the avg. block ack latency
sum_latency = 0
cnt = 0
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) == None):
            sum_latency = sum_latency + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
            cnt = cnt + 1
        elif(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)): continue
            else:
                sum_latency = sum_latency + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
                cnt = cnt + 1
        else: continue
avg_blockAck_latency = sum_latency/cnt
print("Avg Block Ack latency = " + str(avg_blockAck_latency) + " s")
print(cnt)
# Out:
# Avg Block Ack latency = 0.06144521717171958 s
# 198

# %%
#For curiousity
#Calculate the avg. block ack latency of the appending packet loss packets
sum_latency_2 = 0
cnt = 0
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)):
                sum_latency_2 = sum_latency_2 + (evcc_blockAck_time_anchor[i][j]-secc_send_time_anchor[i][j])
                cnt = cnt + 1
        else: continue
avg_blockAck_latency_2 = sum_latency_2/cnt
print("Avg Block Ack latency = " + str(avg_blockAck_latency_2) + " s")
print(cnt)
# Out:
# Avg Block Ack latency = 0.006018000000011625 s
# 2

# %%
#For debug. Can see testing round 6 (i = 5) has longer block ack latency due to packet loss.
# I only append the secc send time, but didn't append the block time.
from statistics import mean

for i in range(0, len(evcc_blockAck_time_anchor)):
    print("i = " + str(i) + ": " + str(mean(evcc_blockAck_time_anchor[i])-mean(secc_send_time_anchor[i])))
# Out:
# i = 0: 0.13259000000000043
# i = 1: 0.05762739999999411
# i = 2: 0.07379889999999989
# i = 3: 0.020514500000004432
# i = 4: 0.055163699999994265
# i = 5: 0.10823449999998047
# i = 6: 0.03496240000001194
# i = 7: 0.07136559999997871
# i = 8: 0.02997659999999769
# i = 9: 0.04093120000001704
# i = 10: 0.06934450000002812
# i = 11: 0.03591700000004039
# i = 12: 0.08424930000001041
# i = 13: 0.08858630000003131
# i = 14: 0.06680649999998423
# i = 15: 0.06276100000002316
# i = 16: 0.05784699999998111
# i = 17: 0.04929760000004535
# i = 18: 0.05170540000000301
# i = 19: 0.026139499999999316

# %%
#For debug
for j in range(0, 10):
    print(evcc_blockAck_time_anchor[0][j]-secc_send_time_anchor[0][j])
# Out:
# 0.06756299999999982
# 0.025282999999998168
# 0.2212990000000019
# 0.45937999999999946
# 0.014808999999999628
# 0.2044479999999993
# 0.0052859999999981255
# 0.08625400000000027
# 0.23743900000000195
# 0.0041389999999985605

# %%
#Use the avg. block ack latency for the lost secc sent packets
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_packet_loss_dict.get(i) != None):
            if(j in secc_packet_loss_dict.get(i)):
                evcc_blockAck_time_anchor[i][j] = secc_send_time_anchor[i][j] + avg_blockAck_latency
                print("i = " + str(i))
                print("j = " + str(j))
        else: continue
# Out:
# i = 12
# j = 9
# i = 18
# j = 2

# %%
#for debug check wierd value
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(secc_send_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))
        if(evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))

# %%
#For debug
#secc send is based on 802.11 capture file (not 802.11_TCP combined file)
i = 12
for j in [8, 9]:
    print("Stage " + str(j+1))
    print(evcc_send_time_anchor[i][j])
    print(secc_send_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j]-evcc_send_time_anchor[i][j])
    print("\n")
# Out:
# Stage 9
# 295.307978
# 295.319841
# 295.363961
# 0.055983000000026095
#
#
# Stage 10
# 295.503135
# 295.518403
# 295.5798482171717
# 0.07671321717168667

# %%
path = 'time_record/qos_10Mbps_80211_processing.txt'
f = open(path, 'w')
for i in range(0, len(evcc_send_time_anchor)):
    for j in range(0, len(evcc_send_time_anchor[i])):
        print((evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j])*1000, file=f, end="")
        f.writelines('\t')
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][len(evcc_blockAck_time_anchor[i])-1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    f.writelines('20')
    f.writelines('\t')
    f.writelines('0')
    f.writelines('\t')
    f.writelines('\n')
f.close()
