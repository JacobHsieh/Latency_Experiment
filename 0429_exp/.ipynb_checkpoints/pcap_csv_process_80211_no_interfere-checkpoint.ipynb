# %%
#Processing evcc block ack
import csv
import numpy as np

with open('0_evcc_block_ack.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    startint_seq_num_block_ack = []
    timelist_block_ack = []
    
    for row in rows:
        startint_seq_num_block_ack.append(int(row['Starting Sequence Number']))
        timelist_block_ack.append(float(row['Time']))

# %%
#for debug
if(len(startint_seq_num_block_ack) != len(timelist_block_ack)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_block_ack))
# Out:
# 5958

# %%
#Processing evcc send
with open('0_evcc_send.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_evcc_send = []
    seq_num_evcc_send = []
    data_length_evcc_send = []
    info_evcc_send = []
    frame_num_evcc_send = []
    
    for row in rows:
        timelist_evcc_send.append(float(row['Time']))
        seq_num_evcc_send.append(int(row['Sequence number']))
        data_length_evcc_send.append(int(row['Data Length']))
        info_evcc_send.append(str(row['Info']))
        frame_num_evcc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_evcc_send) != len(seq_num_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(data_length_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(info_evcc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send) != len(frame_num_evcc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send))
# Out:
# 2512

# %%
timelist_evcc_send[0]
# Out:
# 23.541691

# %%
timelist_evcc_send_split = []
seq_num_evcc_send_split = []
data_length_evcc_send_split = []
info_evcc_send_split = []
frame_num_evcc_send_split = []

round_start_point = 0
round_end_point = 0

sdpreq_index_list = []
#Fetch first packet index of data length = 74 (SDP request) in each round
for i in range(0, len(data_length_evcc_send)):
    if(i == 0 and data_length_evcc_send[i] == 74):
        sdpreq_index_list.append(i)
    if(i > 0 and data_length_evcc_send[i] == 74 and data_length_evcc_send[i-1] != 74):
        sdpreq_index_list.append(i)
sdpreq_index_list.append(len(data_length_evcc_send)) #Add the end of list index

for i in range(0, len(sdpreq_index_list)-1):
    timelist_evcc_send_split.append([timelist_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    seq_num_evcc_send_split.append([seq_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    data_length_evcc_send_split.append([data_length_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    info_evcc_send_split.append([info_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])
    frame_num_evcc_send_split.append([frame_num_evcc_send[j] for j in range(sdpreq_index_list[i], sdpreq_index_list[i+1])])

# %%
#for debug
if(len(timelist_evcc_send_split) != len(seq_num_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(data_length_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(info_evcc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_evcc_send_split) != len(frame_num_evcc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_evcc_send_split)) #Output # of testing rounds
# Out:
# 20

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_evcc_send_split)):
    print(timelist_evcc_send_split[i][0]-timelist_evcc_send_split[i-1][0])
# Out:
# 30.113326
# 28.786429999999996
# 29.429382000000004
# 29.741560000000007
# 28.913809999999984
# 29.952045999999996
# 30.090846000000028
# 30.507975999999985
# 29.429325000000006
# 29.628610999999978
# 30.63664399999999
# 30.276321000000053
# 30.166119999999978
# 30.04560600000002
# 30.55282299999999
# 29.164367999999968
# 29.603012000000035
# 29.388954000000012
# 30.34624599999995

# %%
#Set evcc time anchor in each round per stage
evcc_send_time_anchor = []
#data_length_in_each_stage = [74, 100, 189, 173, 173, 173, 185, 461, 189, 173]
wierd_packet = {}
#packet_loss_testing_round_3_flag = False

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(evcc_send_time_anchor_each_round):
    print("Time difference: " + str(evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-1]-
                          evcc_send_time_anchor_each_round[len(evcc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        return True
    else:
        #debug
        #print("\nWhat is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        #print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet.get(frameNum) != None):
        del wierd_packet[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_evcc_send_split)):
#for i in range(2, 3):
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    evcc_send_time_anchor_each_round = [timelist_evcc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_evcc_send_split[i][0], info_evcc_send_split[i][0])
    stageNum = stageNum + 1
    
    for j in range(1, len(data_length_evcc_send_split[i])):
        #Stage 2
        if(data_length_evcc_send_split[i][j] == 100 and data_length_evcc_send_split[i][j-1] != 100):
            if(checkstage_num(stageNum, 2, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
                
        #Stage 3
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 3, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
                
        #Stage 4 
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            if(info_evcc_send_split[i][j][-5:] == '...TC'):
                if(checkstage_num(stageNum, 4, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    continue
            else: print("Stage " + str(stageNum) +
                        ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                        ", Data length " + str(data_length_evcc_send_split[i][j]) +
                        ", Info " + str(info_evcc_send_split[i][j]))
        #Stage 5, tricky
        if(data_length_evcc_send_split[i][j] == 173):
            if(info_evcc_send_split[i][j][-5:] == '...TC'):
                if(checkstage_num(stageNum, 5, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    continue
                
            else: print("Stage " + str(stageNum) +
                        ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                        ", Data length " + str(data_length_evcc_send_split[i][j]) +
                        ", Info " + str(info_evcc_send_split[i][j]))
        #Stage 6, tricky
        if(data_length_evcc_send_split[i][j] == 173):
            if(info_evcc_send_split[i][j][-5:] == '...TC'):
                if(checkstage_num(stageNum, 6, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    continue
            else: print("Stage " + str(stageNum) +
                        ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                        ", Data length " + str(data_length_evcc_send_split[i][j]) +
                        ", Info " + str(info_evcc_send_split[i][j]))
        #Stage 7
        if(data_length_evcc_send_split[i][j] == 185 and data_length_evcc_send_split[i][j-1] != 185):
            if(checkstage_num(stageNum, 7, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
        #Stage 8
        if(data_length_evcc_send_split[i][j] == 461 and data_length_evcc_send_split[i][j-1] != 461):
            if(checkstage_num(stageNum, 8, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
        #Stage 9
        if(data_length_evcc_send_split[i][j] == 189 and data_length_evcc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 9, info_evcc_send_split[i][j],
                                  timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                  seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                print_time_difference(evcc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
        #Stage 10
        if(data_length_evcc_send_split[i][j] == 173 and data_length_evcc_send_split[i][j-1] != 173):
            
            if(info_evcc_send_split[i][j][-5:] == '...TC'):
                if(checkstage_num(stageNum, 10, info_evcc_send_split[i][j],
                                      timelist_evcc_send_split[i][j], data_length_evcc_send_split[i][j],
                                      seq_num_evcc_send_split[i][j], frame_num_evcc_send_split[i][j])):
                    evcc_send_time_anchor_each_round.append(timelist_evcc_send_split[i][j])
                    printinfo(stageNum, frame_num_evcc_send_split[i][j], info_evcc_send_split[i][j])
                    print_time_difference(evcc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    continue
            else: print("Stage " + str(stageNum) +
                        ", Not TC? No. " + str(frame_num_evcc_send_split[i][j]) +
                        ", Data length " + str(data_length_evcc_send_split[i][j]) +
                        ", Info " + str(info_evcc_send_split[i][j]))
                
        if(stageNum == 11): break
        
    evcc_send_time_anchor.append(evcc_send_time_anchor_each_round)
# Out:
# -------- Test Round 1 --------
# -----------------------------------------
# Stage 1 finish. No. 6076, Info QoS Data, SN=3670, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 6202, Info QoS Data, SN=3679, FN=0, Flags=.p.....TC
# Time difference: 0.8662539999999979
# -----------------------------------------
# Stage 3 finish. No. 6372, Info QoS Data, SN=3691, FN=0, Flags=.p.....TC
# Time difference: 0.4665999999999997
# -----------------------------------------
# Stage 4 finish. No. 6421, Info QoS Data, SN=3694, FN=0, Flags=.p.....TC
# Time difference: 0.2691520000000054
# Stage 5, Not TC? No. 6423, Data length 173, Info QoS Data, SN=1169, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 6423, Data length 173, Info QoS Data, SN=1169, FN=0, Flags=.p....F.C
#
# No. 6452 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 6452, Info QoS Data, SN=3696, FN=0, Flags=.p.....TC
# Time difference: 0.047201999999998634
# Stage 6, Not TC? No. 6454, Data length 173, Info QoS Data, SN=1171, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 6454, Data length 173, Info QoS Data, SN=1171, FN=0, Flags=.p....F.C
#
# No. 6485 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 6485, Info QoS Data, SN=3698, FN=0, Flags=.p.....TC
# Time difference: 0.17962599999999895
# Stage 7, Not TC? No. 6487, Data length 173, Info QoS Data, SN=1173, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 6487, Data length 173, Info QoS Data, SN=1173, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 6526, Info QoS Data, SN=3702, FN=0, Flags=.p.....TC
# Time difference: 0.19061299999999903
# -----------------------------------------
# Stage 8 finish. No. 6563, Info QoS Data, SN=3704, FN=0, Flags=.p.....TC
# Time difference: 0.15498699999999843
#
# No. 6594 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 6594, Info QoS Data, SN=3706, FN=0, Flags=.p.....TC
# Time difference: 0.05766799999999961
#
# No. 6624 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 6624, Info QoS Data, SN=3708, FN=0, Flags=.p.....TC
# Time difference: 0.11610100000000045
# Stage 11, Not TC? No. 6626, Data length 173, Info QoS Data, SN=1182, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 6626, Data length 173, Info QoS Data, SN=1182, FN=0, Flags=.p....F.C
#
# -------- Test Round 2 --------
# -----------------------------------------
# Stage 1 finish. No. 9374, Info QoS Data, SN=3894, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 9425, Info QoS Data, SN=3897, FN=0, Flags=.p.....TC
# Time difference: 0.6495380000000068
# Stage 3, Not TC? No. 9546, Data length 173, Info QoS Data, SN=1227, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 9546, Data length 173, Info QoS Data, SN=1227, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 9586, Info QoS Data, SN=3908, FN=0, Flags=.p.....TC
# Time difference: 0.20731599999999162
# -----------------------------------------
# Stage 4 finish. No. 9637, Info QoS Data, SN=3910, FN=0, Flags=.p.....TC
# Time difference: 0.10991800000000751
# Stage 5, Not TC? No. 9639, Data length 173, Info QoS Data, SN=1233, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 9639, Data length 173, Info QoS Data, SN=1233, FN=0, Flags=.p....F.C
#
# No. 9666 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 9666, Info QoS Data, SN=3912, FN=0, Flags=.p.....TC
# Time difference: 0.020651000000000863
# Stage 6, Not TC? No. 9668, Data length 173, Info QoS Data, SN=1235, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 9668, Data length 173, Info QoS Data, SN=1235, FN=0, Flags=.p....F.C
#
# No. 9699 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 9699, Info QoS Data, SN=3914, FN=0, Flags=.p.....TC
# Time difference: 0.09701699999999391
# Stage 7, Not TC? No. 9701, Data length 173, Info QoS Data, SN=1237, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 9701, Data length 173, Info QoS Data, SN=1237, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 9738, Info QoS Data, SN=3918, FN=0, Flags=.p.....TC
# Time difference: 0.21227500000000532
# -----------------------------------------
# Stage 8 finish. No. 9770, Info QoS Data, SN=3920, FN=0, Flags=.p.....TC
# Time difference: 0.1583869999999905
#
# No. 9798 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 9798, Info QoS Data, SN=3922, FN=0, Flags=.p.....TC
# Time difference: 0.037304000000006
#
# No. 9835 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 9835, Info QoS Data, SN=3924, FN=0, Flags=.p.....TC
# Time difference: 0.13134499999999605
# Stage 11, Not TC? No. 9837, Data length 173, Info QoS Data, SN=1246, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 9837, Data length 173, Info QoS Data, SN=1246, FN=0, Flags=.p....F.C
#
# -------- Test Round 3 --------
# -----------------------------------------
# Stage 1 finish. No. 13361, Info QoS Data, SN=60, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 13427, Info QoS Data, SN=62, FN=0, Flags=.p.....TC
# Time difference: 0.8203790000000026
# Stage 3, Not TC? No. 13547, Data length 173, Info QoS Data, SN=1308, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 13547, Data length 173, Info QoS Data, SN=1308, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 13587, Info QoS Data, SN=73, FN=0, Flags=.p.....TC
# Time difference: 0.24073800000000745
# -----------------------------------------
# Stage 4 finish. No. 13622, Info QoS Data, SN=75, FN=0, Flags=.p.....TC
# Time difference: 0.14106099999999344
# Stage 5, Not TC? No. 13625, Data length 173, Info QoS Data, SN=75, FN=0, Flags=.p..R..TC
# Stage 5, Not TC? No. 13625, Data length 173, Info QoS Data, SN=75, FN=0, Flags=.p..R..TC
# Stage 5, Not TC? No. 13628, Data length 173, Info QoS Data, SN=75, FN=0, Flags=.p..R..TC
# Stage 5, Not TC? No. 13628, Data length 173, Info QoS Data, SN=75, FN=0, Flags=.p..R..TC
# Stage 5, Not TC? No. 13630, Data length 173, Info QoS Data, SN=1313, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 13630, Data length 173, Info QoS Data, SN=1313, FN=0, Flags=.p....F.C
#
# No. 13659 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 13659, Info QoS Data, SN=77, FN=0, Flags=.p.....TC
# Time difference: 0.022451000000003773
# Stage 6, Not TC? No. 13661, Data length 173, Info QoS Data, SN=1315, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 13661, Data length 173, Info QoS Data, SN=1315, FN=0, Flags=.p....F.C
#
# No. 13693 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 13693, Info QoS Data, SN=79, FN=0, Flags=.p.....TC
# Time difference: 0.21055299999999022
# Stage 7, Not TC? No. 13695, Data length 173, Info QoS Data, SN=1317, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 13695, Data length 173, Info QoS Data, SN=1317, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 13743, Info QoS Data, SN=82, FN=0, Flags=.p.....TC
# Time difference: 0.3567560000000043
# -----------------------------------------
# Stage 8 finish. No. 13792, Info QoS Data, SN=85, FN=0, Flags=.p.....TC
# Time difference: 0.27028699999999617
#
# No. 13829 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 13829, Info QoS Data, SN=87, FN=0, Flags=.p.....TC
# Time difference: 0.04499100000001022
#
# No. 13861 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 13861, Info QoS Data, SN=89, FN=0, Flags=.p.....TC
# Time difference: 0.12033399999999972
# Stage 11, Not TC? No. 13863, Data length 173, Info QoS Data, SN=1327, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 13863, Data length 173, Info QoS Data, SN=1327, FN=0, Flags=.p....F.C
#
# -------- Test Round 4 --------
# -----------------------------------------
# Stage 1 finish. No. 16913, Info QoS Data, SN=311, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 17003, Info QoS Data, SN=317, FN=0, Flags=.p.....TC
# Time difference: 0.7795090000000044
# Stage 3, Not TC? No. 17190, Data length 173, Info QoS Data, SN=1370, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 17190, Data length 173, Info QoS Data, SN=1370, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 17234, Info QoS Data, SN=332, FN=0, Flags=.p.....TC
# Time difference: 0.27102299999999957
# -----------------------------------------
# Stage 4 finish. No. 17268, Info QoS Data, SN=334, FN=0, Flags=.p.....TC
# Time difference: 0.1411509999999936
# Stage 5, Not TC? No. 17270, Data length 173, Info QoS Data, SN=1375, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 17270, Data length 173, Info QoS Data, SN=1375, FN=0, Flags=.p....F.C
#
# No. 17296 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 17296, Info QoS Data, SN=336, FN=0, Flags=.p.....TC
# Time difference: 0.019558000000003517
# Stage 6, Not TC? No. 17298, Data length 173, Info QoS Data, SN=1377, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 17298, Data length 173, Info QoS Data, SN=1377, FN=0, Flags=.p....F.C
#
# No. 17346 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 17346, Info QoS Data, SN=338, FN=0, Flags=.p.....TC
# Time difference: 0.33534300000000883
# Stage 7, Not TC? No. 17360, Data length 173, Info QoS Data, SN=1379, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 17360, Data length 173, Info QoS Data, SN=1379, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 17405, Info QoS Data, SN=341, FN=0, Flags=.p.....TC
# Time difference: 0.47159099999998944
# -----------------------------------------
# Stage 8 finish. No. 17462, Info QoS Data, SN=345, FN=0, Flags=.p.....TC
# Time difference: 0.26957899999999313
#
# No. 17490 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 17490, Info QoS Data, SN=347, FN=0, Flags=.p.....TC
# Time difference: 0.032346000000018194
#
# No. 17534 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 17534, Info QoS Data, SN=350, FN=0, Flags=.p.....TC
# Time difference: 0.17579399999999623
# Stage 11, Not TC? No. 17536, Data length 173, Info QoS Data, SN=1388, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 17536, Data length 173, Info QoS Data, SN=1388, FN=0, Flags=.p....F.C
#
# -------- Test Round 5 --------
# -----------------------------------------
# Stage 1 finish. No. 21216, Info QoS Data, SN=616, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 21279, Info QoS Data, SN=619, FN=0, Flags=.p.....TC
# Time difference: 0.5504469999999912
# Stage 3, Not TC? No. 21395, Data length 173, Info QoS Data, SN=1453, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 21395, Data length 173, Info QoS Data, SN=1453, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 21436, Info QoS Data, SN=630, FN=0, Flags=.p.....TC
# Time difference: 0.24069000000000074
# -----------------------------------------
# Stage 4 finish. No. 21465, Info QoS Data, SN=632, FN=0, Flags=.p.....TC
# Time difference: 0.10859400000001074
# Stage 5, Not TC? No. 21467, Data length 173, Info QoS Data, SN=1458, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 21467, Data length 173, Info QoS Data, SN=1458, FN=0, Flags=.p....F.C
#
# No. 21494 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 21494, Info QoS Data, SN=634, FN=0, Flags=.p.....TC
# Time difference: 0.020218999999997322
# Stage 6, Not TC? No. 21496, Data length 173, Info QoS Data, SN=1460, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 21496, Data length 173, Info QoS Data, SN=1460, FN=0, Flags=.p....F.C
#
# No. 21530 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 21530, Info QoS Data, SN=638, FN=0, Flags=.p.....TC
# Time difference: 0.09811299999998369
# Stage 7, Not TC? No. 21532, Data length 173, Info QoS Data, SN=1462, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 21532, Data length 173, Info QoS Data, SN=1462, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 21591, Info QoS Data, SN=645, FN=0, Flags=.p.....TC
# Time difference: 0.17417600000001698
# -----------------------------------------
# Stage 8 finish. No. 21649, Info QoS Data, SN=650, FN=0, Flags=.p.....TC
# Time difference: 0.1352550000000008
#
# No. 21676 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 21676, Info QoS Data, SN=652, FN=0, Flags=.p.....TC
# Time difference: 0.028486999999984164
#
# No. 21707 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 21707, Info QoS Data, SN=654, FN=0, Flags=.p.....TC
# Time difference: 0.09744100000000344
# Stage 11, Not TC? No. 21709, Data length 173, Info QoS Data, SN=1471, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 21709, Data length 173, Info QoS Data, SN=1471, FN=0, Flags=.p....F.C
#
# -------- Test Round 6 --------
# -----------------------------------------
# Stage 1 finish. No. 25213, Info QoS Data, SN=896, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 25275, Info QoS Data, SN=899, FN=0, Flags=.p.....TC
# Time difference: 0.6580760000000225
# Stage 3, Not TC? No. 25412, Data length 173, Info QoS Data, SN=908, FN=0, Flags=.p..R..TC
# Stage 3, Not TC? No. 25412, Data length 173, Info QoS Data, SN=908, FN=0, Flags=.p..R..TC
# Stage 3, Not TC? No. 25412, Data length 173, Info QoS Data, SN=908, FN=0, Flags=.p..R..TC
# Stage 3, Not TC? No. 25412, Data length 173, Info QoS Data, SN=908, FN=0, Flags=.p..R..TC
# Stage 3, Not TC? No. 25415, Data length 173, Info QoS Data, SN=908, FN=0, Flags=.p..R..TC
# Stage 3, Not TC? No. 25415, Data length 173, Info QoS Data, SN=908, FN=0, Flags=.p..R..TC
# Stage 3, Not TC? No. 25417, Data length 173, Info QoS Data, SN=1574, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 25417, Data length 173, Info QoS Data, SN=1574, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 25482, Info QoS Data, SN=911, FN=0, Flags=.p..R..TC
# Time difference: 0.2809649999999806
# -----------------------------------------
# Stage 4 finish. No. 25523, Info QoS Data, SN=913, FN=0, Flags=.p.....TC
# Time difference: 0.1455919999999935
# Stage 5, Not TC? No. 25525, Data length 173, Info QoS Data, SN=1579, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 25525, Data length 173, Info QoS Data, SN=1579, FN=0, Flags=.p....F.C
#
# No. 25554 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 25554, Info QoS Data, SN=915, FN=0, Flags=.p.....TC
# Time difference: 0.019163000000020247
# Stage 6, Not TC? No. 25559, Data length 173, Info QoS Data, SN=1581, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 25559, Data length 173, Info QoS Data, SN=1581, FN=0, Flags=.p....F.C
#
# No. 25730 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 25730, Info QoS Data, SN=939, FN=0, Flags=.p.....TC
# Time difference: 0.6268719999999917
# Stage 7, Not TC? No. 25739, Data length 173, Info QoS Data, SN=1583, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 25739, Data length 173, Info QoS Data, SN=1583, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 25800, Info QoS Data, SN=942, FN=0, Flags=.p.....TC
# Time difference: 0.44711300000000165
# -----------------------------------------
# Stage 8 finish. No. 25882, Info QoS Data, SN=946, FN=0, Flags=.p.....TC
# Time difference: 0.27438900000001354
#
# No. 25911 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 25911, Info QoS Data, SN=948, FN=0, Flags=.p.....TC
# Time difference: 0.03271099999997773
#
# No. 25942 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 25942, Info QoS Data, SN=950, FN=0, Flags=.p.....TC
# Time difference: 0.13921400000000972
# Stage 11, Not TC? No. 25944, Data length 173, Info QoS Data, SN=1593, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 25944, Data length 173, Info QoS Data, SN=1593, FN=0, Flags=.p....F.C
#
# -------- Test Round 7 --------
# -----------------------------------------
# Stage 1 finish. No. 29309, Info QoS Data, SN=1201, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 29473, Info QoS Data, SN=1219, FN=0, Flags=.p.....TC
# Time difference: 0.7249900000000196
# Stage 3, Not TC? No. 29604, Data length 173, Info QoS Data, SN=1642, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 29604, Data length 173, Info QoS Data, SN=1642, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 29651, Info QoS Data, SN=1233, FN=0, Flags=.p.....TC
# Time difference: 0.30088999999998123
# -----------------------------------------
# Stage 4 finish. No. 29720, Info QoS Data, SN=1239, FN=0, Flags=.p.....TC
# Time difference: 0.13870000000000005
# Stage 5, Not TC? No. 29722, Data length 173, Info QoS Data, SN=1647, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 29722, Data length 173, Info QoS Data, SN=1647, FN=0, Flags=.p....F.C
#
# No. 29748 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 29748, Info QoS Data, SN=1241, FN=0, Flags=.p.....TC
# Time difference: 0.01903900000002068
# Stage 6, Not TC? No. 29750, Data length 173, Info QoS Data, SN=1649, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 29750, Data length 173, Info QoS Data, SN=1649, FN=0, Flags=.p....F.C
#
# No. 29811 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 29811, Info QoS Data, SN=1245, FN=0, Flags=.p.....TC
# Time difference: 0.36970099999999206
# -----------------------------------------
# Stage 7 finish. No. 29879, Info QoS Data, SN=1251, FN=0, Flags=.p.....TC
# Time difference: 0.630077
# -----------------------------------------
# Stage 8 finish. No. 29939, Info QoS Data, SN=1255, FN=0, Flags=.p.....TC
# Time difference: 0.33362900000000195
#
# No. 29969 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 29969, Info QoS Data, SN=1257, FN=0, Flags=.p.....TC
# Time difference: 0.05540899999999738
#
# No. 30017 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 30017, Info QoS Data, SN=1259, FN=0, Flags=.p.....TC
# Time difference: 0.16770800000000463
# Stage 11, Not TC? No. 30019, Data length 173, Info QoS Data, SN=1661, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 30019, Data length 173, Info QoS Data, SN=1661, FN=0, Flags=.p....F.C
#
# -------- Test Round 8 --------
# -----------------------------------------
# Stage 1 finish. No. 33249, Info QoS Data, SN=1458, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 33307, Info QoS Data, SN=1462, FN=0, Flags=.p.....TC
# Time difference: 0.6996389999999906
# -----------------------------------------
# Stage 3 finish. No. 33460, Info QoS Data, SN=1474, FN=0, Flags=.p.....TC
# Time difference: 0.30319299999999316
# -----------------------------------------
# Stage 4 finish. No. 33515, Info QoS Data, SN=1478, FN=0, Flags=.p.....TC
# Time difference: 0.13830200000001014
#
# No. 33539 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 33539, Info QoS Data, SN=1480, FN=0, Flags=.p.....TC
# Time difference: 0.017759999999981346
#
# No. 33596 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 33596, Info QoS Data, SN=1485, FN=0, Flags=.p.....TC
# Time difference: 0.3759760000000085
# -----------------------------------------
# Stage 7 finish. No. 33646, Info QoS Data, SN=1488, FN=0, Flags=.p.....TC
# Time difference: 0.6814960000000099
# -----------------------------------------
# Stage 8 finish. No. 33694, Info QoS Data, SN=1491, FN=0, Flags=.p.....TC
# Time difference: 0.34621400000000335
#
# No. 33734 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 33734, Info QoS Data, SN=1494, FN=0, Flags=.p.....TC
# Time difference: 0.2237389999999948
#
# No. 33762 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 33762, Info QoS Data, SN=1496, FN=0, Flags=.p.....TC
# Time difference: 0.10059300000000349
# Stage 11, Not TC? No. 33764, Data length 173, Info QoS Data, SN=1727, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 33764, Data length 173, Info QoS Data, SN=1727, FN=0, Flags=.p....F.C
#
# -------- Test Round 9 --------
# -----------------------------------------
# Stage 1 finish. No. 37852, Info QoS Data, SN=1952, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 38080, Info QoS Data, SN=1776, FN=0, Flags=.p....F.C
# Time difference: 0.8182909999999879
# -----------------------------------------
# Stage 3 finish. No. 38244, Info QoS Data, SN=1988, FN=0, Flags=.p.....TC
# Time difference: 0.33077300000002197
# -----------------------------------------
# Stage 4 finish. No. 38341, Info QoS Data, SN=2000, FN=0, Flags=.p.....TC
# Time difference: 0.14684799999997722
# Stage 5, Not TC? No. 38343, Data length 173, Info QoS Data, SN=1788, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 38343, Data length 173, Info QoS Data, SN=1788, FN=0, Flags=.p....F.C
#
# No. 38369 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 38369, Info QoS Data, SN=2002, FN=0, Flags=.p.....TC
# Time difference: 0.05013999999999896
# Stage 6, Not TC? No. 38372, Data length 173, Info QoS Data, SN=1790, FN=0, Flags=.p..R.F.C
# Stage 6, Not TC? No. 38372, Data length 173, Info QoS Data, SN=1790, FN=0, Flags=.p..R.F.C
#
# No. 38428 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 38428, Info QoS Data, SN=2009, FN=0, Flags=.p.....TC
# Time difference: 0.17372100000000046
# Stage 7, Not TC? No. 38430, Data length 173, Info QoS Data, SN=1792, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 38430, Data length 173, Info QoS Data, SN=1792, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 38499, Info QoS Data, SN=2013, FN=0, Flags=.p.....TC
# Time difference: 0.19793800000002193
# -----------------------------------------
# Stage 8 finish. No. 38559, Info QoS Data, SN=2019, FN=0, Flags=.p.....TC
# Time difference: 0.17129299999999148
#
# No. 38587 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 38587, Info QoS Data, SN=2021, FN=0, Flags=.p.....TC
# Time difference: 0.04523799999998346
#
# No. 38637 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 38637, Info QoS Data, SN=2025, FN=0, Flags=.p.....TC
# Time difference: 0.109958000000006
# Stage 11, Not TC? No. 38642, Data length 173, Info QoS Data, SN=1801, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 38642, Data length 173, Info QoS Data, SN=1801, FN=0, Flags=.p....F.C
#
# -------- Test Round 10 --------
# -----------------------------------------
# Stage 1 finish. No. 41891, Info QoS Data, SN=2202, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 42025, Info QoS Data, SN=2206, FN=0, Flags=.p.....TC
# Time difference: 0.5549570000000017
# -----------------------------------------
# Stage 3 finish. No. 42230, Info QoS Data, SN=2226, FN=0, Flags=.p.....TC
# Time difference: 0.30968999999998914
# -----------------------------------------
# Stage 4 finish. No. 42273, Info QoS Data, SN=2230, FN=0, Flags=.p.....TC
# Time difference: 0.1498770000000036
# Stage 5, Not TC? No. 42275, Data length 173, Info QoS Data, SN=2075, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 42275, Data length 173, Info QoS Data, SN=2075, FN=0, Flags=.p....F.C
#
# No. 42298 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 42298, Info QoS Data, SN=2232, FN=0, Flags=.p.....TC
# Time difference: 0.05013400000001411
# Stage 6, Not TC? No. 42303, Data length 173, Info QoS Data, SN=2077, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 42303, Data length 173, Info QoS Data, SN=2077, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 42303, Data length 173, Info QoS Data, SN=2077, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 42303, Data length 173, Info QoS Data, SN=2077, FN=0, Flags=.p....F.C
#
# No. 42336 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 42336, Info QoS Data, SN=2235, FN=0, Flags=.p.....TC
# Time difference: 0.10885700000000043
# Stage 7, Not TC? No. 42340, Data length 173, Info QoS Data, SN=2079, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 42340, Data length 173, Info QoS Data, SN=2079, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 42369, Info QoS Data, SN=2238, FN=0, Flags=.p.....TC
# Time difference: 0.2048019999999724
# -----------------------------------------
# Stage 8 finish. No. 44112, Info QoS Data, SN=2242, FN=0, Flags=.p.....TC
# Time difference: 0.17951199999998835
#
# No. 44939 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 44939, Info QoS Data, SN=2245, FN=0, Flags=.p.....TC
# Time difference: 0.09453100000001768
#
# No. 47064 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 47064, Info QoS Data, SN=2247, FN=0, Flags=.p.....TC
# Time difference: 0.16384600000003502
# Stage 11, Not TC? No. 47368, Data length 173, Info QoS Data, SN=814, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 47368, Data length 173, Info QoS Data, SN=814, FN=0, Flags=.p....F.C
#
# -------- Test Round 11 --------
# -----------------------------------------
# Stage 1 finish. No. 66535, Info QoS Data, SN=2426, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 66642, Info QoS Data, SN=2434, FN=0, Flags=.p.....TC
# Time difference: 0.6344010000000253
# Stage 3, Not TC? No. 66801, Data length 173, Info QoS Data, SN=2653, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 66801, Data length 173, Info QoS Data, SN=2653, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 66878, Info QoS Data, SN=2451, FN=0, Flags=.p.....TC
# Time difference: 0.3003570000000195
# -----------------------------------------
# Stage 4 finish. No. 66939, Info QoS Data, SN=2455, FN=0, Flags=.p.....TC
# Time difference: 0.1376809999999864
# Stage 5, Not TC? No. 66941, Data length 173, Info QoS Data, SN=2661, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 66941, Data length 173, Info QoS Data, SN=2661, FN=0, Flags=.p....F.C
#
# No. 66967 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 66967, Info QoS Data, SN=2457, FN=0, Flags=.p.....TC
# Time difference: 0.017427999999995336
# Stage 6, Not TC? No. 66969, Data length 173, Info QoS Data, SN=2663, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 66969, Data length 173, Info QoS Data, SN=2663, FN=0, Flags=.p....F.C
#
# No. 67177 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 67177, Info QoS Data, SN=2487, FN=0, Flags=.p.....TC
# Time difference: 0.6129720000000134
# Stage 7, Not TC? No. 67196, Data length 173, Info QoS Data, SN=2665, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 67196, Data length 173, Info QoS Data, SN=2665, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 67259, Info QoS Data, SN=2495, FN=0, Flags=.p.....TC
# Time difference: 0.6174469999999701
# -----------------------------------------
# Stage 8 finish. No. 67332, Info QoS Data, SN=2502, FN=0, Flags=.p.....TC
# Time difference: 0.31080800000000863
#
# No. 67369 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 67369, Info QoS Data, SN=2505, FN=0, Flags=.p.....TC
# Time difference: 0.0872410000000059
#
# No. 67444 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 67444, Info QoS Data, SN=2510, FN=0, Flags=.p.....TC
# Time difference: 0.2397189999999796
# Stage 11, Not TC? No. 67449, Data length 173, Info QoS Data, SN=2675, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 67449, Data length 173, Info QoS Data, SN=2675, FN=0, Flags=.p....F.C
#
# -------- Test Round 12 --------
# -----------------------------------------
# Stage 1 finish. No. 69971, Info QoS Data, SN=2702, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 70050, Info QoS Data, SN=2709, FN=0, Flags=.p.....TC
# Time difference: 0.7551900000000273
# Stage 3, Not TC? No. 70180, Data length 173, Info QoS Data, SN=2725, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 70180, Data length 173, Info QoS Data, SN=2725, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 70222, Info QoS Data, SN=2721, FN=0, Flags=.p.....TC
# Time difference: 0.25665700000001834
# -----------------------------------------
# Stage 4 finish. No. 70278, Info QoS Data, SN=2728, FN=0, Flags=.p.....TC
# Time difference: 0.15744000000000824
# Stage 5, Not TC? No. 70280, Data length 173, Info QoS Data, SN=2730, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 70280, Data length 173, Info QoS Data, SN=2730, FN=0, Flags=.p....F.C
#
# No. 70332 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 70332, Info QoS Data, SN=2734, FN=0, Flags=.p.....TC
# Time difference: 0.025922999999977492
# Stage 6, Not TC? No. 70334, Data length 173, Info QoS Data, SN=2732, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 70334, Data length 173, Info QoS Data, SN=2732, FN=0, Flags=.p....F.C
#
# No. 70439 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 70439, Info QoS Data, SN=2740, FN=0, Flags=.p.....TC
# Time difference: 0.6069439999999986
# Stage 7, Not TC? No. 70444, Data length 173, Info QoS Data, SN=2734, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 70444, Data length 173, Info QoS Data, SN=2734, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 70511, Info QoS Data, SN=2746, FN=0, Flags=.p.....TC
# Time difference: 0.46166799999997465
# -----------------------------------------
# Stage 8 finish. No. 70568, Info QoS Data, SN=2750, FN=0, Flags=.p.....TC
# Time difference: 0.31766400000003614
#
# No. 70597 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 70597, Info QoS Data, SN=2752, FN=0, Flags=.p.....TC
# Time difference: 0.0331820000000107
#
# No. 70631 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 70631, Info QoS Data, SN=2754, FN=0, Flags=.p.....TC
# Time difference: 0.1638709999999719
# Stage 11, Not TC? No. 70633, Data length 173, Info QoS Data, SN=2744, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 70633, Data length 173, Info QoS Data, SN=2744, FN=0, Flags=.p....F.C
#
# -------- Test Round 13 --------
# -----------------------------------------
# Stage 1 finish. No. 73382, Info QoS Data, SN=2974, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 73425, Info QoS Data, SN=2975, FN=0, Flags=.p.....TC
# Time difference: 0.6359769999999685
# Stage 3, Not TC? No. 73563, Data length 173, Info QoS Data, SN=2795, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 73563, Data length 173, Info QoS Data, SN=2795, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 73602, Info QoS Data, SN=2989, FN=0, Flags=.p.....TC
# Time difference: 0.3009739999999965
# -----------------------------------------
# Stage 4 finish. No. 73635, Info QoS Data, SN=2991, FN=0, Flags=.p.....TC
# Time difference: 0.174808999999982
# Stage 5, Not TC? No. 73637, Data length 173, Info QoS Data, SN=2800, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 73637, Data length 173, Info QoS Data, SN=2800, FN=0, Flags=.p....F.C
#
# No. 73663 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 73663, Info QoS Data, SN=2993, FN=0, Flags=.p.....TC
# Time difference: 0.01887400000003936
# Stage 6, Not TC? No. 73665, Data length 173, Info QoS Data, SN=2802, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 73665, Data length 173, Info QoS Data, SN=2802, FN=0, Flags=.p....F.C
#
# No. 73707 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 73707, Info QoS Data, SN=2995, FN=0, Flags=.p.....TC
# Time difference: 0.30465599999996584
# Stage 7, Not TC? No. 73718, Data length 173, Info QoS Data, SN=2804, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 73718, Data length 173, Info QoS Data, SN=2804, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 73770, Info QoS Data, SN=3000, FN=0, Flags=.p.....TC
# Time difference: 0.3586559999999963
# -----------------------------------------
# Stage 8 finish. No. 73820, Info QoS Data, SN=3003, FN=0, Flags=.p.....TC
# Time difference: 0.29945300000002817
#
# No. 73848 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 73848, Info QoS Data, SN=3005, FN=0, Flags=.p.....TC
# Time difference: 0.02947799999998324
#
# No. 73878 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 73878, Info QoS Data, SN=3007, FN=0, Flags=.p.....TC
# Time difference: 0.14804300000002968
# Stage 11, Not TC? No. 73880, Data length 173, Info QoS Data, SN=2814, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 73880, Data length 173, Info QoS Data, SN=2814, FN=0, Flags=.p....F.C
#
# -------- Test Round 14 --------
# -----------------------------------------
# Stage 1 finish. No. 76685, Info QoS Data, SN=3242, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 76793, Info QoS Data, SN=3252, FN=0, Flags=.p.....TC
# Time difference: 0.8478920000000016
# Stage 3, Not TC? No. 76922, Data length 173, Info QoS Data, SN=2866, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 76922, Data length 173, Info QoS Data, SN=2866, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 76964, Info QoS Data, SN=3265, FN=0, Flags=.p.....TC
# Time difference: 0.2354869999999778
# -----------------------------------------
# Stage 4 finish. No. 77004, Info QoS Data, SN=3268, FN=0, Flags=.p.....TC
# Time difference: 0.14004600000004075
# Stage 5, Not TC? No. 77006, Data length 173, Info QoS Data, SN=2871, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 77006, Data length 173, Info QoS Data, SN=2871, FN=0, Flags=.p....F.C
#
# No. 77033 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 77033, Info QoS Data, SN=3270, FN=0, Flags=.p.....TC
# Time difference: 0.019228999999995722
# Stage 6, Not TC? No. 77035, Data length 173, Info QoS Data, SN=2873, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 77035, Data length 173, Info QoS Data, SN=2873, FN=0, Flags=.p....F.C
#
# No. 77123 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 77123, Info QoS Data, SN=3278, FN=0, Flags=.p.....TC
# Time difference: 0.6487659999999664
# Stage 7, Not TC? No. 77128, Data length 173, Info QoS Data, SN=3278, FN=0, Flags=.p..R..TC
# Stage 7, Not TC? No. 77128, Data length 173, Info QoS Data, SN=3278, FN=0, Flags=.p..R..TC
# Stage 7, Not TC? No. 77133, Data length 173, Info QoS Data, SN=2875, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 77133, Data length 173, Info QoS Data, SN=2875, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 77197, Info QoS Data, SN=3285, FN=0, Flags=.p.....TC
# Time difference: 0.4061760000000163
# -----------------------------------------
# Stage 8 finish. No. 77263, Info QoS Data, SN=3291, FN=0, Flags=.p.....TC
# Time difference: 0.24806999999998425
#
# No. 77293 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 77293, Info QoS Data, SN=3293, FN=0, Flags=.p.....TC
# Time difference: 0.03173200000003362
#
# No. 77334 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 77334, Info QoS Data, SN=3296, FN=0, Flags=.p.....TC
# Time difference: 0.17183799999997973
# Stage 11, Not TC? No. 77336, Data length 173, Info QoS Data, SN=2884, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 77336, Data length 173, Info QoS Data, SN=2884, FN=0, Flags=.p....F.C
#
# -------- Test Round 15 --------
# -----------------------------------------
# Stage 1 finish. No. 80181, Info QoS Data, SN=3471, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 80240, Info QoS Data, SN=3474, FN=0, Flags=.p.....TC
# Time difference: 0.7780149999999821
# Stage 3, Not TC? No. 80386, Data length 173, Info QoS Data, SN=2955, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 80386, Data length 173, Info QoS Data, SN=2955, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 80438, Info QoS Data, SN=3486, FN=0, Flags=.p.....TC
# Time difference: 0.2631809999999746
# -----------------------------------------
# Stage 4 finish. No. 80470, Info QoS Data, SN=3488, FN=0, Flags=.p.....TC
# Time difference: 0.14060100000000375
# Stage 5, Not TC? No. 80472, Data length 173, Info QoS Data, SN=2960, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 80472, Data length 173, Info QoS Data, SN=2960, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 80473, Data length 173, Info QoS Data, SN=2960, FN=0, Flags=.p..R.F.C
# Stage 5, Not TC? No. 80473, Data length 173, Info QoS Data, SN=2960, FN=0, Flags=.p..R.F.C
# Stage 5, Not TC? No. 80474, Data length 173, Info QoS Data, SN=2960, FN=0, Flags=.p..R.F.C
# Stage 5, Not TC? No. 80474, Data length 173, Info QoS Data, SN=2960, FN=0, Flags=.p..R.F.C
#
# No. 80500 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 80500, Info QoS Data, SN=3490, FN=0, Flags=.p.....TC
# Time difference: 0.017574000000024625
# Stage 6, Not TC? No. 80502, Data length 173, Info QoS Data, SN=2962, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 80502, Data length 173, Info QoS Data, SN=2962, FN=0, Flags=.p....F.C
#
# No. 80602 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 80602, Info QoS Data, SN=3500, FN=0, Flags=.p.....TC
# Time difference: 0.6497329999999693
# Stage 7, Not TC? No. 80607, Data length 173, Info QoS Data, SN=2964, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 80607, Data length 173, Info QoS Data, SN=2964, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 80644, Info QoS Data, SN=3503, FN=0, Flags=.p.....TC
# Time difference: 0.41566700000004175
# -----------------------------------------
# Stage 8 finish. No. 80709, Info QoS Data, SN=3505, FN=0, Flags=.p.....TC
# Time difference: 0.22569699999996828
#
# No. 80744 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 80744, Info QoS Data, SN=3507, FN=0, Flags=.p.....TC
# Time difference: 0.036358000000006996
#
# No. 80797 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 80797, Info QoS Data, SN=3509, FN=0, Flags=.p.....TC
# Time difference: 0.15867400000001908
# Stage 11, Not TC? No. 80799, Data length 173, Info QoS Data, SN=2973, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 80799, Data length 173, Info QoS Data, SN=2973, FN=0, Flags=.p....F.C
#
# -------- Test Round 16 --------
# -----------------------------------------
# Stage 1 finish. No. 83290, Info QoS Data, SN=3669, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 83343, Info QoS Data, SN=3673, FN=0, Flags=.p.....TC
# Time difference: 0.6565259999999853
# Stage 3, Not TC? No. 83471, Data length 173, Info QoS Data, SN=3026, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 83471, Data length 173, Info QoS Data, SN=3026, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 83511, Info QoS Data, SN=3685, FN=0, Flags=.p.....TC
# Time difference: 0.23718200000001843
# -----------------------------------------
# Stage 4 finish. No. 83555, Info QoS Data, SN=3689, FN=0, Flags=.p.....TC
# Time difference: 0.13300499999996873
# Stage 5, Not TC? No. 83557, Data length 173, Info QoS Data, SN=3031, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 83557, Data length 173, Info QoS Data, SN=3031, FN=0, Flags=.p....F.C
#
# No. 83583 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 83583, Info QoS Data, SN=3691, FN=0, Flags=.p.....TC
# Time difference: 0.014841999999987365
# Stage 6, Not TC? No. 83585, Data length 173, Info QoS Data, SN=3033, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 83585, Data length 173, Info QoS Data, SN=3033, FN=0, Flags=.p....F.C
#
# No. 83620 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 83620, Info QoS Data, SN=3694, FN=0, Flags=.p.....TC
# Time difference: 0.11203900000003841
# Stage 7, Not TC? No. 83622, Data length 173, Info QoS Data, SN=3035, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 83622, Data length 173, Info QoS Data, SN=3035, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 83669, Info QoS Data, SN=3698, FN=0, Flags=.p.....TC
# Time difference: 0.23058800000001156
# -----------------------------------------
# Stage 8 finish. No. 83717, Info QoS Data, SN=3702, FN=0, Flags=.p.....TC
# Time difference: 0.21097999999994954
#
# No. 83745 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 83745, Info QoS Data, SN=3704, FN=0, Flags=.p.....TC
# Time difference: 0.02940399999999954
#
# No. 83783 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 83783, Info QoS Data, SN=3706, FN=0, Flags=.p.....TC
# Time difference: 0.1079000000000292
# Stage 11, Not TC? No. 83785, Data length 173, Info QoS Data, SN=3045, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 83785, Data length 173, Info QoS Data, SN=3045, FN=0, Flags=.p....F.C
#
# -------- Test Round 17 --------
# -----------------------------------------
# Stage 1 finish. No. 86744, Info QoS Data, SN=3944, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 86807, Info QoS Data, SN=3949, FN=0, Flags=.p.....TC
# Time difference: 0.7523240000000442
# Stage 3, Not TC? No. 86941, Data length 173, Info QoS Data, SN=3101, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 86941, Data length 173, Info QoS Data, SN=3101, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 86996, Info QoS Data, SN=3964, FN=0, Flags=.p.....TC
# Time difference: 0.2670389999999543
# -----------------------------------------
# Stage 4 finish. No. 87028, Info QoS Data, SN=3966, FN=0, Flags=.p.....TC
# Time difference: 0.1399099999999862
# Stage 5, Not TC? No. 87030, Data length 173, Info QoS Data, SN=3106, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 87030, Data length 173, Info QoS Data, SN=3106, FN=0, Flags=.p....F.C
#
# No. 87056 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 87056, Info QoS Data, SN=3968, FN=0, Flags=.p.....TC
# Time difference: 0.01784700000007433
# Stage 6, Not TC? No. 87058, Data length 173, Info QoS Data, SN=3108, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 87058, Data length 173, Info QoS Data, SN=3108, FN=0, Flags=.p....F.C
#
# No. 87086 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 87086, Info QoS Data, SN=3970, FN=0, Flags=.p.....TC
# Time difference: 0.1362939999999071
# Stage 7, Not TC? No. 87088, Data length 173, Info QoS Data, SN=3110, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 87088, Data length 173, Info QoS Data, SN=3110, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 87130, Info QoS Data, SN=3974, FN=0, Flags=.p.....TC
# Time difference: 0.2895900000000893
# -----------------------------------------
# Stage 8 finish. No. 87176, Info QoS Data, SN=3977, FN=0, Flags=.p.....TC
# Time difference: 0.19861199999991186
#
# No. 87206 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 87206, Info QoS Data, SN=3979, FN=0, Flags=.p.....TC
# Time difference: 0.029339000000049964
#
# No. 87237 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 87237, Info QoS Data, SN=3981, FN=0, Flags=.p.....TC
# Time difference: 0.09132999999997082
# Stage 11, Not TC? No. 87239, Data length 173, Info QoS Data, SN=3120, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 87239, Data length 173, Info QoS Data, SN=3120, FN=0, Flags=.p....F.C
#
# -------- Test Round 18 --------
# -----------------------------------------
# Stage 1 finish. No. 90034, Info QoS Data, SN=109, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 90081, Info QoS Data, SN=110, FN=0, Flags=.p.....TC
# Time difference: 0.7412369999999555
# Stage 3, Not TC? No. 90200, Data length 173, Info QoS Data, SN=3167, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 90200, Data length 173, Info QoS Data, SN=3167, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 90239, Info QoS Data, SN=121, FN=0, Flags=.p.....TC
# Time difference: 0.24361099999998714
# -----------------------------------------
# Stage 4 finish. No. 90269, Info QoS Data, SN=123, FN=0, Flags=.p.....TC
# Time difference: 0.09978799999998955
# Stage 5, Not TC? No. 90271, Data length 173, Info QoS Data, SN=3172, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 90271, Data length 173, Info QoS Data, SN=3172, FN=0, Flags=.p....F.C
#
# No. 90301 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 90301, Info QoS Data, SN=126, FN=0, Flags=.p.....TC
# Time difference: 0.016115000000013424
# Stage 6, Not TC? No. 90303, Data length 173, Info QoS Data, SN=3174, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 90303, Data length 173, Info QoS Data, SN=3174, FN=0, Flags=.p....F.C
#
# No. 90336 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 90336, Info QoS Data, SN=128, FN=0, Flags=.p.....TC
# Time difference: 0.20884300000000167
# Stage 7, Not TC? No. 90338, Data length 173, Info QoS Data, SN=3176, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 90338, Data length 173, Info QoS Data, SN=3176, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 90373, Info QoS Data, SN=131, FN=0, Flags=.p.....TC
# Time difference: 0.22322000000008302
# -----------------------------------------
# Stage 8 finish. No. 90423, Info QoS Data, SN=134, FN=0, Flags=.p.....TC
# Time difference: 0.25126699999998436
#
# No. 90451 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 90451, Info QoS Data, SN=136, FN=0, Flags=.p.....TC
# Time difference: 0.029367999999976746
#
# No. 90484 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 90484, Info QoS Data, SN=139, FN=0, Flags=.p.....TC
# Time difference: 0.10506999999995514
# Stage 11, Not TC? No. 90486, Data length 173, Info QoS Data, SN=3186, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 90486, Data length 173, Info QoS Data, SN=3186, FN=0, Flags=.p....F.C
#
# -------- Test Round 19 --------
# -----------------------------------------
# Stage 1 finish. No. 93227, Info QoS Data, SN=326, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 93311, Info QoS Data, SN=333, FN=0, Flags=.p.....TC
# Time difference: 0.7166069999999536
# Stage 3, Not TC? No. 93451, Data length 173, Info QoS Data, SN=3239, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 93451, Data length 173, Info QoS Data, SN=3239, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 93496, Info QoS Data, SN=346, FN=0, Flags=.p.....TC
# Time difference: 0.29953100000000177
# -----------------------------------------
# Stage 4 finish. No. 93529, Info QoS Data, SN=348, FN=0, Flags=.p.....TC
# Time difference: 0.14217700000006062
# Stage 5, Not TC? No. 93531, Data length 173, Info QoS Data, SN=3244, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 93531, Data length 173, Info QoS Data, SN=3244, FN=0, Flags=.p....F.C
#
# No. 93557 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 93557, Info QoS Data, SN=350, FN=0, Flags=.p.....TC
# Time difference: 0.016903999999954067
# Stage 6, Not TC? No. 93559, Data length 173, Info QoS Data, SN=3246, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 93559, Data length 173, Info QoS Data, SN=3246, FN=0, Flags=.p....F.C
#
# No. 93611 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 93611, Info QoS Data, SN=354, FN=0, Flags=.p.....TC
# Time difference: 0.23821899999995821
# Stage 7, Not TC? No. 93619, Data length 173, Info QoS Data, SN=3248, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 93619, Data length 173, Info QoS Data, SN=3248, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 93674, Info QoS Data, SN=358, FN=0, Flags=.p.....TC
# Time difference: 0.5882390000000441
# -----------------------------------------
# Stage 8 finish. No. 93730, Info QoS Data, SN=362, FN=0, Flags=.p.....TC
# Time difference: 0.26186600000005456
#
# No. 93753 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 93753, Info QoS Data, SN=364, FN=0, Flags=.p.....TC
# Time difference: 0.028700999999955457
#
# No. 93792 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 93792, Info QoS Data, SN=367, FN=0, Flags=.p.....TC
# Time difference: 0.18020899999999074
# Stage 11, Not TC? No. 93794, Data length 173, Info QoS Data, SN=3258, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 93794, Data length 173, Info QoS Data, SN=3258, FN=0, Flags=.p....F.C
#
# -------- Test Round 20 --------
# -----------------------------------------
# Stage 1 finish. No. 96414, Info QoS Data, SN=568, FN=0, Flags=.p.....TC
# -----------------------------------------
# Stage 2 finish. No. 96462, Info QoS Data, SN=569, FN=0, Flags=.p.....TC
# Time difference: 0.7197570000000724
# Stage 3, Not TC? No. 96593, Data length 173, Info QoS Data, SN=3302, FN=0, Flags=.p....F.C
# Stage 3, Not TC? No. 96593, Data length 173, Info QoS Data, SN=3302, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 3 finish. No. 96633, Info QoS Data, SN=580, FN=0, Flags=.p.....TC
# Time difference: 0.25780199999996967
# -----------------------------------------
# Stage 4 finish. No. 96663, Info QoS Data, SN=582, FN=0, Flags=.p.....TC
# Time difference: 0.10706099999993057
# Stage 5, Not TC? No. 96665, Data length 173, Info QoS Data, SN=3307, FN=0, Flags=.p....F.C
# Stage 5, Not TC? No. 96665, Data length 173, Info QoS Data, SN=3307, FN=0, Flags=.p....F.C
#
# No. 96692 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 5 finish. No. 96692, Info QoS Data, SN=584, FN=0, Flags=.p.....TC
# Time difference: 0.016503000000057
# Stage 6, Not TC? No. 96694, Data length 173, Info QoS Data, SN=3309, FN=0, Flags=.p....F.C
# Stage 6, Not TC? No. 96694, Data length 173, Info QoS Data, SN=3309, FN=0, Flags=.p....F.C
#
# No. 96723 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 6 finish. No. 96723, Info QoS Data, SN=586, FN=0, Flags=.p.....TC
# Time difference: 0.17568199999993794
# Stage 7, Not TC? No. 96725, Data length 173, Info QoS Data, SN=3311, FN=0, Flags=.p....F.C
# Stage 7, Not TC? No. 96725, Data length 173, Info QoS Data, SN=3311, FN=0, Flags=.p....F.C
# -----------------------------------------
# Stage 7 finish. No. 96764, Info QoS Data, SN=590, FN=0, Flags=.p.....TC
# Time difference: 0.1907370000000128
# -----------------------------------------
# Stage 8 finish. No. 96804, Info QoS Data, SN=593, FN=0, Flags=.p.....TC
# Time difference: 0.13288700000009612
#
# No. 96833 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 9 finish. No. 96833, Info QoS Data, SN=595, FN=0, Flags=.p.....TC
# Time difference: 0.027574999999956162
#
# No. 96863 has been found. Delete from wierd list.
#
# -----------------------------------------
# Stage 10 finish. No. 96863, Info QoS Data, SN=597, FN=0, Flags=.p.....TC
# Time difference: 0.10302699999999732
# Stage 11, Not TC? No. 96865, Data length 173, Info QoS Data, SN=3320, FN=0, Flags=.p....F.C
# Stage 11, Not TC? No. 96865, Data length 173, Info QoS Data, SN=3320, FN=0, Flags=.p....F.C

# %%
#for debug
print(str(len(evcc_send_time_anchor)) + '\n')
for i in range(0, len(evcc_send_time_anchor)):
    print(len(evcc_send_time_anchor[i]))
# Out:
# 20
#
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
wierd_packet

# %%
len(wierd_packet)
# Out:
# 41

# %%
#for debug
for i in range(0, len(evcc_send_time_anchor)):
    print(evcc_send_time_anchor[i][len(evcc_send_time_anchor[i])-1]-evcc_send_time_anchor[i][0])
# Out:
# 2.348202999999998
# 1.6237509999999986
# 2.227550000000008
# 2.495894000000007
# 1.4534219999999891
# 2.624095000000011
# 2.7401430000000175
# 2.8869119999999953
# 2.0441999999999894
# 1.8162060000000224
# 2.958054000000004
# 2.7785390000000234
# 2.2709199999999896
# 2.7492359999999962
# 2.6854999999999905
# 1.732465999999988
# 1.922284999999988
# 1.9185189999999466
# 2.472452999999973
# 1.73103100000003

# %%
#Processing secc send
with open('0_secc_send.csv', newline='') as csvfile:
    rows = csv.DictReader(csvfile)
    timelist_secc_send = []
    seq_num_secc_send = []
    data_length_secc_send = []
    info_secc_send = []
    frame_num_secc_send = []
    
    for row in rows:
        timelist_secc_send.append(float(row['Time']))
        seq_num_secc_send.append(int(row['Sequence number']))
        data_length_secc_send.append(int(row['Data Length']))
        info_secc_send.append(str(row['Info']))
        frame_num_secc_send.append(int(row['No.']))

# %%
#for debug
if(len(timelist_secc_send) != len(seq_num_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(data_length_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(info_secc_send)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send) != len(frame_num_secc_send)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send))
# Out:
# 2525

# %%
timelist_secc_send_split = []
seq_num_secc_send_split = []
data_length_secc_send_split = []
info_secc_send_split = []
frame_num_secc_send_split = []

round_start_point = 0
round_end_point = 0

sdpres_index_list = []
#Fetch first packet index of data length = 92 (SDP response) in each round
for i in range(0, len(data_length_secc_send)):
    if(i == 0 and data_length_secc_send[i] == 92):
        sdpres_index_list.append(i)
    if(i > 0 and data_length_secc_send[i] == 92 and data_length_secc_send[i-1] != 92):
        sdpres_index_list.append(i)
sdpres_index_list.append(len(data_length_secc_send)) #Add the end of list index

for i in range(0, len(sdpres_index_list)-1):
        timelist_secc_send_split.append([timelist_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        seq_num_secc_send_split.append([seq_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        data_length_secc_send_split.append([data_length_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        info_secc_send_split.append([info_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])
        frame_num_secc_send_split.append([frame_num_secc_send[j] for j in range(sdpres_index_list[i], sdpres_index_list[i+1])])

# %%
#for debug
if(len(timelist_secc_send_split) != len(seq_num_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(data_length_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(info_secc_send_split)):
    print("Error. Length is not equal.")
elif(len(timelist_secc_send_split) != len(frame_num_secc_send_split)):
    print("Error. Length is not equal.")
else:
    print(len(timelist_secc_send_split)) #Output # of testing rounds
# Out:
# 21

# %%
#for debug, this is ideally the time of each testing round
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 25.188769
# 30.072246999999997
# 28.774023
# 29.489726000000005
# 29.693887000000004
# 28.885309000000007
# 29.992395999999985
# 30.10468800000001
# 30.51431999999997
# 29.384768000000008
# 29.595438
# 30.71906100000001
# 30.207371000000023
# 30.206849999999974
# 30.104236000000014
# 30.51424400000002
# 29.182774999999936
# 29.592855999999983
# 29.38786600000003
# 30.310778000000028

# %%
#Catch wrong packet
timelist_secc_send_split[0]
# Out:
# [13.251211, 13.251324, 13.251481, 13.251538, 23.542011, 38.437257]

# %%
del timelist_secc_send_split[0]
del seq_num_secc_send_split[0]
del data_length_secc_send_split[0]
del info_secc_send_split[0]
del frame_num_secc_send_split[0]

# %%
for i in range(0, len(timelist_secc_send_split)):
    print('i = ' + str(i) + ' ', end = '')
    print(len(timelist_secc_send_split[i]))
# Out:
# i = 0 112
# i = 1 145
# i = 2 123
# i = 3 125
# i = 4 127
# i = 5 132
# i = 6 122
# i = 7 87
# i = 8 136
# i = 9 126
# i = 10 141
# i = 11 128
# i = 12 131
# i = 13 121
# i = 14 124
# i = 15 130
# i = 16 124
# i = 17 128
# i = 18 119
# i = 19 138

# %%
for i in range(1, len(timelist_secc_send_split)):
    print(timelist_secc_send_split[i][0]-timelist_secc_send_split[i-1][0])
# Out:
# 30.072246999999997
# 28.774023
# 29.489726000000005
# 29.693887000000004
# 28.885309000000007
# 29.992395999999985
# 30.10468800000001
# 30.51431999999997
# 29.384768000000008
# 29.595438
# 30.71906100000001
# 30.207371000000023
# 30.206849999999974
# 30.104236000000014
# 30.51424400000002
# 29.182774999999936
# 29.592855999999983
# 29.38786600000003
# 30.310778000000028

# %%
print(len(timelist_secc_send_split))
# Out:
# 20

# %%
#Set secc time anchor in each round per stage
secc_send_time_anchor = []
#data_length_in_each_stage = [92, 173, 157, 189, 253, 173, 189, 173, 493, 173]
wierd_packet_secc = {}
packet_loss_testing_round_18_flag = False

def printinfo(stageNum, frameNum, info_string):
    print("-----------------------------------------")
    print("Stage " + str(stageNum) + " finish. No. " + str(frameNum) + ", Info " + str(info_string))

def print_time_difference(secc_send_time_anchor_each_round):
    print("Time difference: " + str(secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-1]-
                          secc_send_time_anchor_each_round[len(secc_send_time_anchor_each_round)-2]))
    
def checkstage_num(stageNum, valid_stageNum, info_string, time_string, datalen, seqnum, frameNum):
    if(stageNum == valid_stageNum):
        check_wield_packet_list(frameNum)
        return True
    else:
        #debug
        print("\nWhat is this packet? Data Length = " + str(datalen) + " No. " + str(frameNum))
        print("Time " + str(time_string) + " #Seq " + str(seqnum) + " Info " + str(info_string) + "\n")
        wierd_packet_secc[frameNum] = [datalen, stageNum]
        return False

def check_wield_packet_list(frameNum):
    if(wierd_packet_secc.get(frameNum) != None):
        del wierd_packet_secc[frameNum]
        print("\nNo. " + str(frameNum) + " has been found. Delete from wierd list.\n")
    
for i in range(0, len(data_length_secc_send_split)):
#for i in range(18, 19):
    print("\n-------- Test Round " + str(i+1) + " --------")
    #Stage 1
    secc_send_time_anchor_each_round = [timelist_secc_send_split[i][0]]
    stageNum = 1
    printinfo(stageNum, frame_num_secc_send_split[i][0], info_secc_send_split[i][0])
    stageNum = stageNum + 1
    
    for j in range(1, len(data_length_secc_send_split[i])):
        #Stage 2
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 2, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    continue
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 3
        if(data_length_secc_send_split[i][j] == 157 and data_length_secc_send_split[i][j-1] != 157):
            if(checkstage_num(stageNum, 3, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
        #Stage 4
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 4, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1    
                continue
        #Stage 5
        if(data_length_secc_send_split[i][j] == 253 and data_length_secc_send_split[i][j-1] != 253):
            if(checkstage_num(stageNum, 5, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
        #Stage 6
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 6, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    continue
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 7
        if(data_length_secc_send_split[i][j] == 189 and data_length_secc_send_split[i][j-1] != 189):
            if(checkstage_num(stageNum, 7, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                
                #Deal with packet loss......
                if(i == 18 and packet_loss_testing_round_18_flag == False):
                    secc_send_time_anchor_each_round.append(577.034795)
                    printinfo(stageNum, 93738, "Packet Loss")
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    packet_loss_testing_round_18_flag = True
                
                continue
        #Stage 8
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 8, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    continue
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        #Stage 9
        if(data_length_secc_send_split[i][j] == 493 and data_length_secc_send_split[i][j-1] != 493):
            if(checkstage_num(stageNum, 9, info_secc_send_split[i][j],
                                  timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                  seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                print_time_difference(secc_send_time_anchor_each_round)
                stageNum = stageNum + 1
                continue
        #Stage 10
        if(data_length_secc_send_split[i][j] == 173 and data_length_secc_send_split[i][j-1] != 173):
            if(info_secc_send_split[i][j][-2:] == 'TC'):
                if(checkstage_num(stageNum, 10, info_secc_send_split[i][j],
                                      timelist_secc_send_split[i][j], data_length_secc_send_split[i][j],
                                      seq_num_secc_send_split[i][j], frame_num_secc_send_split[i][j])):
                    secc_send_time_anchor_each_round.append(timelist_secc_send_split[i][j])
                    printinfo(stageNum, frame_num_secc_send_split[i][j], info_secc_send_split[i][j])
                    print_time_difference(secc_send_time_anchor_each_round)
                    stageNum = stageNum + 1
                    continue
            else:
                print("Stage " + str(stageNum) +
                      ", Not TC? No. " + str(frame_num_secc_send_split[i][j]) +
                      ", Data length " + str(data_length_secc_send_split[i][j]) +
                      ", Info " + str(info_secc_send_split[i][j]))
        
        if(stageNum == 11): break
        
    secc_send_time_anchor.append(secc_send_time_anchor_each_round)

# %%
#for debug
print(str(len(secc_send_time_anchor)) + '\n')
for i in range(0, len(secc_send_time_anchor)):
    print(len(secc_send_time_anchor[i]))
# Out:
# 20
#
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
#for debug
for i in range(0, len(secc_send_time_anchor)):
    print(secc_send_time_anchor[i][len(secc_send_time_anchor[i])-1]-secc_send_time_anchor[i][0])
# Out:
# 2.248968000000005
# 1.5666050000000098
# 2.1784000000000106
# 2.384629000000004
# 1.3901150000000086
# 2.5893719999999973
# 2.6648910000000114
# 2.7977190000000007
# 1.9589090000000056
# 1.7920560000000023
# 2.975680000000011
# 2.683195000000012
# 2.2358839999999987
# 2.6756450000000314
# 2.554696999999976
# 1.647846999999956
# 1.810051000000044
# 1.8160510000000158
# 2.36863900000003
# 1.666580999999951

# %%
secc_send_time_anchor[0]
# Out:
# [38.43998,
#  39.538523,
#  39.757279,
#  39.964377,
#  39.98473,
#  40.169292,
#  40.400669,
#  40.530101,
#  40.590117,
#  40.688948]

# %%
#BLOCK ACK processing
#Time evcc sends blockACK after secc send
evcc_blockAck_time_anchor = []

blockack_index = 0
for i in range(0, len(secc_send_time_anchor)):
    evcc_blockAck_time_anchor_in_each_round = []
    
    for j in range(0, len(secc_send_time_anchor[i])):
        while(timelist_block_ack[blockack_index] < secc_send_time_anchor[i][j]):
            blockack_index = blockack_index + 1
        evcc_blockAck_time_anchor_in_each_round.append(timelist_block_ack[blockack_index])
        print("ACK time difference = " + str(
        timelist_block_ack[blockack_index] - secc_send_time_anchor[i][j]))
    
    evcc_blockAck_time_anchor.append(evcc_blockAck_time_anchor_in_each_round)

# %%
len(evcc_blockAck_time_anchor)
# Out:
# 20

# %%
for i in range(0, len(evcc_blockAck_time_anchor)):
    print(len(evcc_blockAck_time_anchor[i]))
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
#for debug check wierd value
for i in range(0, len(evcc_blockAck_time_anchor)):
    for j in range(0, len(evcc_blockAck_time_anchor[i])):
        if(evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))
        if(secc_send_time_anchor[i][j] - evcc_send_time_anchor[i][j] < 0):
            print("i = " + str(i) + " j = " + str(j))

# %%
#For debug
i = 2
for j in range(0, 10):
    print("Stage " + str(j+1))
    print(evcc_send_time_anchor[i][j])
    print(secc_send_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j])
    print(evcc_blockAck_time_anchor[i][j]-evcc_send_time_anchor[i][j])
    print("\n")
# Out:
# Stage 1
# 97.226007
# 97.28625
# 97.287998
# 0.061991000000006125
#
#
# Stage 2
# 98.046386
# 98.227021
# 98.228763
# 0.18237700000000245
#
#
# Stage 3
# 98.287124
# 98.297339
# 98.30081
# 0.01368599999999276
#
#
# Stage 4
# 98.428185
# 98.43963
# 98.44168
# 0.01349500000000603
#
#
# Stage 5
# 98.450636
# 98.460927
# 98.462655
# 0.012018999999995117
#
#
# Stage 6
# 98.661189
# 98.670895
# 98.67266
# 0.011471000000000231
#
#
# Stage 7
# 99.017945
# 99.162965
# 99.164704
# 0.14675900000000297
#
#
# Stage 8
# 99.288232
# 99.312653
# 99.318942
# 0.030710000000013338
#
#
# Stage 9
# 99.333223
# 99.350407
# 99.352468
# 0.019244999999997958
#
#
# Stage 10
# 99.453557
# 99.46465
# 99.466388
# 0.012830999999991377

# %%
path = 'no_interference_80211_pcap_processing.txt'
f = open(path, 'w')
for i in range(0, len(evcc_send_time_anchor)):
    for j in range(0, len(evcc_send_time_anchor[i])):
        print((evcc_blockAck_time_anchor[i][j] - evcc_send_time_anchor[i][j])*1000, file=f, end="")
        f.writelines('\t')
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    print((evcc_blockAck_time_anchor[i][len(evcc_blockAck_time_anchor[i])-1] - evcc_send_time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    f.writelines('20')
    f.writelines('\t')
    f.writelines('0')
    f.writelines('\t')
    f.writelines('\n')
f.close()
