# %%
import csv
import numpy as np

with open('4_interfere_evcc_UDP_TCP.csv', newline='') as csvfile:
    #讀取 CSV 檔內容，將每一列轉成一個 dictionary
    rows = csv.DictReader(csvfile)
    lengthlist = []
    timelist = []
    seqlist = []
    tcpseglenlist = []
    infolist = []
    
    for row in rows:
        lengthlist.append(int(row['Length']))
        timelist.append(float(row['Time']))
        seqlist.append(row['Sequence Number'])
        tcpseglenlist.append(row['TCP Segment Len'])
        infolist.append(row['Info'])

# %%
round_split_length = []
round_split_time = []
round_split_seq = []
round_split_tcpseglen = []

round_start_point = 0
round_end_point = 0
isfirstround = True

for i in range(1, len(lengthlist)):
    if(lengthlist[i-1] == 72 and lengthlist[i] == 90):
        if(isfirstround):
            isfirstround = False
            continue
        round_end_point = i-1
        if(round_end_point != 0):
            tmp = []
            tmp2 = []
            tmp3 = []
            tmp4 = []
            for j in range(round_start_point, round_end_point):
                tmp.append(lengthlist[j])
                tmp2.append(timelist[j])
                tmp3.append(seqlist[j])
                tmp4.append(tcpseglenlist[j])
            round_split_length.append(tmp)
            round_split_time.append(tmp2)
            round_split_seq.append(tmp3)
            round_split_tcpseglen.append(tmp4)
            
        round_start_point = i-1
        
    if(i == len(lengthlist) - 1):
        round_end_point = i
        tmp = []
        tmp2 = []
        tmp3 = []
        tmp4 = []
        for j in range(round_start_point, round_end_point):
            tmp.append(lengthlist[j])
            tmp2.append(timelist[j])
            tmp3.append(seqlist[j])
            tmp4.append(tcpseglenlist[j])
        round_split_length.append(tmp)
        round_split_time.append(tmp2)
        round_split_seq.append(tmp3)
        round_split_tcpseglen.append(tmp4)

# %%
#for debug
print(len(round_split_length))
print(len(round_split_time))
print(len(round_split_seq))
print(len(round_split_tcpseglen))
# Out:
# 20
# 20
# 20
# 20

# %%
#for debug, check each length
for i in range(0, len(round_split_length)):
    if(len(round_split_length[i]) != len(round_split_time[i])): print("Error")
    if(len(round_split_seq[i]) != len(round_split_time[i])): print("Error")
    if(len(round_split_tcpseglen[i]) != len(round_split_time[i])): print("Error")
    print(len(round_split_length[i]))
# Out:
# 133
# 127
# 132
# 128
# 134
# 137
# 133
# 135
# 139
# 133
# 68
# 130
# 130
# 143
# 132
# 81
# 131
# 134
# 102
# 127

# %%
#Remove the "TIMEOUT" test round
"""
for i in [18, 15, 10]:
    del round_split_length[i]
    del round_split_time[i]
    del round_split_seq[i]
    del round_split_tcpseglen[i]
"""

# %%
#for debug, check each length
for i in range(0, len(round_split_length)):
    if(len(round_split_length[i]) != len(round_split_time[i])): print("Error")
    if(len(round_split_seq[i]) != len(round_split_time[i])): print("Error")
    if(len(round_split_tcpseglen[i]) != len(round_split_time[i])): print("Error")
    print(len(round_split_length[i]))
# Out:
# 133
# 127
# 132
# 128
# 134
# 137
# 133
# 135
# 139
# 133
# 68
# 130
# 130
# 143
# 132
# 81
# 131
# 134
# 102
# 127

# %%
#for debug
round_split_tcpseglen[0]

# %%
#preprocessing
for i in range(0, len(round_split_seq)):
    for j in range(0, len(round_split_seq[i])):
        if(round_split_seq[i][j] == ''):
            round_split_seq[i][j] = -1
        else: round_split_seq[i][j] = int(round_split_seq[i][j])
        if(round_split_tcpseglen[i][j] == ''):
            round_split_tcpseglen[i][j] = -1
        else: round_split_tcpseglen[i][j] = int(round_split_tcpseglen[i][j])

# %%
#for debug
round_split_seq[2]

# %%
time_anchor = []
stage_num = 0 #for debug
retransmission_time_list = []

def check_stage_num(currentlen, time, seq_num, stage_num_valid):
    global stage_num
    global retransmission_time_list
    if(stage_num != stage_num_valid):
        print("Retransmission? " + str(time) + " Seq# " + str(seq_num))
        retransmission_time_list.append(time)
        return False
    else:
        if(stage_num % 2 == 0):
            print("Stage " + str(stage_num//2+1) + " Req catched. Current length = " + str(currentlen+1))
        else: 
            print("Stage " + str((stage_num+1)//2) + " Res catched. Current length = " + str(currentlen+1))
        stage_num = stage_num + 1
        return True
    

for i in range(0, len(round_split_time)): #Test Round i
    print("--------- Test Round " + str(i+1) + " ---------")
    time_anchor_each_round = []

    for j in range(0, len(round_split_time[i])-1):   
        if(j == 0):
            #Start, Stage1(SDP) Start
            if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 0)):
                 time_anchor_each_round.append(round_split_time[i][j])
            
        if(round_split_seq[i][j] == -1 and round_split_seq[i][j+1] == 0):
            #Stage1 (SDP) finish
            if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 1)):
                 time_anchor_each_round.append(round_split_time[i][j])
        
        if(j >= 1 and round_split_seq[i][j-1] == -1 and round_split_seq[i][j] == 0):
            #Stage 2 Start (TCP SYN)
            if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 2)):
                 time_anchor_each_round.append(round_split_time[i][j])
        
        if(round_split_seq[i][j] >= 1655 and round_split_seq[i][j] <= 1670):
            #Stage2 (Session Initialized) finish
            if(round_split_tcpseglen[i][j] == 85 or round_split_tcpseglen[i][j] == 91):
                #SECC "change ciper spec retransmission" + "encrypted handshake message" sent together...
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 3)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 1660~1670, len != 85 nor 91")
                    
        if(round_split_seq[i][j] >= 330 and round_split_seq[i][j] <= 340):
            #Stage3 (SupportedAppProtocol) Start
            if(round_split_tcpseglen[i][j] == 101):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 4)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 330~340, len != 101")
        
        if(round_split_seq[i][j] >= 1745 and round_split_seq[i][j] <= 1755):
            #Stage3 (SupportedAppProtocol) finish
            if(round_split_tcpseglen[i][j] == 69):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 5)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 1745~1755, len != 69")
        
        if(round_split_seq[i][j] >= 435 and round_split_seq[i][j] <= 440):
            #Stage4 (SessionSetup) Start
            if(round_split_tcpseglen[i][j] == 85):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 6)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 435~440, len != 85")
        
        if(round_split_seq[i][j] >= 1815 and round_split_seq[i][j] <= 1825):
            #Stage4 (SessionSetup) finish
            if(round_split_tcpseglen[i][j] == 101):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 7)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 1815~1825, len != 101")
        
        if(round_split_seq[i][j] >= 520 and round_split_seq[i][j] <= 555):
            #Stage5 (ServiceDiscovery) Start
            if(round_split_tcpseglen[i][j] == 85):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 8)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 520~555, len != 85")
        
        if(round_split_seq[i][j] >= 1915 and round_split_seq[i][j] <= 1925):
            #Stage5 (ServiceDiscovery) finish
            if(round_split_tcpseglen[i][j] == 165):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 9)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 1915~1925, len != 165")
        
        if(round_split_seq[i][j] >= 605 and round_split_seq[i][j] <= 610):
            #Stage6 (ServicePaymentSelection) Start
            if(round_split_tcpseglen[i][j] == 85):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 10)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 605~610, len != 85")
        
        if(round_split_seq[i][j] >= 2075 and round_split_seq[i][j] <= 2085):
            #Stage6 (ServicePaymentSelection) finish
            if(round_split_tcpseglen[i][j] == 85):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 11)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2075~2085, len != 85")
        if(round_split_seq[i][j] >= 2115 and round_split_seq[i][j] <= 2125):
            #Stage7 (ServicePaymentSelection) Start
            if(round_split_tcpseglen[i][j] == 97):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 12)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2115~2125, len != 97")
        
        if(round_split_seq[i][j] >= 2165 and round_split_seq[i][j] <= 2175):
            #Stage7 (PaymentDetail) finish
            if(round_split_tcpseglen[i][j] == 101):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 13)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2165~2175, len != 101")
        
        if(round_split_seq[i][j] >= 2215 and round_split_seq[i][j] <= 2220):
            #Stage8 (Authorization) Start
            if(round_split_tcpseglen[i][j] == 373):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 14)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2215~2220, len != 373")
        
        if(round_split_seq[i][j] >= 2265 and round_split_seq[i][j] <= 2275):
            #Stage8 (Authorization) finish
            if(round_split_tcpseglen[i][j] == 85):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 15)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2265~2275, len != 85")
        
        if(round_split_seq[i][j] >= 2585 and round_split_seq[i][j] <= 2595):
            #Stage9 (ChargeParameterDiscovery) Start
            if(round_split_tcpseglen[i][j] == 101):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 16)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2585~2595, len != 101")
        
        if(round_split_seq[i][j] >= 2350 and round_split_seq[i][j] <= 2360):
            #Stage9 (ChargeParameterDiscovery) finish
            if(round_split_tcpseglen[i][j] == 405):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 17)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2350~2360, len != 405")
        
        if(round_split_seq[i][j] == 2691):
            #Stage10 (PowerDelivery) Start
            if(round_split_tcpseglen[i][j] == 85):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 18)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2690~2695, len != 85")
        
        if(round_split_seq[i][j] >= 2755 and round_split_seq[i][j] <= 2765):
            #Stage10 (PowerDelivery) finish
            if(round_split_tcpseglen[i][j] == 85):
                if(check_stage_num(len(time_anchor_each_round), round_split_time[i][j], round_split_seq[i][j], 19)):
                    time_anchor_each_round.append(round_split_time[i][j])
            else:
                if(round_split_tcpseglen[i][j] != 0):
                    print("len = " + str(round_split_tcpseglen[i][j]))
                    print("Seq# 2755~2765, len != 85")
    
    stage_num = 0
    time_anchor.append(time_anchor_each_round)
    
print(retransmission_time_list)
# Out:
# --------- Test Round 1 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Retransmission? 21.845711 Seq# 1750
# Stage 4 Req catched. Current length = 7
# Retransmission? 22.213244 Seq# 437
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Retransmission? 25.69544 Seq# 2691
# Stage 10 Res catched. Current length = 20
# --------- Test Round 2 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 3 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Retransmission? 102.068639 Seq# 1817
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Retransmission? 103.32537 Seq# 2083
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 4 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Retransmission? 140.705965 Seq# 1919
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Retransmission? 142.084948 Seq# 2270
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Retransmission? 143.020671 Seq# 2691
# Stage 10 Res catched. Current length = 20
# --------- Test Round 5 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Retransmission? 182.610132 Seq# 1918
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Retransmission? 186.102755 Seq# 2691
# Stage 10 Res catched. Current length = 20
# Retransmission? 186.82874 Seq# 2759
# --------- Test Round 6 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Retransmission? 222.364562 Seq# 437
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Retransmission? 222.825614 Seq# 1920
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Retransmission? 223.734339 Seq# 2170
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Retransmission? 224.256708 Seq# 2356
# Stage 10 Req catched. Current length = 19
# Retransmission? 224.795216 Seq# 2691
# Stage 10 Res catched. Current length = 20
# Retransmission? 224.816262 Seq# 2761
# --------- Test Round 7 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Retransmission? 260.540759 Seq# 1819
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 8 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Retransmission? 298.546247 Seq# 607
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Retransmission? 299.01246 Seq# 2084
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 9 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Retransmission? 336.701047 Seq# 1749
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Retransmission? 340.052339 Seq# 2355
# Stage 10 Res catched. Current length = 20
# --------- Test Round 10 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Retransmission? 377.138861 Seq# 437
# Stage 4 Res catched. Current length = 8
# Retransmission? 377.162659 Seq# 1818
# Stage 5 Req catched. Current length = 9
# Retransmission? 377.230969 Seq# 1818
# Stage 5 Res catched. Current length = 10
# Retransmission? 377.85448 Seq# 1919
# Retransmission? 377.856241 Seq# 1919
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Retransmission? 378.249249 Seq# 2084
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 11 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Retransmission? 417.43702 Seq# 1750
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Retransmission? 420.894475 Seq# 2170
# Stage 8 Req catched. Current length = 15
# Retransmission? 422.861869 Seq# 2217
# len = 69
# Seq# 2585~2595, len != 101
# Stage 8 Res catched. Current length = 16
# len = 69
# Seq# 2350~2360, len != 405
# --------- Test Round 12 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Retransmission? 436.536985 Seq# 1659
# Retransmission? 437.153492 Seq# 1659
# Retransmission? 437.403894 Seq# 336
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 13 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Retransmission? 474.389063 Seq# 1818
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Retransmission? 475.360898 Seq# 2169
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# Retransmission? 476.155289 Seq# 2760
# --------- Test Round 14 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Retransmission? 513.024541 Seq# 1817
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Retransmission? 513.264652 Seq# 1918
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Retransmission? 515.627046 Seq# 2590
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 15 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Retransmission? 560.122365 Seq# 437
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# Retransmission? 562.685073 Seq# 2760
# --------- Test Round 16 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Retransmission? 604.554178 Seq# 1664
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Retransmission? 605.513906 Seq# 1919
# Retransmission? 605.641953 Seq# 1919
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Retransmission? 606.40609 Seq# 2084
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 17 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Retransmission? 627.646734 Seq# 1819
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Retransmission? 629.156232 Seq# 2085
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Retransmission? 630.690844 Seq# 2170
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 18 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Retransmission? 671.941718 Seq# 1817
# Retransmission? 673.181562 Seq# 522
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Retransmission? 674.614945 Seq# 2168
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 19 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Retransmission? 715.234835 Seq# 1919
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Retransmission? 716.361046 Seq# 2270
# Stage 9 Req catched. Current length = 17
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Stage 10 Res catched. Current length = 20
# --------- Test Round 20 ---------
# Stage 1 Req catched. Current length = 1
# Stage 1 Res catched. Current length = 2
# Stage 2 Req catched. Current length = 3
# len = 6
# Seq# 1660~1670, len != 85 nor 91
# Stage 2 Res catched. Current length = 4
# Stage 3 Req catched. Current length = 5
# Stage 3 Res catched. Current length = 6
# Stage 4 Req catched. Current length = 7
# Stage 4 Res catched. Current length = 8
# Stage 5 Req catched. Current length = 9
# Stage 5 Res catched. Current length = 10
# Stage 6 Req catched. Current length = 11
# Stage 6 Res catched. Current length = 12
# Stage 7 Req catched. Current length = 13
# Stage 7 Res catched. Current length = 14
# Stage 8 Req catched. Current length = 15
# Stage 8 Res catched. Current length = 16
# Stage 9 Req catched. Current length = 17
# Retransmission? 746.28441 Seq# 2270
# Stage 9 Res catched. Current length = 18
# Stage 10 Req catched. Current length = 19
# Retransmission? 746.793748 Seq# 2355
# Stage 10 Res catched. Current length = 20
# [21.845711, 22.213244, 25.69544, 102.068639, 103.32537, 140.705965, 142.084948, 143.020671, 182.610132, 186.102755, 186.82874, 222.364562, 222.825614, 223.734339, 224.256708, 224.795216, 224.816262, 260.540759, 298.546247, 299.01246, 336.701047, 340.052339, 377.138861, 377.162659, 377.230969, 377.85448, 377.856241, 378.249249, 417.43702, 420.894475, 422.861869, 436.536985, 437.153492, 437.403894, 474.389063, 475.360898, 476.155289, 513.024541, 513.264652, 515.627046, 560.122365, 562.685073, 604.554178, 605.513906, 605.641953, 606.40609, 627.646734, 629.156232, 630.690844, 671.941718, 673.181562, 674.614945, 715.234835, 716.361046, 746.28441, 746.793748]

# %%
#Verify retransmission packet info
for retrans_time in retransmission_time_list:
    print(infolist[timelist.index(retrans_time)])
# Out:
# [TCP Spurious Retransmission] 60645  >  57071 [PSH, ACK] Seq=1750 Ack=437 Win=131072 Len=69 TSval=1394092920 TSecr=803560796
# [TCP Retransmission] 57071  >  60645 [PSH, ACK] Seq=437 Ack=1819 Win=131072 Len=85 TSval=803561568 TSecr=1394092920
# [TCP Retransmission] 57071  >  60645 [PSH, ACK] Seq=2691 Ack=2761 Win=131072 Len=85 TSval=803565036 TSecr=1394095235
# [TCP Spurious Retransmission] 60645  >  57074 [PSH, ACK] Seq=1817 Ack=522 Win=131072 Len=101 TSval=902625636 TSecr=803640848
# [TCP Retransmission] 60645  >  57074 [PSH, ACK] Seq=2083 Ack=692 Win=131072 Len=85 TSval=902626794 TSecr=803641919
# [TCP Spurious Retransmission] 60645  >  57075 [PSH, ACK] Seq=1919 Ack=607 Win=131072 Len=165 TSval=3458314130 TSecr=803679426
# [TCP Spurious Retransmission] 60645  >  57075 [PSH, ACK] Seq=2270 Ack=2590 Win=131072 Len=85 TSval=3458315613 TSecr=803680694
# [TCP Retransmission] 57075  >  60645 [PSH, ACK] Seq=2691 Ack=2760 Win=131072 Len=85 TSval=803682152 TSecr=3458315697
# [TCP Spurious Retransmission] 60645  >  57076 [PSH, ACK] Seq=1918 Ack=607 Win=131072 Len=165 TSval=508421765 TSecr=803720969
# [TCP Retransmission] 57076  >  60645 [PSH, ACK] Seq=2691 Ack=2759 Win=131072 Len=85 TSval=803725172 TSecr=508423559
# [TCP Spurious Retransmission] 60645  >  57076 [PSH, ACK] Seq=2759 Ack=2776 Win=131072 Len=85 TSval=508425960 TSecr=803725172
# [TCP Retransmission] 57077  >  60645 [PSH, ACK] Seq=437 Ack=1819 Win=131072 Len=85 TSval=803761378 TSecr=3568338087
# [TCP Spurious Retransmission] 60645  >  57077 [PSH, ACK] Seq=1920 Ack=607 Win=131072 Len=165 TSval=3568339067 TSecr=803761409
# [TCP Spurious Retransmission] 60645  >  57077 [PSH, ACK] Seq=2170 Ack=2217 Win=131072 Len=101 TSval=3568340018 TSecr=803762180
# [TCP Spurious Retransmission] 60645  >  57077 [PSH, ACK] Seq=2356 Ack=2691 Win=131072 Len=405 TSval=3568340503 TSecr=803762913
# [TCP Retransmission] 57077  >  60645 [PSH, ACK] Seq=2691 Ack=2761 Win=131072 Len=85 TSval=803763792 TSecr=3568340503
# [TCP Retransmission] 60645  >  57077 [PSH, ACK] Seq=2761 Ack=2776 Win=131072 Len=85 TSval=3568341084 TSecr=803763260
# [TCP Spurious Retransmission] 60645  >  57079 [PSH, ACK] Seq=1819 Ack=522 Win=131072 Len=101 TSval=390766173 TSecr=803798755
# [TCP Retransmission] 57080  >  60645 [PSH, ACK] Seq=607 Ack=2084 Win=131072 Len=85 TSval=803837413 TSecr=619166977
# [TCP Spurious Retransmission] 60645  >  57080 [PSH, ACK] Seq=2084 Ack=692 Win=131072 Len=85 TSval=619168170 TSecr=803837413
# [TCP Spurious Retransmission] 60645  >  57081 [PSH, ACK] Seq=1749 Ack=437 Win=131072 Len=69 TSval=3164009467 TSecr=803874754
# [TCP Spurious Retransmission] 60645  >  57081 [PSH, ACK] Seq=2355 Ack=2691 Win=131072 Len=405 TSval=3164012569 TSecr=803878154
# [TCP Retransmission] 57082  >  60645 [PSH, ACK] Seq=437 Ack=1818 Win=131072 Len=85 TSval=803915878 TSecr=1459081553
# [TCP Retransmission] 60645  >  57082 [PSH, ACK] Seq=1818 Ack=522 Win=131072 Len=101 TSval=1459082264 TSecr=803914951
# [TCP Spurious Retransmission] 60645  >  57082 [PSH, ACK] Seq=1818 Ack=522 Win=131072 Len=101 TSval=1459082614 TSecr=803914951
# [TCP Spurious Retransmission] 60645  >  57082 [PSH, ACK] Seq=1919 Ack=607 Win=131072 Len=165 TSval=1459082990 TSecr=803915968
# [TCP Spurious Retransmission] 60645  >  57082 [PSH, ACK] Seq=1919 Ack=607 Win=131072 Len=165 TSval=1459083340 TSecr=803915968
# [TCP Spurious Retransmission] 60645  >  57082 [PSH, ACK] Seq=2084 Ack=692 Win=131072 Len=85 TSval=1459083802 TSecr=803916713
# [TCP Spurious Retransmission] 60645  >  57083 [PSH, ACK] Seq=1750 Ack=437 Win=131072 Len=69 TSval=3628413061 TSecr=803955811
# [TCP Retransmission] 60645  >  57083 [PSH, ACK] Seq=2170 Ack=2217 Win=131072 Len=101 TSval=3628416395 TSecr=803958391
# [TCP Retransmission] 57083  >  60645 [PSH, ACK] Seq=2217 Ack=2271 Win=131072 Len=373 TSval=803961528 TSecr=3628416659
# [TCP Spurious Retransmission] 60645  >  57085 [PSH, ACK] Seq=1659 Ack=336 Win=131072 Len=91 TSval=4175537590 TSecr=803974094
# [TCP Spurious Retransmission] 60645  >  57085 [PSH, ACK] Seq=1659 Ack=336 Win=131072 Len=91 TSval=4175538223 TSecr=803974094
# [TCP Retransmission] 57085  >  60645 [PSH, ACK] Seq=336 Ack=1750 Win=131072 Len=101 TSval=803976048 TSecr=4175538223
# [TCP Retransmission] 60645  >  57086 [PSH, ACK] Seq=1818 Ack=522 Win=131072 Len=101 TSval=1292173574 TSecr=804012463
# [TCP Spurious Retransmission] 60645  >  57086 [PSH, ACK] Seq=2169 Ack=2217 Win=131072 Len=101 TSval=1292174696 TSecr=804013670
# [TCP Spurious Retransmission] 60645  >  57086 [PSH, ACK] Seq=2760 Ack=2776 Win=131072 Len=85 TSval=1292175339 TSecr=804014290
# [TCP Retransmission] 60645  >  57087 [PSH, ACK] Seq=1817 Ack=522 Win=131072 Len=101 TSval=346916916 TSecr=804051034
# [TCP Spurious Retransmission] 60645  >  57087 [PSH, ACK] Seq=1918 Ack=607 Win=131072 Len=165 TSval=346917189 TSecr=804051552
# [TCP Retransmission] 57087  >  60645 [PSH, ACK] Seq=2590 Ack=2354 Win=131072 Len=101 TSval=804054132 TSecr=346918583
# [TCP Retransmission] 57088  >  60645 [PSH, ACK] Seq=437 Ack=1818 Win=131072 Len=85 TSval=804098562 TSecr=3656606018
# [TCP Spurious Retransmission] 60645  >  57088 [PSH, ACK] Seq=2760 Ack=2776 Win=131072 Len=85 TSval=3656609865 TSecr=804100393
# [TCP Spurious Retransmission] 60645  >  57090 [PSH, ACK] Seq=1664 Ack=336 Win=131072 Len=85 TSval=3918523145 TSecr=804141718
# [TCP Spurious Retransmission] 60645  >  57090 [PSH, ACK] Seq=1919 Ack=607 Win=131072 Len=165 TSval=3918524327 TSecr=804143194
# [TCP Spurious Retransmission] 60645  >  57090 [PSH, ACK] Seq=1919 Ack=607 Win=131072 Len=165 TSval=3918524763 TSecr=804143194
# [TCP Retransmission] 60645  >  57090 [PSH, ACK] Seq=2084 Ack=692 Win=131072 Len=85 TSval=3918525336 TSecr=804144131
# [TCP Spurious Retransmission] 60645  >  57091 [PSH, ACK] Seq=1819 Ack=522 Win=131072 Len=101 TSval=3743301080 TSecr=804165187
# [TCP Spurious Retransmission] 60645  >  57091 [PSH, ACK] Seq=2085 Ack=692 Win=131072 Len=85 TSval=3743302577 TSecr=804166626
# [TCP Spurious Retransmission] 60645  >  57091 [PSH, ACK] Seq=2170 Ack=2217 Win=131072 Len=101 TSval=3743303880 TSecr=804167865
# [TCP Spurious Retransmission] 60645  >  57092 [PSH, ACK] Seq=1817 Ack=522 Win=131072 Len=101 TSval=847508639 TSecr=804209664
# [TCP Retransmission] 57092  >  60645 [PSH, ACK] Seq=522 Ack=1918 Win=131072 Len=85 TSval=804211445 TSecr=847508639
# [TCP Spurious Retransmission] 60645  >  57092 [PSH, ACK] Seq=2168 Ack=2217 Win=131072 Len=101 TSval=847511326 TSecr=804212292
# [TCP Spurious Retransmission] 60645  >  57094 [PSH, ACK] Seq=1919 Ack=607 Win=131072 Len=165 TSval=2459593372 TSecr=804252996
# [TCP Spurious Retransmission] 60645  >  57094 [PSH, ACK] Seq=2270 Ack=2590 Win=131072 Len=85 TSval=2459594478 TSecr=804254103
# [TCP Spurious Retransmission] 60645  >  57097 [PSH, ACK] Seq=2270 Ack=2590 Win=131072 Len=85 TSval=1377438862 TSecr=804284012
# [TCP Spurious Retransmission] 60645  >  57097 [PSH, ACK] Seq=2355 Ack=2691 Win=131072 Len=405 TSval=1377439112 TSecr=804284386

# %%
#for debug
print(len(time_anchor))
for i in range(0, len(time_anchor)):
    print("i = " + str(i) + " , len = " + str(len(time_anchor[i])))
# Out:
# 20
# i = 0 , len = 20
# i = 1 , len = 20
# i = 2 , len = 20
# i = 3 , len = 20
# i = 4 , len = 20
# i = 5 , len = 20
# i = 6 , len = 20
# i = 7 , len = 20
# i = 8 , len = 20
# i = 9 , len = 20
# i = 10 , len = 16
# i = 11 , len = 20
# i = 12 , len = 20
# i = 13 , len = 20
# i = 14 , len = 20
# i = 15 , len = 20
# i = 16 , len = 20
# i = 17 , len = 20
# i = 18 , len = 20
# i = 19 , len = 20

# %%
#TIMEOUT Dealing. TIMEOUT ROUND is NOT considered
del time_anchor[18]
del time_anchor[15]
del time_anchor[10]

# %%
#for debug
print(len(time_anchor))
for i in range(0, len(time_anchor)):
    print("i = " + str(i) + " , len = " + str(len(time_anchor[i])))
# Out:
# 17
# i = 0 , len = 20
# i = 1 , len = 20
# i = 2 , len = 20
# i = 3 , len = 20
# i = 4 , len = 20
# i = 5 , len = 20
# i = 6 , len = 20
# i = 7 , len = 20
# i = 8 , len = 20
# i = 9 , len = 20
# i = 10 , len = 20
# i = 11 , len = 20
# i = 12 , len = 20
# i = 13 , len = 20
# i = 14 , len = 20
# i = 15 , len = 20
# i = 16 , len = 20

# %%
time_anchor[0]
# Out:
# [18.618562,
#  19.686794,
#  20.886392,
#  21.357241,
#  21.437598,
#  21.82274,
#  22.00658,
#  22.246135,
#  22.260624,
#  22.414663,
#  22.587689,
#  23.041215,
#  23.378742,
#  23.475651,
#  23.62828,
#  23.960731,
#  23.983429,
#  24.03381,
#  24.147535,
#  26.118351]

# %%
path = 'pcap_processing.txt'
f = open(path, 'w')
for i in range(0, len(time_anchor)):
    for j in range(1, len(time_anchor[i]), 2):
        print((time_anchor[i][j] - time_anchor[i][j-1])*1000, file=f, end="")
        f.writelines('\t')
    f.writelines('\t')
    print((time_anchor[i][3] - time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    print((time_anchor[i][len(time_anchor[i])-1] - time_anchor[i][0])*1000, file=f, end="")
    f.writelines('\t')
    f.writelines('20')
    f.writelines('\t')
    f.writelines('0')
    f.writelines('\t')
    f.writelines('\n')
f.close()
